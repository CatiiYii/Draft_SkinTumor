# %%
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
# !pip install opencv-contrib-python
# !pip install tensorflow-addons
import os
import cv2
import time
import json
import time
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Layer, Input, Conv2D, BatchNormalization, Lambda, Concatenate
import pydensecrf.densecrf as dcrf
from pydensecrf.utils import unary_from_softmax, create_pairwise_bilateral
from tensorflow.keras.layers import (
    Input, SeparableConv2D, BatchNormalization, MaxPooling2D, UpSampling2D, Conv2DTranspose,
    Concatenate, SpatialDropout2D, ReLU, GlobalAveragePooling2D, Add,
    GlobalMaxPooling2D, Dense, Reshape, Multiply, Add, Conv2D, Lambda, Activation
)
from tensorflow.keras.activations import swish
from tensorflow.keras.layers import Conv2D, Activation, Add, Multiply, UpSampling2D, Concatenate
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Input, SeparableConv2D, BatchNormalization, MaxPooling2D, Conv2DTranspose, Concatenate, SpatialDropout2D, ReLU, GlobalAveragePooling2D, GlobalMaxPooling2D, Dense, Reshape, Multiply, Add, Conv2D, Lambda
from tensorflow.keras.initializers import HeNormal
# Out:
# Collecting git+https://github.com/lucasb-eyer/pydensecrf.git
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-5z3fvulv
#   Running command git clone --filter=blob:none --quiet https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-5z3fvulv
#   Resolved https://github.com/lucasb-eyer/pydensecrf.git to commit 2723c7fa4f2ead16ae1ce3d8afe977724bb8f87f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pydensecrf
#   Building wheel for pydensecrf (pyproject.toml) ... done
#   Created wheel for pydensecrf: filename=pydensecrf-1.0-cp311-cp311-linux_x86_64.whl size=3440333 sha256=d5ef5b06dc0f28e348fe02d91bca918c92975cc1db2953253e696f97524bdca1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9in5g09a/wheels/ce/8e/34/6dcfa200a9e2ae3627d8009b8bd1ca9b24512bec50a93304de
# Successfully built pydensecrf
# Installing collected packages: pydensecrf
# Successfully installed pydensecrf-1.0
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-contrib-python) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (24.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 13.4 MB/s eta 0:00:0000:01
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.1
#     Uninstalling typeguard-4.4.1:
#       Successfully uninstalled typeguard-4.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.16.1 requires typeguard<5,>=3, but you have typeguard 2.13.3 which is incompatible.
# inflect 7.5.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3
# 2025-12-14 14:02:27.435490: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765720947.615155      33 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765720947.670250      33 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
working_dir = '/kaggle/working'
for item in os.listdir(working_dir):
    item_path = os.path.join(working_dir, item)
    try:
        if os.path.isfile(item_path) or os.path.islink(item_path):
            os.unlink(item_path)
        elif os.path.isdir(item_path):
            shutil.rmtree(item_path) 
            print(f"❌ xóa thành công {item_path}")
    except Exception as e:
        print(f"Lỗi khi xóa {item_path}: {e}")
# Out:
# ❌ xóa thành công /kaggle/working/.virtual_documents

# %%
def load_isic_dataset(image_path, mask_path, binary_path, csv_file, img_size=(256, 256)):
    image_files = sorted(glob(os.path.join(image_path, "ISIC_*.jpg")))
    images = []
    masks = []
    binary_masks = {}
    image_ids = []
    labels = []

    csv_data = pd.read_csv(csv_file)
    mel_label = csv_data['melanoma'].astype("int64")

    print("Đang đọc và xử lý dữ liệu...")
    for index, img_path in enumerate(tqdm(image_files)):
        img_id = os.path.basename(img_path).split('.')[0]
        mask_file = os.path.join(mask_path, f"{img_id}_segmentation.png")
        binary_file = os.path.join(binary_path, f"{img_id}_features.json")
        if not os.path.exists(mask_file):
            print(f"Không tìm thấy mask cho ảnh mặt nạ {img_id}_segmentation.png")
            continue
        if not os.path.exists(binary_file):
            print(f"Không tìm thấy mask nhị phân cho ảnh {img_id}_features.json")
            continue

        try:
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 

            mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)

            img = cv2.resize(img, img_size)
            mask = cv2.resize(mask, img_size)

            img = img / 255.0
            mask = mask / 255.0

            with open(binary_file, 'r') as f:
                binary_masks[img_id] = json.load(f)

            label = mel_label[index]

            images.append(img)
            masks.append(mask)
            image_ids.append(img_id)
            labels.append(label.astype("long"))

        except Exception as e:
            print(f"Lỗi khi xử lý ảnh {img_id}: {str(e)}")
            continue

    images = np.array(images)
    masks = np.array(masks)[..., np.newaxis] 
    labels = np.array(labels)

    print(f"\nĐã đọc thành công {len(images)} ảnh")
    print(f"Shape của images: {images.shape}")
    print(f"Shape của masks: {masks.shape}")
    print(f"Shape của labels: {labels.shape}")
    return images, masks, binary_masks, image_ids, labels

# %%
train_images, train_masks, train_binarys, train_image_ids, train_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2750/Train_Data',
    mask_path='/kaggle/input/isic-2750/Train_GroundTruth_1',
    binary_path='/kaggle/input/isic-2750/Train_GroundTruth_2',
    csv_file="/kaggle/input/isic-2750/Train_GroundTruth_3.csv",
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 1925/1925 [06:05<00:00,  5.26it/s]
# Đã đọc thành công 1925 ảnh
# Shape của images: (1925, 256, 256, 3)
# Shape của masks: (1925, 256, 256, 1)
# Shape của labels: (1925,)

# %%
test_images, test_masks, test_binarys, test_image_ids, test_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2750/Test_Data',
    mask_path='/kaggle/input/isic-2750/Test_GroundTruth_1',
    binary_path='/kaggle/input/isic-2750/Test_GroundTruth_2',
    csv_file='/kaggle/input/isic-2750/Test_GroundTruth_3.csv',
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 825/825 [02:22<00:00,  5.77it/s]
# Đã đọc thành công 825 ảnh
# Shape của images: (825, 256, 256, 3)
# Shape của masks: (825, 256, 256, 1)
# Shape của labels: (825,)

# %%
def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = (intersection + 1e-7) / (union + 1e-7)
    return iou

# %%
def compute_metric(y_true, y_pred, metric='dice_coefficient', smooth=1e-6, is_numpy=False):
    y_true_f = y_true.flatten() if is_numpy else K.flatten(y_true)
    y_pred_f = y_pred.flatten() if is_numpy else K.flatten(y_pred)
    intersection = np.sum(y_true_f * y_pred_f) if is_numpy else K.sum(y_true_f * y_pred_f)

    if 'dice' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        score = (2. * intersection + smooth) / (sum_fn(y_true_f) + sum_fn(y_pred_f) + smooth)
    elif 'jaccard' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        union = sum_fn(y_true_f) + sum_fn(y_pred_f) - intersection
        score = (intersection + smooth) / (union + smooth)
    else:
        raise ValueError(f"Unsupported metric: {metric}")

    return score if 'coefficient' in metric else 1 - score

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth)

def dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth)

def jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth)

def jaccard_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_loss', smooth)

def np_accuracy(y_true, y_pred):
    return np.mean(y_true.flatten() == y_pred.flatten())

def np_dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth, is_numpy=True)

def np_jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth, is_numpy=True)

def np_dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth, is_numpy=True)

# %%
def cbam_module(input_features, reduction_ratio=8):
    filters = input_features.shape[-1]
    
    avg_pool = GlobalAveragePooling2D()(input_features)
    max_pool = GlobalMaxPooling2D()(input_features)
    
    shared_dense_1 = Dense(filters // reduction_ratio, 
                           activation='relu', 
                           kernel_initializer='he_normal', 
                           use_bias=True)
    
    shared_dense_2 = Dense(filters, 
                           use_bias=True)
    
    avg_out = shared_dense_2(shared_dense_1(avg_pool))
    max_out = shared_dense_2(shared_dense_1(max_pool))
    
    channel_sum = Add()([avg_out, max_out])
    channel_attention = Activation('sigmoid')(channel_sum)
    channel_attention = Reshape((1, 1, filters))(channel_attention)
    channel_refined = Multiply()([input_features, channel_attention])   
   
    avg_spatial = Lambda(lambda x: K.mean(x, axis=-1, keepdims=True), 
                         output_shape=lambda s: (s[0], s[1], s[2], 1))(channel_refined)
    max_spatial = Lambda(lambda x: K.max(x, axis=-1, keepdims=True), 
                         output_shape=lambda s: (s[0], s[1], s[2], 1))(channel_refined)  


    spatial_concat = Concatenate(axis=-1)([avg_spatial, max_spatial])
    
    spatial_attention = Conv2D(1, 
                               (7, 7), 
                               padding='same', 
                               activation='sigmoid', 
                               use_bias=False)(spatial_concat)
    
    refined_features = Multiply()([channel_refined, spatial_attention])
    
    
    return refined_features

# %%
def simam(x, lambda_val=1e-4):  
    shape = tf.shape(x)
    H, W = shape[1], shape[2]
    n = tf.cast(H * W - 1, x.dtype)
    
    mu = tf.reduce_mean(x, axis=[1, 2], keepdims=True)
    d = tf.square(x - mu)
    var = tf.reduce_sum(d, axis=[1, 2], keepdims=True) / n
    e_t = d / (4 * (var + lambda_val)) + 0.5
    
    return x * tf.nn.sigmoid(e_t)

def aspp_module(input_tensor, output_filters=1024, rates=[1, 6, 12, 18]):
    num_branches = len(rates)
    branch_filters = output_filters // num_branches

    branches = []
    for rate in rates:
        branch = SeparableConv2D(branch_filters, (3, 3), padding='same', dilation_rate=rate, use_bias=False,
                                  depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(input_tensor)
        branch = BatchNormalization()(branch)
        branch = ReLU()(branch)
        branches.append(branch)

    concatenated = Concatenate()(branches)
    attended = Lambda(simam)(concatenated)

    final_conv = SeparableConv2D(output_filters, (1, 1), padding='same', use_bias=False,
                                  depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(attended)
    final_conv = BatchNormalization()(final_conv)
    final_conv = ReLU()(final_conv)
    final_conv = SpatialDropout2D(0.2)(final_conv)
    return final_conv

# %%
def CustomSegUNet(input_size=(256, 256, 1)):
    inputs = Input(input_size)

    c1 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(inputs)
    c1 = BatchNormalization()(c1); c1 = ReLU()(c1)
    c1 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c1)
    c1 = BatchNormalization()(c1); c1 = ReLU()(c1)
    c1 = SpatialDropout2D(0.1)(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p1)
    c2 = BatchNormalization()(c2); c2 = ReLU()(c2)
    c2 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c2)
    c2 = BatchNormalization()(c2); c2 = ReLU()(c2)
    c2 = SpatialDropout2D(0.1)(c2)
    p2 = MaxPooling2D((2, 2))(c2)
 
    c3 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p2)
    c3 = BatchNormalization()(c3); c3 = ReLU()(c3)
    c3 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c3)
    c3 = BatchNormalization()(c3); c3 = ReLU()(c3)
    c3 = SpatialDropout2D(0.1)(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p3)
    c4 = BatchNormalization()(c4); c4 = ReLU()(c4)
    c4 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c4)
    c4 = BatchNormalization()(c4); c4 = ReLU()(c4)
    c4 = SpatialDropout2D(0.1)(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p4)
    c5 = BatchNormalization()(c5); c5 = ReLU()(c5)
    c5 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c5)
    c5 = BatchNormalization()(c5); c5 = ReLU()(c5)
    c5 = SpatialDropout2D(0.1)(c5)
    p5 = MaxPooling2D((2, 2))(c5)
    
    c6 = aspp_module(p5, output_filters=1024, rates=[1, 6, 12, 18])

    u7 = Conv2DTranspose(512, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c6)
    u7 = Concatenate()([u7, c5])
    c7 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u7)
    c7 = BatchNormalization()(c7); c7 = ReLU()(c7)
    c7 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c7)
    c7 = BatchNormalization()(c7); c7 = ReLU()(c7)
    c7 = cbam_module(c7)

    u8 = Conv2DTranspose(256, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c7)
    u8 = Concatenate()([u8, c4])
    c8 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u8)
    c8 = BatchNormalization()(c8); c8 = ReLU()(c8)
    c8 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c8)
    c8 = BatchNormalization()(c8); c8 = ReLU()(c8)
    c8 = cbam_module(c8)

    u9 = Conv2DTranspose(256, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c8)
    u9 = Concatenate()([u9, c3])
    c9 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u9)
    c9 = BatchNormalization()(c9); c9 = ReLU()(c9)
    c9 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c9)
    c9 = BatchNormalization()(c9); c9 = ReLU()(c9)
    c9 = cbam_module(c9)

    u10 = Conv2DTranspose(128, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c9)
    u10 = Concatenate()([u10, c2])
    c10 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u10)
    c10 = BatchNormalization()(c10); c10 = ReLU()(c10)
    c10 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c10)
    c10 = BatchNormalization()(c10); c10 = ReLU()(c10)
    c10 = cbam_module(c10)

    u11 = Conv2DTranspose(64, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c10)
    u11 = Concatenate()([u11, c1])
    c11 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u11)
    c11 = BatchNormalization()(c11); c11 = ReLU()(c11)
    c11 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c11)
    c11 = BatchNormalization()(c11); c11 = ReLU()(c11)
    c11 = cbam_module(c11)

 
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c11)

    return Model(inputs=inputs, outputs=outputs)

if __name__ == "__main__":
    model = CustomSegUNet()
    model.summary()
# Out:
# I0000 00:00:1765721469.702303      33 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 1)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d          │ (None, 256, 256, 64)   │            137 │ input_layer[0][0]      │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 64)   │            256 │ separable_conv2d[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 256, 256, 64)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_1        │ (None, 256, 256, 64)   │          4,736 │ re_lu[0][0]            │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256, 256, 64)   │            256 │ separable_conv2d_1[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1 (ReLU)            │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d         │ (None, 256, 256, 64)   │              0 │ re_lu_1[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ spatial_dropout2d[0][… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_2        │ (None, 128, 128, 128)  │          8,896 │ max_pooling2d[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 128, 128, 128)  │            512 │ separable_conv2d_2[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_2 (ReLU)            │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_3        │ (None, 128, 128, 128)  │         17,664 │ re_lu_2[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 128, 128, 128)  │            512 │ separable_conv2d_3[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_3 (ReLU)            │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_1       │ (None, 128, 128, 128)  │              0 │ re_lu_3[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 128)    │              0 │ spatial_dropout2d_1[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_4        │ (None, 64, 64, 256)    │         34,176 │ max_pooling2d_1[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_4[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_4 (ReLU)            │ (None, 64, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_5        │ (None, 64, 64, 256)    │         68,096 │ re_lu_4[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_5[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_5 (ReLU)            │ (None, 64, 64, 256)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_2       │ (None, 64, 64, 256)    │              0 │ re_lu_5[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ spatial_dropout2d_2[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_6        │ (None, 32, 32, 256)    │         68,096 │ max_pooling2d_2[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_6[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_6 (ReLU)            │ (None, 32, 32, 256)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_7        │ (None, 32, 32, 256)    │         68,096 │ re_lu_6[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_7[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_7 (ReLU)            │ (None, 32, 32, 256)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_3       │ (None, 32, 32, 256)    │              0 │ re_lu_7[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 256)    │              0 │ spatial_dropout2d_3[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_8        │ (None, 16, 16, 512)    │        133,888 │ max_pooling2d_3[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_8[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_8 (ReLU)            │ (None, 16, 16, 512)    │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_9        │ (None, 16, 16, 512)    │        267,264 │ re_lu_8[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_9[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_9 (ReLU)            │ (None, 16, 16, 512)    │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_4       │ (None, 16, 16, 512)    │              0 │ re_lu_9[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 8, 8, 512)      │              0 │ spatial_dropout2d_4[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_10       │ (None, 8, 8, 256)      │        135,680 │ max_pooling2d_4[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_11       │ (None, 8, 8, 256)      │        135,680 │ max_pooling2d_4[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_12       │ (None, 8, 8, 256)      │        135,680 │ max_pooling2d_4[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_13       │ (None, 8, 8, 256)      │        135,680 │ max_pooling2d_4[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 8, 8, 256)      │          1,024 │ separable_conv2d_10[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 8, 8, 256)      │          1,024 │ separable_conv2d_11[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 8, 8, 256)      │          1,024 │ separable_conv2d_12[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 8, 8, 256)      │          1,024 │ separable_conv2d_13[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_10 (ReLU)           │ (None, 8, 8, 256)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_11 (ReLU)           │ (None, 8, 8, 256)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_12 (ReLU)           │ (None, 8, 8, 256)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_13 (ReLU)           │ (None, 8, 8, 256)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 8, 8, 1024)     │              0 │ re_lu_10[0][0],        │
# │                           │                        │                │ re_lu_11[0][0],        │
# │                           │                        │                │ re_lu_12[0][0],        │
# │                           │                        │                │ re_lu_13[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 8, 8, 1024)     │              0 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_14       │ (None, 8, 8, 1024)     │      1,049,600 │ lambda[0][0]           │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 8, 8, 1024)     │          4,096 │ separable_conv2d_14[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_14 (ReLU)           │ (None, 8, 8, 1024)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_5       │ (None, 8, 8, 1024)     │              0 │ re_lu_14[0][0]         │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 16, 16, 512)    │      4,719,104 │ spatial_dropout2d_5[0… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 16, 16, 1024)   │              0 │ conv2d_transpose[0][0… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_4[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_15       │ (None, 16, 16, 512)    │        534,016 │ concatenate_1[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_15[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_15 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_16       │ (None, 16, 16, 512)    │        267,264 │ re_lu_15[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_16[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_16 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 512)            │              0 │ re_lu_16[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d      │ (None, 512)            │              0 │ re_lu_16[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 64)             │         32,832 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 512)            │         33,280 │ dense[0][0],           │
# │                           │                        │                │ dense[1][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 512)            │              0 │ dense_1[0][0],         │
# │                           │                        │                │ dense_1[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 512)            │              0 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 1, 1, 512)      │              0 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 16, 16, 512)    │              0 │ re_lu_16[0][0],        │
# │                           │                        │                │ reshape[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_1 (Lambda)         │ (None, 16, 16, 1)      │              0 │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_2 (Lambda)         │ (None, 16, 16, 1)      │              0 │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 16, 16, 2)      │              0 │ lambda_1[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 16, 16, 1)      │             98 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_1 (Multiply)     │ (None, 16, 16, 512)    │              0 │ multiply[0][0],        │
# │                           │                        │                │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 32, 32, 256)    │      1,179,904 │ multiply_1[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 32, 32, 512)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_3[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_17       │ (None, 32, 32, 256)    │        135,936 │ concatenate_3[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_17[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_17 (ReLU)           │ (None, 32, 32, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_18       │ (None, 32, 32, 256)    │         68,096 │ re_lu_17[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_18[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_18 (ReLU)           │ (None, 32, 32, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 256)            │              0 │ re_lu_18[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_1    │ (None, 256)            │              0 │ re_lu_18[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 32)             │          8,224 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 256)            │          8,448 │ dense_2[0][0],         │
# │                           │                        │                │ dense_2[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 256)            │              0 │ dense_3[0][0],         │
# │                           │                        │                │ dense_3[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 256)            │              0 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_1 (Reshape)       │ (None, 1, 1, 256)      │              0 │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_2 (Multiply)     │ (None, 32, 32, 256)    │              0 │ re_lu_18[0][0],        │
# │                           │                        │                │ reshape_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_3 (Lambda)         │ (None, 32, 32, 1)      │              0 │ multiply_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_4 (Lambda)         │ (None, 32, 32, 1)      │              0 │ multiply_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 32, 32, 2)      │              0 │ lambda_3[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 32, 32, 1)      │             98 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_3 (Multiply)     │ (None, 32, 32, 256)    │              0 │ multiply_2[0][0],      │
# │                           │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 64, 64, 256)    │        590,080 │ multiply_3[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 64, 64, 512)    │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_2[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_19       │ (None, 64, 64, 256)    │        135,936 │ concatenate_5[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_19[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_19 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_20       │ (None, 64, 64, 256)    │         68,096 │ re_lu_19[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_20[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_20 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 256)            │              0 │ re_lu_20[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_2    │ (None, 256)            │              0 │ re_lu_20[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 32)             │          8,224 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 256)            │          8,448 │ dense_4[0][0],         │
# │                           │                        │                │ dense_4[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 256)            │              0 │ dense_5[0][0],         │
# │                           │                        │                │ dense_5[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 256)            │              0 │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_2 (Reshape)       │ (None, 1, 1, 256)      │              0 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_4 (Multiply)     │ (None, 64, 64, 256)    │              0 │ re_lu_20[0][0],        │
# │                           │                        │                │ reshape_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_5 (Lambda)         │ (None, 64, 64, 1)      │              0 │ multiply_4[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_6 (Lambda)         │ (None, 64, 64, 1)      │              0 │ multiply_4[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_6             │ (None, 64, 64, 2)      │              0 │ lambda_5[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 64, 64, 1)      │             98 │ concatenate_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_5 (Multiply)     │ (None, 64, 64, 256)    │              0 │ multiply_4[0][0],      │
# │                           │                        │                │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 128, 128, 128)  │        295,040 │ multiply_5[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_7             │ (None, 128, 128, 256)  │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_21       │ (None, 128, 128, 128)  │         35,200 │ concatenate_7[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_21    │ (None, 128, 128, 128)  │            512 │ separable_conv2d_21[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_21 (ReLU)           │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_22       │ (None, 128, 128, 128)  │         17,664 │ re_lu_21[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_22    │ (None, 128, 128, 128)  │            512 │ separable_conv2d_22[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_22 (ReLU)           │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 128)            │              0 │ re_lu_22[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_3    │ (None, 128)            │              0 │ re_lu_22[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 16)             │          2,064 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 128)            │          2,176 │ dense_6[0][0],         │
# │                           │                        │                │ dense_6[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 128)            │              0 │ dense_7[0][0],         │
# │                           │                        │                │ dense_7[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 128)            │              0 │ add_3[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_3 (Reshape)       │ (None, 1, 1, 128)      │              0 │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_6 (Multiply)     │ (None, 128, 128, 128)  │              0 │ re_lu_22[0][0],        │
# │                           │                        │                │ reshape_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_7 (Lambda)         │ (None, 128, 128, 1)    │              0 │ multiply_6[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_8 (Lambda)         │ (None, 128, 128, 1)    │              0 │ multiply_6[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_8             │ (None, 128, 128, 2)    │              0 │ lambda_7[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 1)    │             98 │ concatenate_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_7 (Multiply)     │ (None, 128, 128, 128)  │              0 │ multiply_6[0][0],      │
# │                           │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_4        │ (None, 256, 256, 64)   │         73,792 │ multiply_7[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_9             │ (None, 256, 256, 128)  │              0 │ conv2d_transpose_4[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_23       │ (None, 256, 256, 64)   │          9,408 │ concatenate_9[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_23    │ (None, 256, 256, 64)   │            256 │ separable_conv2d_23[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_23 (ReLU)           │ (None, 256, 256, 64)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_24       │ (None, 256, 256, 64)   │          4,736 │ re_lu_23[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_24    │ (None, 256, 256, 64)   │            256 │ separable_conv2d_24[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_24 (ReLU)           │ (None, 256, 256, 64)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 64)             │              0 │ re_lu_24[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_4    │ (None, 64)             │              0 │ re_lu_24[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 8)              │            520 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_9 (Dense)           │ (None, 64)             │            576 │ dense_8[0][0],         │
# │                           │                        │                │ dense_8[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 64)             │              0 │ dense_9[0][0],         │
# │                           │                        │                │ dense_9[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 64)             │              0 │ add_4[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_4 (Reshape)       │ (None, 1, 1, 64)       │              0 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_8 (Multiply)     │ (None, 256, 256, 64)   │              0 │ re_lu_24[0][0],        │
# │                           │                        │                │ reshape_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_9 (Lambda)         │ (None, 256, 256, 1)    │              0 │ multiply_8[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_10 (Lambda)        │ (None, 256, 256, 1)    │              0 │ multiply_8[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_10            │ (None, 256, 256, 2)    │              0 │ lambda_9[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 256, 256, 1)    │             98 │ concatenate_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_9 (Multiply)     │ (None, 256, 256, 64)   │              0 │ multiply_8[0][0],      │
# │                           │                        │                │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 256, 256, 1)    │             65 │ multiply_9[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 10,530,636 (40.17 MB)
#  Trainable params: 10,516,812 (40.12 MB)
#  Non-trainable params: 13,824 (54.00 KB)

# %%
class EarlyStoppingByAccuracyChange(tf.keras.callbacks.Callback):
    def __init__(self, monitor='accuracy', threshold=0.00001, patience=3, verbose=0):
        super(EarlyStoppingByAccuracyChange, self).__init__()
        self.monitor = monitor
        self.threshold = threshold
        self.patience = patience
        self.verbose = verbose
        self.wait = 0
        self.best_accuracy = -float('inf')  
        self.consecutive_stops = 0 

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current_accuracy = logs.get(self.monitor)
        if current_accuracy is None:
            tf.get_logger().warning(
                'Early stopping requires %s available!', self.monitor
            )
            return

        if current_accuracy > self.best_accuracy:
            self.best_accuracy = current_accuracy
            self.wait = 0
            self.consecutive_stops = 0
        else:
            self.wait += 1
            accuracy_change = current_accuracy - self.best_accuracy
            if abs(accuracy_change) < self.threshold:
                self.consecutive_stops += 1
                if self.consecutive_stops >= self.patience:
                    if self.verbose > 0:
                        print(f"Epoch {epoch+1}: Early stopping triggered due to minimal accuracy change for {self.patience} epochs.")
                    self.model.stop_training = True
            else:
                self.consecutive_stops = 0

# %%
pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-contrib-python) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def convert_to_gray_median(images): 
    grays = []

    for img in images:
        if img.dtype != np.uint8:
            img = (img * 255).astype(np.uint8)
    
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

        img_gray = cv2.medianBlur(gray, 5)
        grays.append(img_gray)

    return np.array(grays)

train_images_gray_median = convert_to_gray_median(train_images)
test_images_gray_median = convert_to_gray_median(test_images)

# %%
initial_lr = 0.001
optimizer = Adam(learning_rate=initial_lr)
segunet = CustomSegUNet(input_size=(256, 256, 1))
segunet.compile(
    optimizer=optimizer,
    loss=dice_loss,
    metrics=['accuracy', jaccard_coefficient]
)
model_checkpoint_dir = 'model'

checkpoint_path = os.path.join(model_checkpoint_dir, 'cp.ckpt')

checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(model_checkpoint_dir, 'custom_seg_unet.weights.h5'),
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

early_stopping = EarlyStoppingByAccuracyChange(
    monitor='accuracy',
    threshold=0.00001,
    patience=10,
    verbose=1
)

lr_reduction = ReduceLROnPlateau(monitor='loss',
                                  patience=5,
                                  verbose=1,
                                  factor=0.5,
                                  min_lr=0.00001)
start_time = time.time()
history = segunet.fit(
    train_images_gray_median, train_masks,
    batch_size=32,
    epochs=100,
    callbacks=[early_stopping, lr_reduction, checkpoint_callback]
)

end_time = time.time()
training_time = end_time - start_time


avg_accuracy = np.mean(history.history['accuracy'])
avg_jaccard = np.mean(history.history['jaccard_coefficient'])
print("SegUNet output shape:", segunet.output_shape)
print(f"⏱️ Thời gian huấn luyện: {training_time:.2f} giây")
print(f"✅ Accuracy trung bình: {avg_accuracy*100:.2f}%")
print(f"🔗 Jaccard trung bình: {avg_jaccard*100:.2f}%")
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765721514.241466     188 service.cc:148] XLA service 0x792be4091510 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1765721514.242178     188 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1765721517.302891     188 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1765721540.326348     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721540.552286     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721542.534470     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721542.749501     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721542.963340     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721543.531745     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721543.744963     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721544.681936     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721544.984651     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721547.552694     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721547.970271     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-14 14:12:28.121294: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,128,128]{3,2,1,0}, f32[32,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-14 14:12:28.227471: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.106274915s
# Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,128,128]{3,2,1,0}, f32[32,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1765721567.032399     188 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 737ms/step - accuracy: 0.6744 - jaccard_coefficient: 0.2875 - loss: 0.5616
# E0000 00:00:1765721617.691035     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721617.925878     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721619.144967     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721619.379296     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721622.256003     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765721622.441041     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6761 - jaccard_coefficient: 0.2890 - loss: 0.5600
# Epoch 1: loss improved from inf to 0.46303, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 157s 1s/step - accuracy: 0.6778 - jaccard_coefficient: 0.2905 - loss: 0.5584 - learning_rate: 0.0010
# Epoch 2/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.8840 - jaccard_coefficient: 0.5619 - loss: 0.2823
# Epoch 2: loss improved from 0.46303 to 0.25275, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.8844 - jaccard_coefficient: 0.5625 - loss: 0.2818 - learning_rate: 0.0010
# Epoch 3/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9224 - jaccard_coefficient: 0.6737 - loss: 0.1958
# Epoch 3: loss improved from 0.25275 to 0.20067, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9224 - jaccard_coefficient: 0.6736 - loss: 0.1958 - learning_rate: 0.0010
# Epoch 4/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9281 - jaccard_coefficient: 0.6868 - loss: 0.1864
# Epoch 4: loss improved from 0.20067 to 0.17904, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9281 - jaccard_coefficient: 0.6870 - loss: 0.1863 - learning_rate: 0.0010
# Epoch 5/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9347 - jaccard_coefficient: 0.7157 - loss: 0.1666
# Epoch 5: loss improved from 0.17904 to 0.16329, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9347 - jaccard_coefficient: 0.7158 - loss: 0.1665 - learning_rate: 0.0010
# Epoch 6/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9381 - jaccard_coefficient: 0.7281 - loss: 0.1584
# Epoch 6: loss improved from 0.16329 to 0.15980, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9381 - jaccard_coefficient: 0.7281 - loss: 0.1585 - learning_rate: 0.0010
# Epoch 7/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9413 - jaccard_coefficient: 0.7393 - loss: 0.1505
# Epoch 7: loss improved from 0.15980 to 0.14529, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9413 - jaccard_coefficient: 0.7394 - loss: 0.1504 - learning_rate: 0.0010
# Epoch 8/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9455 - jaccard_coefficient: 0.7590 - loss: 0.1378
# Epoch 8: loss improved from 0.14529 to 0.13472, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9455 - jaccard_coefficient: 0.7591 - loss: 0.1377 - learning_rate: 0.0010
# Epoch 9/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9472 - jaccard_coefficient: 0.7645 - loss: 0.1343
# Epoch 9: loss improved from 0.13472 to 0.13339, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9472 - jaccard_coefficient: 0.7645 - loss: 0.1343 - learning_rate: 0.0010
# Epoch 10/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9488 - jaccard_coefficient: 0.7751 - loss: 0.1272
# Epoch 10: loss improved from 0.13339 to 0.12706, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9488 - jaccard_coefficient: 0.7751 - loss: 0.1272 - learning_rate: 0.0010
# Epoch 11/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9494 - jaccard_coefficient: 0.7741 - loss: 0.1281
# Epoch 11: loss improved from 0.12706 to 0.12700, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9494 - jaccard_coefficient: 0.7741 - loss: 0.1280 - learning_rate: 0.0010
# Epoch 12/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9500 - jaccard_coefficient: 0.7722 - loss: 0.1296
# Epoch 12: loss did not improve from 0.12700
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 728ms/step - accuracy: 0.9500 - jaccard_coefficient: 0.7722 - loss: 0.1296 - learning_rate: 0.0010
# Epoch 13/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9521 - jaccard_coefficient: 0.7917 - loss: 0.1168
# Epoch 13: loss improved from 0.12700 to 0.12103, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9521 - jaccard_coefficient: 0.7916 - loss: 0.1169 - learning_rate: 0.0010
# Epoch 14/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9538 - jaccard_coefficient: 0.7950 - loss: 0.1151
# Epoch 14: loss improved from 0.12103 to 0.11101, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9538 - jaccard_coefficient: 0.7951 - loss: 0.1150 - learning_rate: 0.0010
# Epoch 15/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9586 - jaccard_coefficient: 0.8123 - loss: 0.1040
# Epoch 15: loss improved from 0.11101 to 0.10569, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9586 - jaccard_coefficient: 0.8121 - loss: 0.1040 - learning_rate: 0.0010
# Epoch 16/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9550 - jaccard_coefficient: 0.7959 - loss: 0.1142
# Epoch 16: loss did not improve from 0.10569
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9550 - jaccard_coefficient: 0.7960 - loss: 0.1142 - learning_rate: 0.0010
# Epoch 17/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9614 - jaccard_coefficient: 0.8233 - loss: 0.0973
# Epoch 17: loss improved from 0.10569 to 0.10031, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9614 - jaccard_coefficient: 0.8232 - loss: 0.0974 - learning_rate: 0.0010
# Epoch 18/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9600 - jaccard_coefficient: 0.8202 - loss: 0.0991
# Epoch 18: loss improved from 0.10031 to 0.09614, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 739ms/step - accuracy: 0.9601 - jaccard_coefficient: 0.8203 - loss: 0.0990 - learning_rate: 0.0010
# Epoch 19/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9616 - jaccard_coefficient: 0.8258 - loss: 0.0960
# Epoch 19: loss improved from 0.09614 to 0.09363, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9616 - jaccard_coefficient: 0.8258 - loss: 0.0959 - learning_rate: 0.0010
# Epoch 20/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9638 - jaccard_coefficient: 0.8340 - loss: 0.0908
# Epoch 20: loss improved from 0.09363 to 0.08816, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9639 - jaccard_coefficient: 0.8341 - loss: 0.0908 - learning_rate: 0.0010
# Epoch 21/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9643 - jaccard_coefficient: 0.8378 - loss: 0.0885
# Epoch 21: loss did not improve from 0.08816
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 728ms/step - accuracy: 0.9643 - jaccard_coefficient: 0.8377 - loss: 0.0886 - learning_rate: 0.0010
# Epoch 22/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9601 - jaccard_coefficient: 0.8285 - loss: 0.0942
# Epoch 22: loss did not improve from 0.08816
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9602 - jaccard_coefficient: 0.8285 - loss: 0.0942 - learning_rate: 0.0010
# Epoch 23/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9653 - jaccard_coefficient: 0.8396 - loss: 0.0875
# Epoch 23: loss improved from 0.08816 to 0.08696, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9653 - jaccard_coefficient: 0.8396 - loss: 0.0875 - learning_rate: 0.0010
# Epoch 24/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9665 - jaccard_coefficient: 0.8363 - loss: 0.0894
# Epoch 24: loss did not improve from 0.08696
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 728ms/step - accuracy: 0.9665 - jaccard_coefficient: 0.8363 - loss: 0.0894 - learning_rate: 0.0010
# Epoch 25/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9659 - jaccard_coefficient: 0.8468 - loss: 0.0832
# Epoch 25: loss improved from 0.08696 to 0.08259, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9659 - jaccard_coefficient: 0.8468 - loss: 0.0832 - learning_rate: 0.0010
# Epoch 26/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9672 - jaccard_coefficient: 0.8491 - loss: 0.0819
# Epoch 26: loss improved from 0.08259 to 0.07862, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9672 - jaccard_coefficient: 0.8492 - loss: 0.0818 - learning_rate: 0.0010
# Epoch 27/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9692 - jaccard_coefficient: 0.8588 - loss: 0.0761
# Epoch 27: loss improved from 0.07862 to 0.07471, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9692 - jaccard_coefficient: 0.8588 - loss: 0.0761 - learning_rate: 0.0010
# Epoch 28/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9682 - jaccard_coefficient: 0.8516 - loss: 0.0804
# Epoch 28: loss did not improve from 0.07471
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 728ms/step - accuracy: 0.9682 - jaccard_coefficient: 0.8516 - loss: 0.0804 - learning_rate: 0.0010
# Epoch 29/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9673 - jaccard_coefficient: 0.8466 - loss: 0.0834
# Epoch 29: loss did not improve from 0.07471
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9673 - jaccard_coefficient: 0.8467 - loss: 0.0833 - learning_rate: 0.0010
# Epoch 30/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9691 - jaccard_coefficient: 0.8596 - loss: 0.0757
# Epoch 30: loss did not improve from 0.07471
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9691 - jaccard_coefficient: 0.8596 - loss: 0.0757 - learning_rate: 0.0010
# Epoch 31/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9690 - jaccard_coefficient: 0.8612 - loss: 0.0748
# Epoch 31: loss improved from 0.07471 to 0.07436, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9690 - jaccard_coefficient: 0.8612 - loss: 0.0748 - learning_rate: 0.0010
# Epoch 32/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9687 - jaccard_coefficient: 0.8610 - loss: 0.0748
# Epoch 32: loss did not improve from 0.07436
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 728ms/step - accuracy: 0.9687 - jaccard_coefficient: 0.8609 - loss: 0.0749 - learning_rate: 0.0010
# Epoch 33/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9683 - jaccard_coefficient: 0.8553 - loss: 0.0783
# Epoch 33: loss did not improve from 0.07436
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9683 - jaccard_coefficient: 0.8553 - loss: 0.0783 - learning_rate: 0.0010
# Epoch 34/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9716 - jaccard_coefficient: 0.8690 - loss: 0.0703
# Epoch 34: loss improved from 0.07436 to 0.06898, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9716 - jaccard_coefficient: 0.8690 - loss: 0.0702 - learning_rate: 0.0010
# Epoch 35/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9718 - jaccard_coefficient: 0.8749 - loss: 0.0669
# Epoch 35: loss improved from 0.06898 to 0.06769, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9718 - jaccard_coefficient: 0.8749 - loss: 0.0669 - learning_rate: 0.0010
# Epoch 36/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9716 - jaccard_coefficient: 0.8710 - loss: 0.0691
# Epoch 36: loss did not improve from 0.06769
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 728ms/step - accuracy: 0.9716 - jaccard_coefficient: 0.8711 - loss: 0.0691 - learning_rate: 0.0010
# Epoch 37/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9746 - jaccard_coefficient: 0.8823 - loss: 0.0626
# Epoch 37: loss improved from 0.06769 to 0.06281, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9745 - jaccard_coefficient: 0.8823 - loss: 0.0626 - learning_rate: 0.0010
# Epoch 38/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9741 - jaccard_coefficient: 0.8792 - loss: 0.0645
# Epoch 38: loss improved from 0.06281 to 0.06192, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9741 - jaccard_coefficient: 0.8792 - loss: 0.0645 - learning_rate: 0.0010
# Epoch 39/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9751 - jaccard_coefficient: 0.8896 - loss: 0.0585
# Epoch 39: loss improved from 0.06192 to 0.06071, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9751 - jaccard_coefficient: 0.8896 - loss: 0.0586 - learning_rate: 0.0010
# Epoch 40/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9761 - jaccard_coefficient: 0.8882 - loss: 0.0593
# Epoch 40: loss improved from 0.06071 to 0.05912, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9761 - jaccard_coefficient: 0.8882 - loss: 0.0593 - learning_rate: 0.0010
# Epoch 41/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9770 - jaccard_coefficient: 0.8923 - loss: 0.0570
# Epoch 41: loss improved from 0.05912 to 0.05896, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9770 - jaccard_coefficient: 0.8922 - loss: 0.0570 - learning_rate: 0.0010
# Epoch 42/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9764 - jaccard_coefficient: 0.8877 - loss: 0.0596
# Epoch 42: loss improved from 0.05896 to 0.05743, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9764 - jaccard_coefficient: 0.8878 - loss: 0.0596 - learning_rate: 0.0010
# Epoch 43/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9775 - jaccard_coefficient: 0.8937 - loss: 0.0562
# Epoch 43: loss improved from 0.05743 to 0.05449, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9775 - jaccard_coefficient: 0.8938 - loss: 0.0562 - learning_rate: 0.0010
# Epoch 44/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9766 - jaccard_coefficient: 0.8941 - loss: 0.0560
# Epoch 44: loss did not improve from 0.05449
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 728ms/step - accuracy: 0.9766 - jaccard_coefficient: 0.8940 - loss: 0.0560 - learning_rate: 0.0010
# Epoch 45/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9759 - jaccard_coefficient: 0.8866 - loss: 0.0603
# Epoch 45: loss did not improve from 0.05449
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9759 - jaccard_coefficient: 0.8867 - loss: 0.0602 - learning_rate: 0.0010
# Epoch 46/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9755 - jaccard_coefficient: 0.8900 - loss: 0.0583
# Epoch 46: loss did not improve from 0.05449
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 728ms/step - accuracy: 0.9755 - jaccard_coefficient: 0.8900 - loss: 0.0583 - learning_rate: 0.0010
# Epoch 47/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9759 - jaccard_coefficient: 0.8879 - loss: 0.0595
# Epoch 47: loss did not improve from 0.05449
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 728ms/step - accuracy: 0.9759 - jaccard_coefficient: 0.8880 - loss: 0.0595 - learning_rate: 0.0010
# Epoch 48/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9767 - jaccard_coefficient: 0.8939 - loss: 0.0562
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 48: loss did not improve from 0.05449
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9767 - jaccard_coefficient: 0.8939 - loss: 0.0561 - learning_rate: 0.0010
# Epoch 49/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9777 - jaccard_coefficient: 0.8966 - loss: 0.0547
# Epoch 49: loss improved from 0.05449 to 0.05197, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9778 - jaccard_coefficient: 0.8966 - loss: 0.0546 - learning_rate: 5.0000e-04
# Epoch 50/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9805 - jaccard_coefficient: 0.9084 - loss: 0.0481
# Epoch 50: loss improved from 0.05197 to 0.04723, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9805 - jaccard_coefficient: 0.9084 - loss: 0.0480 - learning_rate: 5.0000e-04
# Epoch 51/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9816 - jaccard_coefficient: 0.9151 - loss: 0.0444
# Epoch 51: loss improved from 0.04723 to 0.04482, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9816 - jaccard_coefficient: 0.9151 - loss: 0.0444 - learning_rate: 5.0000e-04
# Epoch 52/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9828 - jaccard_coefficient: 0.9177 - loss: 0.0429
# Epoch 52: loss improved from 0.04482 to 0.04215, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9828 - jaccard_coefficient: 0.9178 - loss: 0.0429 - learning_rate: 5.0000e-04
# Epoch 53/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9833 - jaccard_coefficient: 0.9185 - loss: 0.0425
# Epoch 53: loss improved from 0.04215 to 0.04203, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9832 - jaccard_coefficient: 0.9185 - loss: 0.0425 - learning_rate: 5.0000e-04
# Epoch 54/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9836 - jaccard_coefficient: 0.9216 - loss: 0.0409
# Epoch 54: loss improved from 0.04203 to 0.04091, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9835 - jaccard_coefficient: 0.9216 - loss: 0.0409 - learning_rate: 5.0000e-04
# Epoch 55/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9833 - jaccard_coefficient: 0.9244 - loss: 0.0393
# Epoch 55: loss improved from 0.04091 to 0.04035, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9833 - jaccard_coefficient: 0.9244 - loss: 0.0393 - learning_rate: 5.0000e-04
# Epoch 56/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9829 - jaccard_coefficient: 0.9226 - loss: 0.0403
# Epoch 56: loss did not improve from 0.04035
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9829 - jaccard_coefficient: 0.9226 - loss: 0.0403 - learning_rate: 5.0000e-04
# Epoch 57/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9837 - jaccard_coefficient: 0.9246 - loss: 0.0392
# Epoch 57: loss improved from 0.04035 to 0.03935, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9837 - jaccard_coefficient: 0.9246 - loss: 0.0392 - learning_rate: 5.0000e-04
# Epoch 58/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9839 - jaccard_coefficient: 0.9259 - loss: 0.0385
# Epoch 58: loss improved from 0.03935 to 0.03855, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9839 - jaccard_coefficient: 0.9258 - loss: 0.0385 - learning_rate: 5.0000e-04
# Epoch 59/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9834 - jaccard_coefficient: 0.9234 - loss: 0.0398
# Epoch 59: loss improved from 0.03855 to 0.03853, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9834 - jaccard_coefficient: 0.9235 - loss: 0.0398 - learning_rate: 5.0000e-04
# Epoch 60/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9837 - jaccard_coefficient: 0.9254 - loss: 0.0388
# Epoch 60: loss did not improve from 0.03853
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9837 - jaccard_coefficient: 0.9254 - loss: 0.0388 - learning_rate: 5.0000e-04
# Epoch 61/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9836 - jaccard_coefficient: 0.9244 - loss: 0.0393
# Epoch 61: loss did not improve from 0.03853
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9836 - jaccard_coefficient: 0.9244 - loss: 0.0393 - learning_rate: 5.0000e-04
# Epoch 62/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9846 - jaccard_coefficient: 0.9280 - loss: 0.0374
# Epoch 62: loss improved from 0.03853 to 0.03759, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9846 - jaccard_coefficient: 0.9280 - loss: 0.0374 - learning_rate: 5.0000e-04
# Epoch 63/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9843 - jaccard_coefficient: 0.9257 - loss: 0.0386
# Epoch 63: loss did not improve from 0.03759
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9843 - jaccard_coefficient: 0.9257 - loss: 0.0386 - learning_rate: 5.0000e-04
# Epoch 64/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9854 - jaccard_coefficient: 0.9290 - loss: 0.0368
# Epoch 64: loss improved from 0.03759 to 0.03674, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9853 - jaccard_coefficient: 0.9290 - loss: 0.0368 - learning_rate: 5.0000e-04
# Epoch 65/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9853 - jaccard_coefficient: 0.9312 - loss: 0.0356
# Epoch 65: loss did not improve from 0.03674
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9853 - jaccard_coefficient: 0.9312 - loss: 0.0357 - learning_rate: 5.0000e-04
# Epoch 66/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9845 - jaccard_coefficient: 0.9285 - loss: 0.0371
# Epoch 66: loss did not improve from 0.03674
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9845 - jaccard_coefficient: 0.9285 - loss: 0.0371 - learning_rate: 5.0000e-04
# Epoch 67/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9851 - jaccard_coefficient: 0.9287 - loss: 0.0370
# Epoch 67: loss improved from 0.03674 to 0.03648, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9851 - jaccard_coefficient: 0.9287 - loss: 0.0370 - learning_rate: 5.0000e-04
# Epoch 68/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9850 - jaccard_coefficient: 0.9303 - loss: 0.0361
# Epoch 68: loss improved from 0.03648 to 0.03525, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9850 - jaccard_coefficient: 0.9304 - loss: 0.0361 - learning_rate: 5.0000e-04
# Epoch 69/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9836 - jaccard_coefficient: 0.9256 - loss: 0.0387
# Epoch 69: loss did not improve from 0.03525
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9836 - jaccard_coefficient: 0.9257 - loss: 0.0386 - learning_rate: 5.0000e-04
# Epoch 70/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9856 - jaccard_coefficient: 0.9323 - loss: 0.0351
# Epoch 70: loss did not improve from 0.03525
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9856 - jaccard_coefficient: 0.9323 - loss: 0.0351 - learning_rate: 5.0000e-04
# Epoch 71/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9856 - jaccard_coefficient: 0.9341 - loss: 0.0341
# Epoch 71: loss improved from 0.03525 to 0.03450, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9856 - jaccard_coefficient: 0.9341 - loss: 0.0341 - learning_rate: 5.0000e-04
# Epoch 72/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9858 - jaccard_coefficient: 0.9342 - loss: 0.0340
# Epoch 72: loss improved from 0.03450 to 0.03411, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9858 - jaccard_coefficient: 0.9342 - loss: 0.0340 - learning_rate: 5.0000e-04
# Epoch 73/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9855 - jaccard_coefficient: 0.9313 - loss: 0.0356
# Epoch 73: loss did not improve from 0.03411
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9855 - jaccard_coefficient: 0.9314 - loss: 0.0356 - learning_rate: 5.0000e-04
# Epoch 74/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9862 - jaccard_coefficient: 0.9358 - loss: 0.0332
# Epoch 74: loss improved from 0.03411 to 0.03390, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9862 - jaccard_coefficient: 0.9358 - loss: 0.0332 - learning_rate: 5.0000e-04
# Epoch 75/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9861 - jaccard_coefficient: 0.9359 - loss: 0.0331
# Epoch 75: loss improved from 0.03390 to 0.03322, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9861 - jaccard_coefficient: 0.9359 - loss: 0.0331 - learning_rate: 5.0000e-04
# Epoch 76/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9864 - jaccard_coefficient: 0.9347 - loss: 0.0338
# Epoch 76: loss did not improve from 0.03322
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9864 - jaccard_coefficient: 0.9347 - loss: 0.0338 - learning_rate: 5.0000e-04
# Epoch 77/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9865 - jaccard_coefficient: 0.9360 - loss: 0.0331
# Epoch 77: loss improved from 0.03322 to 0.03256, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9865 - jaccard_coefficient: 0.9360 - loss: 0.0331 - learning_rate: 5.0000e-04
# Epoch 78/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9860 - jaccard_coefficient: 0.9351 - loss: 0.0336
# Epoch 78: loss did not improve from 0.03256
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9860 - jaccard_coefficient: 0.9351 - loss: 0.0335 - learning_rate: 5.0000e-04
# Epoch 79/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9868 - jaccard_coefficient: 0.9367 - loss: 0.0327
# Epoch 79: loss improved from 0.03256 to 0.03222, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9868 - jaccard_coefficient: 0.9367 - loss: 0.0327 - learning_rate: 5.0000e-04
# Epoch 80/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9862 - jaccard_coefficient: 0.9371 - loss: 0.0325
# Epoch 80: loss improved from 0.03222 to 0.03197, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 738ms/step - accuracy: 0.9862 - jaccard_coefficient: 0.9371 - loss: 0.0325 - learning_rate: 5.0000e-04
# Epoch 81/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9861 - jaccard_coefficient: 0.9354 - loss: 0.0334
# Epoch 81: loss did not improve from 0.03197
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9861 - jaccard_coefficient: 0.9354 - loss: 0.0334 - learning_rate: 5.0000e-04
# Epoch 82/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9863 - jaccard_coefficient: 0.9377 - loss: 0.0322
# Epoch 82: loss improved from 0.03197 to 0.03152, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9863 - jaccard_coefficient: 0.9378 - loss: 0.0321 - learning_rate: 5.0000e-04
# Epoch 83/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9872 - jaccard_coefficient: 0.9389 - loss: 0.0315
# Epoch 83: loss did not improve from 0.03152
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9872 - jaccard_coefficient: 0.9389 - loss: 0.0315 - learning_rate: 5.0000e-04
# Epoch 84/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - accuracy: 0.9861 - jaccard_coefficient: 0.9362 - loss: 0.0329
# Epoch 84: loss did not improve from 0.03152
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 726ms/step - accuracy: 0.9861 - jaccard_coefficient: 0.9362 - loss: 0.0329 - learning_rate: 5.0000e-04
# Epoch 85/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9863 - jaccard_coefficient: 0.9382 - loss: 0.0319
# Epoch 85: loss did not improve from 0.03152
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9863 - jaccard_coefficient: 0.9382 - loss: 0.0319 - learning_rate: 5.0000e-04
# Epoch 86/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9864 - jaccard_coefficient: 0.9379 - loss: 0.0320
# Epoch 86: loss improved from 0.03152 to 0.03120, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9864 - jaccard_coefficient: 0.9379 - loss: 0.0320 - learning_rate: 5.0000e-04
# Epoch 87/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9869 - jaccard_coefficient: 0.9385 - loss: 0.0317
# Epoch 87: loss improved from 0.03120 to 0.03100, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9869 - jaccard_coefficient: 0.9385 - loss: 0.0317 - learning_rate: 5.0000e-04
# Epoch 88/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9875 - jaccard_coefficient: 0.9410 - loss: 0.0304
# Epoch 88: loss improved from 0.03100 to 0.03082, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9874 - jaccard_coefficient: 0.9410 - loss: 0.0304 - learning_rate: 5.0000e-04
# Epoch 89/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9875 - jaccard_coefficient: 0.9425 - loss: 0.0296
# Epoch 89: loss improved from 0.03082 to 0.03056, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9875 - jaccard_coefficient: 0.9425 - loss: 0.0296 - learning_rate: 5.0000e-04
# Epoch 90/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9875 - jaccard_coefficient: 0.9406 - loss: 0.0306
# Epoch 90: loss improved from 0.03056 to 0.02989, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9875 - jaccard_coefficient: 0.9406 - loss: 0.0306 - learning_rate: 5.0000e-04
# Epoch 91/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9879 - jaccard_coefficient: 0.9435 - loss: 0.0291
# Epoch 91: loss improved from 0.02989 to 0.02969, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9879 - jaccard_coefficient: 0.9434 - loss: 0.0291 - learning_rate: 5.0000e-04
# Epoch 92/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - accuracy: 0.9879 - jaccard_coefficient: 0.9447 - loss: 0.0284
# Epoch 92: loss improved from 0.02969 to 0.02887, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9879 - jaccard_coefficient: 0.9447 - loss: 0.0284 - learning_rate: 5.0000e-04
# Epoch 93/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - accuracy: 0.9878 - jaccard_coefficient: 0.9445 - loss: 0.0285
# Epoch 93: loss improved from 0.02887 to 0.02882, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9878 - jaccard_coefficient: 0.9445 - loss: 0.0285 - learning_rate: 5.0000e-04
# Epoch 94/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9873 - jaccard_coefficient: 0.9421 - loss: 0.0298
# Epoch 94: loss did not improve from 0.02882
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9873 - jaccard_coefficient: 0.9421 - loss: 0.0298 - learning_rate: 5.0000e-04
# Epoch 95/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9879 - jaccard_coefficient: 0.9448 - loss: 0.0284
# Epoch 95: loss improved from 0.02882 to 0.02817, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9879 - jaccard_coefficient: 0.9448 - loss: 0.0284 - learning_rate: 5.0000e-04
# Epoch 96/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9884 - jaccard_coefficient: 0.9466 - loss: 0.0274
# Epoch 96: loss improved from 0.02817 to 0.02738, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9884 - jaccard_coefficient: 0.9466 - loss: 0.0274 - learning_rate: 5.0000e-04
# Epoch 97/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9882 - jaccard_coefficient: 0.9464 - loss: 0.0276
# Epoch 97: loss did not improve from 0.02738
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9882 - jaccard_coefficient: 0.9464 - loss: 0.0276 - learning_rate: 5.0000e-04
# Epoch 98/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9879 - jaccard_coefficient: 0.9460 - loss: 0.0278
# Epoch 98: loss improved from 0.02738 to 0.02716, saving model to model/custom_seg_unet.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 737ms/step - accuracy: 0.9880 - jaccard_coefficient: 0.9460 - loss: 0.0277 - learning_rate: 5.0000e-04
# Epoch 99/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9881 - jaccard_coefficient: 0.9440 - loss: 0.0288
# Epoch 99: loss did not improve from 0.02716
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9881 - jaccard_coefficient: 0.9440 - loss: 0.0288 - learning_rate: 5.0000e-04
# Epoch 100/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9880 - jaccard_coefficient: 0.9431 - loss: 0.0293
# Epoch 100: loss did not improve from 0.02716
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 44s 727ms/step - accuracy: 0.9880 - jaccard_coefficient: 0.9431 - loss: 0.0293 - learning_rate: 5.0000e-04
# SegUNet output shape: (None, 256, 256, 1)
# ⏱️ Thời gian huấn luyện: 4593.76 giây
# ✅ Accuracy trung bình: 97.22%
# 🔗 Jaccard trung bình: 87.72%

# %%
acc = history.history['accuracy']
loss = history.history['loss']
epochs_range = range(1, len(acc) + 1)
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Accuracy', color='green')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Loss', color='red')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('Median-2750.png', dpi=300)
plt.show()

# %%
def apply_morphology(mask, kernel_size=3, iterations=1):
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))
    mask = (mask > 0.5).astype(np.uint8) 
    closed = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=iterations)

    opened = cv2.morphologyEx(closed, cv2.MORPH_OPEN, kernel, iterations=iterations)

    return opened.astype(np.float32) 


print("🔍 Đánh giá không hậu xử lý...")
results = segunet.evaluate(test_images_gray_median, test_masks, verbose=1)
loss, accuracy, jaccard = results
print(f"Không hậu xử lý - Dice Loss: {loss:.4f}, Accuracy: {accuracy*100:.2f}%, Jaccard: {jaccard*100:.2f}%")


print("\n🔧 Đánh giá sau Morphology...")
predictions1 = segunet.predict(test_images_gray_median)
refined_predictions1 = []

for i in tqdm(range(len(test_images_gray_median))):
    pred = predictions1[i].squeeze()

    morph_pred = apply_morphology(pred, kernel_size=7, iterations=2)

    refined_predictions1.append(morph_pred)

refined_predictions1 = np.expand_dims(np.array(refined_predictions1), axis=-1)

accuracy_after = np_accuracy(test_masks, refined_predictions1)
jaccard_after = np_jaccard_coefficient(test_masks, refined_predictions1)
loss_after = np_dice_loss(test_masks, refined_predictions1)

print(f"Sau Morphology - Dice Loss: {loss_after:.4f}, Accuracy: {accuracy_after*100:.2f}%, Jaccard: {jaccard_after*100:.2f}%")
# Out:
# 🔍 Đánh giá không hậu xử lý...
# 25/26 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9560 - jaccard_coefficient: 0.8067 - loss: 0.1099
# E0000 00:00:1765726088.044721     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765726088.284410     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 17s 476ms/step - accuracy: 0.9556 - jaccard_coefficient: 0.8024 - loss: 0.1127
# Không hậu xử lý - Dice Loss: 0.1484, Accuracy: 95.01%, Jaccard: 74.85%
#
# 🔧 Đánh giá sau Morphology...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 12s 319ms/step
# 100%|██████████| 825/825 [00:00<00:00, 1543.80it/s]
# Sau Morphology - Dice Loss: 0.1276, Accuracy: 95.02%, Jaccard: 77.37%
