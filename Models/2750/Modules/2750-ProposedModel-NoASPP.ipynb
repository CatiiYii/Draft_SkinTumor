# %%
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
# !pip install opencv-contrib-python
# !pip install tensorflow-addons

import os
import cv2
import time
import json
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm

from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

import pydensecrf.densecrf as dcrf
from pydensecrf.utils import unary_from_softmax, create_pairwise_bilateral

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.activations import swish
from tensorflow.keras.regularizers import l2
from tensorflow.keras.initializers import HeNormal


from tensorflow.keras.layers import (
    Layer, 
    Input, 
    Conv2D, 
    BatchNormalization, 
    Lambda, 
    Concatenate,
    SeparableConv2D, 
    MaxPooling2D, 
    UpSampling2D, 
    Conv2DTranspose,
    SpatialDropout2D, 
    ReLU, 
    GlobalAveragePooling2D, 
    Add,
    GlobalMaxPooling2D, 
    Dense, 
    Reshape, 
    Multiply, 
    Activation
)
from tensorflow.keras import backend as K
# Out:
# Collecting git+https://github.com/lucasb-eyer/pydensecrf.git
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-ki4y89q_
#   Running command git clone --filter=blob:none --quiet https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-ki4y89q_
#   Resolved https://github.com/lucasb-eyer/pydensecrf.git to commit 2723c7fa4f2ead16ae1ce3d8afe977724bb8f87f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pydensecrf
#   Building wheel for pydensecrf (pyproject.toml) ... done
#   Created wheel for pydensecrf: filename=pydensecrf-1.0-cp311-cp311-linux_x86_64.whl size=3440293 sha256=69e97558f9a13ceb181835359e9416b93bbcd75984dac4a4b0f0456a842a4038
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rjijzaqc/wheels/ce/8e/34/6dcfa200a9e2ae3627d8009b8bd1ca9b24512bec50a93304de
# Successfully built pydensecrf
# Installing collected packages: pydensecrf
# Successfully installed pydensecrf-1.0
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-contrib-python) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (25.0)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 10.0 MB/s eta 0:00:00 0:00:01
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.4
#     Uninstalling typeguard-4.4.4:
#       Successfully uninstalled typeguard-4.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.16.1 requires typeguard<5,>=3, but you have typeguard 2.13.3 which is incompatible.
# inflect 7.5.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3
# 2025-10-25 13:07:27.786471: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761397647.993303      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761397648.060516      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
working_dir = '/kaggle/working'
for item in os.listdir(working_dir):
    item_path = os.path.join(working_dir, item)
    try:
        if os.path.isfile(item_path) or os.path.islink(item_path):
            os.unlink(item_path)  
        elif os.path.isdir(item_path):
            shutil.rmtree(item_path)  
            print(f"❌ xóa thành công {item_path}")
    except Exception as e:
        print(f"Lỗi khi xóa {item_path}: {e}")
# Out:
# ❌ xóa thành công /kaggle/working/.virtual_documents

# %%
def load_isic_dataset(image_path, mask_path, binary_path, csv_file, img_size=(256, 256)):
    image_files = sorted(glob(os.path.join(image_path, "ISIC_*.jpg")))

    images = []
    masks = []
    binary_masks = {}
    image_ids = []
    labels = []

    csv_data = pd.read_csv(csv_file)
    mel_label = csv_data['melanoma'].astype("int64")

    print("Đang đọc và xử lý dữ liệu...")
    for index, img_path in enumerate(tqdm(image_files)):
        img_id = os.path.basename(img_path).split('.')[0]
        mask_file = os.path.join(mask_path, f"{img_id}_segmentation.png")
        binary_file = os.path.join(binary_path, f"{img_id}_features.json")
   
        if not os.path.exists(mask_file):
            print(f"Không tìm thấy mask cho ảnh mặt nạ {img_id}_segmentation.png")
            continue
        if not os.path.exists(binary_file):
            print(f"Không tìm thấy mask nhị phân cho ảnh {img_id}_features.json")
            continue

        try:
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  
    
            mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)

            img = cv2.resize(img, img_size)
            mask = cv2.resize(mask, img_size)

            img = img / 255.0
            mask = mask / 255.0

            with open(binary_file, 'r') as f:
                binary_masks[img_id] = json.load(f)

            label = mel_label[index]

            images.append(img)
            masks.append(mask)
            image_ids.append(img_id)
            labels.append(label.astype("long"))

        except Exception as e:
            print(f"Lỗi khi xử lý ảnh {img_id}: {str(e)}")
            continue

    images = np.array(images)
    masks = np.array(masks)[..., np.newaxis]  
    labels = np.array(labels)

    print(f"\nĐã đọc thành công {len(images)} ảnh")
    print(f"Shape của images: {images.shape}")
    print(f"Shape của masks: {masks.shape}")
    print(f"Shape của labels: {labels.shape}")

    return images, masks, binary_masks, image_ids, labels

# %%
train_images, train_masks, train_binarys, train_image_ids, train_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2750/Train_Data',
    mask_path='/kaggle/input/isic-2750/Train_GroundTruth_1',
    binary_path='/kaggle/input/isic-2750/Train_GroundTruth_2',
    csv_file="/kaggle/input/2075-csv/Train_GroundTruth_3.csv",
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 1925/1925 [05:37<00:00,  5.70it/s]
# Đã đọc thành công 1925 ảnh
# Shape của images: (1925, 256, 256, 3)
# Shape của masks: (1925, 256, 256, 1)
# Shape của labels: (1925,)

# %%
test_images, test_masks, test_binarys, test_image_ids, test_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2750/Test_Data',
    mask_path='/kaggle/input/isic-2750/Test_GroundTruth_1',
    binary_path='/kaggle/input/isic-2750/Test_GroundTruth_2',
    csv_file='/kaggle/input/2075-csv/Test_GroundTruth_3 (1).csv',
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 825/825 [02:05<00:00,  6.59it/s]
# Đã đọc thành công 825 ảnh
# Shape của images: (825, 256, 256, 3)
# Shape của masks: (825, 256, 256, 1)
# Shape của labels: (825,)

# %%
def convert_to_gray_clahe(images_normalized):
    images_clahe = []
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))

    for img in images_normalized:
        img_uint8 = np.uint8(img * 255)

        if len(img_uint8.shape) == 3:
            img_gray = cv2.cvtColor(img_uint8, cv2.COLOR_RGB2GRAY)
        else:
            img_gray = img_uint8  

        img_clahe_uint8 = clahe.apply(img_gray)

        img_clahe = img_clahe_uint8.astype(np.float32) / 255.0

        images_clahe.append(img_clahe)

    return np.array(images_clahe)

train_images_gray_clahe = convert_to_gray_clahe(train_images)
test_images_gray_clahe = convert_to_gray_clahe(test_images)

print(f"Shape ảnh huấn luyện sau CLAHE: {train_images_gray_clahe.shape}")
# Out:
# Shape ảnh huấn luyện sau CLAHE: (1925, 256, 256)

# %%
def compute_metric(y_true, y_pred, metric='dice_coefficient', smooth=1e-6, is_numpy=False):
    y_true_f = y_true.flatten() if is_numpy else K.flatten(y_true)
    y_pred_f = y_pred.flatten() if is_numpy else K.flatten(y_pred)
    intersection = np.sum(y_true_f * y_pred_f) if is_numpy else K.sum(y_true_f * y_pred_f)

    if 'dice' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        score = (2. * intersection + smooth) / (sum_fn(y_true_f) + sum_fn(y_pred_f) + smooth)
    elif 'jaccard' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        union = sum_fn(y_true_f) + sum_fn(y_pred_f) - intersection
        score = (intersection + smooth) / (union + smooth)
    else:
        raise ValueError(f"Unsupported metric: {metric}")

    return score if 'coefficient' in metric else 1 - score

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth)

def dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth)

def jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth)

def jaccard_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_loss', smooth)

def np_accuracy(y_true, y_pred):
    return np.mean(y_true.flatten() == y_pred.flatten())

def np_dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth, is_numpy=True)

def np_jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth, is_numpy=True)

def np_dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth, is_numpy=True)

# %%
def cbam_module(input_features, reduction_ratio=8):

    filters = input_features.shape[-1]

    
    avg_pool = GlobalAveragePooling2D()(input_features)
    max_pool = GlobalMaxPooling2D()(input_features)
    
    shared_dense_1 = Dense(filters // reduction_ratio, 
                           activation='relu', 
                           kernel_initializer='he_normal', 
                           use_bias=True)
    
    shared_dense_2 = Dense(filters, 
                           use_bias=True)
    
    avg_out = shared_dense_2(shared_dense_1(avg_pool))
    max_out = shared_dense_2(shared_dense_1(max_pool))
    
    channel_sum = Add()([avg_out, max_out])
    channel_attention = Activation('sigmoid')(channel_sum)
    channel_attention = Reshape((1, 1, filters))(channel_attention)
    channel_refined = Multiply()([input_features, channel_attention])    
   
    avg_spatial = Lambda(lambda x: K.mean(x, axis=-1, keepdims=True), 
                         output_shape=lambda s: (s[0], s[1], s[2], 1))(channel_refined)
    max_spatial = Lambda(lambda x: K.max(x, axis=-1, keepdims=True), 
                         output_shape=lambda s: (s[0], s[1], s[2], 1))(channel_refined)
    
    spatial_concat = Concatenate(axis=-1)([avg_spatial, max_spatial])
    
    spatial_attention = Conv2D(1, 
                               (7, 7), 
                               padding='same', 
                               activation='sigmoid', 
                               use_bias=False)(spatial_concat)
    
    refined_features = Multiply()([channel_refined, spatial_attention])
    
    
    return refined_features

# %%
def CustomSegUNet(input_size=(256, 256, 1)):
    inputs = Input(input_size)
    c1 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(inputs)
    c1 = BatchNormalization()(c1); c1 = ReLU()(c1)
    c1 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c1)
    c1 = BatchNormalization()(c1); c1 = ReLU()(c1)
    c1 = SpatialDropout2D(0.1)(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p1)
    c2 = BatchNormalization()(c2); c2 = ReLU()(c2)
    c2 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c2)
    c2 = BatchNormalization()(c2); c2 = ReLU()(c2)
    c2 = SpatialDropout2D(0.1)(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p2)
    c3 = BatchNormalization()(c3); c3 = ReLU()(c3)
    c3 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c3)
    c3 = BatchNormalization()(c3); c3 = ReLU()(c3)
    c3 = SpatialDropout2D(0.1)(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p3)
    c4 = BatchNormalization()(c4); c4 = ReLU()(c4)
    c4 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c4)
    c4 = BatchNormalization()(c4); c4 = ReLU()(c4)
    c4 = SpatialDropout2D(0.1)(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p4)
    c5 = BatchNormalization()(c5); c5 = ReLU()(c5)
    c5 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c5)
    c5 = BatchNormalization()(c5); c5 = ReLU()(c5)
    c5 = SpatialDropout2D(0.1)(c5)
    p5 = MaxPooling2D((2, 2))(c5)
 
    c6 = SeparableConv2D(1024, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal(), dilation_rate=(2, 2))(p5)
    c6 = BatchNormalization()(c6)
    c6 = ReLU()(c6)
    c6 = SpatialDropout2D(0.2)(c6)

    u7 = Conv2DTranspose(512, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c6)
    u7 = Concatenate()([u7, c5])
    c7 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u7)
    c7 = BatchNormalization()(c7); c7 = ReLU()(c7)
    c7 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c7)
    c7 = BatchNormalization()(c7); c7 = ReLU()(c7)
    c7 = cbam_module(c7)

    u8 = Conv2DTranspose(256, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c7)
    u8 = Concatenate()([u8, c4])
    c8 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u8)
    c8 = BatchNormalization()(c8); c8 = ReLU()(c8)
    c8 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c8)
    c8 = BatchNormalization()(c8); c8 = ReLU()(c8)
    c8 = cbam_module(c8)

    u9 = Conv2DTranspose(256, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c8)
    u9 = Concatenate()([u9, c3])
    c9 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u9)
    c9 = BatchNormalization()(c9); c9 = ReLU()(c9)
    c9 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c9)
    c9 = BatchNormalization()(c9); c9 = ReLU()(c9)
    c9 = cbam_module(c9)

    u10 = Conv2DTranspose(128, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c9)
    u10 = Concatenate()([u10, c2])
    c10 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u10)
    c10 = BatchNormalization()(c10); c10 = ReLU()(c10)
    c10 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c10)
    c10 = BatchNormalization()(c10); c10 = ReLU()(c10)
    c10 = cbam_module(c10)

    u11 = Conv2DTranspose(64, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c10)
    u11 = Concatenate()([u11, c1])
    c11 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u11)
    c11 = BatchNormalization()(c11); c11 = ReLU()(c11)
    c11 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c11)
    c11 = BatchNormalization()(c11); c11 = ReLU()(c11)
    c11 = cbam_module(c11)

 
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c11)

    return Model(inputs=inputs, outputs=outputs)

if __name__ == "__main__":
    model = CustomSegUNet()
    model.summary()
# Out:
# I0000 00:00:1761398126.852345      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 256, 256,  │        137 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 256, 256,  │      4,736 │ re_lu[0][0]       │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d   │ (None, 256, 256,  │          0 │ re_lu_1[0][0]     │
# │ (SpatialDropout2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 128, 128,  │      8,896 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 128, 128,  │     17,664 │ re_lu_2[0][0]     │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_1 │ (None, 128, 128,  │          0 │ re_lu_3[0][0]     │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 64, 64,    │     34,176 │ max_pooling2d_1[… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_5  │ (None, 64, 64,    │     68,096 │ re_lu_4[0][0]     │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_2 │ (None, 64, 64,    │          0 │ re_lu_5[0][0]     │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_6  │ (None, 32, 32,    │     68,096 │ max_pooling2d_2[… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_7  │ (None, 32, 32,    │     68,096 │ re_lu_6[0][0]     │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_3 │ (None, 32, 32,    │          0 │ re_lu_7[0][0]     │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_8  │ (None, 16, 16,    │    133,888 │ max_pooling2d_3[… │
# │ (SeparableConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_9  │ (None, 16, 16,    │    267,264 │ re_lu_8[0][0]     │
# │ (SeparableConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_4 │ (None, 16, 16,    │          0 │ re_lu_9[0][0]     │
# │ (SpatialDropout2D)  │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 8, 8, 512) │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_10 │ (None, 8, 8,      │    529,920 │ max_pooling2d_4[… │
# │ (SeparableConv2D)   │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_5 │ (None, 8, 8,      │          0 │ re_lu_10[0][0]    │
# │ (SpatialDropout2D)  │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │  4,719,104 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_11 │ (None, 16, 16,    │    534,016 │ concatenate[0][0] │
# │ (SeparableConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_12 │ (None, 16, 16,    │    267,264 │ re_lu_11[0][0]    │
# │ (SeparableConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ re_lu_12[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ re_lu_12[0][0]    │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │     32,832 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 512)       │     33,280 │ dense[0][0],      │
# │                     │                   │            │ dense[1][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 512)       │          0 │ dense_1[0][0],    │
# │                     │                   │            │ dense_1[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 512)       │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 512) │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 16, 16,    │          0 │ re_lu_12[0][0],   │
# │                     │ 512)              │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda (Lambda)     │ (None, 16, 16, 1) │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 16, 16, 1) │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 16, 16, 2) │          0 │ lambda[0][0],     │
# │ (Concatenate)       │                   │            │ lambda_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 16, 16, 1) │         98 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 16, 16,    │          0 │ multiply[0][0],   │
# │ (Multiply)          │ 512)              │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │  1,179,904 │ multiply_1[0][0]  │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_13 │ (None, 32, 32,    │    135,936 │ concatenate_2[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_14 │ (None, 32, 32,    │     68,096 │ re_lu_13[0][0]    │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ re_lu_14[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 256)       │          0 │ re_lu_14[0][0]    │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 32)        │      8,224 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256)       │      8,448 │ dense_2[0][0],    │
# │                     │                   │            │ dense_2[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 256)       │          0 │ dense_3[0][0],    │
# │                     │                   │            │ dense_3[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256)       │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 256) │          0 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 32, 32,    │          0 │ re_lu_14[0][0],   │
# │ (Multiply)          │ 256)              │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 32, 32, 1) │          0 │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_3 (Lambda)   │ (None, 32, 32, 1) │          0 │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 32, 32, 2) │          0 │ lambda_2[0][0],   │
# │ (Concatenate)       │                   │            │ lambda_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32, 1) │         98 │ concatenate_3[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 32, 32,    │          0 │ multiply_2[0][0], │
# │ (Multiply)          │ 256)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │    590,080 │ multiply_3[0][0]  │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_15 │ (None, 64, 64,    │    135,936 │ concatenate_4[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_16 │ (None, 64, 64,    │     68,096 │ re_lu_15[0][0]    │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ re_lu_16[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 256)       │          0 │ re_lu_16[0][0]    │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 32)        │      8,224 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 256)       │      8,448 │ dense_4[0][0],    │
# │                     │                   │            │ dense_4[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 256)       │          0 │ dense_5[0][0],    │
# │                     │                   │            │ dense_5[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 256)       │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 256) │          0 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 64, 64,    │          0 │ re_lu_16[0][0],   │
# │ (Multiply)          │ 256)              │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_4 (Lambda)   │ (None, 64, 64, 1) │          0 │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_5 (Lambda)   │ (None, 64, 64, 1) │          0 │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64, 2) │          0 │ lambda_4[0][0],   │
# │ (Concatenate)       │                   │            │ lambda_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64, 1) │         98 │ concatenate_5[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 64, 64,    │          0 │ multiply_4[0][0], │
# │ (Multiply)          │ 256)              │            │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │    295,040 │ multiply_5[0][0]  │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_17 │ (None, 128, 128,  │     35,200 │ concatenate_6[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_18 │ (None, 128, 128,  │     17,664 │ re_lu_17[0][0]    │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ re_lu_18[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 128)       │          0 │ re_lu_18[0][0]    │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 16)        │      2,064 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 128)       │      2,176 │ dense_6[0][0],    │
# │                     │                   │            │ dense_6[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 128)       │          0 │ dense_7[0][0],    │
# │                     │                   │            │ dense_7[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128)       │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 1, 1, 128) │          0 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 128, 128,  │          0 │ re_lu_18[0][0],   │
# │ (Multiply)          │ 128)              │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_6 (Lambda)   │ (None, 128, 128,  │          0 │ multiply_6[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_7 (Lambda)   │ (None, 128, 128,  │          0 │ multiply_6[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 128, 128,  │          0 │ lambda_6[0][0],   │
# │ (Concatenate)       │ 2)                │            │ lambda_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │         98 │ concatenate_7[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 128, 128,  │          0 │ multiply_6[0][0], │
# │ (Multiply)          │ 128)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 256, 256,  │     73,792 │ multiply_7[0][0]  │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_19 │ (None, 256, 256,  │      9,408 │ concatenate_8[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_19 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_20 │ (None, 256, 256,  │      4,736 │ re_lu_19[0][0]    │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_20 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ re_lu_20[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 64)        │          0 │ re_lu_20[0][0]    │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 8)         │        520 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 64)        │        576 │ dense_8[0][0],    │
# │                     │                   │            │ dense_8[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 64)        │          0 │ dense_9[0][0],    │
# │                     │                   │            │ dense_9[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 64)        │          0 │ add_4[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 1, 1, 64)  │          0 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_8          │ (None, 256, 256,  │          0 │ re_lu_20[0][0],   │
# │ (Multiply)          │ 64)               │            │ reshape_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_8 (Lambda)   │ (None, 256, 256,  │          0 │ multiply_8[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_9 (Lambda)   │ (None, 256, 256,  │          0 │ multiply_8[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 256, 256,  │          0 │ lambda_8[0][0],   │
# │ (Concatenate)       │ 2)                │            │ lambda_9[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 256, 256,  │         98 │ concatenate_9[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_9          │ (None, 256, 256,  │          0 │ multiply_8[0][0], │
# │ (Multiply)          │ 64)               │            │ conv2d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 256, 256,  │         65 │ multiply_9[0][0]  │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 9,464,140 (36.10 MB)
#  Trainable params: 9,452,364 (36.06 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %%
class EarlyStoppingByAccuracyChange(tf.keras.callbacks.Callback):
    def __init__(self, monitor='accuracy', threshold=0.00001, patience=3, verbose=0):
        super(EarlyStoppingByAccuracyChange, self).__init__()
        self.monitor = monitor
        self.threshold = threshold
        self.patience = patience
        self.verbose = verbose
        self.wait = 0
        self.best_accuracy = -float('inf')
        self.consecutive_stops = 0

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current_accuracy = logs.get(self.monitor)
        if current_accuracy is None:
            tf.get_logger().warning(
                'Early stopping requires %s available!', self.monitor
            )
            return

        if current_accuracy > self.best_accuracy:
            self.best_accuracy = current_accuracy
            self.wait = 0
            self.consecutive_stops = 0
        else:
            self.wait += 1
            accuracy_change = current_accuracy - self.best_accuracy
            if abs(accuracy_change) < self.threshold:
                self.consecutive_stops += 1
                if self.consecutive_stops >= self.patience:
                    if self.verbose > 0:
                        print(f"Epoch {epoch+1}: Early stopping triggered due to minimal accuracy change for {self.patience} epochs.")
                    self.model.stop_training = True
            else:
                self.consecutive_stops = 0

# %%
initial_lr = 0.001
optimizer = Adam(learning_rate=initial_lr)


segunet = CustomSegUNet(input_size=(256, 256, 1))
segunet.compile(
    optimizer=optimizer,
    loss=dice_loss,
    metrics=['accuracy', jaccard_coefficient]
)
model_checkpoint_dir = 'model'
checkpoint_path = os.path.join(model_checkpoint_dir, 'cp.ckpt')

checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(model_checkpoint_dir, 'gray2750.weights.h5'),
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True,
    verbose=1
)
early_stopping = EarlyStoppingByAccuracyChange(
    monitor='accuracy',
    threshold=0.00001,
    patience=10,
    verbose=1
)
lr_reduction = ReduceLROnPlateau(monitor='loss',
                                  patience=5,
                                  verbose=1,
                                  factor=0.5,
                                  min_lr=0.00001)
start_time = time.time()
history = segunet.fit(
    train_images_gray_clahe, train_masks,
    batch_size=32,
    epochs=100,
    callbacks=[early_stopping, lr_reduction, checkpoint_callback]
)

end_time = time.time()
training_time = end_time - start_time

avg_accuracy = np.mean(history.history['accuracy'])
avg_jaccard = np.mean(history.history['jaccard_coefficient'])

print("SegUNet output shape:", segunet.output_shape)
print(f"⏱️ Thời gian huấn luyện: {training_time:.2f} giây")
print(f"✅ Accuracy trung bình: {avg_accuracy*100:.2f}%")
print(f"🔗 Jaccard trung bình: {avg_jaccard*100:.2f}%")
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1761398163.588517     195 service.cc:148] XLA service 0x781f700866c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1761398163.589155     195 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1761398166.590413     195 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1761398186.650911     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761398186.876652     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761398188.233944     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761398188.445652     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761398189.013527     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761398189.223150     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761398190.233099     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761398190.535429     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761398193.099319     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761398193.517323     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-10-25 13:16:33.667937: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,128,128]{3,2,1,0}, f32[32,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-10-25 13:16:33.773786: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.106032103s
# Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,128,128]{3,2,1,0}, f32[32,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1761398210.926341     195 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 707ms/step - accuracy: 0.5956 - jaccard_coefficient: 0.2317 - loss: 0.6328
# E0000 00:00:1761398259.046719     193 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761398259.280158     193 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761398260.481307     193 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1761398260.713960     193 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5976 - jaccard_coefficient: 0.2333 - loss: 0.6310
# Epoch 1: loss improved from inf to 0.52070, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.5996 - jaccard_coefficient: 0.2348 - loss: 0.6292 - learning_rate: 0.0010
# Epoch 2/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9069 - jaccard_coefficient: 0.5859 - loss: 0.2637
# Epoch 2: loss improved from 0.52070 to 0.22893, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 710ms/step - accuracy: 0.9071 - jaccard_coefficient: 0.5865 - loss: 0.2632 - learning_rate: 0.0010
# Epoch 3/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9226 - jaccard_coefficient: 0.6712 - loss: 0.1980
# Epoch 3: loss improved from 0.22893 to 0.18113, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9228 - jaccard_coefficient: 0.6716 - loss: 0.1977 - learning_rate: 0.0010
# Epoch 4/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9378 - jaccard_coefficient: 0.7340 - loss: 0.1542
# Epoch 4: loss improved from 0.18113 to 0.16029, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9378 - jaccard_coefficient: 0.7338 - loss: 0.1543 - learning_rate: 0.0010
# Epoch 5/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9412 - jaccard_coefficient: 0.7355 - loss: 0.1540
# Epoch 5: loss improved from 0.16029 to 0.15156, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9412 - jaccard_coefficient: 0.7356 - loss: 0.1540 - learning_rate: 0.0010
# Epoch 6/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9417 - jaccard_coefficient: 0.7508 - loss: 0.1432
# Epoch 6: loss improved from 0.15156 to 0.14794, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9417 - jaccard_coefficient: 0.7507 - loss: 0.1432 - learning_rate: 0.0010
# Epoch 7/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9441 - jaccard_coefficient: 0.7493 - loss: 0.1442
# Epoch 7: loss improved from 0.14794 to 0.13609, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9442 - jaccard_coefficient: 0.7495 - loss: 0.1441 - learning_rate: 0.0010
# Epoch 8/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9482 - jaccard_coefficient: 0.7644 - loss: 0.1340
# Epoch 8: loss improved from 0.13609 to 0.13138, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9482 - jaccard_coefficient: 0.7645 - loss: 0.1340 - learning_rate: 0.0010
# Epoch 9/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9461 - jaccard_coefficient: 0.7577 - loss: 0.1385
# Epoch 9: loss did not improve from 0.13138
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9461 - jaccard_coefficient: 0.7578 - loss: 0.1384 - learning_rate: 0.0010
# Epoch 10/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9498 - jaccard_coefficient: 0.7779 - loss: 0.1255
# Epoch 10: loss improved from 0.13138 to 0.12578, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9498 - jaccard_coefficient: 0.7779 - loss: 0.1255 - learning_rate: 0.0010
# Epoch 11/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9543 - jaccard_coefficient: 0.7939 - loss: 0.1153
# Epoch 11: loss improved from 0.12578 to 0.11809, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 710ms/step - accuracy: 0.9543 - jaccard_coefficient: 0.7938 - loss: 0.1154 - learning_rate: 0.0010
# Epoch 12/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9518 - jaccard_coefficient: 0.7840 - loss: 0.1221
# Epoch 12: loss did not improve from 0.11809
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9518 - jaccard_coefficient: 0.7840 - loss: 0.1221 - learning_rate: 0.0010
# Epoch 13/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9543 - jaccard_coefficient: 0.7961 - loss: 0.1140
# Epoch 13: loss improved from 0.11809 to 0.11559, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9543 - jaccard_coefficient: 0.7961 - loss: 0.1141 - learning_rate: 0.0010
# Epoch 14/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9554 - jaccard_coefficient: 0.8022 - loss: 0.1105
# Epoch 14: loss improved from 0.11559 to 0.11196, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9553 - jaccard_coefficient: 0.8021 - loss: 0.1105 - learning_rate: 0.0010
# Epoch 15/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9560 - jaccard_coefficient: 0.7982 - loss: 0.1127
# Epoch 15: loss improved from 0.11196 to 0.11156, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9560 - jaccard_coefficient: 0.7982 - loss: 0.1127 - learning_rate: 0.0010
# Epoch 16/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9581 - jaccard_coefficient: 0.8040 - loss: 0.1091
# Epoch 16: loss improved from 0.11156 to 0.10641, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 710ms/step - accuracy: 0.9580 - jaccard_coefficient: 0.8041 - loss: 0.1091 - learning_rate: 0.0010
# Epoch 17/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9596 - jaccard_coefficient: 0.8242 - loss: 0.0967
# Epoch 17: loss improved from 0.10641 to 0.09978, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9596 - jaccard_coefficient: 0.8241 - loss: 0.0968 - learning_rate: 0.0010
# Epoch 18/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9610 - jaccard_coefficient: 0.8172 - loss: 0.1010
# Epoch 18: loss improved from 0.09978 to 0.09604, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9610 - jaccard_coefficient: 0.8173 - loss: 0.1009 - learning_rate: 0.0010
# Epoch 19/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9627 - jaccard_coefficient: 0.8284 - loss: 0.0940
# Epoch 19: loss improved from 0.09604 to 0.09391, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9627 - jaccard_coefficient: 0.8284 - loss: 0.0940 - learning_rate: 0.0010
# Epoch 20/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9634 - jaccard_coefficient: 0.8339 - loss: 0.0910
# Epoch 20: loss did not improve from 0.09391
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9634 - jaccard_coefficient: 0.8338 - loss: 0.0910 - learning_rate: 0.0010
# Epoch 21/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9635 - jaccard_coefficient: 0.8360 - loss: 0.0895
# Epoch 21: loss improved from 0.09391 to 0.08947, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9635 - jaccard_coefficient: 0.8360 - loss: 0.0895 - learning_rate: 0.0010
# Epoch 22/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9619 - jaccard_coefficient: 0.8256 - loss: 0.0960
# Epoch 22: loss did not improve from 0.08947
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9619 - jaccard_coefficient: 0.8256 - loss: 0.0960 - learning_rate: 0.0010
# Epoch 23/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9643 - jaccard_coefficient: 0.8385 - loss: 0.0882
# Epoch 23: loss improved from 0.08947 to 0.08900, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9643 - jaccard_coefficient: 0.8385 - loss: 0.0882 - learning_rate: 0.0010
# Epoch 24/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9616 - jaccard_coefficient: 0.8260 - loss: 0.0957
# Epoch 24: loss did not improve from 0.08900
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9616 - jaccard_coefficient: 0.8261 - loss: 0.0956 - learning_rate: 0.0010
# Epoch 25/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9664 - jaccard_coefficient: 0.8451 - loss: 0.0842
# Epoch 25: loss improved from 0.08900 to 0.08543, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9664 - jaccard_coefficient: 0.8450 - loss: 0.0842 - learning_rate: 0.0010
# Epoch 26/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9653 - jaccard_coefficient: 0.8419 - loss: 0.0860
# Epoch 26: loss improved from 0.08543 to 0.08395, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9653 - jaccard_coefficient: 0.8420 - loss: 0.0859 - learning_rate: 0.0010
# Epoch 27/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9673 - jaccard_coefficient: 0.8489 - loss: 0.0821
# Epoch 27: loss improved from 0.08395 to 0.08394, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9673 - jaccard_coefficient: 0.8488 - loss: 0.0822 - learning_rate: 0.0010
# Epoch 28/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9669 - jaccard_coefficient: 0.8522 - loss: 0.0800
# Epoch 28: loss improved from 0.08394 to 0.07809, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9669 - jaccard_coefficient: 0.8523 - loss: 0.0799 - learning_rate: 0.0010
# Epoch 29/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9692 - jaccard_coefficient: 0.8604 - loss: 0.0752
# Epoch 29: loss improved from 0.07809 to 0.07806, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9692 - jaccard_coefficient: 0.8603 - loss: 0.0752 - learning_rate: 0.0010
# Epoch 30/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9687 - jaccard_coefficient: 0.8572 - loss: 0.0771
# Epoch 30: loss improved from 0.07806 to 0.07709, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9687 - jaccard_coefficient: 0.8572 - loss: 0.0771 - learning_rate: 0.0010
# Epoch 31/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9694 - jaccard_coefficient: 0.8554 - loss: 0.0784
# Epoch 31: loss improved from 0.07709 to 0.07612, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9694 - jaccard_coefficient: 0.8555 - loss: 0.0783 - learning_rate: 0.0010
# Epoch 32/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9698 - jaccard_coefficient: 0.8609 - loss: 0.0749
# Epoch 32: loss improved from 0.07612 to 0.07343, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9698 - jaccard_coefficient: 0.8610 - loss: 0.0749 - learning_rate: 0.0010
# Epoch 33/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9709 - jaccard_coefficient: 0.8647 - loss: 0.0728
# Epoch 33: loss improved from 0.07343 to 0.07299, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9709 - jaccard_coefficient: 0.8647 - loss: 0.0728 - learning_rate: 0.0010
# Epoch 34/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9721 - jaccard_coefficient: 0.8735 - loss: 0.0676
# Epoch 34: loss improved from 0.07299 to 0.07051, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9721 - jaccard_coefficient: 0.8734 - loss: 0.0677 - learning_rate: 0.0010
# Epoch 35/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9714 - jaccard_coefficient: 0.8708 - loss: 0.0692
# Epoch 35: loss did not improve from 0.07051
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9714 - jaccard_coefficient: 0.8707 - loss: 0.0692 - learning_rate: 0.0010
# Epoch 36/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9734 - jaccard_coefficient: 0.8715 - loss: 0.0687
# Epoch 36: loss improved from 0.07051 to 0.06984, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9733 - jaccard_coefficient: 0.8715 - loss: 0.0687 - learning_rate: 0.0010
# Epoch 37/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9716 - jaccard_coefficient: 0.8667 - loss: 0.0716
# Epoch 37: loss improved from 0.06984 to 0.06870, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9716 - jaccard_coefficient: 0.8668 - loss: 0.0715 - learning_rate: 0.0010
# Epoch 38/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9743 - jaccard_coefficient: 0.8793 - loss: 0.0644
# Epoch 38: loss improved from 0.06870 to 0.06620, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 710ms/step - accuracy: 0.9743 - jaccard_coefficient: 0.8792 - loss: 0.0644 - learning_rate: 0.0010
# Epoch 39/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9737 - jaccard_coefficient: 0.8814 - loss: 0.0631
# Epoch 39: loss improved from 0.06620 to 0.06450, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9737 - jaccard_coefficient: 0.8814 - loss: 0.0632 - learning_rate: 0.0010
# Epoch 40/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9726 - jaccard_coefficient: 0.8749 - loss: 0.0669
# Epoch 40: loss did not improve from 0.06450
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9726 - jaccard_coefficient: 0.8748 - loss: 0.0669 - learning_rate: 0.0010
# Epoch 41/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.9745 - jaccard_coefficient: 0.8801 - loss: 0.0639
# Epoch 41: loss did not improve from 0.06450
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9745 - jaccard_coefficient: 0.8801 - loss: 0.0639 - learning_rate: 0.0010
# Epoch 42/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9749 - jaccard_coefficient: 0.8818 - loss: 0.0630
# Epoch 42: loss improved from 0.06450 to 0.06163, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9749 - jaccard_coefficient: 0.8818 - loss: 0.0630 - learning_rate: 0.0010
# Epoch 43/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.9753 - jaccard_coefficient: 0.8843 - loss: 0.0615
# Epoch 43: loss did not improve from 0.06163
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9753 - jaccard_coefficient: 0.8843 - loss: 0.0615 - learning_rate: 0.0010
# Epoch 44/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.9746 - jaccard_coefficient: 0.8846 - loss: 0.0613
# Epoch 44: loss improved from 0.06163 to 0.06163, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 707ms/step - accuracy: 0.9746 - jaccard_coefficient: 0.8846 - loss: 0.0613 - learning_rate: 0.0010
# Epoch 45/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9759 - jaccard_coefficient: 0.8851 - loss: 0.0611
# Epoch 45: loss improved from 0.06163 to 0.05918, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9759 - jaccard_coefficient: 0.8851 - loss: 0.0610 - learning_rate: 0.0010
# Epoch 46/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9757 - jaccard_coefficient: 0.8881 - loss: 0.0593
# Epoch 46: loss improved from 0.05918 to 0.05799, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9757 - jaccard_coefficient: 0.8881 - loss: 0.0593 - learning_rate: 0.0010
# Epoch 47/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9770 - jaccard_coefficient: 0.8934 - loss: 0.0564
# Epoch 47: loss did not improve from 0.05799
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9770 - jaccard_coefficient: 0.8934 - loss: 0.0564 - learning_rate: 0.0010
# Epoch 48/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9770 - jaccard_coefficient: 0.8938 - loss: 0.0562
# Epoch 48: loss improved from 0.05799 to 0.05666, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9770 - jaccard_coefficient: 0.8938 - loss: 0.0562 - learning_rate: 0.0010
# Epoch 49/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9766 - jaccard_coefficient: 0.8916 - loss: 0.0574
# Epoch 49: loss did not improve from 0.05666
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9766 - jaccard_coefficient: 0.8916 - loss: 0.0574 - learning_rate: 0.0010
# Epoch 50/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9761 - jaccard_coefficient: 0.8903 - loss: 0.0582
# Epoch 50: loss did not improve from 0.05666
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9761 - jaccard_coefficient: 0.8903 - loss: 0.0582 - learning_rate: 0.0010
# Epoch 51/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9775 - jaccard_coefficient: 0.8926 - loss: 0.0568
# Epoch 51: loss did not improve from 0.05666
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9775 - jaccard_coefficient: 0.8925 - loss: 0.0569 - learning_rate: 0.0010
# Epoch 52/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9758 - jaccard_coefficient: 0.8844 - loss: 0.0615
# Epoch 52: loss did not improve from 0.05666
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9758 - jaccard_coefficient: 0.8845 - loss: 0.0615 - learning_rate: 0.0010
# Epoch 53/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9774 - jaccard_coefficient: 0.8903 - loss: 0.0582
# Epoch 53: loss improved from 0.05666 to 0.05589, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9774 - jaccard_coefficient: 0.8904 - loss: 0.0581 - learning_rate: 0.0010
# Epoch 54/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9788 - jaccard_coefficient: 0.9038 - loss: 0.0506
# Epoch 54: loss improved from 0.05589 to 0.05360, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9788 - jaccard_coefficient: 0.9037 - loss: 0.0507 - learning_rate: 0.0010
# Epoch 55/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9782 - jaccard_coefficient: 0.8976 - loss: 0.0540
# Epoch 55: loss did not improve from 0.05360
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9781 - jaccard_coefficient: 0.8976 - loss: 0.0540 - learning_rate: 0.0010
# Epoch 56/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9774 - jaccard_coefficient: 0.8915 - loss: 0.0575
# Epoch 56: loss did not improve from 0.05360
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9774 - jaccard_coefficient: 0.8916 - loss: 0.0574 - learning_rate: 0.0010
# Epoch 57/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9797 - jaccard_coefficient: 0.9064 - loss: 0.0492
# Epoch 57: loss improved from 0.05360 to 0.04988, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9797 - jaccard_coefficient: 0.9063 - loss: 0.0492 - learning_rate: 0.0010
# Epoch 58/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9783 - jaccard_coefficient: 0.8992 - loss: 0.0533
# Epoch 58: loss did not improve from 0.04988
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9783 - jaccard_coefficient: 0.8993 - loss: 0.0532 - learning_rate: 0.0010
# Epoch 59/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.9810 - jaccard_coefficient: 0.9123 - loss: 0.0459
# Epoch 59: loss improved from 0.04988 to 0.04796, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9810 - jaccard_coefficient: 0.9122 - loss: 0.0460 - learning_rate: 0.0010
# Epoch 60/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9801 - jaccard_coefficient: 0.9094 - loss: 0.0475
# Epoch 60: loss improved from 0.04796 to 0.04793, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9801 - jaccard_coefficient: 0.9094 - loss: 0.0475 - learning_rate: 0.0010
# Epoch 61/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9796 - jaccard_coefficient: 0.9066 - loss: 0.0491
# Epoch 61: loss improved from 0.04793 to 0.04737, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9796 - jaccard_coefficient: 0.9066 - loss: 0.0491 - learning_rate: 0.0010
# Epoch 62/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9804 - jaccard_coefficient: 0.9086 - loss: 0.0480
# Epoch 62: loss did not improve from 0.04737
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9804 - jaccard_coefficient: 0.9086 - loss: 0.0480 - learning_rate: 0.0010
# Epoch 63/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.9803 - jaccard_coefficient: 0.9082 - loss: 0.0482
# Epoch 63: loss did not improve from 0.04737
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 696ms/step - accuracy: 0.9803 - jaccard_coefficient: 0.9082 - loss: 0.0482 - learning_rate: 0.0010
# Epoch 64/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.9802 - jaccard_coefficient: 0.9045 - loss: 0.0502
# Epoch 64: loss improved from 0.04737 to 0.04715, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9802 - jaccard_coefficient: 0.9046 - loss: 0.0502 - learning_rate: 0.0010
# Epoch 65/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.9808 - jaccard_coefficient: 0.9097 - loss: 0.0473
# Epoch 65: loss did not improve from 0.04715
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 696ms/step - accuracy: 0.9808 - jaccard_coefficient: 0.9097 - loss: 0.0474 - learning_rate: 0.0010
# Epoch 66/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.9802 - jaccard_coefficient: 0.9061 - loss: 0.0494
# Epoch 66: loss did not improve from 0.04715
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 696ms/step - accuracy: 0.9802 - jaccard_coefficient: 0.9061 - loss: 0.0494 - learning_rate: 0.0010
# Epoch 67/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9805 - jaccard_coefficient: 0.9106 - loss: 0.0469
# Epoch 67: loss improved from 0.04715 to 0.04685, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9805 - jaccard_coefficient: 0.9106 - loss: 0.0469 - learning_rate: 0.0010
# Epoch 68/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9822 - jaccard_coefficient: 0.9136 - loss: 0.0452
# Epoch 68: loss improved from 0.04685 to 0.04413, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9822 - jaccard_coefficient: 0.9136 - loss: 0.0452 - learning_rate: 0.0010
# Epoch 69/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9822 - jaccard_coefficient: 0.9160 - loss: 0.0440
# Epoch 69: loss did not improve from 0.04413
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9821 - jaccard_coefficient: 0.9160 - loss: 0.0440 - learning_rate: 0.0010
# Epoch 70/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9806 - jaccard_coefficient: 0.9120 - loss: 0.0461
# Epoch 70: loss did not improve from 0.04413
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9806 - jaccard_coefficient: 0.9120 - loss: 0.0461 - learning_rate: 0.0010
# Epoch 71/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9814 - jaccard_coefficient: 0.9128 - loss: 0.0456
# Epoch 71: loss did not improve from 0.04413
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9814 - jaccard_coefficient: 0.9128 - loss: 0.0456 - learning_rate: 0.0010
# Epoch 72/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9794 - jaccard_coefficient: 0.9117 - loss: 0.0462
# Epoch 72: loss did not improve from 0.04413
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9794 - jaccard_coefficient: 0.9116 - loss: 0.0462 - learning_rate: 0.0010
# Epoch 73/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9622 - jaccard_coefficient: 0.8247 - loss: 0.0968
# Epoch 73: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 73: loss did not improve from 0.04413
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9622 - jaccard_coefficient: 0.8248 - loss: 0.0967 - learning_rate: 0.0010
# Epoch 74/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9745 - jaccard_coefficient: 0.8840 - loss: 0.0617
# Epoch 74: loss did not improve from 0.04413
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9745 - jaccard_coefficient: 0.8841 - loss: 0.0616 - learning_rate: 5.0000e-04
# Epoch 75/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9796 - jaccard_coefficient: 0.9036 - loss: 0.0508
# Epoch 75: loss did not improve from 0.04413
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9796 - jaccard_coefficient: 0.9036 - loss: 0.0508 - learning_rate: 5.0000e-04
# Epoch 76/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9808 - jaccard_coefficient: 0.9126 - loss: 0.0458
# Epoch 76: loss did not improve from 0.04413
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9808 - jaccard_coefficient: 0.9126 - loss: 0.0458 - learning_rate: 5.0000e-04
# Epoch 77/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9824 - jaccard_coefficient: 0.9184 - loss: 0.0426
# Epoch 77: loss improved from 0.04413 to 0.04230, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 709ms/step - accuracy: 0.9824 - jaccard_coefficient: 0.9184 - loss: 0.0426 - learning_rate: 5.0000e-04
# Epoch 78/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9838 - jaccard_coefficient: 0.9225 - loss: 0.0403
# Epoch 78: loss improved from 0.04230 to 0.04074, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9838 - jaccard_coefficient: 0.9225 - loss: 0.0403 - learning_rate: 5.0000e-04
# Epoch 79/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.9834 - jaccard_coefficient: 0.9228 - loss: 0.0402
# Epoch 79: loss improved from 0.04074 to 0.04069, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 707ms/step - accuracy: 0.9834 - jaccard_coefficient: 0.9227 - loss: 0.0403 - learning_rate: 5.0000e-04
# Epoch 80/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9840 - jaccard_coefficient: 0.9278 - loss: 0.0375
# Epoch 80: loss improved from 0.04069 to 0.03841, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9840 - jaccard_coefficient: 0.9278 - loss: 0.0375 - learning_rate: 5.0000e-04
# Epoch 81/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9841 - jaccard_coefficient: 0.9277 - loss: 0.0375
# Epoch 81: loss improved from 0.03841 to 0.03791, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9841 - jaccard_coefficient: 0.9277 - loss: 0.0375 - learning_rate: 5.0000e-04
# Epoch 82/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9841 - jaccard_coefficient: 0.9249 - loss: 0.0391
# Epoch 82: loss did not improve from 0.03791
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9841 - jaccard_coefficient: 0.9250 - loss: 0.0391 - learning_rate: 5.0000e-04
# Epoch 83/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9849 - jaccard_coefficient: 0.9295 - loss: 0.0366
# Epoch 83: loss improved from 0.03791 to 0.03712, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9849 - jaccard_coefficient: 0.9295 - loss: 0.0366 - learning_rate: 5.0000e-04
# Epoch 84/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.9838 - jaccard_coefficient: 0.9275 - loss: 0.0377
# Epoch 84: loss did not improve from 0.03712
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9839 - jaccard_coefficient: 0.9275 - loss: 0.0377 - learning_rate: 5.0000e-04
# Epoch 85/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 696ms/step - accuracy: 0.9851 - jaccard_coefficient: 0.9323 - loss: 0.0350
# Epoch 85: loss improved from 0.03712 to 0.03585, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9851 - jaccard_coefficient: 0.9323 - loss: 0.0351 - learning_rate: 5.0000e-04
# Epoch 86/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9846 - jaccard_coefficient: 0.9292 - loss: 0.0367
# Epoch 86: loss did not improve from 0.03585
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9846 - jaccard_coefficient: 0.9293 - loss: 0.0367 - learning_rate: 5.0000e-04
# Epoch 87/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9859 - jaccard_coefficient: 0.9348 - loss: 0.0337
# Epoch 87: loss improved from 0.03585 to 0.03438, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9859 - jaccard_coefficient: 0.9348 - loss: 0.0337 - learning_rate: 5.0000e-04
# Epoch 88/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9857 - jaccard_coefficient: 0.9329 - loss: 0.0347
# Epoch 88: loss did not improve from 0.03438
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9857 - jaccard_coefficient: 0.9329 - loss: 0.0347 - learning_rate: 5.0000e-04
# Epoch 89/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9863 - jaccard_coefficient: 0.9345 - loss: 0.0339
# Epoch 89: loss improved from 0.03438 to 0.03369, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9862 - jaccard_coefficient: 0.9345 - loss: 0.0339 - learning_rate: 5.0000e-04
# Epoch 90/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9857 - jaccard_coefficient: 0.9317 - loss: 0.0354
# Epoch 90: loss did not improve from 0.03369
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9857 - jaccard_coefficient: 0.9317 - loss: 0.0353 - learning_rate: 5.0000e-04
# Epoch 91/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 698ms/step - accuracy: 0.9860 - jaccard_coefficient: 0.9322 - loss: 0.0351
# Epoch 91: loss did not improve from 0.03369
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 698ms/step - accuracy: 0.9860 - jaccard_coefficient: 0.9322 - loss: 0.0351 - learning_rate: 5.0000e-04
# Epoch 92/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9862 - jaccard_coefficient: 0.9361 - loss: 0.0330
# Epoch 92: loss improved from 0.03369 to 0.03280, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9862 - jaccard_coefficient: 0.9361 - loss: 0.0330 - learning_rate: 5.0000e-04
# Epoch 93/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9859 - jaccard_coefficient: 0.9336 - loss: 0.0343
# Epoch 93: loss did not improve from 0.03280
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9859 - jaccard_coefficient: 0.9337 - loss: 0.0343 - learning_rate: 5.0000e-04
# Epoch 94/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9865 - jaccard_coefficient: 0.9379 - loss: 0.0321
# Epoch 94: loss improved from 0.03280 to 0.03237, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9865 - jaccard_coefficient: 0.9378 - loss: 0.0321 - learning_rate: 5.0000e-04
# Epoch 95/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9861 - jaccard_coefficient: 0.9332 - loss: 0.0346
# Epoch 95: loss did not improve from 0.03237
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9861 - jaccard_coefficient: 0.9332 - loss: 0.0346 - learning_rate: 5.0000e-04
# Epoch 96/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9858 - jaccard_coefficient: 0.9356 - loss: 0.0333
# Epoch 96: loss did not improve from 0.03237
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9858 - jaccard_coefficient: 0.9356 - loss: 0.0333 - learning_rate: 5.0000e-04
# Epoch 97/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9857 - jaccard_coefficient: 0.9348 - loss: 0.0337
# Epoch 97: loss did not improve from 0.03237
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9857 - jaccard_coefficient: 0.9348 - loss: 0.0337 - learning_rate: 5.0000e-04
# Epoch 98/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9858 - jaccard_coefficient: 0.9320 - loss: 0.0352
# Epoch 98: loss did not improve from 0.03237
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 697ms/step - accuracy: 0.9858 - jaccard_coefficient: 0.9320 - loss: 0.0352 - learning_rate: 5.0000e-04
# Epoch 99/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9867 - jaccard_coefficient: 0.9378 - loss: 0.0321
# Epoch 99: loss improved from 0.03237 to 0.03199, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9867 - jaccard_coefficient: 0.9378 - loss: 0.0321 - learning_rate: 5.0000e-04
# Epoch 100/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - accuracy: 0.9867 - jaccard_coefficient: 0.9397 - loss: 0.0311
# Epoch 100: loss improved from 0.03199 to 0.03145, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 43s 708ms/step - accuracy: 0.9867 - jaccard_coefficient: 0.9397 - loss: 0.0311 - learning_rate: 5.0000e-04
# SegUNet output shape: (None, 256, 256, 1)
# ⏱️ Thời gian huấn luyện: 4401.98 giây
# ✅ Accuracy trung bình: 96.98%
# 🔗 Jaccard trung bình: 86.81%

# %%
acc = history.history['accuracy']
loss = history.history['loss']
epochs_range = range(1, len(acc) + 1)
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Accuracy', color='green')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Loss', color='red')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.savefig('Gray_2750_acc_loss.png', dpi=300)
plt.show()

# %%
def apply_morphology(mask, kernel_size=3, iterations=1):
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))
    mask = (mask > 0.5).astype(np.uint8)  

    closed = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=iterations)

    opened = cv2.morphologyEx(closed, cv2.MORPH_OPEN, kernel, iterations=iterations)

    return opened.astype(np.float32)  

print("🔍 Đánh giá không hậu xử lý...")
results = segunet.evaluate(test_images_gray_clahe, test_masks, verbose=1)
loss, accuracy, jaccard = results
print(f"Không hậu xử lý - Dice Loss: {loss:.4f}, Accuracy: {accuracy*100:.2f}%, Jaccard: {jaccard*100:.2f}%")

print("\n🔧 Đánh giá sau Morphology...")
predictions1 = segunet.predict(test_images_gray_clahe)
refined_predictions1 = []

for i in tqdm(range(len(test_images_gray_clahe))):
    pred = predictions1[i].squeeze()
    morph_pred = apply_morphology(pred, kernel_size=7, iterations=2)

    refined_predictions1.append(morph_pred)

refined_predictions1 = np.expand_dims(np.array(refined_predictions1), axis=-1)

accuracy_after = np_accuracy(test_masks, refined_predictions1)
jaccard_after = np_jaccard_coefficient(test_masks, refined_predictions1)
loss_after = np_dice_loss(test_masks, refined_predictions1)

print(f"Sau Morphology - Dice Loss: {loss_after:.4f}, Accuracy: {accuracy_after*100:.2f}%, Jaccard: {jaccard_after*100:.2f}%")
# Out:
# 🔍 Đánh giá không hậu xử lý...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 0.9546 - jaccard_coefficient: 0.8043 - loss: 0.1108
# Không hậu xử lý - Dice Loss: 0.1463, Accuracy: 94.94%, Jaccard: 75.00%
#
# 🔧 Đánh giá sau Morphology...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step
# 100%|██████████| 825/825 [00:00<00:00, 1768.60it/s]
# Sau Morphology - Dice Loss: 0.1284, Accuracy: 94.94%, Jaccard: 77.24%

# %%
segunet.save('/kaggle/working/model/2.0-gray_2750_model.h5')
segunet.save('/kaggle/working/model/2.0-gray_2750_model.keras')
