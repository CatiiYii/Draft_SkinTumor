# %%
# !pip install scipy==1.10.1
# !pip install scikit-learn --upgrade

import os
import numpy as np
import tensorflow as tf
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
# !pip install opencv-contrib-python
# !pip install tensorflow-addons

import cv2
import time
import json
import shutil
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm

import pydensecrf.densecrf as dcrf
from pydensecrf.utils import unary_from_softmax, create_pairwise_bilateral
import tensorflow.keras.layers as L
import tensorflow.keras.backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.activations import swish
from tensorflow.keras.regularizers import l2
from tensorflow.keras.initializers import HeNormal

from tensorflow.keras.layers import (
    Layer, 
    Input, 
    Conv2D, 
    BatchNormalization, 
    Lambda, 
    Concatenate,
    SeparableConv2D, 
    MaxPooling2D, 
    UpSampling2D, 
    Conv2DTranspose,
    SpatialDropout2D, 
    ReLU, 
    GlobalAveragePooling2D, 
    Add,
    GlobalMaxPooling2D, 
    Dense, 
    Reshape, 
    Multiply, 
    Activation
)
# Out:
# Collecting scipy==1.10.1
#   Downloading scipy-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /usr/local/lib/python3.11/dist-packages (from scipy==1.10.1) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy<1.27.0,>=1.19.5->scipy==1.10.1) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy<1.27.0,>=1.19.5->scipy==1.10.1) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy<1.27.0,>=1.19.5->scipy==1.10.1) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy<1.27.0,>=1.19.5->scipy==1.10.1) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy<1.27.0,>=1.19.5->scipy==1.10.1) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy<1.27.0,>=1.19.5->scipy==1.10.1) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<1.27.0,>=1.19.5->scipy==1.10.1) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy<1.27.0,>=1.19.5->scipy==1.10.1) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy<1.27.0,>=1.19.5->scipy==1.10.1) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy<1.27.0,>=1.19.5->scipy==1.10.1) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy<1.27.0,>=1.19.5->scipy==1.10.1) (2024.2.0)
# Downloading scipy-1.10.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.1/34.1 MB 53.4 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.15.2
#     Uninstalling scipy-1.15.2:
#       Successfully uninstalled scipy-1.15.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.10.1 which is incompatible.
# nilearn 0.11.1 requires scikit-learn>=1.4.0, but you have scikit-learn 1.2.2 which is incompatible.
# kaggle-environments 1.16.11 requires scipy>=1.11.2, but you have scipy 1.10.1 which is incompatible.
# scikit-image 0.25.1 requires scipy>=1.11.2, but you have scipy 1.10.1 which is incompatible.
# bigframes 1.36.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# imbalanced-learn 0.13.0 requires scikit-learn<2,>=1.3.2, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed scipy-1.10.1
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.2.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.1->scikit-learn) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.1->scikit-learn) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.1->scikit-learn) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.1->scikit-learn) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.1->scikit-learn) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.24.1->scikit-learn) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24.1->scikit-learn) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.24.1->scikit-learn) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.24.1->scikit-learn) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.24.1->scikit-learn) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.24.1->scikit-learn) (2024.2.0)
# Downloading scikit_learn-1.8.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 72.1 MB/s eta 0:00:00:00:010:01
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.10.1 which is incompatible.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.8.0 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.8.0 which is incompatible.
# bigframes 1.36.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# Successfully installed scikit-learn-1.8.0
# 2025-12-13 17:36:01.131101: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765647361.351466      33 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765647361.410347      33 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Collecting git+https://github.com/lucasb-eyer/pydensecrf.git
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-9e_eep3f
#   Running command git clone --filter=blob:none --quiet https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-9e_eep3f
#   Resolved https://github.com/lucasb-eyer/pydensecrf.git to commit 2723c7fa4f2ead16ae1ce3d8afe977724bb8f87f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pydensecrf
#   Building wheel for pydensecrf (pyproject.toml) ... done
#   Created wheel for pydensecrf: filename=pydensecrf-1.0-cp311-cp311-linux_x86_64.whl size=3440331 sha256=e2e0b1aabc55a55004894838fb5d2b1411075c4c742f67404822855f401e3105
#   Stored in directory: /tmp/pip-ephem-wheel-cache-an8vbbf_/wheels/ce/8e/34/6dcfa200a9e2ae3627d8009b8bd1ca9b24512bec50a93304de
# Successfully built pydensecrf
# Installing collected packages: pydensecrf
# Successfully installed pydensecrf-1.0
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-contrib-python) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (24.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 10.5 MB/s eta 0:00:00 0:00:01
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.1
#     Uninstalling typeguard-4.4.1:
#       Successfully uninstalled typeguard-4.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.16.1 requires typeguard<5,>=3, but you have typeguard 2.13.3 which is incompatible.
# inflect 7.5.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3

# %%
working_dir = '/kaggle/working'
for item in os.listdir(working_dir):
    item_path = os.path.join(working_dir, item)
    try:
        if os.path.isfile(item_path) or os.path.islink(item_path):
            os.unlink(item_path)  
        elif os.path.isdir(item_path):
            shutil.rmtree(item_path)  
            print(f"❌ xóa thành công {item_path}")
    except Exception as e:
        print(f"Lỗi khi xóa {item_path}: {e}")
# Out:
# ❌ xóa thành công /kaggle/working/.virtual_documents

# %%
def load_isic_dataset(image_path, mask_path, binary_path, csv_file, img_size=(256, 256)):
    image_files = sorted(glob(os.path.join(image_path, "ISIC_*.jpg")))

    images = []
    masks = []
    binary_masks = {}
    image_ids = []
    labels = []

    csv_data = pd.read_csv(csv_file)
    mel_label = csv_data['melanoma'].astype("int64")

    print("Đang đọc và xử lý dữ liệu...")
    for index, img_path in enumerate(tqdm(image_files)):
        img_id = os.path.basename(img_path).split('.')[0]
        mask_file = os.path.join(mask_path, f"{img_id}_segmentation.png")
        binary_file = os.path.join(binary_path, f"{img_id}_features.json")

        if not os.path.exists(mask_file):
            print(f"Không tìm thấy mask cho ảnh mặt nạ {img_id}_segmentation.png")
            continue
        if not os.path.exists(binary_file):
            print(f"Không tìm thấy mask nhị phân cho ảnh {img_id}_features.json")
            continue

        try:      
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
   
            mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)

            img = cv2.resize(img, img_size)
            mask = cv2.resize(mask, img_size)

            img = img / 255.0
            mask = mask / 255.0

            with open(binary_file, 'r') as f:
                binary_masks[img_id] = json.load(f)

            label = mel_label[index]

            images.append(img)
            masks.append(mask)
            image_ids.append(img_id)
            labels.append(label.astype("long"))

        except Exception as e:
            print(f"Lỗi khi xử lý ảnh {img_id}: {str(e)}")
            continue
   
    images = np.array(images)
    masks = np.array(masks)[..., np.newaxis]  
    labels = np.array(labels)

    print(f"\nĐã đọc thành công {len(images)} ảnh")
    print(f"Shape của images: {images.shape}")
    print(f"Shape của masks: {masks.shape}")
    print(f"Shape của labels: {labels.shape}")

    return images, masks, binary_masks, image_ids, labels

# %%
train_images, train_masks, train_binarys, train_image_ids, train_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2750/Train_Data',
    mask_path='/kaggle/input/isic-2750/Train_GroundTruth_1',
    binary_path='/kaggle/input/isic-2750/Train_GroundTruth_2',
    csv_file="/kaggle/input/2075-csv/Train_GroundTruth_3.csv",
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 1925/1925 [05:11<00:00,  6.17it/s]
# Đã đọc thành công 1925 ảnh
# Shape của images: (1925, 256, 256, 3)
# Shape của masks: (1925, 256, 256, 1)
# Shape của labels: (1925,)

# %%
test_images, test_masks, test_binarys, test_image_ids, test_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2750/Test_Data',
    mask_path='/kaggle/input/isic-2750/Test_GroundTruth_1',
    binary_path='/kaggle/input/isic-2750/Test_GroundTruth_2',
    csv_file='/kaggle/input/2075-csv/Test_GroundTruth_3 (1).csv',
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 825/825 [01:56<00:00,  7.09it/s]
# Đã đọc thành công 825 ảnh
# Shape của images: (825, 256, 256, 3)
# Shape của masks: (825, 256, 256, 1)
# Shape của labels: (825,)

# %%
def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = (intersection + 1e-7) / (union + 1e-7)
    return iou

# %%
def compute_metric(y_true, y_pred, metric='dice_coefficient', smooth=1e-6, is_numpy=False):
    y_true_f = y_true.flatten() if is_numpy else K.flatten(y_true)
    y_pred_f = y_pred.flatten() if is_numpy else K.flatten(y_pred)
    intersection = np.sum(y_true_f * y_pred_f) if is_numpy else K.sum(y_true_f * y_pred_f)

    if 'dice' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        score = (2. * intersection + smooth) / (sum_fn(y_true_f) + sum_fn(y_pred_f) + smooth)
    elif 'jaccard' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        union = sum_fn(y_true_f) + sum_fn(y_pred_f) - intersection
        score = (intersection + smooth) / (union + smooth)
    else:
        raise ValueError(f"Unsupported metric: {metric}")

    return score if 'coefficient' in metric else 1 - score

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth)

def dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth)

def jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth)

def jaccard_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_loss', smooth)

def np_accuracy(y_true, y_pred):
    return np.mean(y_true.flatten() == y_pred.flatten())

def np_dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth, is_numpy=True)

def np_jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth, is_numpy=True)

def np_dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth, is_numpy=True)

# %%
def conv_block(x, num_filters):
    x = L.Conv2D(num_filters, 3, padding="same")(x)
    x = L.BatchNormalization()(x)
    x = L.Activation("relu")(x)

    x = L.Conv2D(num_filters, 3, padding="same")(x)
    x = L.BatchNormalization()(x)
    x = L.Activation("relu")(x)

    return x

def encoder_block(x, num_filters):
    x = conv_block(x, num_filters)
    p = L.MaxPool2D((2, 2))(x)
    return x, p

def attention_gate(g, s, num_filters):
    Wg = L.Conv2D(num_filters, 1, padding="same")(g)

    Ws = L.Conv2D(num_filters, 1, padding="same")(s)

    out = L.Activation("relu")(Wg + Ws)

    psi = L.Conv2D(1, 1, padding="same", activation="sigmoid")(out)

    return psi * s

def decoder_block(x, s, num_filters):
    x = L.UpSampling2D(interpolation="bilinear")(x)
    s = attention_gate(x, s, num_filters)
    x = L.Concatenate()([x, s])
    x = conv_block(x, num_filters)
    return x

def attention_unet(input_shape):
    inputs = L.Input(input_shape)

    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)

    b1 = conv_block(p3, 512)

    d1 = decoder_block(b1, s3, 256)
    d2 = decoder_block(d1, s2, 128)
    d3 = decoder_block(d2, s1, 64)

    outputs = L.Conv2D(1, 1, padding="same", activation="sigmoid")(d3)
  
    model = Model(inputs, outputs, name="Attention-UNET")
    return model

if __name__ == "__main__":
    input_shape = (256, 256, 1)
    model = attention_unet(input_shape)
    model.summary()
# Out:
# I0000 00:00:1765647857.541114      33 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1765647857.541735      33 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "Attention-UNET"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 1)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 64)   │            640 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 64)   │            256 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 256, 256, 64)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 256, 256, 64)   │         36,928 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256, 256, 64)   │            256 │ conv2d_1[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ activation_1[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 128, 128, 128)  │            512 │ conv2d_2[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 128)  │        147,584 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 128, 128, 128)  │            512 │ conv2d_3[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 128)    │              0 │ activation_3[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 64, 64, 256)    │          1,024 │ conv2d_4[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 64, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 64, 64, 256)    │        590,080 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 64, 64, 256)    │          1,024 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 64, 64, 256)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ activation_5[0][0]     │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 32, 32, 512)    │          2,048 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 32, 32, 512)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 32, 32, 512)    │      2,359,808 │ activation_6[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 32, 32, 512)    │          2,048 │ conv2d_7[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 32, 32, 512)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d             │ (None, 64, 64, 512)    │              0 │ activation_7[0][0]     │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 64, 64, 256)    │        131,328 │ up_sampling2d[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_9 (Conv2D)         │ (None, 64, 64, 256)    │         65,792 │ activation_5[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 64, 64, 256)    │              0 │ conv2d_8[0][0],        │
# │                           │                        │                │ conv2d_9[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 64, 64, 256)    │              0 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_10 (Conv2D)        │ (None, 64, 64, 1)      │            257 │ activation_8[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 64, 64, 256)    │              0 │ conv2d_10[0][0],       │
# │                           │                        │                │ activation_5[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 64, 64, 768)    │              0 │ up_sampling2d[0][0],   │
# │                           │                        │                │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_11 (Conv2D)        │ (None, 64, 64, 256)    │      1,769,728 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 64, 64, 256)    │          1,024 │ conv2d_11[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 64, 64, 256)    │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_12 (Conv2D)        │ (None, 64, 64, 256)    │        590,080 │ activation_9[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 64, 64, 256)    │          1,024 │ conv2d_12[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 64, 64, 256)    │              0 │ batch_normalization_9… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_1           │ (None, 128, 128, 256)  │              0 │ activation_10[0][0]    │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_13 (Conv2D)        │ (None, 128, 128, 128)  │         32,896 │ up_sampling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_14 (Conv2D)        │ (None, 128, 128, 128)  │         16,512 │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 128, 128, 128)  │              0 │ conv2d_13[0][0],       │
# │                           │                        │                │ conv2d_14[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 128, 128, 128)  │              0 │ add_1[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_15 (Conv2D)        │ (None, 128, 128, 1)    │            129 │ activation_11[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_1 (Multiply)     │ (None, 128, 128, 128)  │              0 │ conv2d_15[0][0],       │
# │                           │                        │                │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 128, 128, 384)  │              0 │ up_sampling2d_1[0][0], │
# │ (Concatenate)             │                        │                │ multiply_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_16 (Conv2D)        │ (None, 128, 128, 128)  │        442,496 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 128, 128, 128)  │            512 │ conv2d_16[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 128, 128, 128)  │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_17 (Conv2D)        │ (None, 128, 128, 128)  │        147,584 │ activation_12[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 128, 128, 128)  │            512 │ conv2d_17[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 128, 128, 128)  │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_2           │ (None, 256, 256, 128)  │              0 │ activation_13[0][0]    │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_18 (Conv2D)        │ (None, 256, 256, 64)   │          8,256 │ up_sampling2d_2[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_19 (Conv2D)        │ (None, 256, 256, 64)   │          4,160 │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 256, 256, 64)   │              0 │ conv2d_18[0][0],       │
# │                           │                        │                │ conv2d_19[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 256, 256, 64)   │              0 │ add_2[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_20 (Conv2D)        │ (None, 256, 256, 1)    │             65 │ activation_14[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_2 (Multiply)     │ (None, 256, 256, 64)   │              0 │ conv2d_20[0][0],       │
# │                           │                        │                │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 256, 256, 192)  │              0 │ up_sampling2d_2[0][0], │
# │ (Concatenate)             │                        │                │ multiply_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_21 (Conv2D)        │ (None, 256, 256, 64)   │        110,656 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 256, 256, 64)   │            256 │ conv2d_21[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_15             │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_22 (Conv2D)        │ (None, 256, 256, 64)   │         36,928 │ activation_15[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 256, 256, 64)   │            256 │ conv2d_22[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_16             │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_23 (Conv2D)        │ (None, 256, 256, 1)    │             65 │ activation_16[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 8,052,420 (30.72 MB)
#  Trainable params: 8,046,788 (30.70 MB)
#  Non-trainable params: 5,632 (22.00 KB)

# %%
class EarlyStoppingByAccuracyChange(tf.keras.callbacks.Callback):
    def __init__(self, monitor='accuracy', threshold=0.00001, patience=3, verbose=0):
        super(EarlyStoppingByAccuracyChange, self).__init__()
        self.monitor = monitor
        self.threshold = threshold
        self.patience = patience
        self.verbose = verbose
        self.wait = 0
        self.best_accuracy = -float('inf')
        self.consecutive_stops = 0

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current_accuracy = logs.get(self.monitor)
        if current_accuracy is None:
            tf.get_logger().warning(
                'Early stopping requires %s available!', self.monitor
            )
            return

        if current_accuracy > self.best_accuracy:
            self.best_accuracy = current_accuracy
            self.wait = 0
            self.consecutive_stops = 0
        else:
            self.wait += 1
            accuracy_change = current_accuracy - self.best_accuracy
            if abs(accuracy_change) < self.threshold:
                self.consecutive_stops += 1
                if self.consecutive_stops >= self.patience:
                    if self.verbose > 0:
                        print(f"Epoch {epoch+1}: Early stopping triggered due to minimal accuracy change for {self.patience} epochs.")
                    self.model.stop_training = True
            else:
                self.consecutive_stops = 0

# %%
pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-contrib-python) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def convert_to_gray_clahe(images):
    grays = []
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))  

    for img in images:
        if img.dtype != np.uint8:
            img = (img * 255).astype(np.uint8)
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)  

        img_clahe = clahe.apply(gray)  
        grays.append(img_clahe)

    return np.array(grays)

train_images_gray_clahe = convert_to_gray_clahe(train_images)
test_images_gray_clahe = convert_to_gray_clahe(test_images)

# %%
initial_lr = 0.001

optimizer = Adam(learning_rate=initial_lr)

input_shape = (256, 256, 1)

attunet = attention_unet(input_shape)
attunet.compile(
    optimizer=optimizer,
    loss=dice_loss,
    metrics=['accuracy', jaccard_coefficient]
)

model_checkpoint_dir = 'model'

checkpoint_path = os.path.join(model_checkpoint_dir, 'cp.ckpt')

checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(model_checkpoint_dir, 'gray2750.weights.h5'),
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

early_stopping = EarlyStoppingByAccuracyChange(
    monitor='accuracy',
    threshold=0.00001,
    patience=10,
    verbose=1
)

lr_reduction = ReduceLROnPlateau(monitor='loss',
                                  patience=5,
                                  verbose=1,
                                  factor=0.5,
                                  min_lr=0.00001)


start_time = time.time()
history = attunet.fit(
    train_images_gray_clahe, train_masks,
    batch_size=32,
    epochs=100,
    callbacks=[early_stopping, lr_reduction, checkpoint_callback]
)

end_time = time.time()
training_time = end_time - start_time

avg_accuracy = np.mean(history.history['accuracy'])
avg_jaccard = np.mean(history.history['jaccard_coefficient'])

print("attunet output shape:", attunet.output_shape)
print(f"⏱️ Thời gian huấn luyện: {training_time:.2f} giây")
print(f"✅ Accuracy trung bình: {avg_accuracy*100:.2f}%")
print(f"🔗 Jaccard trung bình: {avg_jaccard*100:.2f}%")
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765647881.301987     209 service.cc:148] XLA service 0x7cbfaca42e50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1765647881.302959     209 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1765647881.302967     209 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1765647882.775627     209 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 2025-12-13 17:44:50.023471: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng12{k11=0} for conv (f32[32,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,128,128]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:44:50.201625: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.178249006s
# Trying algorithm eng12{k11=0} for conv (f32[32,128,128,128]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,128,128,128]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:45:16.144978: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:45:16.249887: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.105088986s
# Trying algorithm eng11{k2=1,k3=0} for conv (f32[32,64,256,256]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[64,192,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:46:20.467747: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng1{k2=6,k3=0} for conv (f32[128,384,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,384,128,128]{3,2,1,0}, f32[32,128,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:46:20.484411: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.016789807s
# Trying algorithm eng1{k2=6,k3=0} for conv (f32[128,384,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,384,128,128]{3,2,1,0}, f32[32,128,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:46:30.291171: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng1{k2=8,k3=0} for conv (f32[64,192,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[32,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:46:30.304607: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.013557609s
# Trying algorithm eng1{k2=8,k3=0} for conv (f32[64,192,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[32,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:46:31.304827: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng1{k2=6,k3=0} for conv (f32[64,192,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[32,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:46:31.388364: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.083659095s
# Trying algorithm eng1{k2=6,k3=0} for conv (f32[64,192,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[32,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:46:32.388610: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng1{k2=5,k3=0} for conv (f32[64,192,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[32,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:46:32.415985: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.027509553s
# Trying algorithm eng1{k2=5,k3=0} for conv (f32[64,192,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[32,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:46:33.416215: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng20{k2=1,k3=0} for conv (f32[64,192,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[32,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:46:33.721074: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.304958115s
# Trying algorithm eng20{k2=1,k3=0} for conv (f32[64,192,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[32,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:46:34.721304: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng1{k2=2,k3=0} for conv (f32[64,192,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[32,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 17:46:35.096280: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.375082487s
# Trying algorithm eng1{k2=2,k3=0} for conv (f32[64,192,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,192,256,256]{3,2,1,0}, f32[32,64,256,256]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1765648001.132643     209 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step - accuracy: 0.8552 - jaccard_coefficient: 0.4386 - loss: 0.4012
# E0000 00:00:1765648170.345967     209 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765648170.656501     209 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765648175.128446     209 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765648175.364399     209 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8554 - jaccard_coefficient: 0.4396 - loss: 0.4002
# Epoch 1: loss improved from inf to 0.34063, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 327s 3s/step - accuracy: 0.8556 - jaccard_coefficient: 0.4407 - loss: 0.3992 - learning_rate: 0.0010
# Epoch 2/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8936 - jaccard_coefficient: 0.5763 - loss: 0.2706
# Epoch 2: loss improved from 0.34063 to 0.26635, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.8936 - jaccard_coefficient: 0.5763 - loss: 0.2706 - learning_rate: 0.0010
# Epoch 3/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9068 - jaccard_coefficient: 0.6164 - loss: 0.2391
# Epoch 3: loss improved from 0.26635 to 0.23877, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9067 - jaccard_coefficient: 0.6163 - loss: 0.2391 - learning_rate: 0.0010
# Epoch 4/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9072 - jaccard_coefficient: 0.6084 - loss: 0.2469
# Epoch 4: loss improved from 0.23877 to 0.23505, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9072 - jaccard_coefficient: 0.6086 - loss: 0.2467 - learning_rate: 0.0010
# Epoch 5/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9107 - jaccard_coefficient: 0.6193 - loss: 0.2376
# Epoch 5: loss improved from 0.23505 to 0.22150, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9107 - jaccard_coefficient: 0.6197 - loss: 0.2374 - learning_rate: 0.0010
# Epoch 6/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9193 - jaccard_coefficient: 0.6583 - loss: 0.2072
# Epoch 6: loss improved from 0.22150 to 0.20878, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9193 - jaccard_coefficient: 0.6583 - loss: 0.2072 - learning_rate: 0.0010
# Epoch 7/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9195 - jaccard_coefficient: 0.6667 - loss: 0.2021
# Epoch 7: loss improved from 0.20878 to 0.20314, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9195 - jaccard_coefficient: 0.6665 - loss: 0.2021 - learning_rate: 0.0010
# Epoch 8/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9248 - jaccard_coefficient: 0.6788 - loss: 0.1923
# Epoch 8: loss improved from 0.20314 to 0.19533, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9248 - jaccard_coefficient: 0.6786 - loss: 0.1924 - learning_rate: 0.0010
# Epoch 9/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9161 - jaccard_coefficient: 0.6524 - loss: 0.2114
# Epoch 9: loss did not improve from 0.19533
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9161 - jaccard_coefficient: 0.6523 - loss: 0.2114 - learning_rate: 0.0010
# Epoch 10/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9181 - jaccard_coefficient: 0.6670 - loss: 0.2008
# Epoch 10: loss did not improve from 0.19533
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9181 - jaccard_coefficient: 0.6670 - loss: 0.2008 - learning_rate: 0.0010
# Epoch 11/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9168 - jaccard_coefficient: 0.6619 - loss: 0.2052
# Epoch 11: loss did not improve from 0.19533
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9168 - jaccard_coefficient: 0.6618 - loss: 0.2052 - learning_rate: 0.0010
# Epoch 12/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9206 - jaccard_coefficient: 0.6653 - loss: 0.2032
# Epoch 12: loss improved from 0.19533 to 0.19282, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9206 - jaccard_coefficient: 0.6655 - loss: 0.2030 - learning_rate: 0.0010
# Epoch 13/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9220 - jaccard_coefficient: 0.6821 - loss: 0.1905
# Epoch 13: loss improved from 0.19282 to 0.18705, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9220 - jaccard_coefficient: 0.6821 - loss: 0.1904 - learning_rate: 0.0010
# Epoch 14/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9223 - jaccard_coefficient: 0.6802 - loss: 0.1915
# Epoch 14: loss did not improve from 0.18705
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9224 - jaccard_coefficient: 0.6802 - loss: 0.1916 - learning_rate: 0.0010
# Epoch 15/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9306 - jaccard_coefficient: 0.6952 - loss: 0.1808
# Epoch 15: loss improved from 0.18705 to 0.17994, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9306 - jaccard_coefficient: 0.6953 - loss: 0.1808 - learning_rate: 0.0010
# Epoch 16/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9318 - jaccard_coefficient: 0.7098 - loss: 0.1711
# Epoch 16: loss improved from 0.17994 to 0.17349, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9318 - jaccard_coefficient: 0.7097 - loss: 0.1711 - learning_rate: 0.0010
# Epoch 17/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9313 - jaccard_coefficient: 0.6975 - loss: 0.1792
# Epoch 17: loss did not improve from 0.17349
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9312 - jaccard_coefficient: 0.6975 - loss: 0.1792 - learning_rate: 0.0010
# Epoch 18/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9309 - jaccard_coefficient: 0.7116 - loss: 0.1696
# Epoch 18: loss improved from 0.17349 to 0.17008, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9310 - jaccard_coefficient: 0.7116 - loss: 0.1696 - learning_rate: 0.0010
# Epoch 19/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9331 - jaccard_coefficient: 0.7167 - loss: 0.1669
# Epoch 19: loss improved from 0.17008 to 0.16634, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9331 - jaccard_coefficient: 0.7167 - loss: 0.1669 - learning_rate: 0.0010
# Epoch 20/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9373 - jaccard_coefficient: 0.7310 - loss: 0.1569
# Epoch 20: loss did not improve from 0.16634
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9372 - jaccard_coefficient: 0.7307 - loss: 0.1571 - learning_rate: 0.0010
# Epoch 21/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9339 - jaccard_coefficient: 0.7109 - loss: 0.1701
# Epoch 21: loss did not improve from 0.16634
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9339 - jaccard_coefficient: 0.7109 - loss: 0.1701 - learning_rate: 0.0010
# Epoch 22/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9299 - jaccard_coefficient: 0.7044 - loss: 0.1743
# Epoch 22: loss did not improve from 0.16634
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9299 - jaccard_coefficient: 0.7045 - loss: 0.1742 - learning_rate: 0.0010
# Epoch 23/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9369 - jaccard_coefficient: 0.7243 - loss: 0.1609
# Epoch 23: loss did not improve from 0.16634
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9368 - jaccard_coefficient: 0.7240 - loss: 0.1610 - learning_rate: 0.0010
# Epoch 24/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9362 - jaccard_coefficient: 0.7206 - loss: 0.1635
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 24: loss did not improve from 0.16634
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9362 - jaccard_coefficient: 0.7205 - loss: 0.1635 - learning_rate: 0.0010
# Epoch 25/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9374 - jaccard_coefficient: 0.7276 - loss: 0.1590
# Epoch 25: loss improved from 0.16634 to 0.15646, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9374 - jaccard_coefficient: 0.7276 - loss: 0.1590 - learning_rate: 5.0000e-04
# Epoch 26/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9390 - jaccard_coefficient: 0.7296 - loss: 0.1573
# Epoch 26: loss improved from 0.15646 to 0.15105, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9390 - jaccard_coefficient: 0.7298 - loss: 0.1572 - learning_rate: 5.0000e-04
# Epoch 27/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9381 - jaccard_coefficient: 0.7351 - loss: 0.1536
# Epoch 27: loss did not improve from 0.15105
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9381 - jaccard_coefficient: 0.7350 - loss: 0.1536 - learning_rate: 5.0000e-04
# Epoch 28/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9366 - jaccard_coefficient: 0.7237 - loss: 0.1616
# Epoch 28: loss did not improve from 0.15105
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9367 - jaccard_coefficient: 0.7238 - loss: 0.1614 - learning_rate: 5.0000e-04
# Epoch 29/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9417 - jaccard_coefficient: 0.7420 - loss: 0.1488
# Epoch 29: loss improved from 0.15105 to 0.14919, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9416 - jaccard_coefficient: 0.7420 - loss: 0.1488 - learning_rate: 5.0000e-04
# Epoch 30/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9401 - jaccard_coefficient: 0.7445 - loss: 0.1475
# Epoch 30: loss improved from 0.14919 to 0.14884, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9401 - jaccard_coefficient: 0.7445 - loss: 0.1476 - learning_rate: 5.0000e-04
# Epoch 31/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9435 - jaccard_coefficient: 0.7452 - loss: 0.1469
# Epoch 31: loss improved from 0.14884 to 0.14225, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9435 - jaccard_coefficient: 0.7453 - loss: 0.1469 - learning_rate: 5.0000e-04
# Epoch 32/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9439 - jaccard_coefficient: 0.7548 - loss: 0.1408
# Epoch 32: loss did not improve from 0.14225
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9439 - jaccard_coefficient: 0.7546 - loss: 0.1409 - learning_rate: 5.0000e-04
# Epoch 33/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9427 - jaccard_coefficient: 0.7476 - loss: 0.1457
# Epoch 33: loss improved from 0.14225 to 0.14213, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9427 - jaccard_coefficient: 0.7477 - loss: 0.1456 - learning_rate: 5.0000e-04
# Epoch 34/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9427 - jaccard_coefficient: 0.7496 - loss: 0.1439
# Epoch 34: loss improved from 0.14213 to 0.13951, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9428 - jaccard_coefficient: 0.7497 - loss: 0.1438 - learning_rate: 5.0000e-04
# Epoch 35/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9414 - jaccard_coefficient: 0.7577 - loss: 0.1388
# Epoch 35: loss improved from 0.13951 to 0.13804, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9414 - jaccard_coefficient: 0.7577 - loss: 0.1388 - learning_rate: 5.0000e-04
# Epoch 36/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9440 - jaccard_coefficient: 0.7549 - loss: 0.1408
# Epoch 36: loss did not improve from 0.13804
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9440 - jaccard_coefficient: 0.7548 - loss: 0.1408 - learning_rate: 5.0000e-04
# Epoch 37/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9489 - jaccard_coefficient: 0.7693 - loss: 0.1309
# Epoch 37: loss improved from 0.13804 to 0.13779, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9489 - jaccard_coefficient: 0.7691 - loss: 0.1311 - learning_rate: 5.0000e-04
# Epoch 38/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9481 - jaccard_coefficient: 0.7708 - loss: 0.1304
# Epoch 38: loss improved from 0.13779 to 0.13652, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9480 - jaccard_coefficient: 0.7707 - loss: 0.1305 - learning_rate: 5.0000e-04
# Epoch 39/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9444 - jaccard_coefficient: 0.7584 - loss: 0.1384
# Epoch 39: loss improved from 0.13652 to 0.13649, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9445 - jaccard_coefficient: 0.7585 - loss: 0.1383 - learning_rate: 5.0000e-04
# Epoch 40/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9452 - jaccard_coefficient: 0.7593 - loss: 0.1374
# Epoch 40: loss improved from 0.13649 to 0.13414, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9452 - jaccard_coefficient: 0.7593 - loss: 0.1374 - learning_rate: 5.0000e-04
# Epoch 41/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9453 - jaccard_coefficient: 0.7614 - loss: 0.1363
# Epoch 41: loss did not improve from 0.13414
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9453 - jaccard_coefficient: 0.7614 - loss: 0.1363 - learning_rate: 5.0000e-04
# Epoch 42/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9481 - jaccard_coefficient: 0.7747 - loss: 0.1277
# Epoch 42: loss did not improve from 0.13414
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9480 - jaccard_coefficient: 0.7744 - loss: 0.1279 - learning_rate: 5.0000e-04
# Epoch 43/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9459 - jaccard_coefficient: 0.7585 - loss: 0.1380
# Epoch 43: loss did not improve from 0.13414
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9459 - jaccard_coefficient: 0.7584 - loss: 0.1380 - learning_rate: 5.0000e-04
# Epoch 44/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9472 - jaccard_coefficient: 0.7654 - loss: 0.1339
# Epoch 44: loss improved from 0.13414 to 0.13155, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9472 - jaccard_coefficient: 0.7655 - loss: 0.1339 - learning_rate: 5.0000e-04
# Epoch 45/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9500 - jaccard_coefficient: 0.7770 - loss: 0.1260
# Epoch 45: loss improved from 0.13155 to 0.12936, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9500 - jaccard_coefficient: 0.7769 - loss: 0.1260 - learning_rate: 5.0000e-04
# Epoch 46/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9477 - jaccard_coefficient: 0.7736 - loss: 0.1284
# Epoch 46: loss improved from 0.12936 to 0.12726, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9478 - jaccard_coefficient: 0.7737 - loss: 0.1284 - learning_rate: 5.0000e-04
# Epoch 47/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9499 - jaccard_coefficient: 0.7759 - loss: 0.1269
# Epoch 47: loss improved from 0.12726 to 0.12725, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9499 - jaccard_coefficient: 0.7759 - loss: 0.1269 - learning_rate: 5.0000e-04
# Epoch 48/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9485 - jaccard_coefficient: 0.7753 - loss: 0.1272
# Epoch 48: loss improved from 0.12725 to 0.12607, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9486 - jaccard_coefficient: 0.7754 - loss: 0.1272 - learning_rate: 5.0000e-04
# Epoch 49/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9503 - jaccard_coefficient: 0.7859 - loss: 0.1207
# Epoch 49: loss improved from 0.12607 to 0.11741, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9503 - jaccard_coefficient: 0.7859 - loss: 0.1206 - learning_rate: 5.0000e-04
# Epoch 50/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9512 - jaccard_coefficient: 0.7788 - loss: 0.1247
# Epoch 50: loss did not improve from 0.11741
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9512 - jaccard_coefficient: 0.7789 - loss: 0.1247 - learning_rate: 5.0000e-04
# Epoch 51/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9522 - jaccard_coefficient: 0.7839 - loss: 0.1219
# Epoch 51: loss did not improve from 0.11741
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9522 - jaccard_coefficient: 0.7839 - loss: 0.1219 - learning_rate: 5.0000e-04
# Epoch 52/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9521 - jaccard_coefficient: 0.7913 - loss: 0.1170
# Epoch 52: loss did not improve from 0.11741
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9521 - jaccard_coefficient: 0.7913 - loss: 0.1170 - learning_rate: 5.0000e-04
# Epoch 53/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9565 - jaccard_coefficient: 0.7989 - loss: 0.1123
# Epoch 53: loss improved from 0.11741 to 0.11596, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9565 - jaccard_coefficient: 0.7988 - loss: 0.1124 - learning_rate: 5.0000e-04
# Epoch 54/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9494 - jaccard_coefficient: 0.7775 - loss: 0.1259
# Epoch 54: loss did not improve from 0.11596
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9494 - jaccard_coefficient: 0.7777 - loss: 0.1257 - learning_rate: 5.0000e-04
# Epoch 55/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9531 - jaccard_coefficient: 0.7931 - loss: 0.1160
# Epoch 55: loss improved from 0.11596 to 0.11392, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9531 - jaccard_coefficient: 0.7931 - loss: 0.1160 - learning_rate: 5.0000e-04
# Epoch 56/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9540 - jaccard_coefficient: 0.7872 - loss: 0.1197
# Epoch 56: loss improved from 0.11392 to 0.11337, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9540 - jaccard_coefficient: 0.7874 - loss: 0.1196 - learning_rate: 5.0000e-04
# Epoch 57/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9545 - jaccard_coefficient: 0.7936 - loss: 0.1157
# Epoch 57: loss did not improve from 0.11337
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9545 - jaccard_coefficient: 0.7936 - loss: 0.1157 - learning_rate: 5.0000e-04
# Epoch 58/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9566 - jaccard_coefficient: 0.7990 - loss: 0.1121
# Epoch 58: loss improved from 0.11337 to 0.10802, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9566 - jaccard_coefficient: 0.7991 - loss: 0.1120 - learning_rate: 5.0000e-04
# Epoch 59/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9596 - jaccard_coefficient: 0.8120 - loss: 0.1041
# Epoch 59: loss improved from 0.10802 to 0.10646, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 152s 2s/step - accuracy: 0.9596 - jaccard_coefficient: 0.8119 - loss: 0.1042 - learning_rate: 5.0000e-04
# Epoch 60/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9473 - jaccard_coefficient: 0.7731 - loss: 0.1292
# Epoch 60: loss did not improve from 0.10646
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9474 - jaccard_coefficient: 0.7734 - loss: 0.1290 - learning_rate: 5.0000e-04
# Epoch 61/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9536 - jaccard_coefficient: 0.7874 - loss: 0.1196
# Epoch 61: loss did not improve from 0.10646
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9536 - jaccard_coefficient: 0.7876 - loss: 0.1195 - learning_rate: 5.0000e-04
# Epoch 62/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9566 - jaccard_coefficient: 0.8035 - loss: 0.1095
# Epoch 62: loss improved from 0.10646 to 0.10497, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 152s 2s/step - accuracy: 0.9566 - jaccard_coefficient: 0.8036 - loss: 0.1094 - learning_rate: 5.0000e-04
# Epoch 63/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9605 - jaccard_coefficient: 0.8199 - loss: 0.0994
# Epoch 63: loss improved from 0.10497 to 0.09600, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 152s 2s/step - accuracy: 0.9605 - jaccard_coefficient: 0.8200 - loss: 0.0994 - learning_rate: 5.0000e-04
# Epoch 64/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9620 - jaccard_coefficient: 0.8247 - loss: 0.0963
# Epoch 64: loss improved from 0.09600 to 0.09466, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9620 - jaccard_coefficient: 0.8247 - loss: 0.0963 - learning_rate: 5.0000e-04
# Epoch 65/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9529 - jaccard_coefficient: 0.7862 - loss: 0.1211
# Epoch 65: loss did not improve from 0.09466
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9529 - jaccard_coefficient: 0.7864 - loss: 0.1209 - learning_rate: 5.0000e-04
# Epoch 66/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9612 - jaccard_coefficient: 0.8231 - loss: 0.0975
# Epoch 66: loss did not improve from 0.09466
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9612 - jaccard_coefficient: 0.8231 - loss: 0.0975 - learning_rate: 5.0000e-04
# Epoch 67/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9596 - jaccard_coefficient: 0.8232 - loss: 0.0972
# Epoch 67: loss did not improve from 0.09466
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9597 - jaccard_coefficient: 0.8232 - loss: 0.0972 - learning_rate: 5.0000e-04
# Epoch 68/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9618 - jaccard_coefficient: 0.8300 - loss: 0.0932
# Epoch 68: loss improved from 0.09466 to 0.09136, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 152s 2s/step - accuracy: 0.9618 - jaccard_coefficient: 0.8301 - loss: 0.0932 - learning_rate: 5.0000e-04
# Epoch 69/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9562 - jaccard_coefficient: 0.8020 - loss: 0.1103
# Epoch 69: loss did not improve from 0.09136
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9562 - jaccard_coefficient: 0.8021 - loss: 0.1102 - learning_rate: 5.0000e-04
# Epoch 70/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9620 - jaccard_coefficient: 0.8273 - loss: 0.0949
# Epoch 70: loss did not improve from 0.09136
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9620 - jaccard_coefficient: 0.8273 - loss: 0.0948 - learning_rate: 5.0000e-04
# Epoch 71/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9651 - jaccard_coefficient: 0.8366 - loss: 0.0895
# Epoch 71: loss improved from 0.09136 to 0.08770, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9651 - jaccard_coefficient: 0.8367 - loss: 0.0894 - learning_rate: 5.0000e-04
# Epoch 72/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9671 - jaccard_coefficient: 0.8466 - loss: 0.0836
# Epoch 72: loss improved from 0.08770 to 0.08300, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9671 - jaccard_coefficient: 0.8465 - loss: 0.0836 - learning_rate: 5.0000e-04
# Epoch 73/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9493 - jaccard_coefficient: 0.7717 - loss: 0.1298
# Epoch 73: loss did not improve from 0.08300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9493 - jaccard_coefficient: 0.7717 - loss: 0.1297 - learning_rate: 5.0000e-04
# Epoch 74/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9585 - jaccard_coefficient: 0.8053 - loss: 0.1085
# Epoch 74: loss did not improve from 0.08300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9585 - jaccard_coefficient: 0.8055 - loss: 0.1084 - learning_rate: 5.0000e-04
# Epoch 75/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9663 - jaccard_coefficient: 0.8443 - loss: 0.0847
# Epoch 75: loss did not improve from 0.08300
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9663 - jaccard_coefficient: 0.8443 - loss: 0.0847 - learning_rate: 5.0000e-04
# Epoch 76/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9683 - jaccard_coefficient: 0.8497 - loss: 0.0814
# Epoch 76: loss improved from 0.08300 to 0.07846, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 152s 2s/step - accuracy: 0.9683 - jaccard_coefficient: 0.8498 - loss: 0.0814 - learning_rate: 5.0000e-04
# Epoch 77/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9686 - jaccard_coefficient: 0.8509 - loss: 0.0807
# Epoch 77: loss improved from 0.07846 to 0.07695, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9686 - jaccard_coefficient: 0.8509 - loss: 0.0807 - learning_rate: 5.0000e-04
# Epoch 78/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9660 - jaccard_coefficient: 0.8527 - loss: 0.0798
# Epoch 78: loss did not improve from 0.07695
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9660 - jaccard_coefficient: 0.8527 - loss: 0.0798 - learning_rate: 5.0000e-04
# Epoch 79/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9720 - jaccard_coefficient: 0.8687 - loss: 0.0705
# Epoch 79: loss improved from 0.07695 to 0.07072, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9720 - jaccard_coefficient: 0.8687 - loss: 0.0705 - learning_rate: 5.0000e-04
# Epoch 80/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9719 - jaccard_coefficient: 0.8710 - loss: 0.0690
# Epoch 80: loss did not improve from 0.07072
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9719 - jaccard_coefficient: 0.8709 - loss: 0.0691 - learning_rate: 5.0000e-04
# Epoch 81/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9693 - jaccard_coefficient: 0.8623 - loss: 0.0742
# Epoch 81: loss did not improve from 0.07072
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9694 - jaccard_coefficient: 0.8624 - loss: 0.0741 - learning_rate: 5.0000e-04
# Epoch 82/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9737 - jaccard_coefficient: 0.8753 - loss: 0.0666
# Epoch 82: loss improved from 0.07072 to 0.06621, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 152s 2s/step - accuracy: 0.9737 - jaccard_coefficient: 0.8754 - loss: 0.0666 - learning_rate: 5.0000e-04
# Epoch 83/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9724 - jaccard_coefficient: 0.8747 - loss: 0.0670
# Epoch 83: loss did not improve from 0.06621
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9724 - jaccard_coefficient: 0.8746 - loss: 0.0670 - learning_rate: 5.0000e-04
# Epoch 84/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9714 - jaccard_coefficient: 0.8702 - loss: 0.0696
# Epoch 84: loss did not improve from 0.06621
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9714 - jaccard_coefficient: 0.8703 - loss: 0.0695 - learning_rate: 5.0000e-04
# Epoch 85/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9743 - jaccard_coefficient: 0.8836 - loss: 0.0619
# Epoch 85: loss improved from 0.06621 to 0.06292, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9743 - jaccard_coefficient: 0.8836 - loss: 0.0619 - learning_rate: 5.0000e-04
# Epoch 86/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9740 - jaccard_coefficient: 0.8772 - loss: 0.0656
# Epoch 86: loss improved from 0.06292 to 0.06258, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9740 - jaccard_coefficient: 0.8772 - loss: 0.0656 - learning_rate: 5.0000e-04
# Epoch 87/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9737 - jaccard_coefficient: 0.8814 - loss: 0.0632
# Epoch 87: loss improved from 0.06258 to 0.06217, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9738 - jaccard_coefficient: 0.8814 - loss: 0.0632 - learning_rate: 5.0000e-04
# Epoch 88/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9740 - jaccard_coefficient: 0.8816 - loss: 0.0631
# Epoch 88: loss did not improve from 0.06217
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9740 - jaccard_coefficient: 0.8816 - loss: 0.0631 - learning_rate: 5.0000e-04
# Epoch 89/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9757 - jaccard_coefficient: 0.8881 - loss: 0.0594
# Epoch 89: loss improved from 0.06217 to 0.05842, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9757 - jaccard_coefficient: 0.8881 - loss: 0.0594 - learning_rate: 5.0000e-04
# Epoch 90/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9772 - jaccard_coefficient: 0.8926 - loss: 0.0568
# Epoch 90: loss did not improve from 0.05842
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9772 - jaccard_coefficient: 0.8925 - loss: 0.0569 - learning_rate: 5.0000e-04
# Epoch 91/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9757 - jaccard_coefficient: 0.8892 - loss: 0.0587
# Epoch 91: loss improved from 0.05842 to 0.05690, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 152s 2s/step - accuracy: 0.9757 - jaccard_coefficient: 0.8892 - loss: 0.0586 - learning_rate: 5.0000e-04
# Epoch 92/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9477 - jaccard_coefficient: 0.7726 - loss: 0.1294
# Epoch 92: loss did not improve from 0.05690
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9477 - jaccard_coefficient: 0.7728 - loss: 0.1293 - learning_rate: 5.0000e-04
# Epoch 93/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9678 - jaccard_coefficient: 0.8508 - loss: 0.0809
# Epoch 93: loss did not improve from 0.05690
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9679 - jaccard_coefficient: 0.8510 - loss: 0.0807 - learning_rate: 5.0000e-04
# Epoch 94/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9749 - jaccard_coefficient: 0.8871 - loss: 0.0599
# Epoch 94: loss did not improve from 0.05690
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9750 - jaccard_coefficient: 0.8871 - loss: 0.0599 - learning_rate: 5.0000e-04
# Epoch 95/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9767 - jaccard_coefficient: 0.8948 - loss: 0.0556
# Epoch 95: loss improved from 0.05690 to 0.05401, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9768 - jaccard_coefficient: 0.8949 - loss: 0.0556 - learning_rate: 5.0000e-04
# Epoch 96/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9790 - jaccard_coefficient: 0.9039 - loss: 0.0505
# Epoch 96: loss improved from 0.05401 to 0.05183, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 152s 2s/step - accuracy: 0.9790 - jaccard_coefficient: 0.9039 - loss: 0.0506 - learning_rate: 5.0000e-04
# Epoch 97/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9793 - jaccard_coefficient: 0.9051 - loss: 0.0499
# Epoch 97: loss improved from 0.05183 to 0.04995, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9793 - jaccard_coefficient: 0.9051 - loss: 0.0499 - learning_rate: 5.0000e-04
# Epoch 98/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9807 - jaccard_coefficient: 0.9066 - loss: 0.0490
# Epoch 98: loss improved from 0.04995 to 0.04936, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9807 - jaccard_coefficient: 0.9066 - loss: 0.0490 - learning_rate: 5.0000e-04
# Epoch 99/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9803 - jaccard_coefficient: 0.9073 - loss: 0.0487
# Epoch 99: loss improved from 0.04936 to 0.04885, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9803 - jaccard_coefficient: 0.9073 - loss: 0.0487 - learning_rate: 5.0000e-04
# Epoch 100/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9807 - jaccard_coefficient: 0.9092 - loss: 0.0476
# Epoch 100: loss improved from 0.04885 to 0.04712, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9807 - jaccard_coefficient: 0.9092 - loss: 0.0476 - learning_rate: 5.0000e-04
# attunet output shape: (None, 256, 256, 1)
# ⏱️ Thời gian huấn luyện: 15272.04 giây
# ✅ Accuracy trung bình: 94.95%
# 🔗 Jaccard trung bình: 77.94%

# %%
acc = history.history['accuracy']
loss = history.history['loss']
epochs_range = range(1, len(acc) + 1)
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Accuracy', color='green')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Loss', color='red')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.savefig('Gray_2750_acc_loss.png', dpi=300)
plt.show()

# %%
def apply_morphology(mask, kernel_size=3, iterations=1):
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))
    mask = (mask > 0.5).astype(np.uint8)
  
    closed = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=iterations)

  
    opened = cv2.morphologyEx(closed, cv2.MORPH_OPEN, kernel, iterations=iterations)

    return opened.astype(np.float32)  

print("🔍 Đánh giá không hậu xử lý...")
results = attunet.evaluate(test_images_gray_clahe, test_masks, verbose=1)
loss, accuracy, jaccard = results
print(f"Không hậu xử lý - Dice Loss: {loss:.4f}, Accuracy: {accuracy*100:.2f}%, Jaccard: {jaccard*100:.2f}%")
print("\n🔧 Đánh giá sau Morphology...")
predictions1 = attunet.predict(test_images_gray_clahe)
refined_predictions1 = []

for i in tqdm(range(len(test_images_gray_clahe))):
    pred = predictions1[i].squeeze()

    morph_pred = apply_morphology(pred, kernel_size=7, iterations=2)

    refined_predictions1.append(morph_pred)

refined_predictions1 = np.expand_dims(np.array(refined_predictions1), axis=-1)

accuracy_after = np_accuracy(test_masks, refined_predictions1)
jaccard_after = np_jaccard_coefficient(test_masks, refined_predictions1)
loss_after = np_dice_loss(test_masks, refined_predictions1)

print(f"Sau Morphology - Dice Loss: {loss_after:.4f}, Accuracy: {accuracy_after*100:.2f}%, Jaccard: {jaccard_after*100:.2f}%")
# Out:
# 🔍 Đánh giá không hậu xử lý...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.9392 - jaccard_coefficient: 0.7437 - loss: 0.1515
# Không hậu xử lý - Dice Loss: 0.1973, Accuracy: 93.45%, Jaccard: 67.96%
#
# 🔧 Đánh giá sau Morphology...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 23s 872ms/step
# 100%|██████████| 825/825 [00:00<00:00, 1536.71it/s]
# Sau Morphology - Dice Loss: 0.1659, Accuracy: 93.52%, Jaccard: 71.53%

# %%
def show_predictions_with_metrics_grid(refined_predictions1,
                                       images, masks,
                                       indices,
                                       save_path):

    num_images = len(indices)
    plt.figure(figsize=(8, 4 * num_images))  

    for i, idx in enumerate(indices):
        image = images[idx]
        true_mask = masks[idx]
        pred_morph = refined_predictions1[idx]
      
        if pred_morph.shape != true_mask.shape:
            pred_morph = cv2.resize(pred_morph, (true_mask.shape[1], true_mask.shape[0]), interpolation=cv2.INTER_NEAREST)

        accuracy = np_accuracy(true_mask, pred_morph)

        ax1 = plt.subplot(num_images, 2, 2*i + 1)
        ax1.imshow(image)
        ax1.axis('off')

        ax2 = plt.subplot(num_images, 2, 2*i + 2)
        ax2.imshow(pred_morph, cmap='gray')
        ax2.axis('off')
        ax2.text(0.5, -0.01,
                 f"Accuracy: {accuracy:.3f}",
                 fontsize=16, ha='center', va='top', transform=ax2.transAxes)

    plt.tight_layout()
    plt.savefig(save_path, bbox_inches='tight', dpi=300)
    plt.show()

show_predictions_with_metrics_grid(
    refined_predictions1=refined_predictions1,
    images=test_images,
    masks=test_masks,
    indices=[722, 191, 54, 700],
    save_path='best_morphology_results_gray_2750.png'
)

# %%
attunet.save('/kaggle/working/model/2.0-gray_2750_model.h5')
attunet.save('/kaggle/working/model/2.0-gray_2750_model.keras')
