# %%
# !pip install scipy==1.10.1
# !pip install scikit-learn --upgrade
import os
import numpy as np
import tensorflow as tf
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
# !pip install opencv-contrib-python
# !pip install tensorflow-addons

import cv2
import time
import json
import shutil
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import pydensecrf.densecrf as dcrf
from pydensecrf.utils import unary_from_softmax, create_pairwise_bilateral
import tensorflow.keras.backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.activations import swish
from tensorflow.keras.regularizers import l2
from tensorflow.keras.initializers import HeNormal

from tensorflow.keras.layers import (
    Layer, 
    Input, 
    Conv2D, 
    BatchNormalization, 
    Lambda, 
    Concatenate,
    SeparableConv2D, 
    MaxPooling2D, 
    UpSampling2D, 
    Conv2DTranspose,
    SpatialDropout2D, 
    ReLU, 
    GlobalAveragePooling2D, 
    Add,
    GlobalMaxPooling2D, 
    Dense, 
    Reshape, 
    Multiply, 
    Activation
)
# Out:
# Requirement already satisfied: scipy==1.10.1 in /usr/local/lib/python3.11/dist-packages (1.10.1)
# Collecting numpy<1.27.0,>=1.19.5 (from scipy==1.10.1)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 105.0 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# mne 1.10.2 requires scipy>=1.11, but you have scipy 1.10.1 which is incompatible.
# ydata-profiling 4.17.0 requires typeguard<5,>=3, but you have typeguard 2.13.3 which is incompatible.
# kaggle-environments 1.18.0 requires scipy>=1.11.2, but you have scipy 1.10.1 which is incompatible.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.8.0 which is incompatible.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# jax 0.5.2 requires scipy>=1.11.1, but you have scipy 1.10.1 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.10.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.8.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# scikit-image 0.25.2 requires scipy>=1.11.4, but you have scipy 1.10.1 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# cvxpy 1.6.7 requires scipy>=1.11.0, but you have scipy 1.10.1 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# xarray-einstats 0.9.1 requires scipy>=1.11, but you have scipy 1.10.1 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# jaxlib 0.5.1 requires scipy>=1.11.1, but you have scipy 1.10.1 which is incompatible.
# Successfully installed numpy-1.26.4
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.11/dist-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn) (3.6.0)
# Collecting git+https://github.com/lucasb-eyer/pydensecrf.git
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-nnbjswkw
#   Running command git clone --filter=blob:none --quiet https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-nnbjswkw
#   Resolved https://github.com/lucasb-eyer/pydensecrf.git to commit 2723c7fa4f2ead16ae1ce3d8afe977724bb8f87f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.12.0.88)
# Collecting numpy<2.3.0,>=2 (from opencv-contrib-python)
#   Using cached numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Using cached numpy-2.2.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# scipy 1.10.1 requires numpy<1.27.0,>=1.19.5, but you have numpy 2.2.6 which is incompatible.
# mkl-umath 0.1.1 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-random 1.2.4 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# mkl-fft 1.3.8 requires numpy<1.27.0,>=1.26.4, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# datasets 4.4.1 requires pyarrow>=21.0.0, but you have pyarrow 19.0.1 which is incompatible.
# mne 1.10.2 requires scipy>=1.11, but you have scipy 1.10.1 which is incompatible.
# ydata-profiling 4.17.0 requires numpy<2.2,>=1.16.0, but you have numpy 2.2.6 which is incompatible.
# ydata-profiling 4.17.0 requires typeguard<5,>=3, but you have typeguard 2.13.3 which is incompatible.
# kaggle-environments 1.18.0 requires scipy>=1.11.2, but you have scipy 1.10.1 which is incompatible.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.8.0 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.7, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.5 which is incompatible.
# google-colab 1.0.0 requires tornado==6.4.2, but you have tornado 6.5.2 which is incompatible.
# jax 0.5.2 requires scipy>=1.11.1, but you have scipy 1.10.1 which is incompatible.
# tsfresh 0.21.0 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.10.1 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.8.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# scikit-image 0.25.2 requires scipy>=1.11.4, but you have scipy 1.10.1 which is incompatible.
# cvxpy 1.6.7 requires scipy>=1.11.0, but you have scipy 1.10.1 which is incompatible.
# gradio 5.38.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.4 which is incompatible.
# xarray-einstats 0.9.1 requires scipy>=1.11, but you have scipy 1.10.1 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.2 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.6 which is incompatible.
# tensorflow 2.18.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 6.33.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# jaxlib 0.5.1 requires scipy>=1.11.1, but you have scipy 1.10.1 which is incompatible.
# Successfully installed numpy-2.2.6
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.11/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (25.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (2.13.3)

# %%
working_dir = '/kaggle/working'
for item in os.listdir(working_dir):
    item_path = os.path.join(working_dir, item)
    try:
        if os.path.isfile(item_path) or os.path.islink(item_path):
            os.unlink(item_path) 
        elif os.path.isdir(item_path):
            shutil.rmtree(item_path) 
            print(f"❌ xóa thành công {item_path}")
    except Exception as e:
        print(f"Lỗi khi xóa {item_path}: {e}")
# Out:
# ❌ xóa thành công /kaggle/working/.virtual_documents

# %%
def load_isic_dataset(image_path, mask_path, binary_path, csv_file, img_size=(256, 256)):
    image_files = sorted(glob(os.path.join(image_path, "ISIC_*.jpg")))
    images = []
    masks = []
    binary_masks = {}
    image_ids = []
    labels = []
    csv_data = pd.read_csv(csv_file)
    mel_label = csv_data['melanoma'].astype("int64")

    print("Đang đọc và xử lý dữ liệu...")
    for index, img_path in enumerate(tqdm(image_files)):
        img_id = os.path.basename(img_path).split('.')[0]
        mask_file = os.path.join(mask_path, f"{img_id}_segmentation.png")
        binary_file = os.path.join(binary_path, f"{img_id}_features.json")

        if not os.path.exists(mask_file):
            print(f"Không tìm thấy mask cho ảnh mặt nạ {img_id}_segmentation.png")
            continue
        if not os.path.exists(binary_file):
            print(f"Không tìm thấy mask nhị phân cho ảnh {img_id}_features.json")
            continue

        try:
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 

            mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)
            img = cv2.resize(img, img_size)
            mask = cv2.resize(mask, img_size)

            img = img / 255.0
            mask = mask / 255.0

            with open(binary_file, 'r') as f:
                binary_masks[img_id] = json.load(f)
            label = mel_label[index]
            images.append(img)
            masks.append(mask)
            image_ids.append(img_id)
            labels.append(label.astype("long"))

        except Exception as e:
            print(f"Lỗi khi xử lý ảnh {img_id}: {str(e)}")
            continue

    images = np.array(images)
    masks = np.array(masks)[..., np.newaxis] 
    labels = np.array(labels)

    print(f"\nĐã đọc thành công {len(images)} ảnh")
    print(f"Shape của images: {images.shape}")
    print(f"Shape của masks: {masks.shape}")
    print(f"Shape của labels: {labels.shape}")

    return images, masks, binary_masks, image_ids, labels

# %%
train_images, train_masks, train_binarys, train_image_ids, train_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2750/Train_Data',
    mask_path='/kaggle/input/isic-2750/Train_GroundTruth_1',
    binary_path='/kaggle/input/isic-2750/Train_GroundTruth_2',
    csv_file="/kaggle/input/2075-csv/Train_GroundTruth_3.csv",
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 1925/1925 [05:12<00:00,  6.16it/s]
# Đã đọc thành công 1925 ảnh
# Shape của images: (1925, 256, 256, 3)
# Shape của masks: (1925, 256, 256, 1)
# Shape của labels: (1925,)

# %%
test_images, test_masks, test_binarys, test_image_ids, test_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2750/Test_Data',
    mask_path='/kaggle/input/isic-2750/Test_GroundTruth_1',
    binary_path='/kaggle/input/isic-2750/Test_GroundTruth_2',
    csv_file='/kaggle/input/2075-csv/Test_GroundTruth_3 (1).csv',
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 825/825 [01:57<00:00,  7.05it/s]
# Đã đọc thành công 825 ảnh
# Shape của images: (825, 256, 256, 3)
# Shape của masks: (825, 256, 256, 1)
# Shape của labels: (825,)

# %%
def convert_to_gray_clahe(images_normalized):
    images_clahe = []
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))

    for img in images_normalized:
        img_uint8 = np.uint8(img * 255)

        if len(img_uint8.shape) == 3:
            img_gray = cv2.cvtColor(img_uint8, cv2.COLOR_RGB2GRAY)
        else:
            img_gray = img_uint8  

        img_clahe_uint8 = clahe.apply(img_gray)

        img_clahe = img_clahe_uint8.astype(np.float32) / 255.0

        images_clahe.append(img_clahe)

    return np.array(images_clahe)

train_images_gray_clahe = convert_to_gray_clahe(train_images)
test_images_gray_clahe = convert_to_gray_clahe(test_images)

print(f"Shape ảnh huấn luyện sau CLAHE: {train_images_gray_clahe.shape}")
# Out:
# Shape ảnh huấn luyện sau CLAHE: (1925, 256, 256)

# %%
def compute_metric(y_true, y_pred, metric='dice_coefficient', smooth=1e-6, is_numpy=False):
    y_true_f = y_true.flatten() if is_numpy else K.flatten(y_true)
    y_pred_f = y_pred.flatten() if is_numpy else K.flatten(y_pred)
    intersection = np.sum(y_true_f * y_pred_f) if is_numpy else K.sum(y_true_f * y_pred_f)

    if 'dice' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        score = (2. * intersection + smooth) / (sum_fn(y_true_f) + sum_fn(y_pred_f) + smooth)
    elif 'jaccard' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        union = sum_fn(y_true_f) + sum_fn(y_pred_f) - intersection
        score = (intersection + smooth) / (union + smooth)
    else:
        raise ValueError(f"Unsupported metric: {metric}")

    return score if 'coefficient' in metric else 1 - score

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth)

def dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth)

def jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth)

def jaccard_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_loss', smooth)


def np_accuracy(y_true, y_pred):
    return np.mean(y_true.flatten() == y_pred.flatten())

def np_dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth, is_numpy=True)

def np_jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth, is_numpy=True)

def np_dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth, is_numpy=True)

# %%
def cbam_module(input_features, reduction_ratio=8):
    filters = input_features.shape[-1]    
    avg_pool = GlobalAveragePooling2D()(input_features)
    max_pool = GlobalMaxPooling2D()(input_features)
    
    shared_dense_1 = Dense(filters // reduction_ratio, 
                           activation='relu', 
                           kernel_initializer='he_normal', 
                           use_bias=True)
    
    shared_dense_2 = Dense(filters, 
                           use_bias=True)
    
    avg_out = shared_dense_2(shared_dense_1(avg_pool))
    max_out = shared_dense_2(shared_dense_1(max_pool))
    
    channel_sum = Add()([avg_out, max_out])
    channel_attention = Activation('sigmoid')(channel_sum)
    channel_attention = Reshape((1, 1, filters))(channel_attention)
    channel_refined = Multiply()([input_features, channel_attention])   
   
    avg_spatial = Lambda(lambda x: K.mean(x, axis=-1, keepdims=True), 
                         output_shape=lambda s: (s[0], s[1], s[2], 1))(channel_refined)
    max_spatial = Lambda(lambda x: K.max(x, axis=-1, keepdims=True), 
                         output_shape=lambda s: (s[0], s[1], s[2], 1))(channel_refined)


    spatial_concat = Concatenate(axis=-1)([avg_spatial, max_spatial])
    
    spatial_attention = Conv2D(1, 
                               (7, 7), 
                               padding='same', 
                               activation='sigmoid', 
                               use_bias=False)(spatial_concat)
    
    refined_features = Multiply()([channel_refined, spatial_attention])
    
    
    return refined_features

# %%
def simam(x, lambda_val=1e-4):  
    shape = tf.shape(x)
    H, W = shape[1], shape[2]
    n = tf.cast(H * W - 1, x.dtype)
    
    mu = tf.reduce_mean(x, axis=[1, 2], keepdims=True)
    d = tf.square(x - mu)
    var = tf.reduce_sum(d, axis=[1, 2], keepdims=True) / n
    e_t = d / (4 * (var + lambda_val)) + 0.5
    
    return x * tf.nn.sigmoid(e_t)

def aspp_module(input_tensor, output_filters=1024, rates=[1, 6, 12, 18]):   
    num_branches = len(rates)
    branch_filters = output_filters // num_branches

    branches = []
    for rate in rates:
        branch = SeparableConv2D(branch_filters, (3, 3), padding='same', dilation_rate=rate, use_bias=False,
                                  depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(input_tensor)
        branch = BatchNormalization()(branch)
        branch = ReLU()(branch)
        branches.append(branch)

    concatenated = Concatenate()(branches)
    attended = Lambda(simam)(concatenated)
  
    final_conv = SeparableConv2D(output_filters, (1, 1), padding='same', use_bias=False,
                                  depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(concatenated)
    final_conv = BatchNormalization()(final_conv)
    final_conv = ReLU()(final_conv)
    final_conv = SpatialDropout2D(0.2)(final_conv)
    return final_conv

# %%
def CustomSegUNet(input_size=(256, 256, 1)):
    inputs = Input(input_size)

    c1 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(inputs)
    c1 = BatchNormalization()(c1); c1 = ReLU()(c1)
    c1 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c1)
    c1 = BatchNormalization()(c1); c1 = ReLU()(c1)
    c1 = SpatialDropout2D(0.1)(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p1)
    c2 = BatchNormalization()(c2); c2 = ReLU()(c2)
    c2 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c2)
    c2 = BatchNormalization()(c2); c2 = ReLU()(c2)
    c2 = SpatialDropout2D(0.1)(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p2)
    c3 = BatchNormalization()(c3); c3 = ReLU()(c3)
    c3 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c3)
    c3 = BatchNormalization()(c3); c3 = ReLU()(c3)
    c3 = SpatialDropout2D(0.1)(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p3)
    c4 = BatchNormalization()(c4); c4 = ReLU()(c4)
    c4 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c4)
    c4 = BatchNormalization()(c4); c4 = ReLU()(c4)
    c4 = SpatialDropout2D(0.1)(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p4)
    c5 = BatchNormalization()(c5); c5 = ReLU()(c5)
    c5 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c5)
    c5 = BatchNormalization()(c5); c5 = ReLU()(c5)
    c5 = SpatialDropout2D(0.1)(c5)
    p5 = MaxPooling2D((2, 2))(c5)
    
    c6 = aspp_module(p5, output_filters=1024, rates=[1, 6, 12, 18])

    u7 = Conv2DTranspose(512, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c6)
    u7 = Concatenate()([u7, c5])
    c7 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u7)
    c7 = BatchNormalization()(c7); c7 = ReLU()(c7)
    c7 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c7)
    c7 = BatchNormalization()(c7); c7 = ReLU()(c7)
    c7 = cbam_module(c7)

    u8 = Conv2DTranspose(256, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c7)
    u8 = Concatenate()([u8, c4])
    c8 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u8)
    c8 = BatchNormalization()(c8); c8 = ReLU()(c8)
    c8 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c8)
    c8 = BatchNormalization()(c8); c8 = ReLU()(c8)
    c8 = cbam_module(c8)

    u9 = Conv2DTranspose(256, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c8)
    u9 = Concatenate()([u9, c3])
    c9 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u9)
    c9 = BatchNormalization()(c9); c9 = ReLU()(c9)
    c9 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c9)
    c9 = BatchNormalization()(c9); c9 = ReLU()(c9)
    c9 = cbam_module(c9)

    u10 = Conv2DTranspose(128, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c9)
    u10 = Concatenate()([u10, c2])
    c10 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u10)
    c10 = BatchNormalization()(c10); c10 = ReLU()(c10)
    c10 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c10)
    c10 = BatchNormalization()(c10); c10 = ReLU()(c10)
    c10 = cbam_module(c10)

    u11 = Conv2DTranspose(64, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c10)
    u11 = Concatenate()([u11, c1])
    c11 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u11)
    c11 = BatchNormalization()(c11); c11 = ReLU()(c11)
    c11 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c11)
    c11 = BatchNormalization()(c11); c11 = ReLU()(c11)
    c11 = cbam_module(c11)
 
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c11)

    return Model(inputs=inputs, outputs=outputs)

if __name__ == "__main__":
    model = CustomSegUNet()
    model.summary()
# Out:
# I0000 00:00:1765641780.941025      47 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 256, 256,  │        137 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 256, 256,  │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 256, 256,  │      4,736 │ re_lu[0][0]       │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d   │ (None, 256, 256,  │          0 │ re_lu_1[0][0]     │
# │ (SpatialDropout2D)  │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 128, 128,  │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 128, 128,  │      8,896 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 128, 128,  │     17,664 │ re_lu_2[0][0]     │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_1 │ (None, 128, 128,  │          0 │ re_lu_3[0][0]     │
# │ (SpatialDropout2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 64, 64,    │     34,176 │ max_pooling2d_1[… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_5  │ (None, 64, 64,    │     68,096 │ re_lu_4[0][0]     │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_2 │ (None, 64, 64,    │          0 │ re_lu_5[0][0]     │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 32, 32,    │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_6  │ (None, 32, 32,    │     68,096 │ max_pooling2d_2[… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_7  │ (None, 32, 32,    │     68,096 │ re_lu_6[0][0]     │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_3 │ (None, 32, 32,    │          0 │ re_lu_7[0][0]     │
# │ (SpatialDropout2D)  │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 16, 16,    │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_8  │ (None, 16, 16,    │    133,888 │ max_pooling2d_3[… │
# │ (SeparableConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_9  │ (None, 16, 16,    │    267,264 │ re_lu_8[0][0]     │
# │ (SeparableConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_4 │ (None, 16, 16,    │          0 │ re_lu_9[0][0]     │
# │ (SpatialDropout2D)  │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 8, 8, 512) │          0 │ spatial_dropout2… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_10 │ (None, 8, 8, 256) │    135,680 │ max_pooling2d_4[… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_11 │ (None, 8, 8, 256) │    135,680 │ max_pooling2d_4[… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_12 │ (None, 8, 8, 256) │    135,680 │ max_pooling2d_4[… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_13 │ (None, 8, 8, 256) │    135,680 │ max_pooling2d_4[… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 8, 8,      │          0 │ re_lu_10[0][0],   │
# │ (Concatenate)       │ 1024)             │            │ re_lu_11[0][0],   │
# │                     │                   │            │ re_lu_12[0][0],   │
# │                     │                   │            │ re_lu_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_14 │ (None, 8, 8,      │  1,049,600 │ concatenate[0][0] │
# │ (SeparableConv2D)   │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8,      │      4,096 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 8, 8,      │          0 │ batch_normalizat… │
# │                     │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spatial_dropout2d_5 │ (None, 8, 8,      │          0 │ re_lu_14[0][0]    │
# │ (SpatialDropout2D)  │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 16, 16,    │  4,719,104 │ spatial_dropout2… │
# │ (Conv2DTranspose)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 16, 16,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 1024)             │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_15 │ (None, 16, 16,    │    534,016 │ concatenate_1[0]… │
# │ (SeparableConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_15 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_16 │ (None, 16, 16,    │    267,264 │ re_lu_15[0][0]    │
# │ (SeparableConv2D)   │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │      2,048 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_16 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 512)       │          0 │ re_lu_16[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 512)       │          0 │ re_lu_16[0][0]    │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 64)        │     32,832 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 512)       │     33,280 │ dense[0][0],      │
# │                     │                   │            │ dense[1][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 512)       │          0 │ dense_1[0][0],    │
# │                     │                   │            │ dense_1[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 512)       │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 512) │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 16, 16,    │          0 │ re_lu_16[0][0],   │
# │                     │ 512)              │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_1 (Lambda)   │ (None, 16, 16, 1) │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_2 (Lambda)   │ (None, 16, 16, 1) │          0 │ multiply[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 16, 16, 2) │          0 │ lambda_1[0][0],   │
# │ (Concatenate)       │                   │            │ lambda_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 16, 16, 1) │         98 │ concatenate_2[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 16, 16,    │          0 │ multiply[0][0],   │
# │ (Multiply)          │ 512)              │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 32, 32,    │  1,179,904 │ multiply_1[0][0]  │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 32, 32,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_17 │ (None, 32, 32,    │    135,936 │ concatenate_3[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_17 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_18 │ (None, 32, 32,    │     68,096 │ re_lu_17[0][0]    │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_18 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ re_lu_18[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 256)       │          0 │ re_lu_18[0][0]    │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 32)        │      8,224 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256)       │      8,448 │ dense_2[0][0],    │
# │                     │                   │            │ dense_2[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 256)       │          0 │ dense_3[0][0],    │
# │                     │                   │            │ dense_3[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 256)       │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 256) │          0 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 32, 32,    │          0 │ re_lu_18[0][0],   │
# │ (Multiply)          │ 256)              │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_3 (Lambda)   │ (None, 32, 32, 1) │          0 │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_4 (Lambda)   │ (None, 32, 32, 1) │          0 │ multiply_2[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 32, 32, 2) │          0 │ lambda_3[0][0],   │
# │ (Concatenate)       │                   │            │ lambda_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32, 1) │         98 │ concatenate_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 32, 32,    │          0 │ multiply_2[0][0], │
# │ (Multiply)          │ 256)              │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 64, 64,    │    590,080 │ multiply_3[0][0]  │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_19 │ (None, 64, 64,    │    135,936 │ concatenate_5[0]… │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_19 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_20 │ (None, 64, 64,    │     68,096 │ re_lu_19[0][0]    │
# │ (SeparableConv2D)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │      1,024 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_20 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 256)       │          0 │ re_lu_20[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 256)       │          0 │ re_lu_20[0][0]    │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 32)        │      8,224 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 256)       │      8,448 │ dense_4[0][0],    │
# │                     │                   │            │ dense_4[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 256)       │          0 │ dense_5[0][0],    │
# │                     │                   │            │ dense_5[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 256)       │          0 │ add_2[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_2 (Reshape) │ (None, 1, 1, 256) │          0 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_4          │ (None, 64, 64,    │          0 │ re_lu_20[0][0],   │
# │ (Multiply)          │ 256)              │            │ reshape_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_5 (Lambda)   │ (None, 64, 64, 1) │          0 │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_6 (Lambda)   │ (None, 64, 64, 1) │          0 │ multiply_4[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 64, 64, 2) │          0 │ lambda_5[0][0],   │
# │ (Concatenate)       │                   │            │ lambda_6[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64, 1) │         98 │ concatenate_6[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_5          │ (None, 64, 64,    │          0 │ multiply_4[0][0], │
# │ (Multiply)          │ 256)              │            │ conv2d_2[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 128, 128,  │    295,040 │ multiply_5[0][0]  │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_21 │ (None, 128, 128,  │     35,200 │ concatenate_7[0]… │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_21 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_22 │ (None, 128, 128,  │     17,664 │ re_lu_21[0][0]    │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        512 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_22 (ReLU)     │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ re_lu_22[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 128)       │          0 │ re_lu_22[0][0]    │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 16)        │      2,064 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 128)       │      2,176 │ dense_6[0][0],    │
# │                     │                   │            │ dense_6[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_3 (Add)         │ (None, 128)       │          0 │ dense_7[0][0],    │
# │                     │                   │            │ dense_7[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 128)       │          0 │ add_3[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_3 (Reshape) │ (None, 1, 1, 128) │          0 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 128, 128,  │          0 │ re_lu_22[0][0],   │
# │ (Multiply)          │ 128)              │            │ reshape_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_7 (Lambda)   │ (None, 128, 128,  │          0 │ multiply_6[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_8 (Lambda)   │ (None, 128, 128,  │          0 │ multiply_6[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, 128, 128,  │          0 │ lambda_7[0][0],   │
# │ (Concatenate)       │ 2)                │            │ lambda_8[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │         98 │ concatenate_8[0]… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 128, 128,  │          0 │ multiply_6[0][0], │
# │ (Multiply)          │ 128)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_4  │ (None, 256, 256,  │     73,792 │ multiply_7[0][0]  │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ spatial_dropout2… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_23 │ (None, 256, 256,  │      9,408 │ concatenate_9[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_23 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_24 │ (None, 256, 256,  │      4,736 │ re_lu_23[0][0]    │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 256, 256,  │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_24 (ReLU)     │ (None, 256, 256,  │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ re_lu_24[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 64)        │          0 │ re_lu_24[0][0]    │
# │ (GlobalMaxPooling2… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_8 (Dense)     │ (None, 8)         │        520 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_9 (Dense)     │ (None, 64)        │        576 │ dense_8[0][0],    │
# │                     │                   │            │ dense_8[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_4 (Add)         │ (None, 64)        │          0 │ dense_9[0][0],    │
# │                     │                   │            │ dense_9[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 64)        │          0 │ add_4[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_4 (Reshape) │ (None, 1, 1, 64)  │          0 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_8          │ (None, 256, 256,  │          0 │ re_lu_24[0][0],   │
# │ (Multiply)          │ 64)               │            │ reshape_4[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_9 (Lambda)   │ (None, 256, 256,  │          0 │ multiply_8[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lambda_10 (Lambda)  │ (None, 256, 256,  │          0 │ multiply_8[0][0]  │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, 256, 256,  │          0 │ lambda_9[0][0],   │
# │ (Concatenate)       │ 2)                │            │ lambda_10[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 256, 256,  │         98 │ concatenate_10[0… │
# │                     │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_9          │ (None, 256, 256,  │          0 │ multiply_8[0][0], │
# │ (Multiply)          │ 64)               │            │ conv2d_4[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 256, 256,  │         65 │ multiply_9[0][0]  │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 10,530,636 (40.17 MB)
#  Trainable params: 10,516,812 (40.12 MB)
#  Non-trainable params: 13,824 (54.00 KB)

# %%
class EarlyStoppingByAccuracyChange(tf.keras.callbacks.Callback):
    def __init__(self, monitor='accuracy', threshold=0.00001, patience=3, verbose=0):
        super(EarlyStoppingByAccuracyChange, self).__init__()
        self.monitor = monitor
        self.threshold = threshold
        self.patience = patience
        self.verbose = verbose
        self.wait = 0
        self.best_accuracy = -float('inf')
        self.consecutive_stops = 0

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current_accuracy = logs.get(self.monitor)
        if current_accuracy is None:
            tf.get_logger().warning(
                'Early stopping requires %s available!', self.monitor
            )
            return

        if current_accuracy > self.best_accuracy:
            self.best_accuracy = current_accuracy
            self.wait = 0
            self.consecutive_stops = 0
        else:
            self.wait += 1
            accuracy_change = current_accuracy - self.best_accuracy
            if abs(accuracy_change) < self.threshold:
                self.consecutive_stops += 1
                if self.consecutive_stops >= self.patience:
                    if self.verbose > 0:
                        print(f"Epoch {epoch+1}: Early stopping triggered due to minimal accuracy change for {self.patience} epochs.")
                    self.model.stop_training = True
            else:
                self.consecutive_stops = 0

# %%
initial_lr = 0.001
optimizer = Adam(learning_rate=initial_lr)


segunet = CustomSegUNet(input_size=(256, 256, 1))
segunet.compile(
    optimizer=optimizer,
    loss=dice_loss,
    metrics=['accuracy', jaccard_coefficient, dice_coefficient]
)

model_checkpoint_dir = 'model'

checkpoint_path = os.path.join(model_checkpoint_dir, 'cp.ckpt')

checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(model_checkpoint_dir, 'gray2750.weights.h5'),
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True,
    verbose=1
)
early_stopping = EarlyStoppingByAccuracyChange(
    monitor='accuracy',
    threshold=0.00001,
    patience=10,
    verbose=1
)

lr_reduction = ReduceLROnPlateau(monitor='loss',
                                  patience=5,
                                  verbose=1,
                                  factor=0.5,
                                  min_lr=0.00001)


start_time = time.time()
history = segunet.fit(
    train_images_gray_clahe, train_masks,
    batch_size=32,
    epochs=100,
    callbacks=[early_stopping, lr_reduction, checkpoint_callback]
)

end_time = time.time()
training_time = end_time - start_time
avg_accuracy = np.mean(history.history['accuracy'])
avg_jaccard = np.mean(history.history['jaccard_coefficient'])
avg_dice = np.mean(history.history['dice_coefficient'])

print("SegUNet output shape:", segunet.output_shape)
print(f"Thời gian huấn luyện: {training_time:.2f} giây")
print(f"Accuracy trung bình: {avg_accuracy*100:.2f}%")
print(f"Jaccard trung bình: {avg_jaccard*100:.2f}%")
print(f"Dice trung bình: {avg_dice*100:.2f}%")
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765641808.324442     274 service.cc:148] XLA service 0x7dced8002d00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1765641808.325131     274 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1765641811.626046     274 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1765641834.736359     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765641834.962584     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765641836.896166     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765641837.105181     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765641837.672404     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765641837.881921     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765641838.817496     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765641839.120355     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765641841.686231     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765641842.104516     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 16:04:02.255517: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,128,128]{3,2,1,0}, f32[32,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-13 16:04:02.361112: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.105726781s
# Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,128,128]{3,2,1,0}, f32[32,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1765641861.323832     274 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 60/61 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - accuracy: 0.6500 - dice_coefficient: 0.4457 - jaccard_coefficient: 0.2928 - loss: 0.5543
# E0000 00:00:1765641912.537661     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765641912.771562     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765641913.986055     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765641914.219677     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765641917.112539     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765641917.296633     274 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6521 - dice_coefficient: 0.4473 - jaccard_coefficient: 0.2942 - loss: 0.5527
# Epoch 1: loss improved from inf to 0.45735, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 148s 1s/step - accuracy: 0.6542 - dice_coefficient: 0.4488 - jaccard_coefficient: 0.2956 - loss: 0.5511 - learning_rate: 0.0010
# Epoch 2/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9098 - dice_coefficient: 0.7414 - jaccard_coefficient: 0.5921 - loss: 0.2586
# Epoch 2: loss improved from 0.45735 to 0.22465, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9099 - dice_coefficient: 0.7420 - jaccard_coefficient: 0.5928 - loss: 0.2581 - learning_rate: 0.0010
# Epoch 3/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9346 - dice_coefficient: 0.8252 - jaccard_coefficient: 0.7043 - loss: 0.1748
# Epoch 3: loss improved from 0.22465 to 0.17373, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9346 - dice_coefficient: 0.8252 - jaccard_coefficient: 0.7043 - loss: 0.1748 - learning_rate: 0.0010
# Epoch 4/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9296 - dice_coefficient: 0.8163 - jaccard_coefficient: 0.6922 - loss: 0.1837
# Epoch 4: loss improved from 0.17373 to 0.17019, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9297 - dice_coefficient: 0.8165 - jaccard_coefficient: 0.6925 - loss: 0.1835 - learning_rate: 0.0010
# Epoch 5/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9397 - dice_coefficient: 0.8386 - jaccard_coefficient: 0.7236 - loss: 0.1614
# Epoch 5: loss improved from 0.17019 to 0.15488, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9397 - dice_coefficient: 0.8387 - jaccard_coefficient: 0.7238 - loss: 0.1613 - learning_rate: 0.0010
# Epoch 6/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9433 - dice_coefficient: 0.8562 - jaccard_coefficient: 0.7494 - loss: 0.1437
# Epoch 6: loss improved from 0.15488 to 0.14020, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9433 - dice_coefficient: 0.8563 - jaccard_coefficient: 0.7495 - loss: 0.1437 - learning_rate: 0.0010
# Epoch 7/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9426 - dice_coefficient: 0.8530 - jaccard_coefficient: 0.7447 - loss: 0.1470
# Epoch 7: loss did not improve from 0.14020
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9426 - dice_coefficient: 0.8531 - jaccard_coefficient: 0.7447 - loss: 0.1469 - learning_rate: 0.0010
# Epoch 8/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9366 - dice_coefficient: 0.8334 - jaccard_coefficient: 0.7170 - loss: 0.1666
# Epoch 8: loss did not improve from 0.14020
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9367 - dice_coefficient: 0.8337 - jaccard_coefficient: 0.7174 - loss: 0.1663 - learning_rate: 0.0010
# Epoch 9/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9492 - dice_coefficient: 0.8722 - jaccard_coefficient: 0.7745 - loss: 0.1278
# Epoch 9: loss improved from 0.14020 to 0.13044, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9492 - dice_coefficient: 0.8721 - jaccard_coefficient: 0.7744 - loss: 0.1278 - learning_rate: 0.0010
# Epoch 10/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9501 - dice_coefficient: 0.8743 - jaccard_coefficient: 0.7774 - loss: 0.1257
# Epoch 10: loss improved from 0.13044 to 0.12617, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9500 - dice_coefficient: 0.8743 - jaccard_coefficient: 0.7774 - loss: 0.1257 - learning_rate: 0.0010
# Epoch 11/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9484 - dice_coefficient: 0.8709 - jaccard_coefficient: 0.7725 - loss: 0.1291
# Epoch 11: loss did not improve from 0.12617
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9484 - dice_coefficient: 0.8708 - jaccard_coefficient: 0.7724 - loss: 0.1292 - learning_rate: 0.0010
# Epoch 12/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9562 - dice_coefficient: 0.8874 - jaccard_coefficient: 0.7981 - loss: 0.1126
# Epoch 12: loss improved from 0.12617 to 0.11244, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9562 - dice_coefficient: 0.8874 - jaccard_coefficient: 0.7981 - loss: 0.1126 - learning_rate: 0.0010
# Epoch 13/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9525 - dice_coefficient: 0.8827 - jaccard_coefficient: 0.7908 - loss: 0.1173
# Epoch 13: loss did not improve from 0.11244
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9525 - dice_coefficient: 0.8827 - jaccard_coefficient: 0.7907 - loss: 0.1173 - learning_rate: 0.0010
# Epoch 14/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9531 - dice_coefficient: 0.8839 - jaccard_coefficient: 0.7929 - loss: 0.1161
# Epoch 14: loss did not improve from 0.11244
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9531 - dice_coefficient: 0.8839 - jaccard_coefficient: 0.7929 - loss: 0.1161 - learning_rate: 0.0010
# Epoch 15/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9572 - dice_coefficient: 0.8939 - jaccard_coefficient: 0.8089 - loss: 0.1061
# Epoch 15: loss improved from 0.11244 to 0.10990, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9571 - dice_coefficient: 0.8938 - jaccard_coefficient: 0.8088 - loss: 0.1062 - learning_rate: 0.0010
# Epoch 16/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9542 - dice_coefficient: 0.8803 - jaccard_coefficient: 0.7875 - loss: 0.1197
# Epoch 16: loss improved from 0.10990 to 0.10878, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9543 - dice_coefficient: 0.8805 - jaccard_coefficient: 0.7878 - loss: 0.1195 - learning_rate: 0.0010
# Epoch 17/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9607 - dice_coefficient: 0.9011 - jaccard_coefficient: 0.8204 - loss: 0.0989
# Epoch 17: loss improved from 0.10878 to 0.09998, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9607 - dice_coefficient: 0.9011 - jaccard_coefficient: 0.8204 - loss: 0.0989 - learning_rate: 0.0010
# Epoch 18/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9589 - dice_coefficient: 0.8951 - jaccard_coefficient: 0.8112 - loss: 0.1049
# Epoch 18: loss improved from 0.09998 to 0.09761, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9590 - dice_coefficient: 0.8952 - jaccard_coefficient: 0.8114 - loss: 0.1048 - learning_rate: 0.0010
# Epoch 19/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9615 - dice_coefficient: 0.9008 - jaccard_coefficient: 0.8203 - loss: 0.0992
# Epoch 19: loss improved from 0.09761 to 0.09663, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9615 - dice_coefficient: 0.9008 - jaccard_coefficient: 0.8204 - loss: 0.0992 - learning_rate: 0.0010
# Epoch 20/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9623 - dice_coefficient: 0.9072 - jaccard_coefficient: 0.8306 - loss: 0.0928
# Epoch 20: loss improved from 0.09663 to 0.09229, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9623 - dice_coefficient: 0.9072 - jaccard_coefficient: 0.8306 - loss: 0.0928 - learning_rate: 0.0010
# Epoch 21/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9641 - dice_coefficient: 0.9089 - jaccard_coefficient: 0.8340 - loss: 0.0911
# Epoch 21: loss did not improve from 0.09229
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9641 - dice_coefficient: 0.9088 - jaccard_coefficient: 0.8339 - loss: 0.0912 - learning_rate: 0.0010
# Epoch 22/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9624 - dice_coefficient: 0.9062 - jaccard_coefficient: 0.8292 - loss: 0.0938
# Epoch 22: loss did not improve from 0.09229
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9624 - dice_coefficient: 0.9061 - jaccard_coefficient: 0.8291 - loss: 0.0937 - learning_rate: 0.0010
# Epoch 23/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9628 - dice_coefficient: 0.9095 - jaccard_coefficient: 0.8346 - loss: 0.0904
# Epoch 23: loss did not improve from 0.09229
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9628 - dice_coefficient: 0.9093 - jaccard_coefficient: 0.8344 - loss: 0.0905 - learning_rate: 0.0010
# Epoch 24/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9595 - dice_coefficient: 0.8971 - jaccard_coefficient: 0.8139 - loss: 0.1029
# Epoch 24: loss did not improve from 0.09229
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9595 - dice_coefficient: 0.8972 - jaccard_coefficient: 0.8140 - loss: 0.1028 - learning_rate: 0.0010
# Epoch 25/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9593 - dice_coefficient: 0.8976 - jaccard_coefficient: 0.8147 - loss: 0.1024
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 25: loss did not improve from 0.09229
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9593 - dice_coefficient: 0.8977 - jaccard_coefficient: 0.8149 - loss: 0.1023 - learning_rate: 0.0010
# Epoch 26/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9668 - dice_coefficient: 0.9160 - jaccard_coefficient: 0.8455 - loss: 0.0839
# Epoch 26: loss improved from 0.09229 to 0.08389, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9668 - dice_coefficient: 0.9160 - jaccard_coefficient: 0.8455 - loss: 0.0839 - learning_rate: 5.0000e-04
# Epoch 27/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9688 - dice_coefficient: 0.9254 - jaccard_coefficient: 0.8614 - loss: 0.0746
# Epoch 27: loss improved from 0.08389 to 0.07774, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9688 - dice_coefficient: 0.9254 - jaccard_coefficient: 0.8613 - loss: 0.0746 - learning_rate: 5.0000e-04
# Epoch 28/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9702 - dice_coefficient: 0.9240 - jaccard_coefficient: 0.8589 - loss: 0.0761
# Epoch 28: loss improved from 0.07774 to 0.07565, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9702 - dice_coefficient: 0.9240 - jaccard_coefficient: 0.8589 - loss: 0.0760 - learning_rate: 5.0000e-04
# Epoch 29/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9700 - dice_coefficient: 0.9270 - jaccard_coefficient: 0.8645 - loss: 0.0730
# Epoch 29: loss improved from 0.07565 to 0.07241, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9700 - dice_coefficient: 0.9270 - jaccard_coefficient: 0.8645 - loss: 0.0730 - learning_rate: 5.0000e-04
# Epoch 30/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9694 - dice_coefficient: 0.9245 - jaccard_coefficient: 0.8599 - loss: 0.0755
# Epoch 30: loss did not improve from 0.07241
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9694 - dice_coefficient: 0.9245 - jaccard_coefficient: 0.8599 - loss: 0.0755 - learning_rate: 5.0000e-04
# Epoch 31/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9719 - dice_coefficient: 0.9292 - jaccard_coefficient: 0.8680 - loss: 0.0708
# Epoch 31: loss improved from 0.07241 to 0.06988, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9719 - dice_coefficient: 0.9292 - jaccard_coefficient: 0.8681 - loss: 0.0708 - learning_rate: 5.0000e-04
# Epoch 32/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9730 - dice_coefficient: 0.9306 - jaccard_coefficient: 0.8705 - loss: 0.0694
# Epoch 32: loss improved from 0.06988 to 0.06832, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9730 - dice_coefficient: 0.9306 - jaccard_coefficient: 0.8705 - loss: 0.0694 - learning_rate: 5.0000e-04
# Epoch 33/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9743 - dice_coefficient: 0.9381 - jaccard_coefficient: 0.8835 - loss: 0.0619
# Epoch 33: loss improved from 0.06832 to 0.06504, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9743 - dice_coefficient: 0.9380 - jaccard_coefficient: 0.8834 - loss: 0.0620 - learning_rate: 5.0000e-04
# Epoch 34/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9734 - dice_coefficient: 0.9369 - jaccard_coefficient: 0.8815 - loss: 0.0631
# Epoch 34: loss improved from 0.06504 to 0.06491, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9734 - dice_coefficient: 0.9369 - jaccard_coefficient: 0.8815 - loss: 0.0631 - learning_rate: 5.0000e-04
# Epoch 35/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9742 - dice_coefficient: 0.9372 - jaccard_coefficient: 0.8820 - loss: 0.0628
# Epoch 35: loss improved from 0.06491 to 0.06278, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9742 - dice_coefficient: 0.9372 - jaccard_coefficient: 0.8819 - loss: 0.0628 - learning_rate: 5.0000e-04
# Epoch 36/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9740 - dice_coefficient: 0.9368 - jaccard_coefficient: 0.8813 - loss: 0.0632
# Epoch 36: loss did not improve from 0.06278
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9740 - dice_coefficient: 0.9368 - jaccard_coefficient: 0.8813 - loss: 0.0632 - learning_rate: 5.0000e-04
# Epoch 37/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9744 - dice_coefficient: 0.9360 - jaccard_coefficient: 0.8800 - loss: 0.0640
# Epoch 37: loss did not improve from 0.06278
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9744 - dice_coefficient: 0.9361 - jaccard_coefficient: 0.8801 - loss: 0.0639 - learning_rate: 5.0000e-04
# Epoch 38/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9749 - dice_coefficient: 0.9387 - jaccard_coefficient: 0.8847 - loss: 0.0613
# Epoch 38: loss improved from 0.06278 to 0.06241, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9749 - dice_coefficient: 0.9386 - jaccard_coefficient: 0.8847 - loss: 0.0614 - learning_rate: 5.0000e-04
# Epoch 39/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9746 - dice_coefficient: 0.9384 - jaccard_coefficient: 0.8841 - loss: 0.0616
# Epoch 39: loss improved from 0.06241 to 0.06031, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9746 - dice_coefficient: 0.9384 - jaccard_coefficient: 0.8842 - loss: 0.0616 - learning_rate: 5.0000e-04
# Epoch 40/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9763 - dice_coefficient: 0.9421 - jaccard_coefficient: 0.8907 - loss: 0.0579
# Epoch 40: loss improved from 0.06031 to 0.05994, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9763 - dice_coefficient: 0.9420 - jaccard_coefficient: 0.8906 - loss: 0.0579 - learning_rate: 5.0000e-04
# Epoch 41/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9750 - dice_coefficient: 0.9391 - jaccard_coefficient: 0.8852 - loss: 0.0609
# Epoch 41: loss did not improve from 0.05994
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9750 - dice_coefficient: 0.9390 - jaccard_coefficient: 0.8852 - loss: 0.0610 - learning_rate: 5.0000e-04
# Epoch 42/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9749 - dice_coefficient: 0.9404 - jaccard_coefficient: 0.8877 - loss: 0.0595
# Epoch 42: loss improved from 0.05994 to 0.05986, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9749 - dice_coefficient: 0.9404 - jaccard_coefficient: 0.8877 - loss: 0.0595 - learning_rate: 5.0000e-04
# Epoch 43/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9713 - dice_coefficient: 0.9313 - jaccard_coefficient: 0.8717 - loss: 0.0687
# Epoch 43: loss did not improve from 0.05986
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9713 - dice_coefficient: 0.9313 - jaccard_coefficient: 0.8717 - loss: 0.0687 - learning_rate: 5.0000e-04
# Epoch 44/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9749 - dice_coefficient: 0.9389 - jaccard_coefficient: 0.8851 - loss: 0.0611
# Epoch 44: loss did not improve from 0.05986
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9749 - dice_coefficient: 0.9390 - jaccard_coefficient: 0.8851 - loss: 0.0610 - learning_rate: 5.0000e-04
# Epoch 45/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9768 - dice_coefficient: 0.9442 - jaccard_coefficient: 0.8945 - loss: 0.0558
# Epoch 45: loss improved from 0.05986 to 0.05605, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9768 - dice_coefficient: 0.9442 - jaccard_coefficient: 0.8945 - loss: 0.0558 - learning_rate: 5.0000e-04
# Epoch 46/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9783 - dice_coefficient: 0.9471 - jaccard_coefficient: 0.8997 - loss: 0.0529
# Epoch 46: loss improved from 0.05605 to 0.05330, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9783 - dice_coefficient: 0.9471 - jaccard_coefficient: 0.8997 - loss: 0.0529 - learning_rate: 5.0000e-04
# Epoch 47/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9787 - dice_coefficient: 0.9453 - jaccard_coefficient: 0.8964 - loss: 0.0547
# Epoch 47: loss did not improve from 0.05330
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9787 - dice_coefficient: 0.9453 - jaccard_coefficient: 0.8964 - loss: 0.0547 - learning_rate: 5.0000e-04
# Epoch 48/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9793 - dice_coefficient: 0.9497 - jaccard_coefficient: 0.9043 - loss: 0.0503
# Epoch 48: loss improved from 0.05330 to 0.05145, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9793 - dice_coefficient: 0.9497 - jaccard_coefficient: 0.9043 - loss: 0.0503 - learning_rate: 5.0000e-04
# Epoch 49/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9779 - dice_coefficient: 0.9471 - jaccard_coefficient: 0.8998 - loss: 0.0529
# Epoch 49: loss improved from 0.05145 to 0.05102, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 742ms/step - accuracy: 0.9779 - dice_coefficient: 0.9472 - jaccard_coefficient: 0.8998 - loss: 0.0528 - learning_rate: 5.0000e-04
# Epoch 50/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9789 - dice_coefficient: 0.9473 - jaccard_coefficient: 0.9001 - loss: 0.0527
# Epoch 50: loss did not improve from 0.05102
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9789 - dice_coefficient: 0.9473 - jaccard_coefficient: 0.9001 - loss: 0.0527 - learning_rate: 5.0000e-04
# Epoch 51/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9781 - dice_coefficient: 0.9481 - jaccard_coefficient: 0.9014 - loss: 0.0519
# Epoch 51: loss did not improve from 0.05102
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9782 - dice_coefficient: 0.9481 - jaccard_coefficient: 0.9014 - loss: 0.0519 - learning_rate: 5.0000e-04
# Epoch 52/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9782 - dice_coefficient: 0.9484 - jaccard_coefficient: 0.9020 - loss: 0.0516
# Epoch 52: loss did not improve from 0.05102
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9782 - dice_coefficient: 0.9484 - jaccard_coefficient: 0.9020 - loss: 0.0516 - learning_rate: 5.0000e-04
# Epoch 53/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9813 - dice_coefficient: 0.9531 - jaccard_coefficient: 0.9106 - loss: 0.0469
# Epoch 53: loss improved from 0.05102 to 0.04876, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9813 - dice_coefficient: 0.9531 - jaccard_coefficient: 0.9106 - loss: 0.0469 - learning_rate: 5.0000e-04
# Epoch 54/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9798 - dice_coefficient: 0.9522 - jaccard_coefficient: 0.9089 - loss: 0.0478
# Epoch 54: loss improved from 0.04876 to 0.04790, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9798 - dice_coefficient: 0.9522 - jaccard_coefficient: 0.9089 - loss: 0.0478 - learning_rate: 5.0000e-04
# Epoch 55/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9817 - dice_coefficient: 0.9549 - jaccard_coefficient: 0.9137 - loss: 0.0451
# Epoch 55: loss improved from 0.04790 to 0.04618, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9816 - dice_coefficient: 0.9549 - jaccard_coefficient: 0.9137 - loss: 0.0451 - learning_rate: 5.0000e-04
# Epoch 56/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9803 - dice_coefficient: 0.9511 - jaccard_coefficient: 0.9068 - loss: 0.0489
# Epoch 56: loss did not improve from 0.04618
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9802 - dice_coefficient: 0.9511 - jaccard_coefficient: 0.9069 - loss: 0.0489 - learning_rate: 5.0000e-04
# Epoch 57/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9803 - dice_coefficient: 0.9526 - jaccard_coefficient: 0.9097 - loss: 0.0474
# Epoch 57: loss improved from 0.04618 to 0.04540, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9803 - dice_coefficient: 0.9527 - jaccard_coefficient: 0.9097 - loss: 0.0474 - learning_rate: 5.0000e-04
# Epoch 58/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9814 - dice_coefficient: 0.9558 - jaccard_coefficient: 0.9155 - loss: 0.0442
# Epoch 58: loss improved from 0.04540 to 0.04499, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9814 - dice_coefficient: 0.9558 - jaccard_coefficient: 0.9154 - loss: 0.0442 - learning_rate: 5.0000e-04
# Epoch 59/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9807 - dice_coefficient: 0.9526 - jaccard_coefficient: 0.9096 - loss: 0.0474
# Epoch 59: loss did not improve from 0.04499
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9807 - dice_coefficient: 0.9526 - jaccard_coefficient: 0.9096 - loss: 0.0474 - learning_rate: 5.0000e-04
# Epoch 60/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9808 - dice_coefficient: 0.9548 - jaccard_coefficient: 0.9138 - loss: 0.0452
# Epoch 60: loss did not improve from 0.04499
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9808 - dice_coefficient: 0.9548 - jaccard_coefficient: 0.9138 - loss: 0.0452 - learning_rate: 5.0000e-04
# Epoch 61/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9810 - dice_coefficient: 0.9546 - jaccard_coefficient: 0.9132 - loss: 0.0454
# Epoch 61: loss improved from 0.04499 to 0.04476, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9810 - dice_coefficient: 0.9546 - jaccard_coefficient: 0.9132 - loss: 0.0454 - learning_rate: 5.0000e-04
# Epoch 62/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9807 - dice_coefficient: 0.9555 - jaccard_coefficient: 0.9148 - loss: 0.0445
# Epoch 62: loss did not improve from 0.04476
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9808 - dice_coefficient: 0.9555 - jaccard_coefficient: 0.9148 - loss: 0.0445 - learning_rate: 5.0000e-04
# Epoch 63/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9822 - dice_coefficient: 0.9563 - jaccard_coefficient: 0.9164 - loss: 0.0437
# Epoch 63: loss did not improve from 0.04476
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9822 - dice_coefficient: 0.9563 - jaccard_coefficient: 0.9163 - loss: 0.0437 - learning_rate: 5.0000e-04
# Epoch 64/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9821 - dice_coefficient: 0.9560 - jaccard_coefficient: 0.9157 - loss: 0.0440
# Epoch 64: loss did not improve from 0.04476
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9821 - dice_coefficient: 0.9559 - jaccard_coefficient: 0.9157 - loss: 0.0440 - learning_rate: 5.0000e-04
# Epoch 65/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9819 - dice_coefficient: 0.9557 - jaccard_coefficient: 0.9153 - loss: 0.0442
# Epoch 65: loss improved from 0.04476 to 0.04447, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9819 - dice_coefficient: 0.9557 - jaccard_coefficient: 0.9152 - loss: 0.0442 - learning_rate: 5.0000e-04
# Epoch 66/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9802 - dice_coefficient: 0.9511 - jaccard_coefficient: 0.9068 - loss: 0.0489
# Epoch 66: loss did not improve from 0.04447
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9802 - dice_coefficient: 0.9511 - jaccard_coefficient: 0.9069 - loss: 0.0489 - learning_rate: 5.0000e-04
# Epoch 67/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9824 - dice_coefficient: 0.9571 - jaccard_coefficient: 0.9178 - loss: 0.0429
# Epoch 67: loss improved from 0.04447 to 0.04203, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9824 - dice_coefficient: 0.9571 - jaccard_coefficient: 0.9178 - loss: 0.0429 - learning_rate: 5.0000e-04
# Epoch 68/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9814 - dice_coefficient: 0.9551 - jaccard_coefficient: 0.9144 - loss: 0.0449
# Epoch 68: loss improved from 0.04203 to 0.04153, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9814 - dice_coefficient: 0.9552 - jaccard_coefficient: 0.9145 - loss: 0.0448 - learning_rate: 5.0000e-04
# Epoch 69/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9829 - dice_coefficient: 0.9588 - jaccard_coefficient: 0.9211 - loss: 0.0412
# Epoch 69: loss did not improve from 0.04153
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9829 - dice_coefficient: 0.9588 - jaccard_coefficient: 0.9211 - loss: 0.0412 - learning_rate: 5.0000e-04
# Epoch 70/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9823 - dice_coefficient: 0.9576 - jaccard_coefficient: 0.9190 - loss: 0.0424
# Epoch 70: loss improved from 0.04153 to 0.04049, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9823 - dice_coefficient: 0.9576 - jaccard_coefficient: 0.9190 - loss: 0.0424 - learning_rate: 5.0000e-04
# Epoch 71/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9814 - dice_coefficient: 0.9556 - jaccard_coefficient: 0.9151 - loss: 0.0444
# Epoch 71: loss did not improve from 0.04049
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9814 - dice_coefficient: 0.9556 - jaccard_coefficient: 0.9151 - loss: 0.0444 - learning_rate: 5.0000e-04
# Epoch 72/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9816 - dice_coefficient: 0.9546 - jaccard_coefficient: 0.9138 - loss: 0.0454
# Epoch 72: loss did not improve from 0.04049
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9816 - dice_coefficient: 0.9546 - jaccard_coefficient: 0.9138 - loss: 0.0454 - learning_rate: 5.0000e-04
# Epoch 73/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9790 - dice_coefficient: 0.9488 - jaccard_coefficient: 0.9028 - loss: 0.0512
# Epoch 73: loss did not improve from 0.04049
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9791 - dice_coefficient: 0.9488 - jaccard_coefficient: 0.9029 - loss: 0.0512 - learning_rate: 5.0000e-04
# Epoch 74/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9829 - dice_coefficient: 0.9586 - jaccard_coefficient: 0.9206 - loss: 0.0414
# Epoch 74: loss did not improve from 0.04049
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9829 - dice_coefficient: 0.9586 - jaccard_coefficient: 0.9206 - loss: 0.0414 - learning_rate: 5.0000e-04
# Epoch 75/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9836 - dice_coefficient: 0.9585 - jaccard_coefficient: 0.9204 - loss: 0.0415
# Epoch 75: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 75: loss did not improve from 0.04049
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9836 - dice_coefficient: 0.9585 - jaccard_coefficient: 0.9204 - loss: 0.0415 - learning_rate: 5.0000e-04
# Epoch 76/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9842 - dice_coefficient: 0.9623 - jaccard_coefficient: 0.9273 - loss: 0.0377
# Epoch 76: loss improved from 0.04049 to 0.03790, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9842 - dice_coefficient: 0.9622 - jaccard_coefficient: 0.9273 - loss: 0.0377 - learning_rate: 2.5000e-04
# Epoch 77/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9851 - dice_coefficient: 0.9646 - jaccard_coefficient: 0.9318 - loss: 0.0354
# Epoch 77: loss improved from 0.03790 to 0.03620, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9851 - dice_coefficient: 0.9646 - jaccard_coefficient: 0.9317 - loss: 0.0354 - learning_rate: 2.5000e-04
# Epoch 78/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9853 - dice_coefficient: 0.9628 - jaccard_coefficient: 0.9284 - loss: 0.0372
# Epoch 78: loss improved from 0.03620 to 0.03559, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9853 - dice_coefficient: 0.9628 - jaccard_coefficient: 0.9285 - loss: 0.0372 - learning_rate: 2.5000e-04
# Epoch 79/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9851 - dice_coefficient: 0.9628 - jaccard_coefficient: 0.9288 - loss: 0.0372
# Epoch 79: loss improved from 0.03559 to 0.03536, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9852 - dice_coefficient: 0.9628 - jaccard_coefficient: 0.9288 - loss: 0.0372 - learning_rate: 2.5000e-04
# Epoch 80/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9859 - dice_coefficient: 0.9665 - jaccard_coefficient: 0.9352 - loss: 0.0335
# Epoch 80: loss improved from 0.03536 to 0.03390, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9859 - dice_coefficient: 0.9664 - jaccard_coefficient: 0.9351 - loss: 0.0336 - learning_rate: 2.5000e-04
# Epoch 81/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9859 - dice_coefficient: 0.9661 - jaccard_coefficient: 0.9345 - loss: 0.0339
# Epoch 81: loss improved from 0.03390 to 0.03378, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9859 - dice_coefficient: 0.9661 - jaccard_coefficient: 0.9345 - loss: 0.0339 - learning_rate: 2.5000e-04
# Epoch 82/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9862 - dice_coefficient: 0.9672 - jaccard_coefficient: 0.9366 - loss: 0.0328
# Epoch 82: loss improved from 0.03378 to 0.03352, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9862 - dice_coefficient: 0.9672 - jaccard_coefficient: 0.9365 - loss: 0.0328 - learning_rate: 2.5000e-04
# Epoch 83/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9868 - dice_coefficient: 0.9681 - jaccard_coefficient: 0.9383 - loss: 0.0319
# Epoch 83: loss improved from 0.03352 to 0.03312, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9868 - dice_coefficient: 0.9681 - jaccard_coefficient: 0.9382 - loss: 0.0319 - learning_rate: 2.5000e-04
# Epoch 84/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9864 - dice_coefficient: 0.9675 - jaccard_coefficient: 0.9370 - loss: 0.0325
# Epoch 84: loss improved from 0.03312 to 0.03301, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9864 - dice_coefficient: 0.9675 - jaccard_coefficient: 0.9370 - loss: 0.0325 - learning_rate: 2.5000e-04
# Epoch 85/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9858 - dice_coefficient: 0.9671 - jaccard_coefficient: 0.9364 - loss: 0.0329
# Epoch 85: loss improved from 0.03301 to 0.03246, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9858 - dice_coefficient: 0.9671 - jaccard_coefficient: 0.9364 - loss: 0.0329 - learning_rate: 2.5000e-04
# Epoch 86/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9864 - dice_coefficient: 0.9674 - jaccard_coefficient: 0.9369 - loss: 0.0326
# Epoch 86: loss did not improve from 0.03246
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9864 - dice_coefficient: 0.9674 - jaccard_coefficient: 0.9369 - loss: 0.0326 - learning_rate: 2.5000e-04
# Epoch 87/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9863 - dice_coefficient: 0.9683 - jaccard_coefficient: 0.9386 - loss: 0.0317
# Epoch 87: loss did not improve from 0.03246
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9863 - dice_coefficient: 0.9683 - jaccard_coefficient: 0.9386 - loss: 0.0317 - learning_rate: 2.5000e-04
# Epoch 88/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9869 - dice_coefficient: 0.9683 - jaccard_coefficient: 0.9386 - loss: 0.0317
# Epoch 88: loss improved from 0.03246 to 0.03207, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9869 - dice_coefficient: 0.9683 - jaccard_coefficient: 0.9386 - loss: 0.0317 - learning_rate: 2.5000e-04
# Epoch 89/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9869 - dice_coefficient: 0.9687 - jaccard_coefficient: 0.9393 - loss: 0.0313
# Epoch 89: loss improved from 0.03207 to 0.03160, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9869 - dice_coefficient: 0.9686 - jaccard_coefficient: 0.9393 - loss: 0.0314 - learning_rate: 2.5000e-04
# Epoch 90/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9871 - dice_coefficient: 0.9698 - jaccard_coefficient: 0.9414 - loss: 0.0302
# Epoch 90: loss improved from 0.03160 to 0.03141, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9870 - dice_coefficient: 0.9698 - jaccard_coefficient: 0.9414 - loss: 0.0302 - learning_rate: 2.5000e-04
# Epoch 91/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9868 - dice_coefficient: 0.9684 - jaccard_coefficient: 0.9388 - loss: 0.0316
# Epoch 91: loss did not improve from 0.03141
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9868 - dice_coefficient: 0.9684 - jaccard_coefficient: 0.9388 - loss: 0.0316 - learning_rate: 2.5000e-04
# Epoch 92/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9867 - dice_coefficient: 0.9675 - jaccard_coefficient: 0.9372 - loss: 0.0325
# Epoch 92: loss did not improve from 0.03141
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9867 - dice_coefficient: 0.9675 - jaccard_coefficient: 0.9372 - loss: 0.0324 - learning_rate: 2.5000e-04
# Epoch 93/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9875 - dice_coefficient: 0.9704 - jaccard_coefficient: 0.9425 - loss: 0.0296
# Epoch 93: loss improved from 0.03141 to 0.03099, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 741ms/step - accuracy: 0.9875 - dice_coefficient: 0.9704 - jaccard_coefficient: 0.9425 - loss: 0.0296 - learning_rate: 2.5000e-04
# Epoch 94/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9871 - dice_coefficient: 0.9681 - jaccard_coefficient: 0.9382 - loss: 0.0319
# Epoch 94: loss did not improve from 0.03099
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9871 - dice_coefficient: 0.9681 - jaccard_coefficient: 0.9383 - loss: 0.0319 - learning_rate: 2.5000e-04
# Epoch 95/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9870 - dice_coefficient: 0.9701 - jaccard_coefficient: 0.9421 - loss: 0.0299
# Epoch 95: loss improved from 0.03099 to 0.03051, saving model to model/gray2750.weights.h5
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 740ms/step - accuracy: 0.9870 - dice_coefficient: 0.9701 - jaccard_coefficient: 0.9420 - loss: 0.0299 - learning_rate: 2.5000e-04
# Epoch 96/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9879 - dice_coefficient: 0.9697 - jaccard_coefficient: 0.9413 - loss: 0.0303
# Epoch 96: loss did not improve from 0.03051
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9878 - dice_coefficient: 0.9697 - jaccard_coefficient: 0.9412 - loss: 0.0303 - learning_rate: 2.5000e-04
# Epoch 97/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9874 - dice_coefficient: 0.9702 - jaccard_coefficient: 0.9421 - loss: 0.0298
# Epoch 97: loss did not improve from 0.03051
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9874 - dice_coefficient: 0.9701 - jaccard_coefficient: 0.9421 - loss: 0.0299 - learning_rate: 2.5000e-04
# Epoch 98/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9873 - dice_coefficient: 0.9688 - jaccard_coefficient: 0.9395 - loss: 0.0312
# Epoch 98: loss did not improve from 0.03051
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 730ms/step - accuracy: 0.9873 - dice_coefficient: 0.9688 - jaccard_coefficient: 0.9395 - loss: 0.0312 - learning_rate: 2.5000e-04
# Epoch 99/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9874 - dice_coefficient: 0.9688 - jaccard_coefficient: 0.9397 - loss: 0.0312
# Epoch 99: loss did not improve from 0.03051
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9874 - dice_coefficient: 0.9688 - jaccard_coefficient: 0.9397 - loss: 0.0312 - learning_rate: 2.5000e-04
# Epoch 100/100
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9875 - dice_coefficient: 0.9700 - jaccard_coefficient: 0.9418 - loss: 0.0300
# Epoch 100: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 100: loss did not improve from 0.03051
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 45s 729ms/step - accuracy: 0.9875 - dice_coefficient: 0.9700 - jaccard_coefficient: 0.9418 - loss: 0.0300 - learning_rate: 2.5000e-04
# SegUNet output shape: (None, 256, 256, 1)
# Thời gian huấn luyện: 4599.41 giây
# Accuracy trung bình: 97.15%
# Jaccard trung bình: 87.37%
# Dice trung bình: 92.99%

# %%
acc = history.history['accuracy']
loss = history.history['loss']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Accuracy', color='green')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Loss', color='red')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.savefig('Gray_2750_acc_loss.png', dpi=300)
plt.show()

# %%
def apply_morphology(mask, kernel_size=3, iterations=1):
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))
    mask = (mask > 0.5).astype(np.uint8)  

    closed = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=iterations)

    opened = cv2.morphologyEx(closed, cv2.MORPH_OPEN, kernel, iterations=iterations)

    return opened.astype(np.float32)  


print("🔍 Đánh giá không hậu xử lý...")
results = segunet.evaluate(test_images_gray_clahe, test_masks, verbose=1)
loss, accuracy, jaccard, dice = results

print(f"Không hậu xử lý - Dice Loss: {loss:.4f}, Accuracy: {accuracy*100:.2f}%, Jaccard: {jaccard*100:.2f}%")

print("\n🔧 Đánh giá sau Morphology...")
predictions1 = segunet.predict(test_images_gray_clahe)
refined_predictions1 = []

for i in tqdm(range(len(test_images_gray_clahe))):
    pred = predictions1[i].squeeze()

    morph_pred = apply_morphology(pred, kernel_size=7, iterations=2) 

    refined_predictions1.append(morph_pred)



refined_predictions1 = np.expand_dims(np.array(refined_predictions1), axis=-1)
accuracy_after = np_accuracy(test_masks, refined_predictions1)
jaccard_after = np_jaccard_coefficient(test_masks, refined_predictions1)
loss_after = np_dice_loss(test_masks, refined_predictions1)

print(f"Sau Morphology - Dice Loss: {loss_after:.4f}, Accuracy: {accuracy_after*100:.2f}%, Jaccard: {jaccard_after*100:.2f}%")
# Out:
# 🔍 Đánh giá không hậu xử lý...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - accuracy: 0.9571 - dice_coefficient: 0.8961 - jaccard_coefficient: 0.8149 - loss: 0.1039
# Không hậu xử lý - Dice Loss: 0.1337, Accuracy: 95.29%, Jaccard: 76.86%
#
# 🔧 Đánh giá sau Morphology...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step
# 100%|██████████| 825/825 [00:00<00:00, 1669.89it/s]
# Sau Morphology - Dice Loss: 0.1193, Accuracy: 95.29%, Jaccard: 78.68%

# %%
def apply_crf(original_image, model_output):
    H, W = original_image.shape[:2]
    model_output = np.squeeze(model_output)
    probs = np.stack([1.0 - model_output, model_output], axis=0)

    d = dcrf.DenseCRF2D(W, H, 2)
    d.setUnaryEnergy(unary_from_softmax(probs))
    d.addPairwiseGaussian(sxy=3, compat=3)

    if len(original_image.shape) == 2:
        original_image = original_image[..., np.newaxis]
    if original_image.shape[-1] == 3:
        original_image = cv2.cvtColor(original_image, cv2.COLOR_RGB2GRAY)[..., np.newaxis]

    pairwise_energy = create_pairwise_bilateral(sdims=(80, 80), schan=(13,), img=original_image.astype(np.uint8), chdim=2)
    d.addPairwiseEnergy(pairwise_energy, compat=10)

    Q = d.inference(1)
    return np.argmax(Q, axis=0).reshape((H, W))

print("Đánh giá trước CRF...")
results = segunet.evaluate(test_images_gray_clahe, test_masks, verbose=1)
loss, accuracy, jaccard, dice = results

print(f"Trước CRF - Dice Loss: {loss:.4f}, Accuracy: {accuracy*100:.2f}%, Jaccard: {jaccard*100:.2f}%")
print("\nĐánh giá sau CRF...")
predictions2 = segunet.predict(test_images_gray_clahe)
refined_predictions2 = []

for i in range(len(test_images_gray_clahe)):
    img = test_images_gray_clahe[i]
    if img.max() <= 1.0:
        img = (img * 255).astype(np.uint8)
    refined_pred = apply_crf(img, predictions2[i])
    refined_predictions2.append(refined_pred)

refined_predictions2 = np.array(refined_predictions2)
accuracy_after = np_accuracy(test_masks, refined_predictions2)
jaccard_after = np_jaccard_coefficient(test_masks, refined_predictions2)
loss_after = np_dice_loss(test_masks, refined_predictions2)

print(f"Sau CRF - Dice Loss: {loss_after:.4f}, Accuracy: {accuracy_after*100:.2f}%, Jaccard: {jaccard_after*100:.2f}%")
# Out:
# Đánh giá trước CRF...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - accuracy: 0.9571 - dice_coefficient: 0.8961 - jaccard_coefficient: 0.8149 - loss: 0.1039
# Trước CRF - Dice Loss: 0.1337, Accuracy: 95.29%, Jaccard: 76.86%
#
# Đánh giá sau CRF...
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 175ms/step
# Sau CRF - Dice Loss: 0.1194, Accuracy: 95.28%, Jaccard: 78.66%

# %%
def show_predictions_with_metrics_grid(refined_predictions1,
                                       images, masks,
                                       indices,
                                       save_path):

    num_images = len(indices)
    plt.figure(figsize=(8, 4 * num_images)) 

    for i, idx in enumerate(indices):
        image = images[idx]
        true_mask = masks[idx]
        pred_morph = refined_predictions1[idx]

       
        if pred_morph.shape != true_mask.shape:
            pred_morph = cv2.resize(pred_morph, (true_mask.shape[1], true_mask.shape[0]), interpolation=cv2.INTER_NEAREST)
      
        accuracy = np_accuracy(true_mask, pred_morph)
        ax1 = plt.subplot(num_images, 2, 2*i + 1)
        ax1.imshow(image)
        ax1.axis('off')

        ax2 = plt.subplot(num_images, 2, 2*i + 2)
        ax2.imshow(pred_morph, cmap='gray')  
        ax2.axis('off')
        ax2.text(0.5, -0.01,
                 f"Accuracy: {accuracy:.3f}",
                 fontsize=16, ha='center', va='top', transform=ax2.transAxes)

    plt.tight_layout()
    plt.savefig(save_path, bbox_inches='tight', dpi=300)
    plt.show()

show_predictions_with_metrics_grid(
    refined_predictions1=refined_predictions1,
    images=test_images,
    masks=test_masks,
    indices=[722, 191, 54, 700],
    save_path='best_morphology_results_gray_2750.png'
)

# %%
segunet.save('/kaggle/working/model/2.0-gray_2750_model.h5')
segunet.save('/kaggle/working/model/2.0-gray_2750_model.keras')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
