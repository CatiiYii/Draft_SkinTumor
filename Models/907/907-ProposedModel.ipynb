# %%
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
# !pip install opencv-contrib-python
# !pip install tensorflow-addons
import os
import cv2
import time
import json
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Layer, Input, Conv2D, BatchNormalization, Lambda, Concatenate
import pydensecrf.densecrf as dcrf
from pydensecrf.utils import unary_from_softmax, create_pairwise_bilateral
from tensorflow.keras.layers import (
    Input, SeparableConv2D, BatchNormalization, MaxPooling2D, UpSampling2D, Conv2DTranspose,
    Concatenate, SpatialDropout2D, ReLU, GlobalAveragePooling2D, Add,
    GlobalMaxPooling2D, Dense, Reshape, Multiply, Add, Conv2D, Lambda, Activation
)
from tensorflow.keras.activations import swish
from tensorflow.keras.layers import Conv2D, Activation, Add, Multiply, UpSampling2D, Concatenate
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Input, SeparableConv2D, BatchNormalization, MaxPooling2D, Conv2DTranspose, Concatenate, SpatialDropout2D, ReLU, GlobalAveragePooling2D, GlobalMaxPooling2D, Dense, Reshape, Multiply, Add, Conv2D, Lambda
from tensorflow.keras.initializers import HeNormal
# Out:
# Collecting git+https://github.com/lucasb-eyer/pydensecrf.git
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-qb1f9nbh
#   Running command git clone --filter=blob:none --quiet https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-qb1f9nbh
#   Resolved https://github.com/lucasb-eyer/pydensecrf.git to commit 2723c7fa4f2ead16ae1ce3d8afe977724bb8f87f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pydensecrf
#   Building wheel for pydensecrf (pyproject.toml) ... done
#   Created wheel for pydensecrf: filename=pydensecrf-1.0-cp311-cp311-linux_x86_64.whl size=3440333 sha256=48f316a9d552b430e84e722be27a8e97609dfdd50faa254906f299dbd2635e53
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q71uwqss/wheels/ce/8e/34/6dcfa200a9e2ae3627d8009b8bd1ca9b24512bec50a93304de
# Successfully built pydensecrf
# Installing collected packages: pydensecrf
# Successfully installed pydensecrf-1.0
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-contrib-python) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (24.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 9.7 MB/s eta 0:00:00a 0:00:01
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.1
#     Uninstalling typeguard-4.4.1:
#       Successfully uninstalled typeguard-4.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.16.1 requires typeguard<5,>=3, but you have typeguard 2.13.3 which is incompatible.
# inflect 7.5.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3
# 2025-12-05 13:59:09.106213: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764943149.300421      33 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1764943149.357391      33 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
working_dir = '/kaggle/working'
for item in os.listdir(working_dir):
    item_path = os.path.join(working_dir, item)
    try:
        if os.path.isfile(item_path) or os.path.islink(item_path):
            os.unlink(item_path)  
        elif os.path.isdir(item_path):
            shutil.rmtree(item_path)  
            print(f"❌ xóa thành công {item_path}")
    except Exception as e:
        print(f"Lỗi khi xóa {item_path}: {e}")
# Out:
# ❌ xóa thành công /kaggle/working/.virtual_documents

# %%
def load_isic_dataset(image_path, mask_path, binary_path, csv_file, img_size=(256, 256)):
    image_files = sorted(glob(os.path.join(image_path, "ISIC_*.jpg")))
    images = []
    masks = []
    binary_masks = {}
    image_ids = []
    labels = []

    csv_data = pd.read_csv(csv_file)
    mel_label = csv_data['melanoma'].astype("int64")

    print("Đang đọc và xử lý dữ liệu...")
    for index, img_path in enumerate(tqdm(image_files)):
        img_id = os.path.basename(img_path).split('.')[0]
        mask_file = os.path.join(mask_path, f"{img_id}_segmentation.png")
        binary_file = os.path.join(binary_path, f"{img_id}_features.json")

        if not os.path.exists(mask_file):
            print(f"Không tìm thấy mask cho ảnh mặt nạ {img_id}_segmentation.png")
            continue
        if not os.path.exists(binary_file):
            print(f"Không tìm thấy mask nhị phân cho ảnh {img_id}_features.json")
            continue

        try:
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  
          
            mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)

            img = cv2.resize(img, img_size)
            mask = cv2.resize(mask, img_size)

            img = img / 255.0
            mask = mask / 255.0

            with open(binary_file, 'r') as f:
                binary_masks[img_id] = json.load(f)
           
            label = mel_label[index]

            images.append(img)
            masks.append(mask)
            image_ids.append(img_id)
            labels.append(label.astype("long"))

        except Exception as e:
            print(f"Lỗi khi xử lý ảnh {img_id}: {str(e)}")
            continue

    images = np.array(images)
    masks = np.array(masks)[..., np.newaxis]  
    labels = np.array(labels)

    print(f"\nĐã đọc thành công {len(images)} ảnh")
    print(f"Shape của images: {images.shape}")
    print(f"Shape của masks: {masks.shape}")
    print(f"Shape của labels: {labels.shape}")

    return images, masks, binary_masks, image_ids, labels

# %%
train_images, train_masks, train_binarys, train_image_ids, train_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2017-melanoma/Train_Data',
    mask_path='/kaggle/input/isic-2017-melanoma/Train_GroundTruth_1',
    binary_path='/kaggle/input/isic-2017-melanoma/Train_GroundTruth_2',
    csv_file="/kaggle/input/isic-2017-melanoma/Train_GroundTruth_3.csv",
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 635/635 [01:51<00:00,  5.70it/s]
# Đã đọc thành công 635 ảnh
# Shape của images: (635, 256, 256, 3)
# Shape của masks: (635, 256, 256, 1)
# Shape của labels: (635,)

# %%
test_images, test_masks, test_binarys, test_image_ids, test_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2017-melanoma/Test_Data',
    mask_path='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_1',
    binary_path='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_2',
    csv_file='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_3.csv',
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 272/272 [00:41<00:00,  6.48it/s]
# Đã đọc thành công 272 ảnh
# Shape của images: (272, 256, 256, 3)
# Shape của masks: (272, 256, 256, 1)
# Shape của labels: (272,)

# %%
def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = (intersection + 1e-7) / (union + 1e-7)
    return iou

# %%
def compute_metric(y_true, y_pred, metric='dice_coefficient', smooth=1e-6, is_numpy=False):
    y_true_f = y_true.flatten() if is_numpy else K.flatten(y_true)
    y_pred_f = y_pred.flatten() if is_numpy else K.flatten(y_pred)
    intersection = np.sum(y_true_f * y_pred_f) if is_numpy else K.sum(y_true_f * y_pred_f)

    if 'dice' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        score = (2. * intersection + smooth) / (sum_fn(y_true_f) + sum_fn(y_pred_f) + smooth)
    elif 'jaccard' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        union = sum_fn(y_true_f) + sum_fn(y_pred_f) - intersection
        score = (intersection + smooth) / (union + smooth)
    else:
        raise ValueError(f"Unsupported metric: {metric}")

    return score if 'coefficient' in metric else 1 - score

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth)

def dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth)

def jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth)

def jaccard_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_loss', smooth)

def np_accuracy(y_true, y_pred):
    return np.mean(y_true.flatten() == y_pred.flatten())

def np_dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth, is_numpy=True)

def np_jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth, is_numpy=True)

def np_dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth, is_numpy=True)

# %%
def cbam_module(input_features, reduction_ratio=8):

    filters = input_features.shape[-1]       
    avg_pool = GlobalAveragePooling2D()(input_features)
    max_pool = GlobalMaxPooling2D()(input_features)
    
    shared_dense_1 = Dense(filters // reduction_ratio, 
                           activation='relu', 
                           kernel_initializer='he_normal', 
                           use_bias=True)
    
    shared_dense_2 = Dense(filters, 
                           use_bias=True)
    
    avg_out = shared_dense_2(shared_dense_1(avg_pool))
    max_out = shared_dense_2(shared_dense_1(max_pool))
    
    channel_sum = Add()([avg_out, max_out])
    channel_attention = Activation('sigmoid')(channel_sum)
    channel_attention = Reshape((1, 1, filters))(channel_attention)
    channel_refined = Multiply()([input_features, channel_attention])  
   
    avg_spatial = Lambda(lambda x: K.mean(x, axis=-1, keepdims=True), 
                         output_shape=lambda s: (s[0], s[1], s[2], 1))(channel_refined)
    max_spatial = Lambda(lambda x: K.max(x, axis=-1, keepdims=True), 
                         output_shape=lambda s: (s[0], s[1], s[2], 1))(channel_refined)   


    spatial_concat = Concatenate(axis=-1)([avg_spatial, max_spatial])
    
    spatial_attention = Conv2D(1, 
                               (7, 7), 
                               padding='same', 
                               activation='sigmoid', 
                               use_bias=False)(spatial_concat)
    
    refined_features = Multiply()([channel_refined, spatial_attention])
    
    
    return refined_features

# %%
def simam(x, lambda_val=1e-4):  
    shape = tf.shape(x)
    H, W = shape[1], shape[2]
    n = tf.cast(H * W - 1, x.dtype)
    
    mu = tf.reduce_mean(x, axis=[1, 2], keepdims=True)
    d = tf.square(x - mu)
    var = tf.reduce_sum(d, axis=[1, 2], keepdims=True) / n
    e_t = d / (4 * (var + lambda_val)) + 0.5
    
    return x * tf.nn.sigmoid(e_t)

def aspp_module(input_tensor, output_filters=1024, rates=[1, 6, 12, 18]):
    num_branches = len(rates)
    branch_filters = output_filters // num_branches

    branches = []
    for rate in rates:
        branch = SeparableConv2D(branch_filters, (3, 3), padding='same', dilation_rate=rate, use_bias=False,
                                  depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(input_tensor)
        branch = BatchNormalization()(branch)
        branch = ReLU()(branch)
        branches.append(branch)

    concatenated = Concatenate()(branches)
    attended = Lambda(simam)(concatenated)
    final_conv = SeparableConv2D(output_filters, (1, 1), padding='same', use_bias=False,
                                  depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(attended)
    final_conv = BatchNormalization()(final_conv)
    final_conv = ReLU()(final_conv)
    final_conv = SpatialDropout2D(0.2)(final_conv)
    return final_conv

# %%
def CustomSegUNet(input_size=(256, 256, 1)):
    inputs = Input(input_size)
    c1 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(inputs)
    c1 = BatchNormalization()(c1); c1 = ReLU()(c1)
    c1 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c1)
    c1 = BatchNormalization()(c1); c1 = ReLU()(c1)
    c1 = SpatialDropout2D(0.1)(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p1)
    c2 = BatchNormalization()(c2); c2 = ReLU()(c2)
    c2 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c2)
    c2 = BatchNormalization()(c2); c2 = ReLU()(c2)
    c2 = SpatialDropout2D(0.1)(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p2)
    c3 = BatchNormalization()(c3); c3 = ReLU()(c3)
    c3 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c3)
    c3 = BatchNormalization()(c3); c3 = ReLU()(c3)
    c3 = SpatialDropout2D(0.1)(c3)
    p3 = MaxPooling2D((2, 2))(c3)
  
    c4 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p3)
    c4 = BatchNormalization()(c4); c4 = ReLU()(c4)
    c4 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c4)
    c4 = BatchNormalization()(c4); c4 = ReLU()(c4)
    c4 = SpatialDropout2D(0.1)(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p4)
    c5 = BatchNormalization()(c5); c5 = ReLU()(c5)
    c5 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c5)
    c5 = BatchNormalization()(c5); c5 = ReLU()(c5)
    c5 = SpatialDropout2D(0.1)(c5)
    p5 = MaxPooling2D((2, 2))(c5)

    
    c6 = aspp_module(p5, output_filters=1024, rates=[1, 6, 12, 18])

    u7 = Conv2DTranspose(512, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c6)
    u7 = Concatenate()([u7, c5])
    c7 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u7)
    c7 = BatchNormalization()(c7); c7 = ReLU()(c7)
    c7 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c7)
    c7 = BatchNormalization()(c7); c7 = ReLU()(c7)
    c7 = cbam_module(c7)

    u8 = Conv2DTranspose(256, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c7)
    u8 = Concatenate()([u8, c4])
    c8 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u8)
    c8 = BatchNormalization()(c8); c8 = ReLU()(c8)
    c8 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c8)
    c8 = BatchNormalization()(c8); c8 = ReLU()(c8)
    c8 = cbam_module(c8)

    u9 = Conv2DTranspose(256, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c8)
    u9 = Concatenate()([u9, c3])
    c9 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u9)
    c9 = BatchNormalization()(c9); c9 = ReLU()(c9)
    c9 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c9)
    c9 = BatchNormalization()(c9); c9 = ReLU()(c9)
    c9 = cbam_module(c9)

    u10 = Conv2DTranspose(128, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c9)
    u10 = Concatenate()([u10, c2])
    c10 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u10)
    c10 = BatchNormalization()(c10); c10 = ReLU()(c10)
    c10 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c10)
    c10 = BatchNormalization()(c10); c10 = ReLU()(c10)
    c10 = cbam_module(c10)

    u11 = Conv2DTranspose(64, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c10)
    u11 = Concatenate()([u11, c1])
    c11 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u11)
    c11 = BatchNormalization()(c11); c11 = ReLU()(c11)
    c11 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c11)
    c11 = BatchNormalization()(c11); c11 = ReLU()(c11)
    c11 = cbam_module(c11)
 
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c11)

    return Model(inputs=inputs, outputs=outputs)

if __name__ == "__main__":
    model = CustomSegUNet()
    model.summary()
# Out:
# I0000 00:00:1764943314.833437      33 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 1)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d          │ (None, 256, 256, 64)   │            137 │ input_layer[0][0]      │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 64)   │            256 │ separable_conv2d[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 256, 256, 64)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_1        │ (None, 256, 256, 64)   │          4,736 │ re_lu[0][0]            │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256, 256, 64)   │            256 │ separable_conv2d_1[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1 (ReLU)            │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d         │ (None, 256, 256, 64)   │              0 │ re_lu_1[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ spatial_dropout2d[0][… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_2        │ (None, 128, 128, 128)  │          8,896 │ max_pooling2d[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 128, 128, 128)  │            512 │ separable_conv2d_2[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_2 (ReLU)            │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_3        │ (None, 128, 128, 128)  │         17,664 │ re_lu_2[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 128, 128, 128)  │            512 │ separable_conv2d_3[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_3 (ReLU)            │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_1       │ (None, 128, 128, 128)  │              0 │ re_lu_3[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 128)    │              0 │ spatial_dropout2d_1[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_4        │ (None, 64, 64, 256)    │         34,176 │ max_pooling2d_1[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_4[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_4 (ReLU)            │ (None, 64, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_5        │ (None, 64, 64, 256)    │         68,096 │ re_lu_4[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_5[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_5 (ReLU)            │ (None, 64, 64, 256)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_2       │ (None, 64, 64, 256)    │              0 │ re_lu_5[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ spatial_dropout2d_2[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_6        │ (None, 32, 32, 256)    │         68,096 │ max_pooling2d_2[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_6[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_6 (ReLU)            │ (None, 32, 32, 256)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_7        │ (None, 32, 32, 256)    │         68,096 │ re_lu_6[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_7[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_7 (ReLU)            │ (None, 32, 32, 256)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_3       │ (None, 32, 32, 256)    │              0 │ re_lu_7[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 256)    │              0 │ spatial_dropout2d_3[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_8        │ (None, 16, 16, 512)    │        133,888 │ max_pooling2d_3[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_8[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_8 (ReLU)            │ (None, 16, 16, 512)    │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_9        │ (None, 16, 16, 512)    │        267,264 │ re_lu_8[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_9[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_9 (ReLU)            │ (None, 16, 16, 512)    │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_4       │ (None, 16, 16, 512)    │              0 │ re_lu_9[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 8, 8, 512)      │              0 │ spatial_dropout2d_4[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_10       │ (None, 8, 8, 256)      │        135,680 │ max_pooling2d_4[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_11       │ (None, 8, 8, 256)      │        135,680 │ max_pooling2d_4[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_12       │ (None, 8, 8, 256)      │        135,680 │ max_pooling2d_4[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_13       │ (None, 8, 8, 256)      │        135,680 │ max_pooling2d_4[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 8, 8, 256)      │          1,024 │ separable_conv2d_10[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 8, 8, 256)      │          1,024 │ separable_conv2d_11[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 8, 8, 256)      │          1,024 │ separable_conv2d_12[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 8, 8, 256)      │          1,024 │ separable_conv2d_13[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_10 (ReLU)           │ (None, 8, 8, 256)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_11 (ReLU)           │ (None, 8, 8, 256)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_12 (ReLU)           │ (None, 8, 8, 256)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_13 (ReLU)           │ (None, 8, 8, 256)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 8, 8, 1024)     │              0 │ re_lu_10[0][0],        │
# │                           │                        │                │ re_lu_11[0][0],        │
# │                           │                        │                │ re_lu_12[0][0],        │
# │                           │                        │                │ re_lu_13[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 8, 8, 1024)     │              0 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_14       │ (None, 8, 8, 1024)     │      1,049,600 │ lambda[0][0]           │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 8, 8, 1024)     │          4,096 │ separable_conv2d_14[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_14 (ReLU)           │ (None, 8, 8, 1024)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_5       │ (None, 8, 8, 1024)     │              0 │ re_lu_14[0][0]         │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 16, 16, 512)    │      4,719,104 │ spatial_dropout2d_5[0… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 16, 16, 1024)   │              0 │ conv2d_transpose[0][0… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_4[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_15       │ (None, 16, 16, 512)    │        534,016 │ concatenate_1[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_15[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_15 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_16       │ (None, 16, 16, 512)    │        267,264 │ re_lu_15[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_16[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_16 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 512)            │              0 │ re_lu_16[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d      │ (None, 512)            │              0 │ re_lu_16[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 64)             │         32,832 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 512)            │         33,280 │ dense[0][0],           │
# │                           │                        │                │ dense[1][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 512)            │              0 │ dense_1[0][0],         │
# │                           │                        │                │ dense_1[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 512)            │              0 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 1, 1, 512)      │              0 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 16, 16, 512)    │              0 │ re_lu_16[0][0],        │
# │                           │                        │                │ reshape[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_1 (Lambda)         │ (None, 16, 16, 1)      │              0 │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_2 (Lambda)         │ (None, 16, 16, 1)      │              0 │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 16, 16, 2)      │              0 │ lambda_1[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 16, 16, 1)      │             98 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_1 (Multiply)     │ (None, 16, 16, 512)    │              0 │ multiply[0][0],        │
# │                           │                        │                │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 32, 32, 256)    │      1,179,904 │ multiply_1[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 32, 32, 512)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_3[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_17       │ (None, 32, 32, 256)    │        135,936 │ concatenate_3[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_17[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_17 (ReLU)           │ (None, 32, 32, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_18       │ (None, 32, 32, 256)    │         68,096 │ re_lu_17[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_18[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_18 (ReLU)           │ (None, 32, 32, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 256)            │              0 │ re_lu_18[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_1    │ (None, 256)            │              0 │ re_lu_18[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 32)             │          8,224 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 256)            │          8,448 │ dense_2[0][0],         │
# │                           │                        │                │ dense_2[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 256)            │              0 │ dense_3[0][0],         │
# │                           │                        │                │ dense_3[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 256)            │              0 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_1 (Reshape)       │ (None, 1, 1, 256)      │              0 │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_2 (Multiply)     │ (None, 32, 32, 256)    │              0 │ re_lu_18[0][0],        │
# │                           │                        │                │ reshape_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_3 (Lambda)         │ (None, 32, 32, 1)      │              0 │ multiply_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_4 (Lambda)         │ (None, 32, 32, 1)      │              0 │ multiply_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 32, 32, 2)      │              0 │ lambda_3[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 32, 32, 1)      │             98 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_3 (Multiply)     │ (None, 32, 32, 256)    │              0 │ multiply_2[0][0],      │
# │                           │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 64, 64, 256)    │        590,080 │ multiply_3[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 64, 64, 512)    │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_2[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_19       │ (None, 64, 64, 256)    │        135,936 │ concatenate_5[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_19[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_19 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_20       │ (None, 64, 64, 256)    │         68,096 │ re_lu_19[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_20[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_20 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 256)            │              0 │ re_lu_20[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_2    │ (None, 256)            │              0 │ re_lu_20[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 32)             │          8,224 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 256)            │          8,448 │ dense_4[0][0],         │
# │                           │                        │                │ dense_4[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 256)            │              0 │ dense_5[0][0],         │
# │                           │                        │                │ dense_5[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 256)            │              0 │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_2 (Reshape)       │ (None, 1, 1, 256)      │              0 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_4 (Multiply)     │ (None, 64, 64, 256)    │              0 │ re_lu_20[0][0],        │
# │                           │                        │                │ reshape_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_5 (Lambda)         │ (None, 64, 64, 1)      │              0 │ multiply_4[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_6 (Lambda)         │ (None, 64, 64, 1)      │              0 │ multiply_4[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_6             │ (None, 64, 64, 2)      │              0 │ lambda_5[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 64, 64, 1)      │             98 │ concatenate_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_5 (Multiply)     │ (None, 64, 64, 256)    │              0 │ multiply_4[0][0],      │
# │                           │                        │                │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 128, 128, 128)  │        295,040 │ multiply_5[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_7             │ (None, 128, 128, 256)  │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_21       │ (None, 128, 128, 128)  │         35,200 │ concatenate_7[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_21    │ (None, 128, 128, 128)  │            512 │ separable_conv2d_21[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_21 (ReLU)           │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_22       │ (None, 128, 128, 128)  │         17,664 │ re_lu_21[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_22    │ (None, 128, 128, 128)  │            512 │ separable_conv2d_22[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_22 (ReLU)           │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 128)            │              0 │ re_lu_22[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_3    │ (None, 128)            │              0 │ re_lu_22[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 16)             │          2,064 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 128)            │          2,176 │ dense_6[0][0],         │
# │                           │                        │                │ dense_6[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 128)            │              0 │ dense_7[0][0],         │
# │                           │                        │                │ dense_7[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 128)            │              0 │ add_3[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_3 (Reshape)       │ (None, 1, 1, 128)      │              0 │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_6 (Multiply)     │ (None, 128, 128, 128)  │              0 │ re_lu_22[0][0],        │
# │                           │                        │                │ reshape_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_7 (Lambda)         │ (None, 128, 128, 1)    │              0 │ multiply_6[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_8 (Lambda)         │ (None, 128, 128, 1)    │              0 │ multiply_6[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_8             │ (None, 128, 128, 2)    │              0 │ lambda_7[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 1)    │             98 │ concatenate_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_7 (Multiply)     │ (None, 128, 128, 128)  │              0 │ multiply_6[0][0],      │
# │                           │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_4        │ (None, 256, 256, 64)   │         73,792 │ multiply_7[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_9             │ (None, 256, 256, 128)  │              0 │ conv2d_transpose_4[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_23       │ (None, 256, 256, 64)   │          9,408 │ concatenate_9[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_23    │ (None, 256, 256, 64)   │            256 │ separable_conv2d_23[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_23 (ReLU)           │ (None, 256, 256, 64)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_24       │ (None, 256, 256, 64)   │          4,736 │ re_lu_23[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_24    │ (None, 256, 256, 64)   │            256 │ separable_conv2d_24[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_24 (ReLU)           │ (None, 256, 256, 64)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 64)             │              0 │ re_lu_24[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_4    │ (None, 64)             │              0 │ re_lu_24[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 8)              │            520 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_9 (Dense)           │ (None, 64)             │            576 │ dense_8[0][0],         │
# │                           │                        │                │ dense_8[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 64)             │              0 │ dense_9[0][0],         │
# │                           │                        │                │ dense_9[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 64)             │              0 │ add_4[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_4 (Reshape)       │ (None, 1, 1, 64)       │              0 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_8 (Multiply)     │ (None, 256, 256, 64)   │              0 │ re_lu_24[0][0],        │
# │                           │                        │                │ reshape_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_9 (Lambda)         │ (None, 256, 256, 1)    │              0 │ multiply_8[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_10 (Lambda)        │ (None, 256, 256, 1)    │              0 │ multiply_8[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_10            │ (None, 256, 256, 2)    │              0 │ lambda_9[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 256, 256, 1)    │             98 │ concatenate_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_9 (Multiply)     │ (None, 256, 256, 64)   │              0 │ multiply_8[0][0],      │
# │                           │                        │                │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 256, 256, 1)    │             65 │ multiply_9[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 10,530,636 (40.17 MB)
#  Trainable params: 10,516,812 (40.12 MB)
#  Non-trainable params: 13,824 (54.00 KB)

# %%
class EarlyStoppingByAccuracyChange(tf.keras.callbacks.Callback):
    def __init__(self, monitor='accuracy', threshold=0.00001, patience=3, verbose=0):
        super(EarlyStoppingByAccuracyChange, self).__init__()
        self.monitor = monitor
        self.threshold = threshold
        self.patience = patience
        self.verbose = verbose
        self.wait = 0
        self.best_accuracy = -float('inf')
        self.consecutive_stops = 0

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current_accuracy = logs.get(self.monitor)
        if current_accuracy is None:
            tf.get_logger().warning(
                'Early stopping requires %s available!', self.monitor
            )
            return

        if current_accuracy > self.best_accuracy:
            self.best_accuracy = current_accuracy
            self.wait = 0
            self.consecutive_stops = 0
        else:
            self.wait += 1
            accuracy_change = current_accuracy - self.best_accuracy
            if abs(accuracy_change) < self.threshold:
                self.consecutive_stops += 1
                if self.consecutive_stops >= self.patience:
                    if self.verbose > 0:
                        print(f"Epoch {epoch+1}: Early stopping triggered due to minimal accuracy change for {self.patience} epochs.")
                    self.model.stop_training = True
            else:
                self.consecutive_stops = 0

# %%
pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-contrib-python) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def convert_to_gray_clahe(images):
    grays = []
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    for img in images:
        if img.dtype != np.uint8:
            img = (img * 255).astype(np.uint8)
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)  

        img_clahe = clahe.apply(gray)  
        grays.append(img_clahe)

    return np.array(grays)
train_images_gray_clahe = convert_to_gray_clahe(train_images)
test_images_gray_clahe = convert_to_gray_clahe(test_images)

# %%
initial_lr = 0.001
optimizer = Adam(learning_rate=initial_lr)


segunet = CustomSegUNet(input_size=(256, 256, 1))
segunet.compile(
    optimizer=optimizer,
    loss=dice_loss,
    metrics=['accuracy', jaccard_coefficient, dice_coefficient]
)
model_checkpoint_dir = 'model'


checkpoint_path = os.path.join(model_checkpoint_dir, 'cp.ckpt')

checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(model_checkpoint_dir, 'gray2750.weights.h5'),
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True,
    verbose=1
)
early_stopping = EarlyStoppingByAccuracyChange(
    monitor='accuracy',
    threshold=0.00001,
    patience=10,
    verbose=1
)
lr_reduction = ReduceLROnPlateau(monitor='loss',
                                  patience=5,
                                  verbose=1,
                                  factor=0.5,
                                  min_lr=0.00001)
start_time = time.time()
history = segunet.fit(
    train_images_gray_clahe, train_masks,
    batch_size=32,
    epochs=100,
    callbacks=[early_stopping, lr_reduction, checkpoint_callback]
)

end_time = time.time()
training_time = end_time - start_time
avg_accuracy = np.mean(history.history['accuracy'])
avg_jaccard = np.mean(history.history['jaccard_coefficient'])
avg_dice = np.mean(history.history['dice_coefficient'])

print("SegUNet output shape:", segunet.output_shape)
print(f"Thời gian huấn luyện: {training_time:.2f} giây")
print(f"Accuracy trung bình: {avg_accuracy*100:.2f}%")
print(f"Jaccard trung bình: {avg_jaccard*100:.2f}%")
print(f"Dice trung bình: {avg_dice*100:.2f}%")
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764943353.558943     188 service.cc:148] XLA service 0x7f0800084850 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1764943353.560362     188 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1764943356.639594     188 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1764943379.608514     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943379.834595     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943381.751050     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943381.960422     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943382.527228     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943382.737655     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943383.674241     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943383.977082     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943386.553140     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943386.971981     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-05 14:03:07.121699: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,128,128]{3,2,1,0}, f32[32,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-05 14:03:07.228488: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.106915763s
# Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,128,128]{3,2,1,0}, f32[32,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1764943405.397333     188 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 736ms/step - accuracy: 0.6675 - dice_coefficient: 0.3817 - jaccard_coefficient: 0.2367 - loss: 0.6183
# E0000 00:00:1764943428.127530     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943428.368123     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943433.678042     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943433.919014     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943444.005272     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943444.225683     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943446.034979     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943446.243926     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943446.775279     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943446.984268     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943447.831497     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943448.122460     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943450.363892     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1764943450.757418     188 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-05 14:04:10.959892: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,256,128,128]{3,2,1,0}, f32[27,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-05 14:04:10.989168: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.029383997s
# Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,256,128,128]{3,2,1,0}, f32[27,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6673 - dice_coefficient: 0.3837 - jaccard_coefficient: 0.2383 - loss: 0.6164
# Epoch 1: loss improved from inf to 0.57896, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 149s 3s/step - accuracy: 0.6671 - dice_coefficient: 0.3855 - jaccard_coefficient: 0.2397 - loss: 0.6146 - learning_rate: 0.0010
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.7396 - dice_coefficient: 0.5444 - jaccard_coefficient: 0.3775 - loss: 0.4556
# Epoch 2: loss improved from 0.57896 to 0.41531, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.7415 - dice_coefficient: 0.5463 - jaccard_coefficient: 0.3794 - loss: 0.4537 - learning_rate: 0.0010
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.8538 - dice_coefficient: 0.6684 - jaccard_coefficient: 0.5047 - loss: 0.3316
# Epoch 3: loss improved from 0.41531 to 0.30844, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 761ms/step - accuracy: 0.8540 - dice_coefficient: 0.6695 - jaccard_coefficient: 0.5060 - loss: 0.3305 - learning_rate: 0.0010
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.8899 - dice_coefficient: 0.7404 - jaccard_coefficient: 0.5894 - loss: 0.2596
# Epoch 4: loss improved from 0.30844 to 0.25418, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 761ms/step - accuracy: 0.8898 - dice_coefficient: 0.7406 - jaccard_coefficient: 0.5897 - loss: 0.2593 - learning_rate: 0.0010
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9036 - dice_coefficient: 0.7737 - jaccard_coefficient: 0.6317 - loss: 0.2263
# Epoch 5: loss improved from 0.25418 to 0.22499, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 761ms/step - accuracy: 0.9034 - dice_coefficient: 0.7738 - jaccard_coefficient: 0.6318 - loss: 0.2263 - learning_rate: 0.0010
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9130 - dice_coefficient: 0.8079 - jaccard_coefficient: 0.6789 - loss: 0.1921
# Epoch 6: loss improved from 0.22499 to 0.20590, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 761ms/step - accuracy: 0.9127 - dice_coefficient: 0.8072 - jaccard_coefficient: 0.6780 - loss: 0.1928 - learning_rate: 0.0010
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9110 - dice_coefficient: 0.8043 - jaccard_coefficient: 0.6735 - loss: 0.1957
# Epoch 7: loss improved from 0.20590 to 0.19674, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 761ms/step - accuracy: 0.9109 - dice_coefficient: 0.8043 - jaccard_coefficient: 0.6734 - loss: 0.1957 - learning_rate: 0.0010
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9037 - dice_coefficient: 0.7890 - jaccard_coefficient: 0.6536 - loss: 0.2110
# Epoch 8: loss did not improve from 0.19674
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - accuracy: 0.9039 - dice_coefficient: 0.7896 - jaccard_coefficient: 0.6543 - loss: 0.2104 - learning_rate: 0.0010
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9124 - dice_coefficient: 0.8136 - jaccard_coefficient: 0.6869 - loss: 0.1864
# Epoch 9: loss improved from 0.19674 to 0.18969, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9124 - dice_coefficient: 0.8134 - jaccard_coefficient: 0.6867 - loss: 0.1865 - learning_rate: 0.0010
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9245 - dice_coefficient: 0.8388 - jaccard_coefficient: 0.7231 - loss: 0.1612
# Epoch 10: loss improved from 0.18969 to 0.16889, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9244 - dice_coefficient: 0.8384 - jaccard_coefficient: 0.7225 - loss: 0.1615 - learning_rate: 0.0010
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9258 - dice_coefficient: 0.8455 - jaccard_coefficient: 0.7328 - loss: 0.1545
# Epoch 11: loss improved from 0.16889 to 0.16082, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 757ms/step - accuracy: 0.9257 - dice_coefficient: 0.8452 - jaccard_coefficient: 0.7324 - loss: 0.1548 - learning_rate: 0.0010
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9234 - dice_coefficient: 0.8351 - jaccard_coefficient: 0.7173 - loss: 0.1649
# Epoch 12: loss did not improve from 0.16082
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - accuracy: 0.9234 - dice_coefficient: 0.8351 - jaccard_coefficient: 0.7174 - loss: 0.1649 - learning_rate: 0.0010
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9278 - dice_coefficient: 0.8460 - jaccard_coefficient: 0.7338 - loss: 0.1540
# Epoch 13: loss improved from 0.16082 to 0.15606, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9278 - dice_coefficient: 0.8459 - jaccard_coefficient: 0.7337 - loss: 0.1541 - learning_rate: 0.0010
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9312 - dice_coefficient: 0.8598 - jaccard_coefficient: 0.7545 - loss: 0.1402
# Epoch 14: loss improved from 0.15606 to 0.14334, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9312 - dice_coefficient: 0.8597 - jaccard_coefficient: 0.7543 - loss: 0.1403 - learning_rate: 0.0010
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9335 - dice_coefficient: 0.8587 - jaccard_coefficient: 0.7529 - loss: 0.1413
# Epoch 15: loss improved from 0.14334 to 0.13659, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9336 - dice_coefficient: 0.8590 - jaccard_coefficient: 0.7532 - loss: 0.1411 - learning_rate: 0.0010
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9457 - dice_coefficient: 0.8838 - jaccard_coefficient: 0.7924 - loss: 0.1162
# Epoch 16: loss improved from 0.13659 to 0.12748, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9454 - dice_coefficient: 0.8833 - jaccard_coefficient: 0.7916 - loss: 0.1167 - learning_rate: 0.0010
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9411 - dice_coefficient: 0.8785 - jaccard_coefficient: 0.7839 - loss: 0.1215
# Epoch 17: loss improved from 0.12748 to 0.11701, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 761ms/step - accuracy: 0.9412 - dice_coefficient: 0.8788 - jaccard_coefficient: 0.7842 - loss: 0.1212 - learning_rate: 0.0010
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9412 - dice_coefficient: 0.8804 - jaccard_coefficient: 0.7867 - loss: 0.1196
# Epoch 18: loss did not improve from 0.11701
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - accuracy: 0.9411 - dice_coefficient: 0.8801 - jaccard_coefficient: 0.7863 - loss: 0.1199 - learning_rate: 0.0010
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9421 - dice_coefficient: 0.8754 - jaccard_coefficient: 0.7787 - loss: 0.1246
# Epoch 19: loss did not improve from 0.11701
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9421 - dice_coefficient: 0.8754 - jaccard_coefficient: 0.7788 - loss: 0.1246 - learning_rate: 0.0010
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9420 - dice_coefficient: 0.8801 - jaccard_coefficient: 0.7865 - loss: 0.1199
# Epoch 20: loss did not improve from 0.11701
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9420 - dice_coefficient: 0.8799 - jaccard_coefficient: 0.7863 - loss: 0.1201 - learning_rate: 0.0010
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9471 - dice_coefficient: 0.8841 - jaccard_coefficient: 0.7934 - loss: 0.1159
# Epoch 21: loss did not improve from 0.11701
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - accuracy: 0.9471 - dice_coefficient: 0.8840 - jaccard_coefficient: 0.7933 - loss: 0.1160 - learning_rate: 0.0010
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9449 - dice_coefficient: 0.8834 - jaccard_coefficient: 0.7924 - loss: 0.1166
# Epoch 22: loss improved from 0.11701 to 0.11410, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9449 - dice_coefficient: 0.8835 - jaccard_coefficient: 0.7926 - loss: 0.1165 - learning_rate: 0.0010
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9513 - dice_coefficient: 0.8943 - jaccard_coefficient: 0.8091 - loss: 0.1057
# Epoch 23: loss improved from 0.11410 to 0.10583, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 761ms/step - accuracy: 0.9512 - dice_coefficient: 0.8943 - jaccard_coefficient: 0.8091 - loss: 0.1057 - learning_rate: 0.0010
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9533 - dice_coefficient: 0.8962 - jaccard_coefficient: 0.8124 - loss: 0.1038
# Epoch 24: loss improved from 0.10583 to 0.10180, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9532 - dice_coefficient: 0.8963 - jaccard_coefficient: 0.8126 - loss: 0.1037 - learning_rate: 0.0010
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9495 - dice_coefficient: 0.8951 - jaccard_coefficient: 0.8106 - loss: 0.1049
# Epoch 25: loss improved from 0.10180 to 0.10151, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9496 - dice_coefficient: 0.8953 - jaccard_coefficient: 0.8109 - loss: 0.1048 - learning_rate: 0.0010
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9568 - dice_coefficient: 0.9064 - jaccard_coefficient: 0.8291 - loss: 0.0936
# Epoch 26: loss improved from 0.10151 to 0.09417, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9567 - dice_coefficient: 0.9064 - jaccard_coefficient: 0.8290 - loss: 0.0936 - learning_rate: 0.0010
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9540 - dice_coefficient: 0.9024 - jaccard_coefficient: 0.8223 - loss: 0.0976
# Epoch 27: loss did not improve from 0.09417
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9540 - dice_coefficient: 0.9023 - jaccard_coefficient: 0.8222 - loss: 0.0977 - learning_rate: 0.0010
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9587 - dice_coefficient: 0.9113 - jaccard_coefficient: 0.8377 - loss: 0.0887
# Epoch 28: loss improved from 0.09417 to 0.09235, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 761ms/step - accuracy: 0.9585 - dice_coefficient: 0.9111 - jaccard_coefficient: 0.8374 - loss: 0.0889 - learning_rate: 0.0010
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9513 - dice_coefficient: 0.9040 - jaccard_coefficient: 0.8255 - loss: 0.0960
# Epoch 29: loss did not improve from 0.09235
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9513 - dice_coefficient: 0.9038 - jaccard_coefficient: 0.8252 - loss: 0.0962 - learning_rate: 0.0010
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9522 - dice_coefficient: 0.8978 - jaccard_coefficient: 0.8149 - loss: 0.1022
# Epoch 30: loss did not improve from 0.09235
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - accuracy: 0.9523 - dice_coefficient: 0.8982 - jaccard_coefficient: 0.8155 - loss: 0.1019 - learning_rate: 0.0010
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9574 - dice_coefficient: 0.9114 - jaccard_coefficient: 0.8373 - loss: 0.0886
# Epoch 31: loss improved from 0.09235 to 0.08845, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 761ms/step - accuracy: 0.9574 - dice_coefficient: 0.9114 - jaccard_coefficient: 0.8373 - loss: 0.0886 - learning_rate: 0.0010
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9600 - dice_coefficient: 0.9168 - jaccard_coefficient: 0.8467 - loss: 0.0832
# Epoch 32: loss improved from 0.08845 to 0.08319, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9600 - dice_coefficient: 0.9168 - jaccard_coefficient: 0.8467 - loss: 0.0832 - learning_rate: 0.0010
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9612 - dice_coefficient: 0.9183 - jaccard_coefficient: 0.8494 - loss: 0.0817
# Epoch 33: loss improved from 0.08319 to 0.07980, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 756ms/step - accuracy: 0.9612 - dice_coefficient: 0.9184 - jaccard_coefficient: 0.8495 - loss: 0.0816 - learning_rate: 0.0010
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9614 - dice_coefficient: 0.9199 - jaccard_coefficient: 0.8522 - loss: 0.0801
# Epoch 34: loss did not improve from 0.07980
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - accuracy: 0.9614 - dice_coefficient: 0.9197 - jaccard_coefficient: 0.8519 - loss: 0.0803 - learning_rate: 0.0010
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9632 - dice_coefficient: 0.9229 - jaccard_coefficient: 0.8572 - loss: 0.0771
# Epoch 35: loss improved from 0.07980 to 0.07765, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9632 - dice_coefficient: 0.9229 - jaccard_coefficient: 0.8571 - loss: 0.0771 - learning_rate: 0.0010
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9650 - dice_coefficient: 0.9262 - jaccard_coefficient: 0.8627 - loss: 0.0738
# Epoch 36: loss improved from 0.07765 to 0.07500, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9650 - dice_coefficient: 0.9261 - jaccard_coefficient: 0.8626 - loss: 0.0739 - learning_rate: 0.0010
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9662 - dice_coefficient: 0.9286 - jaccard_coefficient: 0.8671 - loss: 0.0714
# Epoch 37: loss improved from 0.07500 to 0.07252, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9662 - dice_coefficient: 0.9286 - jaccard_coefficient: 0.8670 - loss: 0.0714 - learning_rate: 0.0010
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9638 - dice_coefficient: 0.9229 - jaccard_coefficient: 0.8570 - loss: 0.0771
# Epoch 38: loss did not improve from 0.07252
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - accuracy: 0.9638 - dice_coefficient: 0.9230 - jaccard_coefficient: 0.8572 - loss: 0.0770 - learning_rate: 0.0010
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9643 - dice_coefficient: 0.9253 - jaccard_coefficient: 0.8612 - loss: 0.0747
# Epoch 39: loss did not improve from 0.07252
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9643 - dice_coefficient: 0.9253 - jaccard_coefficient: 0.8613 - loss: 0.0746 - learning_rate: 0.0010
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9658 - dice_coefficient: 0.9322 - jaccard_coefficient: 0.8732 - loss: 0.0678
# Epoch 40: loss improved from 0.07252 to 0.07101, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9658 - dice_coefficient: 0.9320 - jaccard_coefficient: 0.8730 - loss: 0.0679 - learning_rate: 0.0010
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9653 - dice_coefficient: 0.9245 - jaccard_coefficient: 0.8600 - loss: 0.0755
# Epoch 41: loss did not improve from 0.07101
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9652 - dice_coefficient: 0.9244 - jaccard_coefficient: 0.8598 - loss: 0.0756 - learning_rate: 0.0010
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9645 - dice_coefficient: 0.9272 - jaccard_coefficient: 0.8647 - loss: 0.0728
# Epoch 42: loss improved from 0.07101 to 0.06982, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9646 - dice_coefficient: 0.9273 - jaccard_coefficient: 0.8649 - loss: 0.0727 - learning_rate: 0.0010
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9701 - dice_coefficient: 0.9344 - jaccard_coefficient: 0.8769 - loss: 0.0656
# Epoch 43: loss improved from 0.06982 to 0.06619, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9700 - dice_coefficient: 0.9343 - jaccard_coefficient: 0.8769 - loss: 0.0657 - learning_rate: 0.0010
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9683 - dice_coefficient: 0.9337 - jaccard_coefficient: 0.8758 - loss: 0.0663
# Epoch 44: loss improved from 0.06619 to 0.06528, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 762ms/step - accuracy: 0.9683 - dice_coefficient: 0.9338 - jaccard_coefficient: 0.8759 - loss: 0.0662 - learning_rate: 0.0010
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9695 - dice_coefficient: 0.9344 - jaccard_coefficient: 0.8770 - loss: 0.0656
# Epoch 45: loss did not improve from 0.06528
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9694 - dice_coefficient: 0.9344 - jaccard_coefficient: 0.8770 - loss: 0.0656 - learning_rate: 0.0010
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9688 - dice_coefficient: 0.9351 - jaccard_coefficient: 0.8783 - loss: 0.0649
# Epoch 46: loss improved from 0.06528 to 0.06461, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9688 - dice_coefficient: 0.9351 - jaccard_coefficient: 0.8783 - loss: 0.0649 - learning_rate: 0.0010
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9690 - dice_coefficient: 0.9376 - jaccard_coefficient: 0.8827 - loss: 0.0624
# Epoch 47: loss improved from 0.06461 to 0.06046, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9691 - dice_coefficient: 0.9377 - jaccard_coefficient: 0.8829 - loss: 0.0623 - learning_rate: 0.0010
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9706 - dice_coefficient: 0.9426 - jaccard_coefficient: 0.8915 - loss: 0.0574
# Epoch 48: loss improved from 0.06046 to 0.05951, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9706 - dice_coefficient: 0.9425 - jaccard_coefficient: 0.8913 - loss: 0.0575 - learning_rate: 0.0010
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9719 - dice_coefficient: 0.9399 - jaccard_coefficient: 0.8867 - loss: 0.0601
# Epoch 49: loss improved from 0.05951 to 0.05724, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9719 - dice_coefficient: 0.9400 - jaccard_coefficient: 0.8870 - loss: 0.0600 - learning_rate: 0.0010
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9704 - dice_coefficient: 0.9401 - jaccard_coefficient: 0.8871 - loss: 0.0599
# Epoch 50: loss did not improve from 0.05724
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9704 - dice_coefficient: 0.9400 - jaccard_coefficient: 0.8870 - loss: 0.0600 - learning_rate: 0.0010
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9720 - dice_coefficient: 0.9407 - jaccard_coefficient: 0.8883 - loss: 0.0593
# Epoch 51: loss did not improve from 0.05724
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9719 - dice_coefficient: 0.9406 - jaccard_coefficient: 0.8882 - loss: 0.0594 - learning_rate: 0.0010
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9726 - dice_coefficient: 0.9444 - jaccard_coefficient: 0.8947 - loss: 0.0556
# Epoch 52: loss improved from 0.05724 to 0.05705, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9726 - dice_coefficient: 0.9443 - jaccard_coefficient: 0.8946 - loss: 0.0557 - learning_rate: 0.0010
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9716 - dice_coefficient: 0.9419 - jaccard_coefficient: 0.8903 - loss: 0.0581
# Epoch 53: loss improved from 0.05705 to 0.05591, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9717 - dice_coefficient: 0.9420 - jaccard_coefficient: 0.8905 - loss: 0.0580 - learning_rate: 0.0010
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9735 - dice_coefficient: 0.9451 - jaccard_coefficient: 0.8961 - loss: 0.0549
# Epoch 54: loss improved from 0.05591 to 0.05438, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 758ms/step - accuracy: 0.9735 - dice_coefficient: 0.9451 - jaccard_coefficient: 0.8962 - loss: 0.0549 - learning_rate: 0.0010
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9748 - dice_coefficient: 0.9502 - jaccard_coefficient: 0.9052 - loss: 0.0498
# Epoch 55: loss improved from 0.05438 to 0.05313, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9748 - dice_coefficient: 0.9500 - jaccard_coefficient: 0.9049 - loss: 0.0500 - learning_rate: 0.0010
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9736 - dice_coefficient: 0.9455 - jaccard_coefficient: 0.8968 - loss: 0.0545
# Epoch 56: loss did not improve from 0.05313
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9736 - dice_coefficient: 0.9455 - jaccard_coefficient: 0.8969 - loss: 0.0545 - learning_rate: 0.0010
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9747 - dice_coefficient: 0.9474 - jaccard_coefficient: 0.9002 - loss: 0.0526
# Epoch 57: loss did not improve from 0.05313
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9747 - dice_coefficient: 0.9473 - jaccard_coefficient: 0.9000 - loss: 0.0526 - learning_rate: 0.0010
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9740 - dice_coefficient: 0.9452 - jaccard_coefficient: 0.8962 - loss: 0.0548
# Epoch 58: loss did not improve from 0.05313
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9740 - dice_coefficient: 0.9452 - jaccard_coefficient: 0.8961 - loss: 0.0548 - learning_rate: 0.0010
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9748 - dice_coefficient: 0.9437 - jaccard_coefficient: 0.8935 - loss: 0.0563
# Epoch 59: loss did not improve from 0.05313
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9747 - dice_coefficient: 0.9437 - jaccard_coefficient: 0.8935 - loss: 0.0563 - learning_rate: 0.0010
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9748 - dice_coefficient: 0.9473 - jaccard_coefficient: 0.9000 - loss: 0.0527
# Epoch 60: loss improved from 0.05313 to 0.05020, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 758ms/step - accuracy: 0.9748 - dice_coefficient: 0.9474 - jaccard_coefficient: 0.9002 - loss: 0.0526 - learning_rate: 0.0010
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9772 - dice_coefficient: 0.9500 - jaccard_coefficient: 0.9048 - loss: 0.0500
# Epoch 61: loss improved from 0.05020 to 0.04824, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9772 - dice_coefficient: 0.9501 - jaccard_coefficient: 0.9050 - loss: 0.0499 - learning_rate: 0.0010
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9764 - dice_coefficient: 0.9531 - jaccard_coefficient: 0.9105 - loss: 0.0469
# Epoch 62: loss improved from 0.04824 to 0.04822, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 758ms/step - accuracy: 0.9764 - dice_coefficient: 0.9530 - jaccard_coefficient: 0.9104 - loss: 0.0470 - learning_rate: 0.0010
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9781 - dice_coefficient: 0.9549 - jaccard_coefficient: 0.9137 - loss: 0.0451
# Epoch 63: loss improved from 0.04822 to 0.04349, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9781 - dice_coefficient: 0.9550 - jaccard_coefficient: 0.9139 - loss: 0.0450 - learning_rate: 0.0010
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9771 - dice_coefficient: 0.9532 - jaccard_coefficient: 0.9107 - loss: 0.0468
# Epoch 64: loss did not improve from 0.04349
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - accuracy: 0.9772 - dice_coefficient: 0.9533 - jaccard_coefficient: 0.9110 - loss: 0.0467 - learning_rate: 0.0010
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9802 - dice_coefficient: 0.9600 - jaccard_coefficient: 0.9230 - loss: 0.0400
# Epoch 65: loss improved from 0.04349 to 0.04080, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9802 - dice_coefficient: 0.9599 - jaccard_coefficient: 0.9230 - loss: 0.0401 - learning_rate: 0.0010
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9804 - dice_coefficient: 0.9615 - jaccard_coefficient: 0.9259 - loss: 0.0385
# Epoch 66: loss improved from 0.04080 to 0.04052, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9804 - dice_coefficient: 0.9614 - jaccard_coefficient: 0.9257 - loss: 0.0386 - learning_rate: 0.0010
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9797 - dice_coefficient: 0.9601 - jaccard_coefficient: 0.9234 - loss: 0.0399
# Epoch 67: loss did not improve from 0.04052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - accuracy: 0.9797 - dice_coefficient: 0.9600 - jaccard_coefficient: 0.9232 - loss: 0.0400 - learning_rate: 0.0010
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9795 - dice_coefficient: 0.9579 - jaccard_coefficient: 0.9193 - loss: 0.0421
# Epoch 68: loss did not improve from 0.04052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9795 - dice_coefficient: 0.9579 - jaccard_coefficient: 0.9192 - loss: 0.0421 - learning_rate: 0.0010
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9799 - dice_coefficient: 0.9594 - jaccard_coefficient: 0.9221 - loss: 0.0406
# Epoch 69: loss did not improve from 0.04052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9798 - dice_coefficient: 0.9593 - jaccard_coefficient: 0.9219 - loss: 0.0407 - learning_rate: 0.0010
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9791 - dice_coefficient: 0.9585 - jaccard_coefficient: 0.9203 - loss: 0.0415
# Epoch 70: loss did not improve from 0.04052
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - accuracy: 0.9791 - dice_coefficient: 0.9585 - jaccard_coefficient: 0.9204 - loss: 0.0415 - learning_rate: 0.0010
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9816 - dice_coefficient: 0.9605 - jaccard_coefficient: 0.9241 - loss: 0.0395
# Epoch 71: loss improved from 0.04052 to 0.03917, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 758ms/step - accuracy: 0.9815 - dice_coefficient: 0.9605 - jaccard_coefficient: 0.9241 - loss: 0.0395 - learning_rate: 0.0010
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9806 - dice_coefficient: 0.9608 - jaccard_coefficient: 0.9245 - loss: 0.0392
# Epoch 72: loss improved from 0.03917 to 0.03895, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9806 - dice_coefficient: 0.9608 - jaccard_coefficient: 0.9246 - loss: 0.0392 - learning_rate: 0.0010
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9794 - dice_coefficient: 0.9609 - jaccard_coefficient: 0.9247 - loss: 0.0391
# Epoch 73: loss did not improve from 0.03895
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9795 - dice_coefficient: 0.9608 - jaccard_coefficient: 0.9246 - loss: 0.0392 - learning_rate: 0.0010
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9828 - dice_coefficient: 0.9637 - jaccard_coefficient: 0.9300 - loss: 0.0363
# Epoch 74: loss improved from 0.03895 to 0.03683, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9828 - dice_coefficient: 0.9637 - jaccard_coefficient: 0.9299 - loss: 0.0363 - learning_rate: 0.0010
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9821 - dice_coefficient: 0.9647 - jaccard_coefficient: 0.9319 - loss: 0.0353
# Epoch 75: loss improved from 0.03683 to 0.03624, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9821 - dice_coefficient: 0.9647 - jaccard_coefficient: 0.9319 - loss: 0.0353 - learning_rate: 0.0010
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9835 - dice_coefficient: 0.9663 - jaccard_coefficient: 0.9349 - loss: 0.0337
# Epoch 76: loss improved from 0.03624 to 0.03518, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 756ms/step - accuracy: 0.9834 - dice_coefficient: 0.9663 - jaccard_coefficient: 0.9348 - loss: 0.0337 - learning_rate: 0.0010
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9828 - dice_coefficient: 0.9648 - jaccard_coefficient: 0.9320 - loss: 0.0352
# Epoch 77: loss did not improve from 0.03518
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9828 - dice_coefficient: 0.9648 - jaccard_coefficient: 0.9320 - loss: 0.0352 - learning_rate: 0.0010
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9834 - dice_coefficient: 0.9655 - jaccard_coefficient: 0.9334 - loss: 0.0345
# Epoch 78: loss improved from 0.03518 to 0.03462, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9834 - dice_coefficient: 0.9655 - jaccard_coefficient: 0.9334 - loss: 0.0345 - learning_rate: 0.0010
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9835 - dice_coefficient: 0.9663 - jaccard_coefficient: 0.9348 - loss: 0.0337
# Epoch 79: loss improved from 0.03462 to 0.03437, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9834 - dice_coefficient: 0.9663 - jaccard_coefficient: 0.9348 - loss: 0.0337 - learning_rate: 0.0010
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9834 - dice_coefficient: 0.9675 - jaccard_coefficient: 0.9370 - loss: 0.0325
# Epoch 80: loss did not improve from 0.03437
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9834 - dice_coefficient: 0.9674 - jaccard_coefficient: 0.9368 - loss: 0.0326 - learning_rate: 0.0010
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9845 - dice_coefficient: 0.9685 - jaccard_coefficient: 0.9389 - loss: 0.0315
# Epoch 81: loss improved from 0.03437 to 0.03230, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9845 - dice_coefficient: 0.9685 - jaccard_coefficient: 0.9389 - loss: 0.0315 - learning_rate: 0.0010
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.9846 - dice_coefficient: 0.9685 - jaccard_coefficient: 0.9389 - loss: 0.0315
# Epoch 82: loss improved from 0.03230 to 0.03151, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9846 - dice_coefficient: 0.9685 - jaccard_coefficient: 0.9389 - loss: 0.0315 - learning_rate: 0.0010
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9848 - dice_coefficient: 0.9692 - jaccard_coefficient: 0.9403 - loss: 0.0308
# Epoch 83: loss improved from 0.03151 to 0.03102, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 758ms/step - accuracy: 0.9848 - dice_coefficient: 0.9692 - jaccard_coefficient: 0.9402 - loss: 0.0308 - learning_rate: 0.0010
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9843 - dice_coefficient: 0.9686 - jaccard_coefficient: 0.9392 - loss: 0.0314
# Epoch 84: loss improved from 0.03102 to 0.03065, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9843 - dice_coefficient: 0.9687 - jaccard_coefficient: 0.9393 - loss: 0.0313 - learning_rate: 0.0010
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9851 - dice_coefficient: 0.9700 - jaccard_coefficient: 0.9419 - loss: 0.0300
# Epoch 85: loss did not improve from 0.03065
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9851 - dice_coefficient: 0.9700 - jaccard_coefficient: 0.9417 - loss: 0.0300 - learning_rate: 0.0010
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9848 - dice_coefficient: 0.9703 - jaccard_coefficient: 0.9423 - loss: 0.0297
# Epoch 86: loss improved from 0.03065 to 0.02937, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9848 - dice_coefficient: 0.9703 - jaccard_coefficient: 0.9424 - loss: 0.0297 - learning_rate: 0.0010
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9866 - dice_coefficient: 0.9715 - jaccard_coefficient: 0.9445 - loss: 0.0285
# Epoch 87: loss did not improve from 0.02937
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9865 - dice_coefficient: 0.9714 - jaccard_coefficient: 0.9444 - loss: 0.0286 - learning_rate: 0.0010
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9857 - dice_coefficient: 0.9708 - jaccard_coefficient: 0.9433 - loss: 0.0292
# Epoch 88: loss did not improve from 0.02937
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - accuracy: 0.9857 - dice_coefficient: 0.9708 - jaccard_coefficient: 0.9432 - loss: 0.0292 - learning_rate: 0.0010
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9854 - dice_coefficient: 0.9714 - jaccard_coefficient: 0.9444 - loss: 0.0286
# Epoch 89: loss did not improve from 0.02937
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - accuracy: 0.9854 - dice_coefficient: 0.9714 - jaccard_coefficient: 0.9443 - loss: 0.0286 - learning_rate: 0.0010
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9861 - dice_coefficient: 0.9716 - jaccard_coefficient: 0.9447 - loss: 0.0284
# Epoch 90: loss improved from 0.02937 to 0.02937, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9861 - dice_coefficient: 0.9715 - jaccard_coefficient: 0.9446 - loss: 0.0285 - learning_rate: 0.0010
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9857 - dice_coefficient: 0.9715 - jaccard_coefficient: 0.9446 - loss: 0.0285
# Epoch 91: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 91: loss did not improve from 0.02937
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - accuracy: 0.9857 - dice_coefficient: 0.9714 - jaccard_coefficient: 0.9445 - loss: 0.0286 - learning_rate: 0.0010
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9856 - dice_coefficient: 0.9715 - jaccard_coefficient: 0.9446 - loss: 0.0285
# Epoch 92: loss improved from 0.02937 to 0.02781, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9856 - dice_coefficient: 0.9715 - jaccard_coefficient: 0.9447 - loss: 0.0285 - learning_rate: 5.0000e-04
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9876 - dice_coefficient: 0.9757 - jaccard_coefficient: 0.9525 - loss: 0.0243
# Epoch 93: loss improved from 0.02781 to 0.02539, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 758ms/step - accuracy: 0.9876 - dice_coefficient: 0.9756 - jaccard_coefficient: 0.9524 - loss: 0.0244 - learning_rate: 5.0000e-04
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9875 - dice_coefficient: 0.9741 - jaccard_coefficient: 0.9496 - loss: 0.0259
# Epoch 94: loss did not improve from 0.02539
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9875 - dice_coefficient: 0.9741 - jaccard_coefficient: 0.9496 - loss: 0.0259 - learning_rate: 5.0000e-04
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9883 - dice_coefficient: 0.9752 - jaccard_coefficient: 0.9516 - loss: 0.0248
# Epoch 95: loss improved from 0.02539 to 0.02439, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 761ms/step - accuracy: 0.9883 - dice_coefficient: 0.9752 - jaccard_coefficient: 0.9517 - loss: 0.0248 - learning_rate: 5.0000e-04
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9877 - dice_coefficient: 0.9756 - jaccard_coefficient: 0.9524 - loss: 0.0244
# Epoch 96: loss improved from 0.02439 to 0.02365, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9878 - dice_coefficient: 0.9756 - jaccard_coefficient: 0.9524 - loss: 0.0244 - learning_rate: 5.0000e-04
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9880 - dice_coefficient: 0.9765 - jaccard_coefficient: 0.9541 - loss: 0.0235
# Epoch 97: loss improved from 0.02365 to 0.02343, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.9880 - dice_coefficient: 0.9765 - jaccard_coefficient: 0.9541 - loss: 0.0235 - learning_rate: 5.0000e-04
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9887 - dice_coefficient: 0.9755 - jaccard_coefficient: 0.9522 - loss: 0.0245
# Epoch 98: loss improved from 0.02343 to 0.02310, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9887 - dice_coefficient: 0.9756 - jaccard_coefficient: 0.9523 - loss: 0.0244 - learning_rate: 5.0000e-04
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - accuracy: 0.9890 - dice_coefficient: 0.9780 - jaccard_coefficient: 0.9569 - loss: 0.0220
# Epoch 99: loss improved from 0.02310 to 0.02306, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 759ms/step - accuracy: 0.9889 - dice_coefficient: 0.9779 - jaccard_coefficient: 0.9568 - loss: 0.0221 - learning_rate: 5.0000e-04
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 728ms/step - accuracy: 0.9879 - dice_coefficient: 0.9762 - jaccard_coefficient: 0.9534 - loss: 0.0238
# Epoch 100: loss did not improve from 0.02306
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 728ms/step - accuracy: 0.9879 - dice_coefficient: 0.9761 - jaccard_coefficient: 0.9534 - loss: 0.0239 - learning_rate: 5.0000e-04
# SegUNet output shape: (None, 256, 256, 1)
# Thời gian huấn luyện: 1632.36 giây
# Accuracy trung bình: 95.90%
# Jaccard trung bình: 85.26%
# Dice trung bình: 91.52%

# %%
acc = history.history['accuracy']
loss = history.history['loss']
epochs_range = range(1, len(acc) + 1)
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Accuracy', color='green')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Loss', color='red')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.savefig('Gray_2750_acc_loss.png', dpi=300)
plt.show()

# %%
def apply_morphology(mask, kernel_size=3, iterations=1):
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))
    mask = (mask > 0.5).astype(np.uint8) 
    
    closed = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=iterations)

    opened = cv2.morphologyEx(closed, cv2.MORPH_OPEN, kernel, iterations=iterations)

    return opened.astype(np.float32)  

print("🔍 Đánh giá không hậu xử lý...")
results = segunet.evaluate(test_images_gray_clahe, test_masks, verbose=1)
loss, accuracy, jaccard, dice = results

print(f"Không hậu xử lý - Dice Loss: {loss:.4f}, Accuracy: {accuracy*100:.2f}%, Jaccard: {jaccard*100:.2f}%")

print("\n🔧 Đánh giá sau Morphology...")
predictions1 = segunet.predict(test_images_gray_clahe)
refined_predictions1 = []

for i in tqdm(range(len(test_images_gray_clahe))):
    pred = predictions1[i].squeeze()

    morph_pred = apply_morphology(pred, kernel_size=7, iterations=2)

    refined_predictions1.append(morph_pred)

refined_predictions1 = np.expand_dims(np.array(refined_predictions1), axis=-1)

accuracy_after = np_accuracy(test_masks, refined_predictions1)
jaccard_after = np_jaccard_coefficient(test_masks, refined_predictions1)
loss_after = np_dice_loss(test_masks, refined_predictions1)

print(f"Sau Morphology - Dice Loss: {loss_after:.4f}, Accuracy: {accuracy_after*100:.2f}%, Jaccard: {jaccard_after*100:.2f}%")
# Out:
# 🔍 Đánh giá không hậu xử lý...
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 878ms/step - accuracy: 0.9289 - dice_coefficient: 0.8405 - jaccard_coefficient: 0.7288 - loss: 0.1594
# Không hậu xử lý - Dice Loss: 0.1852, Accuracy: 92.37%, Jaccard: 69.11%
#
# 🔧 Đánh giá sau Morphology...
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 9s 645ms/step
# 100%|██████████| 272/272 [00:00<00:00, 1554.99it/s]
# Sau Morphology - Dice Loss: 0.1699, Accuracy: 92.39%, Jaccard: 70.95%

# %%
def apply_crf(original_image, model_output):
    H, W = original_image.shape[:2]
    model_output = np.squeeze(model_output)
    probs = np.stack([1.0 - model_output, model_output], axis=0)

    d = dcrf.DenseCRF2D(W, H, 2)
    d.setUnaryEnergy(unary_from_softmax(probs))
    d.addPairwiseGaussian(sxy=3, compat=3)

    if len(original_image.shape) == 2:
        original_image = original_image[..., np.newaxis]
    if original_image.shape[-1] == 3:
        original_image = cv2.cvtColor(original_image, cv2.COLOR_RGB2GRAY)[..., np.newaxis]

    pairwise_energy = create_pairwise_bilateral(sdims=(80, 80), schan=(13,), img=original_image.astype(np.uint8), chdim=2)
    d.addPairwiseEnergy(pairwise_energy, compat=10)

    Q = d.inference(1)
    return np.argmax(Q, axis=0).reshape((H, W))

print("Đánh giá trước CRF...")
results = segunet.evaluate(test_images_gray_clahe, test_masks, verbose=1)
loss, accuracy, jaccard, dice = results

print(f"Trước CRF - Dice Loss: {loss:.4f}, Accuracy: {accuracy*100:.2f}%, Jaccard: {jaccard*100:.2f}%")

print("\nĐánh giá sau CRF...")
predictions2 = segunet.predict(test_images_gray_clahe)
refined_predictions2 = []

for i in range(len(test_images_gray_clahe)):
    img = test_images_gray_clahe[i]
    if img.max() <= 1.0:
        img = (img * 255).astype(np.uint8)
    refined_pred = apply_crf(img, predictions2[i])
    refined_predictions2.append(refined_pred)

refined_predictions2 = np.array(refined_predictions2)
accuracy_after = np_accuracy(test_masks, refined_predictions2)
jaccard_after = np_jaccard_coefficient(test_masks, refined_predictions2)
loss_after = np_dice_loss(test_masks, refined_predictions2)

print(f"Sau CRF - Dice Loss: {loss_after:.4f}, Accuracy: {accuracy_after*100:.2f}%, Jaccard: {jaccard_after*100:.2f}%")
# Out:
# Đánh giá trước CRF...
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.9289 - dice_coefficient: 0.8405 - jaccard_coefficient: 0.7288 - loss: 0.1594
# Trước CRF - Dice Loss: 0.1852, Accuracy: 92.37%, Jaccard: 69.11%
#
# Đánh giá sau CRF...
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step
# Sau CRF - Dice Loss: 0.1720, Accuracy: 92.38%, Jaccard: 70.65%

# %%
segunet.save('/kaggle/working/model/gray_907_model.h5')
segunet.save('/kaggle/working/model/gray_907_model.keras')
