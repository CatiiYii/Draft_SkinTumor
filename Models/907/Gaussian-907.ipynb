# %%
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
# !pip install opencv-contrib-python
# !pip install tensorflow-addons
import os
import cv2
import time
import json
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Layer, Input, Conv2D, BatchNormalization, Lambda, Concatenate
import pydensecrf.densecrf as dcrf
from pydensecrf.utils import unary_from_softmax, create_pairwise_bilateral
from tensorflow.keras.layers import Input, SeparableConv2D, BatchNormalization, MaxPooling2D, Conv2DTranspose, Concatenate, SpatialDropout2D, ReLU, GlobalAveragePooling2D, GlobalMaxPooling2D, Dense, Reshape, Multiply, Add, Conv2D, Lambda
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.layers import (
    Input, SeparableConv2D, BatchNormalization, MaxPooling2D, UpSampling2D, Conv2DTranspose,
    Concatenate, SpatialDropout2D, ReLU, GlobalAveragePooling2D, Add,
    GlobalMaxPooling2D, Dense, Reshape, Multiply, Add, Conv2D, Lambda, Activation
)
from tensorflow.keras.activations import swish
from tensorflow.keras.layers import Conv2D, Activation, Add, Multiply, UpSampling2D, Concatenate

from tensorflow.keras.regularizers import l2
# Out:
# Collecting git+https://github.com/lucasb-eyer/pydensecrf.git
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-0i1mvkbv
#   Running command git clone --filter=blob:none --quiet https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-0i1mvkbv
#   Resolved https://github.com/lucasb-eyer/pydensecrf.git to commit 2723c7fa4f2ead16ae1ce3d8afe977724bb8f87f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pydensecrf
#   Building wheel for pydensecrf (pyproject.toml) ... done
#   Created wheel for pydensecrf: filename=pydensecrf-1.0-cp311-cp311-linux_x86_64.whl size=3440333 sha256=77779b7ea0e34fcc9eaec6221f35ee86268a635395db3cc443daa23af0c72745
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yxrs0y_z/wheels/ce/8e/34/6dcfa200a9e2ae3627d8009b8bd1ca9b24512bec50a93304de
# Successfully built pydensecrf
# Installing collected packages: pydensecrf
# Successfully installed pydensecrf-1.0
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-contrib-python) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (24.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 9.4 MB/s eta 0:00:00a 0:00:01
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.1
#     Uninstalling typeguard-4.4.1:
#       Successfully uninstalled typeguard-4.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.16.1 requires typeguard<5,>=3, but you have typeguard 2.13.3 which is incompatible.
# inflect 7.5.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3
# 2025-12-14 19:23:59.033267: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765740239.242439      33 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765740239.299131      33 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
working_dir = '/kaggle/working'
for item in os.listdir(working_dir):
    item_path = os.path.join(working_dir, item)
    try:
        if os.path.isfile(item_path) or os.path.islink(item_path):
            os.unlink(item_path)  
        elif os.path.isdir(item_path):
            shutil.rmtree(item_path)
            print(f"❌ xóa thành công {item_path}")
    except Exception as e:
        print(f"Lỗi khi xóa {item_path}: {e}")
# Out:
# ❌ xóa thành công /kaggle/working/.virtual_documents

# %%
def load_isic_dataset(image_path, mask_path, binary_path, csv_file, img_size=(256, 256)):
    image_files = sorted(glob(os.path.join(image_path, "ISIC_*.jpg")))
    images = []
    masks = []
    binary_masks = {}
    image_ids = []
    labels = []

    csv_data = pd.read_csv(csv_file)
    mel_label = csv_data['melanoma'].astype("int64")

    print("Đang đọc và xử lý dữ liệu...")
    for index, img_path in enumerate(tqdm(image_files)):
        img_id = os.path.basename(img_path).split('.')[0]
        mask_file = os.path.join(mask_path, f"{img_id}_segmentation.png")
        binary_file = os.path.join(binary_path, f"{img_id}_features.json")

      
        if not os.path.exists(mask_file):
            print(f"Không tìm thấy mask cho ảnh mặt nạ {img_id}_segmentation.png")
            continue
        if not os.path.exists(binary_file):
            print(f"Không tìm thấy mask nhị phân cho ảnh {img_id}_features.json")
            continue

        try:
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  

            mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)

            img = cv2.resize(img, img_size)
            mask = cv2.resize(mask, img_size)

            img = img / 255.0
            mask = mask / 255.0

            with open(binary_file, 'r') as f:
                binary_masks[img_id] = json.load(f)

            label = mel_label[index]

            images.append(img)
            masks.append(mask)
            image_ids.append(img_id)
            labels.append(label.astype("long"))

        except Exception as e:
            print(f"Lỗi khi xử lý ảnh {img_id}: {str(e)}")
            continue

    images = np.array(images)
    masks = np.array(masks)[..., np.newaxis] 
    labels = np.array(labels)

    print(f"\nĐã đọc thành công {len(images)} ảnh")
    print(f"Shape của images: {images.shape}")
    print(f"Shape của masks: {masks.shape}")
    print(f"Shape của labels: {labels.shape}")

    return images, masks, binary_masks, image_ids, labels

# %%
train_images, train_masks, train_binarys, train_image_ids, train_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2017-melanoma/Train_Data',
    mask_path='/kaggle/input/isic-2017-melanoma/Train_GroundTruth_1',
    binary_path='/kaggle/input/isic-2017-melanoma/Train_GroundTruth_2',
    csv_file="/kaggle/input/isic-2017-melanoma/Train_GroundTruth_3.csv",
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 635/635 [01:47<00:00,  5.90it/s]
# Đã đọc thành công 635 ảnh
# Shape của images: (635, 256, 256, 3)
# Shape của masks: (635, 256, 256, 1)
# Shape của labels: (635,)

# %%
test_images, test_masks, test_binarys, test_image_ids, test_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2017-melanoma/Test_Data',
    mask_path='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_1',
    binary_path='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_2',
    csv_file='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_3.csv',
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 272/272 [00:39<00:00,  6.92it/s]
# Đã đọc thành công 272 ảnh
# Shape của images: (272, 256, 256, 3)
# Shape của masks: (272, 256, 256, 1)
# Shape của labels: (272,)

# %%
def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = (intersection + 1e-7) / (union + 1e-7)
    return iou

# %%
def compute_metric(y_true, y_pred, metric='dice_coefficient', smooth=1e-6, is_numpy=False):
    y_true_f = y_true.flatten() if is_numpy else K.flatten(y_true)
    y_pred_f = y_pred.flatten() if is_numpy else K.flatten(y_pred)
    intersection = np.sum(y_true_f * y_pred_f) if is_numpy else K.sum(y_true_f * y_pred_f)

    if 'dice' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        score = (2. * intersection + smooth) / (sum_fn(y_true_f) + sum_fn(y_pred_f) + smooth)
    elif 'jaccard' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        union = sum_fn(y_true_f) + sum_fn(y_pred_f) - intersection
        score = (intersection + smooth) / (union + smooth)
    else:
        raise ValueError(f"Unsupported metric: {metric}")

    return score if 'coefficient' in metric else 1 - score

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth)

def dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth)

def jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth)

def jaccard_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_loss', smooth)

def np_accuracy(y_true, y_pred):
    return np.mean(y_true.flatten() == y_pred.flatten())

def np_dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth, is_numpy=True)

def np_jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth, is_numpy=True)

def np_dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth, is_numpy=True)

# %%
def cbam_module(input_features, reduction_ratio=8):

    filters = input_features.shape[-1]
   
    avg_pool = GlobalAveragePooling2D()(input_features)
    max_pool = GlobalMaxPooling2D()(input_features)
    
    shared_dense_1 = Dense(filters // reduction_ratio, 
                           activation='relu', 
                           kernel_initializer='he_normal', 
                           use_bias=True)
    
    shared_dense_2 = Dense(filters, 
                           use_bias=True)
    
    avg_out = shared_dense_2(shared_dense_1(avg_pool))
    max_out = shared_dense_2(shared_dense_1(max_pool))
    
    channel_sum = Add()([avg_out, max_out])
    channel_attention = Activation('sigmoid')(channel_sum)
    channel_attention = Reshape((1, 1, filters))(channel_attention)
    channel_refined = Multiply()([input_features, channel_attention])
   
    avg_spatial = Lambda(lambda x: K.mean(x, axis=-1, keepdims=True), 
                         output_shape=lambda s: (s[0], s[1], s[2], 1))(channel_refined)
    max_spatial = Lambda(lambda x: K.max(x, axis=-1, keepdims=True), 
                         output_shape=lambda s: (s[0], s[1], s[2], 1))(channel_refined)
    
    spatial_concat = Concatenate(axis=-1)([avg_spatial, max_spatial])
    
    spatial_attention = Conv2D(1, 
                               (7, 7), 
                               padding='same', 
                               activation='sigmoid', 
                               use_bias=False)(spatial_concat)
    
    refined_features = Multiply()([channel_refined, spatial_attention])
    
    
    return refined_features

# %%
def simam(x, lambda_val=1e-4):  
    shape = tf.shape(x)
    H, W = shape[1], shape[2]
    n = tf.cast(H * W - 1, x.dtype)
    
    mu = tf.reduce_mean(x, axis=[1, 2], keepdims=True)
    d = tf.square(x - mu)
    var = tf.reduce_sum(d, axis=[1, 2], keepdims=True) / n
    e_t = d / (4 * (var + lambda_val)) + 0.5
    
    return x * tf.nn.sigmoid(e_t)

def aspp_module(input_tensor, output_filters=1024, rates=[1, 6, 12, 18]):
    num_branches = len(rates)
    branch_filters = output_filters // num_branches

    branches = []
    for rate in rates:
        branch = SeparableConv2D(branch_filters, (3, 3), padding='same', dilation_rate=rate, use_bias=False,
                                  depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(input_tensor)
        branch = BatchNormalization()(branch)
        branch = ReLU()(branch)
        branches.append(branch)

    concatenated = Concatenate()(branches)
    attended = Lambda(simam)(concatenated)

    final_conv = SeparableConv2D(output_filters, (1, 1), padding='same', use_bias=False,
                                  depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(attended)
    final_conv = BatchNormalization()(final_conv)
    final_conv = ReLU()(final_conv)
    final_conv = SpatialDropout2D(0.2)(final_conv)
    return final_conv

# %%
def CustomSegUNet(input_size=(256, 256, 1)):
    inputs = Input(input_size)

    c1 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(inputs)
    c1 = BatchNormalization()(c1); c1 = ReLU()(c1)
    c1 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c1)
    c1 = BatchNormalization()(c1); c1 = ReLU()(c1)
    c1 = SpatialDropout2D(0.1)(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p1)
    c2 = BatchNormalization()(c2); c2 = ReLU()(c2)
    c2 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c2)
    c2 = BatchNormalization()(c2); c2 = ReLU()(c2)
    c2 = SpatialDropout2D(0.1)(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p2)
    c3 = BatchNormalization()(c3); c3 = ReLU()(c3)
    c3 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c3)
    c3 = BatchNormalization()(c3); c3 = ReLU()(c3)
    c3 = SpatialDropout2D(0.1)(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p3)
    c4 = BatchNormalization()(c4); c4 = ReLU()(c4)
    c4 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c4)
    c4 = BatchNormalization()(c4); c4 = ReLU()(c4)
    c4 = SpatialDropout2D(0.1)(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p4)
    c5 = BatchNormalization()(c5); c5 = ReLU()(c5)
    c5 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c5)
    c5 = BatchNormalization()(c5); c5 = ReLU()(c5)
    c5 = SpatialDropout2D(0.1)(c5)
    p5 = MaxPooling2D((2, 2))(c5)

    
    c6 = aspp_module(p5, output_filters=1024, rates=[1, 6, 12, 18])

    u7 = Conv2DTranspose(512, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c6)
    u7 = Concatenate()([u7, c5])
    c7 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u7)
    c7 = BatchNormalization()(c7); c7 = ReLU()(c7)
    c7 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c7)
    c7 = BatchNormalization()(c7); c7 = ReLU()(c7)
    c7 = cbam_module(c7)

    u8 = Conv2DTranspose(256, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c7)
    u8 = Concatenate()([u8, c4])
    c8 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u8)
    c8 = BatchNormalization()(c8); c8 = ReLU()(c8)
    c8 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c8)
    c8 = BatchNormalization()(c8); c8 = ReLU()(c8)
    c8 = cbam_module(c8)

    u9 = Conv2DTranspose(256, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c8)
    u9 = Concatenate()([u9, c3])
    c9 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u9)
    c9 = BatchNormalization()(c9); c9 = ReLU()(c9)
    c9 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c9)
    c9 = BatchNormalization()(c9); c9 = ReLU()(c9)
    c9 = cbam_module(c9)

    u10 = Conv2DTranspose(128, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c9)
    u10 = Concatenate()([u10, c2])
    c10 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u10)
    c10 = BatchNormalization()(c10); c10 = ReLU()(c10)
    c10 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c10)
    c10 = BatchNormalization()(c10); c10 = ReLU()(c10)
    c10 = cbam_module(c10)

    u11 = Conv2DTranspose(64, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c10)
    u11 = Concatenate()([u11, c1])
    c11 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u11)
    c11 = BatchNormalization()(c11); c11 = ReLU()(c11)
    c11 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c11)
    c11 = BatchNormalization()(c11); c11 = ReLU()(c11)
    c11 = cbam_module(c11)

 
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c11)

    return Model(inputs=inputs, outputs=outputs)

if __name__ == "__main__":
    model = CustomSegUNet()
    model.summary()
# Out:
# I0000 00:00:1765740399.006887      33 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 1)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d          │ (None, 256, 256, 64)   │            137 │ input_layer[0][0]      │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 64)   │            256 │ separable_conv2d[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 256, 256, 64)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_1        │ (None, 256, 256, 64)   │          4,736 │ re_lu[0][0]            │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256, 256, 64)   │            256 │ separable_conv2d_1[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1 (ReLU)            │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d         │ (None, 256, 256, 64)   │              0 │ re_lu_1[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ spatial_dropout2d[0][… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_2        │ (None, 128, 128, 128)  │          8,896 │ max_pooling2d[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 128, 128, 128)  │            512 │ separable_conv2d_2[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_2 (ReLU)            │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_3        │ (None, 128, 128, 128)  │         17,664 │ re_lu_2[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 128, 128, 128)  │            512 │ separable_conv2d_3[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_3 (ReLU)            │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_1       │ (None, 128, 128, 128)  │              0 │ re_lu_3[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 128)    │              0 │ spatial_dropout2d_1[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_4        │ (None, 64, 64, 256)    │         34,176 │ max_pooling2d_1[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_4[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_4 (ReLU)            │ (None, 64, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_5        │ (None, 64, 64, 256)    │         68,096 │ re_lu_4[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_5[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_5 (ReLU)            │ (None, 64, 64, 256)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_2       │ (None, 64, 64, 256)    │              0 │ re_lu_5[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ spatial_dropout2d_2[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_6        │ (None, 32, 32, 256)    │         68,096 │ max_pooling2d_2[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_6[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_6 (ReLU)            │ (None, 32, 32, 256)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_7        │ (None, 32, 32, 256)    │         68,096 │ re_lu_6[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_7[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_7 (ReLU)            │ (None, 32, 32, 256)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_3       │ (None, 32, 32, 256)    │              0 │ re_lu_7[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 256)    │              0 │ spatial_dropout2d_3[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_8        │ (None, 16, 16, 512)    │        133,888 │ max_pooling2d_3[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_8[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_8 (ReLU)            │ (None, 16, 16, 512)    │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_9        │ (None, 16, 16, 512)    │        267,264 │ re_lu_8[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_9[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_9 (ReLU)            │ (None, 16, 16, 512)    │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_4       │ (None, 16, 16, 512)    │              0 │ re_lu_9[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 8, 8, 512)      │              0 │ spatial_dropout2d_4[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_10       │ (None, 8, 8, 256)      │        135,680 │ max_pooling2d_4[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_11       │ (None, 8, 8, 256)      │        135,680 │ max_pooling2d_4[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_12       │ (None, 8, 8, 256)      │        135,680 │ max_pooling2d_4[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_13       │ (None, 8, 8, 256)      │        135,680 │ max_pooling2d_4[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 8, 8, 256)      │          1,024 │ separable_conv2d_10[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 8, 8, 256)      │          1,024 │ separable_conv2d_11[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 8, 8, 256)      │          1,024 │ separable_conv2d_12[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 8, 8, 256)      │          1,024 │ separable_conv2d_13[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_10 (ReLU)           │ (None, 8, 8, 256)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_11 (ReLU)           │ (None, 8, 8, 256)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_12 (ReLU)           │ (None, 8, 8, 256)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_13 (ReLU)           │ (None, 8, 8, 256)      │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 8, 8, 1024)     │              0 │ re_lu_10[0][0],        │
# │                           │                        │                │ re_lu_11[0][0],        │
# │                           │                        │                │ re_lu_12[0][0],        │
# │                           │                        │                │ re_lu_13[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 8, 8, 1024)     │              0 │ concatenate[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_14       │ (None, 8, 8, 1024)     │      1,049,600 │ lambda[0][0]           │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 8, 8, 1024)     │          4,096 │ separable_conv2d_14[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_14 (ReLU)           │ (None, 8, 8, 1024)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_5       │ (None, 8, 8, 1024)     │              0 │ re_lu_14[0][0]         │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 16, 16, 512)    │      4,719,104 │ spatial_dropout2d_5[0… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 16, 16, 1024)   │              0 │ conv2d_transpose[0][0… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_4[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_15       │ (None, 16, 16, 512)    │        534,016 │ concatenate_1[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_15[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_15 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_16       │ (None, 16, 16, 512)    │        267,264 │ re_lu_15[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_16[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_16 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 512)            │              0 │ re_lu_16[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d      │ (None, 512)            │              0 │ re_lu_16[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 64)             │         32,832 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 512)            │         33,280 │ dense[0][0],           │
# │                           │                        │                │ dense[1][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 512)            │              0 │ dense_1[0][0],         │
# │                           │                        │                │ dense_1[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 512)            │              0 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 1, 1, 512)      │              0 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 16, 16, 512)    │              0 │ re_lu_16[0][0],        │
# │                           │                        │                │ reshape[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_1 (Lambda)         │ (None, 16, 16, 1)      │              0 │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_2 (Lambda)         │ (None, 16, 16, 1)      │              0 │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 16, 16, 2)      │              0 │ lambda_1[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 16, 16, 1)      │             98 │ concatenate_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_1 (Multiply)     │ (None, 16, 16, 512)    │              0 │ multiply[0][0],        │
# │                           │                        │                │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 32, 32, 256)    │      1,179,904 │ multiply_1[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 32, 32, 512)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_3[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_17       │ (None, 32, 32, 256)    │        135,936 │ concatenate_3[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_17[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_17 (ReLU)           │ (None, 32, 32, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_18       │ (None, 32, 32, 256)    │         68,096 │ re_lu_17[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_18[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_18 (ReLU)           │ (None, 32, 32, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 256)            │              0 │ re_lu_18[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_1    │ (None, 256)            │              0 │ re_lu_18[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 32)             │          8,224 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 256)            │          8,448 │ dense_2[0][0],         │
# │                           │                        │                │ dense_2[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 256)            │              0 │ dense_3[0][0],         │
# │                           │                        │                │ dense_3[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 256)            │              0 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_1 (Reshape)       │ (None, 1, 1, 256)      │              0 │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_2 (Multiply)     │ (None, 32, 32, 256)    │              0 │ re_lu_18[0][0],        │
# │                           │                        │                │ reshape_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_3 (Lambda)         │ (None, 32, 32, 1)      │              0 │ multiply_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_4 (Lambda)         │ (None, 32, 32, 1)      │              0 │ multiply_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 32, 32, 2)      │              0 │ lambda_3[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 32, 32, 1)      │             98 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_3 (Multiply)     │ (None, 32, 32, 256)    │              0 │ multiply_2[0][0],      │
# │                           │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 64, 64, 256)    │        590,080 │ multiply_3[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 64, 64, 512)    │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_2[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_19       │ (None, 64, 64, 256)    │        135,936 │ concatenate_5[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_19[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_19 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_20       │ (None, 64, 64, 256)    │         68,096 │ re_lu_19[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_20[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_20 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 256)            │              0 │ re_lu_20[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_2    │ (None, 256)            │              0 │ re_lu_20[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 32)             │          8,224 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 256)            │          8,448 │ dense_4[0][0],         │
# │                           │                        │                │ dense_4[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 256)            │              0 │ dense_5[0][0],         │
# │                           │                        │                │ dense_5[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 256)            │              0 │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_2 (Reshape)       │ (None, 1, 1, 256)      │              0 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_4 (Multiply)     │ (None, 64, 64, 256)    │              0 │ re_lu_20[0][0],        │
# │                           │                        │                │ reshape_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_5 (Lambda)         │ (None, 64, 64, 1)      │              0 │ multiply_4[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_6 (Lambda)         │ (None, 64, 64, 1)      │              0 │ multiply_4[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_6             │ (None, 64, 64, 2)      │              0 │ lambda_5[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 64, 64, 1)      │             98 │ concatenate_6[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_5 (Multiply)     │ (None, 64, 64, 256)    │              0 │ multiply_4[0][0],      │
# │                           │                        │                │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 128, 128, 128)  │        295,040 │ multiply_5[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_7             │ (None, 128, 128, 256)  │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_21       │ (None, 128, 128, 128)  │         35,200 │ concatenate_7[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_21    │ (None, 128, 128, 128)  │            512 │ separable_conv2d_21[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_21 (ReLU)           │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_22       │ (None, 128, 128, 128)  │         17,664 │ re_lu_21[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_22    │ (None, 128, 128, 128)  │            512 │ separable_conv2d_22[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_22 (ReLU)           │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 128)            │              0 │ re_lu_22[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_3    │ (None, 128)            │              0 │ re_lu_22[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 16)             │          2,064 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 128)            │          2,176 │ dense_6[0][0],         │
# │                           │                        │                │ dense_6[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 128)            │              0 │ dense_7[0][0],         │
# │                           │                        │                │ dense_7[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 128)            │              0 │ add_3[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_3 (Reshape)       │ (None, 1, 1, 128)      │              0 │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_6 (Multiply)     │ (None, 128, 128, 128)  │              0 │ re_lu_22[0][0],        │
# │                           │                        │                │ reshape_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_7 (Lambda)         │ (None, 128, 128, 1)    │              0 │ multiply_6[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_8 (Lambda)         │ (None, 128, 128, 1)    │              0 │ multiply_6[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_8             │ (None, 128, 128, 2)    │              0 │ lambda_7[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_8[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 1)    │             98 │ concatenate_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_7 (Multiply)     │ (None, 128, 128, 128)  │              0 │ multiply_6[0][0],      │
# │                           │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_4        │ (None, 256, 256, 64)   │         73,792 │ multiply_7[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_9             │ (None, 256, 256, 128)  │              0 │ conv2d_transpose_4[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_23       │ (None, 256, 256, 64)   │          9,408 │ concatenate_9[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_23    │ (None, 256, 256, 64)   │            256 │ separable_conv2d_23[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_23 (ReLU)           │ (None, 256, 256, 64)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_24       │ (None, 256, 256, 64)   │          4,736 │ re_lu_23[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_24    │ (None, 256, 256, 64)   │            256 │ separable_conv2d_24[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_24 (ReLU)           │ (None, 256, 256, 64)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 64)             │              0 │ re_lu_24[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_4    │ (None, 64)             │              0 │ re_lu_24[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 8)              │            520 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_9 (Dense)           │ (None, 64)             │            576 │ dense_8[0][0],         │
# │                           │                        │                │ dense_8[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 64)             │              0 │ dense_9[0][0],         │
# │                           │                        │                │ dense_9[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 64)             │              0 │ add_4[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_4 (Reshape)       │ (None, 1, 1, 64)       │              0 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_8 (Multiply)     │ (None, 256, 256, 64)   │              0 │ re_lu_24[0][0],        │
# │                           │                        │                │ reshape_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_9 (Lambda)         │ (None, 256, 256, 1)    │              0 │ multiply_8[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_10 (Lambda)        │ (None, 256, 256, 1)    │              0 │ multiply_8[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_10            │ (None, 256, 256, 2)    │              0 │ lambda_9[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_10[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 256, 256, 1)    │             98 │ concatenate_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_9 (Multiply)     │ (None, 256, 256, 64)   │              0 │ multiply_8[0][0],      │
# │                           │                        │                │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 256, 256, 1)    │             65 │ multiply_9[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 10,530,636 (40.17 MB)
#  Trainable params: 10,516,812 (40.12 MB)
#  Non-trainable params: 13,824 (54.00 KB)

# %%
class EarlyStoppingByAccuracyChange(tf.keras.callbacks.Callback):
    def __init__(self, monitor='accuracy', threshold=0.00001, patience=3, verbose=0):
        super(EarlyStoppingByAccuracyChange, self).__init__()
        self.monitor = monitor
        self.threshold = threshold
        self.patience = patience
        self.verbose = verbose
        self.wait = 0
        self.best_accuracy = -float('inf')
        self.consecutive_stops = 0

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current_accuracy = logs.get(self.monitor)
        if current_accuracy is None:
            tf.get_logger().warning(
                'Early stopping requires %s available!', self.monitor
            )
            return

        if current_accuracy > self.best_accuracy:
            self.best_accuracy = current_accuracy
            self.wait = 0
            self.consecutive_stops = 0
        else:
            self.wait += 1
            accuracy_change = current_accuracy - self.best_accuracy
            if abs(accuracy_change) < self.threshold:
                self.consecutive_stops += 1
                if self.consecutive_stops >= self.patience:
                    if self.verbose > 0:
                        print(f"Epoch {epoch+1}: Early stopping triggered due to minimal accuracy change for {self.patience} epochs.")
                    self.model.stop_training = True
            else:
                self.consecutive_stops = 0

# %%
pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-contrib-python) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def convert_to_gray_gaus(images):
    grays = []
    for img in images:
        if img.dtype != np.uint8:
            img = (img * 255).astype(np.uint8)
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        blurred = cv2.GaussianBlur(gray, (5, 5), 0)
        grays.append(blurred)
    return np.array(grays)

train_images_gray_gaus = convert_to_gray_gaus(train_images)
test_images_gray_gaus = convert_to_gray_gaus(test_images)

# %%
initial_lr = 0.001
optimizer = Adam(learning_rate=initial_lr)
segunet = CustomSegUNet(input_size=(256, 256, 1))
segunet.compile(
    optimizer=optimizer,
    loss=dice_loss,
    metrics=['accuracy', jaccard_coefficient]
)

model_checkpoint_dir = 'model'


checkpoint_path = os.path.join(model_checkpoint_dir, 'cp.ckpt')

checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(model_checkpoint_dir, 'custom_seg_unet.weights.h5'),
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True,
    verbose=1
)
early_stopping = EarlyStoppingByAccuracyChange(
    monitor='accuracy',
    threshold=0.00001,
    patience=10,
    verbose=1
)

lr_reduction = ReduceLROnPlateau(monitor='loss',
                                  patience=5,
                                  verbose=1,
                                  factor=0.5,
                                  min_lr=0.00001)



start_time = time.time()


history = segunet.fit(
    train_images_gray_gaus, train_masks,
    batch_size=32,
    epochs=100,
    callbacks=[early_stopping, lr_reduction, checkpoint_callback]
)

end_time = time.time()
training_time = end_time - start_time
avg_accuracy = np.mean(history.history['accuracy'])
avg_jaccard = np.mean(history.history['jaccard_coefficient'])

print("SegUNet output shape:", segunet.output_shape)
print(f"⏱️ Thời gian huấn luyện: {training_time:.2f} giây")
print(f"✅ Accuracy trung bình: {avg_accuracy*100:.2f}%")
print(f"🔗 Jaccard trung bình: {avg_jaccard*100:.2f}%")
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765740439.258262     189 service.cc:148] XLA service 0x7e0b34094e20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1765740439.259044     189 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1765740442.436907     189 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1765740465.537389     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740465.763652     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740467.669970     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740467.878911     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740468.444515     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740468.654290     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740469.586982     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740469.890015     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740472.459321     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740472.877682     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-14 19:27:53.027699: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,128,128]{3,2,1,0}, f32[32,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-14 19:27:53.134191: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.106706961s
# Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,128,128]{3,2,1,0}, f32[32,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1765740492.028293     189 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - accuracy: 0.7579 - jaccard_coefficient: 0.2099 - loss: 0.6565
# E0000 00:00:1765740515.037848     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740515.277609     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740520.669820     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740520.909546     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740531.057602     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740531.277669     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740533.088023     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740533.295449     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740533.824825     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740534.032969     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740534.874984     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740535.165425     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740537.408198     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765740537.801258     189 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-14 19:28:58.004109: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,256,128,128]{3,2,1,0}, f32[27,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-14 19:28:58.033347: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.029332692s
# Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,256,128,128]{3,2,1,0}, f32[27,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7573 - jaccard_coefficient: 0.2123 - loss: 0.6534
# Epoch 1: loss improved from inf to 0.59460, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 152s 3s/step - accuracy: 0.7568 - jaccard_coefficient: 0.2144 - loss: 0.6506 - learning_rate: 0.0010
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.7426 - jaccard_coefficient: 0.3593 - loss: 0.4739
# Epoch 2: loss improved from 0.59460 to 0.42124, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 762ms/step - accuracy: 0.7447 - jaccard_coefficient: 0.3619 - loss: 0.4713 - learning_rate: 0.0010
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.8493 - jaccard_coefficient: 0.5114 - loss: 0.3248
# Epoch 3: loss improved from 0.42124 to 0.32266, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.8494 - jaccard_coefficient: 0.5115 - loss: 0.3247 - learning_rate: 0.0010
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.8641 - jaccard_coefficient: 0.5363 - loss: 0.3036
# Epoch 4: loss improved from 0.32266 to 0.29730, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 760ms/step - accuracy: 0.8639 - jaccard_coefficient: 0.5367 - loss: 0.3033 - learning_rate: 0.0010
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.8773 - jaccard_coefficient: 0.5866 - loss: 0.2612
# Epoch 5: loss improved from 0.29730 to 0.25834, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.8774 - jaccard_coefficient: 0.5868 - loss: 0.2610 - learning_rate: 0.0010
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.8883 - jaccard_coefficient: 0.6141 - loss: 0.2396
# Epoch 6: loss improved from 0.25834 to 0.23770, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.8883 - jaccard_coefficient: 0.6142 - loss: 0.2395 - learning_rate: 0.0010
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.8937 - jaccard_coefficient: 0.6292 - loss: 0.2284
# Epoch 7: loss improved from 0.23770 to 0.22698, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.8937 - jaccard_coefficient: 0.6293 - loss: 0.2284 - learning_rate: 0.0010
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.8942 - jaccard_coefficient: 0.6494 - loss: 0.2133
# Epoch 8: loss improved from 0.22698 to 0.21920, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 766ms/step - accuracy: 0.8943 - jaccard_coefficient: 0.6491 - loss: 0.2136 - learning_rate: 0.0010
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.8976 - jaccard_coefficient: 0.6348 - loss: 0.2239
# Epoch 9: loss improved from 0.21920 to 0.20777, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.8979 - jaccard_coefficient: 0.6359 - loss: 0.2231 - learning_rate: 0.0010
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9020 - jaccard_coefficient: 0.6655 - loss: 0.2015
# Epoch 10: loss did not improve from 0.20777
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9020 - jaccard_coefficient: 0.6651 - loss: 0.2018 - learning_rate: 0.0010
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9141 - jaccard_coefficient: 0.6826 - loss: 0.1895
# Epoch 11: loss improved from 0.20777 to 0.19371, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 765ms/step - accuracy: 0.9138 - jaccard_coefficient: 0.6823 - loss: 0.1897 - learning_rate: 0.0010
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9148 - jaccard_coefficient: 0.6898 - loss: 0.1843
# Epoch 12: loss improved from 0.19371 to 0.18214, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 765ms/step - accuracy: 0.9148 - jaccard_coefficient: 0.6899 - loss: 0.1842 - learning_rate: 0.0010
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9209 - jaccard_coefficient: 0.7063 - loss: 0.1726
# Epoch 13: loss improved from 0.18214 to 0.17581, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9207 - jaccard_coefficient: 0.7061 - loss: 0.1727 - learning_rate: 0.0010
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9107 - jaccard_coefficient: 0.7013 - loss: 0.1763
# Epoch 14: loss improved from 0.17581 to 0.17292, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 762ms/step - accuracy: 0.9111 - jaccard_coefficient: 0.7015 - loss: 0.1761 - learning_rate: 0.0010
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9206 - jaccard_coefficient: 0.7013 - loss: 0.1758
# Epoch 15: loss improved from 0.17292 to 0.16874, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9206 - jaccard_coefficient: 0.7018 - loss: 0.1754 - learning_rate: 0.0010
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9263 - jaccard_coefficient: 0.7315 - loss: 0.1560
# Epoch 16: loss improved from 0.16874 to 0.15522, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9263 - jaccard_coefficient: 0.7315 - loss: 0.1559 - learning_rate: 0.0010
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9280 - jaccard_coefficient: 0.7350 - loss: 0.1540
# Epoch 17: loss did not improve from 0.15522
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9279 - jaccard_coefficient: 0.7347 - loss: 0.1541 - learning_rate: 0.0010
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9193 - jaccard_coefficient: 0.7056 - loss: 0.1732
# Epoch 18: loss did not improve from 0.15522
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9195 - jaccard_coefficient: 0.7065 - loss: 0.1726 - learning_rate: 0.0010
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9335 - jaccard_coefficient: 0.7561 - loss: 0.1392
# Epoch 19: loss improved from 0.15522 to 0.14240, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9335 - jaccard_coefficient: 0.7559 - loss: 0.1394 - learning_rate: 0.0010
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9361 - jaccard_coefficient: 0.7514 - loss: 0.1427
# Epoch 20: loss improved from 0.14240 to 0.13927, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9361 - jaccard_coefficient: 0.7516 - loss: 0.1425 - learning_rate: 0.0010
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9340 - jaccard_coefficient: 0.7546 - loss: 0.1403
# Epoch 21: loss improved from 0.13927 to 0.13585, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 765ms/step - accuracy: 0.9340 - jaccard_coefficient: 0.7549 - loss: 0.1401 - learning_rate: 0.0010
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9426 - jaccard_coefficient: 0.7782 - loss: 0.1249
# Epoch 22: loss improved from 0.13585 to 0.12693, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9424 - jaccard_coefficient: 0.7781 - loss: 0.1250 - learning_rate: 0.0010
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9386 - jaccard_coefficient: 0.7791 - loss: 0.1245
# Epoch 23: loss did not improve from 0.12693
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9387 - jaccard_coefficient: 0.7788 - loss: 0.1247 - learning_rate: 0.0010
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9420 - jaccard_coefficient: 0.7848 - loss: 0.1211
# Epoch 24: loss improved from 0.12693 to 0.12530, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9419 - jaccard_coefficient: 0.7844 - loss: 0.1213 - learning_rate: 0.0010
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9451 - jaccard_coefficient: 0.7873 - loss: 0.1192
# Epoch 25: loss did not improve from 0.12530
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9449 - jaccard_coefficient: 0.7868 - loss: 0.1196 - learning_rate: 0.0010
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9423 - jaccard_coefficient: 0.7814 - loss: 0.1231
# Epoch 26: loss improved from 0.12530 to 0.11936, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9423 - jaccard_coefficient: 0.7817 - loss: 0.1229 - learning_rate: 0.0010
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9431 - jaccard_coefficient: 0.7920 - loss: 0.1165
# Epoch 27: loss improved from 0.11936 to 0.11752, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 762ms/step - accuracy: 0.9432 - jaccard_coefficient: 0.7920 - loss: 0.1165 - learning_rate: 0.0010
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9468 - jaccard_coefficient: 0.7995 - loss: 0.1117
# Epoch 28: loss improved from 0.11752 to 0.11401, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9468 - jaccard_coefficient: 0.7993 - loss: 0.1118 - learning_rate: 0.0010
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9468 - jaccard_coefficient: 0.7989 - loss: 0.1120
# Epoch 29: loss improved from 0.11401 to 0.10786, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 761ms/step - accuracy: 0.9469 - jaccard_coefficient: 0.7992 - loss: 0.1118 - learning_rate: 0.0010
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9510 - jaccard_coefficient: 0.8108 - loss: 0.1046
# Epoch 30: loss improved from 0.10786 to 0.10390, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 762ms/step - accuracy: 0.9510 - jaccard_coefficient: 0.8109 - loss: 0.1046 - learning_rate: 0.0010
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9480 - jaccard_coefficient: 0.8072 - loss: 0.1069
# Epoch 31: loss did not improve from 0.10390
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9481 - jaccard_coefficient: 0.8073 - loss: 0.1068 - learning_rate: 0.0010
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9519 - jaccard_coefficient: 0.8206 - loss: 0.0987
# Epoch 32: loss improved from 0.10390 to 0.10179, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 762ms/step - accuracy: 0.9519 - jaccard_coefficient: 0.8204 - loss: 0.0988 - learning_rate: 0.0010
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9547 - jaccard_coefficient: 0.8319 - loss: 0.0919
# Epoch 33: loss improved from 0.10179 to 0.09611, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9546 - jaccard_coefficient: 0.8316 - loss: 0.0921 - learning_rate: 0.0010
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9558 - jaccard_coefficient: 0.8300 - loss: 0.0932
# Epoch 34: loss improved from 0.09611 to 0.09450, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9557 - jaccard_coefficient: 0.8299 - loss: 0.0932 - learning_rate: 0.0010
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9538 - jaccard_coefficient: 0.8272 - loss: 0.0949
# Epoch 35: loss did not improve from 0.09450
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9538 - jaccard_coefficient: 0.8269 - loss: 0.0951 - learning_rate: 0.0010
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9512 - jaccard_coefficient: 0.8082 - loss: 0.1063
# Epoch 36: loss did not improve from 0.09450
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9512 - jaccard_coefficient: 0.8087 - loss: 0.1061 - learning_rate: 0.0010
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9548 - jaccard_coefficient: 0.8355 - loss: 0.0898
# Epoch 37: loss improved from 0.09450 to 0.09356, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 765ms/step - accuracy: 0.9548 - jaccard_coefficient: 0.8352 - loss: 0.0900 - learning_rate: 0.0010
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9605 - jaccard_coefficient: 0.8449 - loss: 0.0842
# Epoch 38: loss improved from 0.09356 to 0.08494, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9604 - jaccard_coefficient: 0.8449 - loss: 0.0842 - learning_rate: 0.0010
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9591 - jaccard_coefficient: 0.8528 - loss: 0.0796
# Epoch 39: loss improved from 0.08494 to 0.08077, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9591 - jaccard_coefficient: 0.8527 - loss: 0.0796 - learning_rate: 0.0010
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9594 - jaccard_coefficient: 0.8450 - loss: 0.0842
# Epoch 40: loss did not improve from 0.08077
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9594 - jaccard_coefficient: 0.8450 - loss: 0.0841 - learning_rate: 0.0010
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9638 - jaccard_coefficient: 0.8590 - loss: 0.0760
# Epoch 41: loss improved from 0.08077 to 0.07910, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9637 - jaccard_coefficient: 0.8588 - loss: 0.0761 - learning_rate: 0.0010
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9601 - jaccard_coefficient: 0.8485 - loss: 0.0820
# Epoch 42: loss did not improve from 0.07910
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9601 - jaccard_coefficient: 0.8485 - loss: 0.0820 - learning_rate: 0.0010
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9655 - jaccard_coefficient: 0.8637 - loss: 0.0733
# Epoch 43: loss improved from 0.07910 to 0.07589, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9654 - jaccard_coefficient: 0.8635 - loss: 0.0734 - learning_rate: 0.0010
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9615 - jaccard_coefficient: 0.8527 - loss: 0.0796
# Epoch 44: loss did not improve from 0.07589
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9615 - jaccard_coefficient: 0.8527 - loss: 0.0796 - learning_rate: 0.0010
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9656 - jaccard_coefficient: 0.8645 - loss: 0.0729
# Epoch 45: loss did not improve from 0.07589
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9654 - jaccard_coefficient: 0.8639 - loss: 0.0732 - learning_rate: 0.0010
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9656 - jaccard_coefficient: 0.8651 - loss: 0.0725
# Epoch 46: loss improved from 0.07589 to 0.07523, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9655 - jaccard_coefficient: 0.8648 - loss: 0.0726 - learning_rate: 0.0010
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9643 - jaccard_coefficient: 0.8598 - loss: 0.0756
# Epoch 47: loss improved from 0.07523 to 0.07120, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9644 - jaccard_coefficient: 0.8601 - loss: 0.0754 - learning_rate: 0.0010
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9687 - jaccard_coefficient: 0.8747 - loss: 0.0669
# Epoch 48: loss improved from 0.07120 to 0.06775, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 762ms/step - accuracy: 0.9686 - jaccard_coefficient: 0.8746 - loss: 0.0670 - learning_rate: 0.0010
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9662 - jaccard_coefficient: 0.8648 - loss: 0.0726
# Epoch 49: loss did not improve from 0.06775
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9662 - jaccard_coefficient: 0.8649 - loss: 0.0726 - learning_rate: 0.0010
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9642 - jaccard_coefficient: 0.8613 - loss: 0.0747
# Epoch 50: loss did not improve from 0.06775
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9642 - jaccard_coefficient: 0.8615 - loss: 0.0746 - learning_rate: 0.0010
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9679 - jaccard_coefficient: 0.8764 - loss: 0.0659
# Epoch 51: loss did not improve from 0.06775
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9678 - jaccard_coefficient: 0.8762 - loss: 0.0660 - learning_rate: 0.0010
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9652 - jaccard_coefficient: 0.8639 - loss: 0.0736
# Epoch 52: loss did not improve from 0.06775
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9653 - jaccard_coefficient: 0.8641 - loss: 0.0735 - learning_rate: 0.0010
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9690 - jaccard_coefficient: 0.8767 - loss: 0.0658
# Epoch 53: loss improved from 0.06775 to 0.06686, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9690 - jaccard_coefficient: 0.8766 - loss: 0.0659 - learning_rate: 0.0010
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9689 - jaccard_coefficient: 0.8741 - loss: 0.0673
# Epoch 54: loss did not improve from 0.06686
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9688 - jaccard_coefficient: 0.8741 - loss: 0.0673 - learning_rate: 0.0010
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9689 - jaccard_coefficient: 0.8828 - loss: 0.0623
# Epoch 55: loss improved from 0.06686 to 0.06476, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9689 - jaccard_coefficient: 0.8826 - loss: 0.0624 - learning_rate: 0.0010
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9677 - jaccard_coefficient: 0.8819 - loss: 0.0628
# Epoch 56: loss improved from 0.06476 to 0.06148, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9678 - jaccard_coefficient: 0.8820 - loss: 0.0628 - learning_rate: 0.0010
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9715 - jaccard_coefficient: 0.8884 - loss: 0.0591
# Epoch 57: loss improved from 0.06148 to 0.05979, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9714 - jaccard_coefficient: 0.8884 - loss: 0.0592 - learning_rate: 0.0010
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9699 - jaccard_coefficient: 0.8865 - loss: 0.0602
# Epoch 58: loss improved from 0.05979 to 0.05869, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9700 - jaccard_coefficient: 0.8866 - loss: 0.0602 - learning_rate: 0.0010
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9708 - jaccard_coefficient: 0.8896 - loss: 0.0585
# Epoch 59: loss did not improve from 0.05869
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9708 - jaccard_coefficient: 0.8894 - loss: 0.0586 - learning_rate: 0.0010
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9703 - jaccard_coefficient: 0.8829 - loss: 0.0623
# Epoch 60: loss did not improve from 0.05869
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9703 - jaccard_coefficient: 0.8827 - loss: 0.0624 - learning_rate: 0.0010
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9718 - jaccard_coefficient: 0.8901 - loss: 0.0582
# Epoch 61: loss did not improve from 0.05869
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9718 - jaccard_coefficient: 0.8900 - loss: 0.0583 - learning_rate: 0.0010
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9701 - jaccard_coefficient: 0.8849 - loss: 0.0611
# Epoch 62: loss did not improve from 0.05869
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9701 - jaccard_coefficient: 0.8849 - loss: 0.0611 - learning_rate: 0.0010
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9721 - jaccard_coefficient: 0.8877 - loss: 0.0595
# Epoch 63: loss improved from 0.05869 to 0.05656, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9721 - jaccard_coefficient: 0.8880 - loss: 0.0594 - learning_rate: 0.0010
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9717 - jaccard_coefficient: 0.8918 - loss: 0.0573
# Epoch 64: loss improved from 0.05656 to 0.05596, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9717 - jaccard_coefficient: 0.8919 - loss: 0.0572 - learning_rate: 0.0010
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9748 - jaccard_coefficient: 0.9048 - loss: 0.0500
# Epoch 65: loss improved from 0.05596 to 0.05313, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9748 - jaccard_coefficient: 0.9045 - loss: 0.0502 - learning_rate: 0.0010
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9756 - jaccard_coefficient: 0.9021 - loss: 0.0515
# Epoch 66: loss improved from 0.05313 to 0.04992, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9756 - jaccard_coefficient: 0.9022 - loss: 0.0514 - learning_rate: 0.0010
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9753 - jaccard_coefficient: 0.8992 - loss: 0.0531
# Epoch 67: loss did not improve from 0.04992
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9753 - jaccard_coefficient: 0.8992 - loss: 0.0531 - learning_rate: 0.0010
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9737 - jaccard_coefficient: 0.8975 - loss: 0.0541
# Epoch 68: loss did not improve from 0.04992
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9737 - jaccard_coefficient: 0.8975 - loss: 0.0541 - learning_rate: 0.0010
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9745 - jaccard_coefficient: 0.9019 - loss: 0.0517
# Epoch 69: loss did not improve from 0.04992
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9745 - jaccard_coefficient: 0.9018 - loss: 0.0517 - learning_rate: 0.0010
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9750 - jaccard_coefficient: 0.9031 - loss: 0.0509
# Epoch 70: loss did not improve from 0.04992
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9750 - jaccard_coefficient: 0.9030 - loss: 0.0510 - learning_rate: 0.0010
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9751 - jaccard_coefficient: 0.9033 - loss: 0.0509
# Epoch 71: loss improved from 0.04992 to 0.04919, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9752 - jaccard_coefficient: 0.9034 - loss: 0.0508 - learning_rate: 0.0010
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9789 - jaccard_coefficient: 0.9135 - loss: 0.0452
# Epoch 72: loss improved from 0.04919 to 0.04643, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9789 - jaccard_coefficient: 0.9134 - loss: 0.0453 - learning_rate: 0.0010
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9764 - jaccard_coefficient: 0.9086 - loss: 0.0480
# Epoch 73: loss did not improve from 0.04643
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9763 - jaccard_coefficient: 0.9084 - loss: 0.0480 - learning_rate: 0.0010
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9760 - jaccard_coefficient: 0.9035 - loss: 0.0508
# Epoch 74: loss did not improve from 0.04643
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9760 - jaccard_coefficient: 0.9036 - loss: 0.0507 - learning_rate: 0.0010
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9764 - jaccard_coefficient: 0.9102 - loss: 0.0470
# Epoch 75: loss did not improve from 0.04643
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9764 - jaccard_coefficient: 0.9101 - loss: 0.0471 - learning_rate: 0.0010
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9769 - jaccard_coefficient: 0.9074 - loss: 0.0486
# Epoch 76: loss did not improve from 0.04643
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9769 - jaccard_coefficient: 0.9073 - loss: 0.0486 - learning_rate: 0.0010
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9742 - jaccard_coefficient: 0.9039 - loss: 0.0506
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 77: loss did not improve from 0.04643
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9742 - jaccard_coefficient: 0.9037 - loss: 0.0506 - learning_rate: 0.0010
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9786 - jaccard_coefficient: 0.9163 - loss: 0.0437
# Epoch 78: loss improved from 0.04643 to 0.04399, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9786 - jaccard_coefficient: 0.9163 - loss: 0.0437 - learning_rate: 5.0000e-04
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9800 - jaccard_coefficient: 0.9216 - loss: 0.0408
# Epoch 79: loss improved from 0.04399 to 0.04105, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 762ms/step - accuracy: 0.9800 - jaccard_coefficient: 0.9216 - loss: 0.0408 - learning_rate: 5.0000e-04
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9809 - jaccard_coefficient: 0.9266 - loss: 0.0381
# Epoch 80: loss improved from 0.04105 to 0.03788, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9809 - jaccard_coefficient: 0.9266 - loss: 0.0381 - learning_rate: 5.0000e-04
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9807 - jaccard_coefficient: 0.9243 - loss: 0.0394
# Epoch 81: loss did not improve from 0.03788
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9808 - jaccard_coefficient: 0.9243 - loss: 0.0394 - learning_rate: 5.0000e-04
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9813 - jaccard_coefficient: 0.9231 - loss: 0.0400
# Epoch 82: loss did not improve from 0.03788
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9813 - jaccard_coefficient: 0.9231 - loss: 0.0400 - learning_rate: 5.0000e-04
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 730ms/step - accuracy: 0.9805 - jaccard_coefficient: 0.9226 - loss: 0.0403
# Epoch 83: loss improved from 0.03788 to 0.03771, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9805 - jaccard_coefficient: 0.9228 - loss: 0.0402 - learning_rate: 5.0000e-04
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9817 - jaccard_coefficient: 0.9300 - loss: 0.0363
# Epoch 84: loss did not improve from 0.03771
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9817 - jaccard_coefficient: 0.9298 - loss: 0.0364 - learning_rate: 5.0000e-04
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9810 - jaccard_coefficient: 0.9246 - loss: 0.0392
# Epoch 85: loss improved from 0.03771 to 0.03758, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9810 - jaccard_coefficient: 0.9247 - loss: 0.0391 - learning_rate: 5.0000e-04
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9827 - jaccard_coefficient: 0.9302 - loss: 0.0362
# Epoch 86: loss improved from 0.03758 to 0.03652, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9827 - jaccard_coefficient: 0.9302 - loss: 0.0362 - learning_rate: 5.0000e-04
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9825 - jaccard_coefficient: 0.9304 - loss: 0.0361
# Epoch 87: loss improved from 0.03652 to 0.03544, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9825 - jaccard_coefficient: 0.9305 - loss: 0.0360 - learning_rate: 5.0000e-04
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9824 - jaccard_coefficient: 0.9303 - loss: 0.0361
# Epoch 88: loss did not improve from 0.03544
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9824 - jaccard_coefficient: 0.9303 - loss: 0.0361 - learning_rate: 5.0000e-04
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9827 - jaccard_coefficient: 0.9320 - loss: 0.0352
# Epoch 89: loss improved from 0.03544 to 0.03443, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 764ms/step - accuracy: 0.9827 - jaccard_coefficient: 0.9320 - loss: 0.0352 - learning_rate: 5.0000e-04
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9826 - jaccard_coefficient: 0.9288 - loss: 0.0369
# Epoch 90: loss did not improve from 0.03443
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9826 - jaccard_coefficient: 0.9290 - loss: 0.0368 - learning_rate: 5.0000e-04
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9838 - jaccard_coefficient: 0.9351 - loss: 0.0335
# Epoch 91: loss improved from 0.03443 to 0.03408, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9838 - jaccard_coefficient: 0.9351 - loss: 0.0336 - learning_rate: 5.0000e-04
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9847 - jaccard_coefficient: 0.9388 - loss: 0.0316
# Epoch 92: loss improved from 0.03408 to 0.03204, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9846 - jaccard_coefficient: 0.9387 - loss: 0.0316 - learning_rate: 5.0000e-04
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9843 - jaccard_coefficient: 0.9367 - loss: 0.0327
# Epoch 93: loss did not improve from 0.03204
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9843 - jaccard_coefficient: 0.9368 - loss: 0.0326 - learning_rate: 5.0000e-04
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9847 - jaccard_coefficient: 0.9376 - loss: 0.0322
# Epoch 94: loss did not improve from 0.03204
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9846 - jaccard_coefficient: 0.9375 - loss: 0.0323 - learning_rate: 5.0000e-04
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9838 - jaccard_coefficient: 0.9326 - loss: 0.0349
# Epoch 95: loss did not improve from 0.03204
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9838 - jaccard_coefficient: 0.9327 - loss: 0.0349 - learning_rate: 5.0000e-04
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9839 - jaccard_coefficient: 0.9388 - loss: 0.0316
# Epoch 96: loss did not improve from 0.03204
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9839 - jaccard_coefficient: 0.9387 - loss: 0.0316 - learning_rate: 5.0000e-04
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9837 - jaccard_coefficient: 0.9400 - loss: 0.0309
# Epoch 97: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 97: loss did not improve from 0.03204
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 733ms/step - accuracy: 0.9837 - jaccard_coefficient: 0.9398 - loss: 0.0310 - learning_rate: 5.0000e-04
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9847 - jaccard_coefficient: 0.9389 - loss: 0.0315
# Epoch 98: loss improved from 0.03204 to 0.03153, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 763ms/step - accuracy: 0.9846 - jaccard_coefficient: 0.9389 - loss: 0.0315 - learning_rate: 2.5000e-04
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9858 - jaccard_coefficient: 0.9439 - loss: 0.0289
# Epoch 99: loss improved from 0.03153 to 0.02911, saving model to model/custom_seg_unet.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 765ms/step - accuracy: 0.9858 - jaccard_coefficient: 0.9439 - loss: 0.0289 - learning_rate: 2.5000e-04
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.9854 - jaccard_coefficient: 0.9417 - loss: 0.0301
# Epoch 100: loss did not improve from 0.02911
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9854 - jaccard_coefficient: 0.9417 - loss: 0.0301 - learning_rate: 2.5000e-04
# SegUNet output shape: (None, 256, 256, 1)
# ⏱️ Thời gian huấn luyện: 1639.70 giây
# ✅ Accuracy trung bình: 95.31%
# 🔗 Jaccard trung bình: 82.97%

# %%
acc = history.history['accuracy']
loss = history.history['loss']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Accuracy', color='green')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Loss', color='red')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('Gray_2750_1024Bottleneck_famedited.png', dpi=300)
plt.show()

# %%
def apply_morphology(mask, kernel_size=3, iterations=1):

    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))
    mask = (mask > 0.5).astype(np.uint8)  

    closed = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=iterations)

    opened = cv2.morphologyEx(closed, cv2.MORPH_OPEN, kernel, iterations=iterations)

    return opened.astype(np.float32) 

print("🔍 Đánh giá không hậu xử lý...")
results = segunet.evaluate(test_images_gray_gaus, test_masks, verbose=1)
loss, accuracy, jaccard = results
print(f"Không hậu xử lý - Dice Loss: {loss:.4f}, Accuracy: {accuracy*100:.2f}%, Jaccard: {jaccard*100:.2f}%")

print("\n🔧 Đánh giá sau Morphology...")
predictions1 = segunet.predict(test_images_gray_gaus)
refined_predictions1 = []

for i in tqdm(range(len(test_images_gray_gaus))):
    pred = predictions1[i].squeeze()  

    morph_pred = apply_morphology(pred, kernel_size=7, iterations=2)

    refined_predictions1.append(morph_pred)

refined_predictions1 = np.expand_dims(np.array(refined_predictions1), axis=-1)

accuracy_after = np_accuracy(test_masks, refined_predictions1)
jaccard_after = np_jaccard_coefficient(test_masks, refined_predictions1)
loss_after = np_dice_loss(test_masks, refined_predictions1)
print(f"Sau Morphology - Dice Loss: {loss_after:.4f}, Accuracy: {accuracy_after*100:.2f}%, Jaccard: {jaccard_after*100:.2f}%")
# Out:
# 🔍 Đánh giá không hậu xử lý...
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 12s 916ms/step - accuracy: 0.9209 - jaccard_coefficient: 0.7133 - loss: 0.1720
# Không hậu xử lý - Dice Loss: 0.1955, Accuracy: 91.61%, Jaccard: 68.58%
#
# 🔧 Đánh giá sau Morphology...
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 759ms/step
# 100%|██████████| 272/272 [00:00<00:00, 1295.18it/s]
# Sau Morphology - Dice Loss: 0.1775, Accuracy: 91.60%, Jaccard: 69.85%
