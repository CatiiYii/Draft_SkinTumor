# %%
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
# !pip install opencv-contrib-python
# !pip install tensorflow-addons

import os
import cv2
import time
import json
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm

from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

import pydensecrf.densecrf as dcrf
from pydensecrf.utils import unary_from_softmax, create_pairwise_bilateral

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.activations import swish
from tensorflow.keras.regularizers import l2
from tensorflow.keras.initializers import HeNormal


from tensorflow.keras.layers import (
    Layer, 
    Input, 
    Conv2D, 
    BatchNormalization, 
    Lambda, 
    Concatenate,
    SeparableConv2D, 
    MaxPooling2D, 
    UpSampling2D, 
    Conv2DTranspose,
    SpatialDropout2D, 
    ReLU, 
    GlobalAveragePooling2D, 
    Add,
    GlobalMaxPooling2D, 
    Dense, 
    Reshape, 
    Multiply, 
    Activation
)
from tensorflow.keras import backend as K
# Out:
# Collecting git+https://github.com/lucasb-eyer/pydensecrf.git
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-c0x9d1x8
#   Running command git clone --filter=blob:none --quiet https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-c0x9d1x8
#   Resolved https://github.com/lucasb-eyer/pydensecrf.git to commit 2723c7fa4f2ead16ae1ce3d8afe977724bb8f87f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pydensecrf
#   Building wheel for pydensecrf (pyproject.toml) ... done
#   Created wheel for pydensecrf: filename=pydensecrf-1.0-cp311-cp311-linux_x86_64.whl size=3440333 sha256=5c57ab54936c9c7d42c875631dd1f155489f26c92e84c8563fc55969c9a51590
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9m2hpv5z/wheels/ce/8e/34/6dcfa200a9e2ae3627d8009b8bd1ca9b24512bec50a93304de
# Successfully built pydensecrf
# Installing collected packages: pydensecrf
# Successfully installed pydensecrf-1.0
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-contrib-python) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (25.0)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 6.0 MB/s eta 0:00:00a 0:00:01
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.2
#     Uninstalling typeguard-4.4.2:
#       Successfully uninstalled typeguard-4.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.16.1 requires typeguard<5,>=3, but you have typeguard 2.13.3 which is incompatible.
# inflect 7.5.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3
# 2025-11-23 13:48:26.282683: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763905706.484123      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763905706.537186      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
working_dir = '/kaggle/working'
for item in os.listdir(working_dir):
    item_path = os.path.join(working_dir, item)
    try:
        if os.path.isfile(item_path) or os.path.islink(item_path):
            os.unlink(item_path) 
        elif os.path.isdir(item_path):
            shutil.rmtree(item_path)  
            print(f"❌ xóa thành công {item_path}")
    except Exception as e:
        print(f"Lỗi khi xóa {item_path}: {e}")
# Out:
# ❌ xóa thành công /kaggle/working/.virtual_documents

# %%
def get_bounding_box(mask, padding=15):

    if len(mask.shape) < 2 or len(mask.shape) > 3:
        raise ValueError("Mask phải là 2D hoặc 3D (grayscale).")

    mask = (mask > 0).astype(np.uint8)

    coords = np.argwhere(mask > 0)
    
    if coords.size == 0:
        return None  
    
    y_min, x_min = coords.min(axis=0)
    y_max, x_max = coords.max(axis=0)

    dynamic_padding = max(padding, min((x_max - x_min) // 10, (y_max - y_min) // 10))

    h, w = mask.shape[:2]
    x_min = max(0, x_min - dynamic_padding)
    y_min = max(0, y_min - dynamic_padding)
    x_max = min(w, x_max + dynamic_padding)
    y_max = min(h, y_max + dynamic_padding)

    return x_min, y_min, x_max, y_max

# %%
def preprocess_image_no_clahe(img, mask, img_size=(256, 256)):
    bbox = get_bounding_box(mask, padding=15)

    if bbox is None:     
        cropped_img_rgb = img 
        cropped_mask = mask
    else:
        x_min, y_min, x_max, y_max = bbox  
        cropped_img_rgb = img[y_min:y_max, x_min:x_max]
        cropped_mask = mask[y_min:y_max, x_min:x_max]

    img_resized = cv2.resize(cropped_img_rgb, img_size, interpolation=cv2.INTER_LINEAR)

    mask_resized = cv2.resize(cropped_mask, img_size, interpolation=cv2.INTER_NEAREST)

    img_gray = cv2.cvtColor(img_resized, cv2.COLOR_RGB2GRAY)

    img_normalized = img_gray.astype(np.float32) / 255.0

    mask_normalized = (mask_resized > 127).astype(np.float32)

    return img_normalized, mask_normalized

# %%
def load_isic_dataset(image_path, mask_path, binary_path, csv_file, img_size=(256, 256)):

    image_files = sorted(glob(os.path.join(image_path, "ISIC_*.jpg")))

    images = []
    masks = []
    binary_masks = {}
    image_ids = []
    labels = []

    csv_data = pd.read_csv(csv_file)
    mel_label_series = csv_data.set_index('image_id')['melanoma'].astype("int64")

    print("Đang đọc và xử lý dữ liệu (Cropping + Resize + Grayscale + MinMax)...")
    for img_path in tqdm(image_files):      
        img_id = os.path.basename(img_path).split('.')[0]
        mask_file = os.path.join(mask_path, f"{img_id}_segmentation.png")
        binary_file = os.path.join(binary_path, f"{img_id}_features.json")

        if not os.path.exists(mask_file) or not os.path.exists(binary_file) or img_id not in mel_label_series.index:
            continue

        try:
            img_original = cv2.imread(img_path)
            img_original = cv2.cvtColor(img_original, cv2.COLOR_BGR2RGB)

            mask_original = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)

            img_final, mask_final = preprocess_image_no_clahe(img_original, mask_original, img_size)

            with open(binary_file, 'r') as f:
                binary_masks[img_id] = json.load(f)

            label = mel_label_series.loc[img_id]

            images.append(img_final)
            masks.append(mask_final)
            image_ids.append(img_id)
            labels.append(label)

        except Exception as e:
            print(f"Lỗi khi xử lý ảnh {img_id}: {str(e)}")
            continue

    images = np.array(images)[..., np.newaxis] 
    masks = np.array(masks)[..., np.newaxis]   
    labels = np.array(labels)

    print(f"\nĐã đọc thành công {len(images)} ảnh")
    print(f"Shape của images: {images.shape} (Ảnh Grayscale 1 kênh, MinMax [0, 1])")
    print(f"Shape của masks: {masks.shape}")
    print(f"Shape của labels: {labels.shape}")
    
    return images, masks, binary_masks, image_ids, labels

# %%
train_images, train_masks, train_binarys, train_image_ids, train_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2017-melanoma/Train_Data',
    mask_path='/kaggle/input/isic-2017-melanoma/Train_GroundTruth_1',
    binary_path='/kaggle/input/isic-2017-melanoma/Train_GroundTruth_2',
    csv_file="/kaggle/input/isic-2017-melanoma/Train_GroundTruth_3.csv",
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu (Cropping + Resize + Grayscale + MinMax)...
# 100%|██████████| 635/635 [02:42<00:00,  3.90it/s]
# Đã đọc thành công 635 ảnh
# Shape của images: (635, 256, 256, 1) (Ảnh Grayscale 1 kênh, MinMax [0, 1])
# Shape của masks: (635, 256, 256, 1)
# Shape của labels: (635,)

# %%
test_images, test_masks, test_binarys, test_image_ids, test_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2017-melanoma/Test_Data',
    mask_path='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_1',
    binary_path='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_2',
    csv_file='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_3.csv',
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu (Cropping + Resize + Grayscale + MinMax)...
# 100%|██████████| 272/272 [01:10<00:00,  3.84it/s]
# Đã đọc thành công 272 ảnh
# Shape của images: (272, 256, 256, 1) (Ảnh Grayscale 1 kênh, MinMax [0, 1])
# Shape của masks: (272, 256, 256, 1)
# Shape của labels: (272,)

# %%
def convert_to_gray_clahe(images_normalized):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    images_clahe_processed = []

    for img in images_normalized:
        if img.ndim == 3 and img.shape[-1] == 1:
            img = img.squeeze(-1)

        img_uint8 = (img * 255).astype(np.uint8)
                
        img_clahe_uint8 = clahe.apply(img_uint8)
        
        img_clahe_normalized = img_clahe_uint8.astype(np.float32) / 255.0
        
        images_clahe_processed.append(img_clahe_normalized)

    return np.array(images_clahe_processed)[..., np.newaxis] 


train_images_gray_clahe = convert_to_gray_clahe(train_images)
test_images_gray_clahe = convert_to_gray_clahe(test_images)

print(f"Shape ảnh huấn luyện sau CLAHE: {train_images_gray_clahe.shape}")
# Out:
# Shape ảnh huấn luyện sau CLAHE: (635, 256, 256, 1)

# %%
def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = (intersection + 1e-7) / (union + 1e-7)
    return iou
    
def compute_metric(y_true, y_pred, metric='dice_coefficient', smooth=1e-6, is_numpy=False):

    y_true_f = y_true.flatten() if is_numpy else K.flatten(y_true)
    y_pred_f = y_pred.flatten() if is_numpy else K.flatten(y_pred)
    intersection = np.sum(y_true_f * y_pred_f) if is_numpy else K.sum(y_true_f * y_pred_f)

    if 'dice' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        score = (2. * intersection + smooth) / (sum_fn(y_true_f) + sum_fn(y_pred_f) + smooth)
    elif 'jaccard' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        union = sum_fn(y_true_f) + sum_fn(y_pred_f) - intersection
        score = (intersection + smooth) / (union + smooth)
    else:
        raise ValueError(f"Unsupported metric: {metric}")

    return score if 'coefficient' in metric else 1 - score

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth)

def dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth)

def jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth)

def jaccard_loss(y_true, y_pred, smooth=1e-6):   
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)

    intersection = K.sum(y_true_f * y_pred_f)

    union = K.sum(y_true_f) + K.sum(y_pred_f) - intersection

    jaccard_coeff = (intersection + smooth) / (union + smooth)

    return 1.0 - jaccard_coeff

def np_accuracy(y_true, y_pred):
    return np.mean(y_true.flatten() == y_pred.flatten())

def np_dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth, is_numpy=True)

def np_jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth, is_numpy=True)

def np_dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth, is_numpy=True)

# %%
def cbam_module(input_features, reduction_ratio=8):

    filters = input_features.shape[-1]

    
    avg_pool = GlobalAveragePooling2D()(input_features)
    max_pool = GlobalMaxPooling2D()(input_features)
    
    shared_dense_1 = Dense(filters // reduction_ratio, 
                           activation='relu', 
                           kernel_initializer='he_normal', 
                           use_bias=True)
    
    shared_dense_2 = Dense(filters, 
                           use_bias=True)
    
    avg_out = shared_dense_2(shared_dense_1(avg_pool))
    max_out = shared_dense_2(shared_dense_1(max_pool))
    
    channel_sum = Add()([avg_out, max_out])
    channel_attention = Activation('sigmoid')(channel_sum)
    channel_attention = Reshape((1, 1, filters))(channel_attention)
    channel_refined = Multiply()([input_features, channel_attention])  
   
    avg_spatial = Lambda(lambda x: K.mean(x, axis=-1, keepdims=True), 
                         output_shape=lambda s: (s[0], s[1], s[2], 1))(channel_refined)
    max_spatial = Lambda(lambda x: K.max(x, axis=-1, keepdims=True), 
                         output_shape=lambda s: (s[0], s[1], s[2], 1))(channel_refined)  

    spatial_concat = Concatenate(axis=-1)([avg_spatial, max_spatial])
    
    spatial_attention = Conv2D(1, 
                               (7, 7), 
                               padding='same', 
                               activation='sigmoid', 
                               use_bias=False)(spatial_concat)
    
    refined_features = Multiply()([channel_refined, spatial_attention])
    
    
    return refined_features

# %%
def simam(x, lambda_val=1e-4):  
    shape = tf.shape(x)
    H, W = shape[1], shape[2]
    n = tf.cast(H * W - 1, x.dtype)
    
    mu = tf.reduce_mean(x, axis=[1, 2], keepdims=True)
    d = tf.square(x - mu)
    var = tf.reduce_sum(d, axis=[1, 2], keepdims=True) / n
    e_t = d / (4 * (var + lambda_val)) + 0.5
    
    return x * tf.nn.sigmoid(e_t)

def aspp_module(input_tensor, output_filters=1024, rates=[1, 6, 12, 18]):  
    num_branches = len(rates)
    branch_filters = output_filters // num_branches

    branches = []
    for rate in rates:
        branch = SeparableConv2D(branch_filters, (3, 3), padding='same', dilation_rate=rate, use_bias=False,
                                  depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(input_tensor)
        branch = BatchNormalization()(branch)
        branch = ReLU()(branch)
        branches.append(branch)

    concatenated = Concatenate()(branches)
    attended = Lambda(simam)(concatenated)

    final_conv = SeparableConv2D(output_filters, (1, 1), padding='same', use_bias=False,
                                  depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(attended)
    final_conv = BatchNormalization()(final_conv)
    final_conv = ReLU()(final_conv)
    final_conv = SpatialDropout2D(0.2)(final_conv)
    return final_conv

# %%
def CustomSegUNet(input_size=(256, 256, 1)):
    inputs = Input(input_size)

    c1 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(inputs)
    c1 = BatchNormalization()(c1); c1 = ReLU()(c1)
    c1 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c1)
    c1 = BatchNormalization()(c1); c1 = ReLU()(c1)
    c1 = SpatialDropout2D(0.1)(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p1)
    c2 = BatchNormalization()(c2); c2 = ReLU()(c2)
    c2 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c2)
    c2 = BatchNormalization()(c2); c2 = ReLU()(c2)
    c2 = SpatialDropout2D(0.1)(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p2)
    c3 = BatchNormalization()(c3); c3 = ReLU()(c3)
    c3 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c3)
    c3 = BatchNormalization()(c3); c3 = ReLU()(c3)
    c3 = SpatialDropout2D(0.1)(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p3)
    c4 = BatchNormalization()(c4); c4 = ReLU()(c4)
    c4 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c4)
    c4 = BatchNormalization()(c4); c4 = ReLU()(c4)
    c4 = SpatialDropout2D(0.1)(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p4)
    c5 = BatchNormalization()(c5); c5 = ReLU()(c5)
    c5 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c5)
    c5 = BatchNormalization()(c5); c5 = ReLU()(c5)
    c5 = SpatialDropout2D(0.1)(c5)
    p5 = MaxPooling2D((2, 2))(c5)

    
    c6 = aspp_module(p5, output_filters=1024, rates=[1, 6, 12, 18])

    u7 = Conv2DTranspose(512, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c6)
    u7 = Concatenate()([u7, c5])
    c7 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u7)
    c7 = BatchNormalization()(c7); c7 = ReLU()(c7)
    c7 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c7)
    c7 = BatchNormalization()(c7); c7 = ReLU()(c7)
    c7 = cbam_module(c7)

    u8 = Conv2DTranspose(256, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c7)
    u8 = Concatenate()([u8, c4])
    c8 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u8)
    c8 = BatchNormalization()(c8); c8 = ReLU()(c8)
    c8 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c8)
    c8 = BatchNormalization()(c8); c8 = ReLU()(c8)
    c8 = cbam_module(c8)

    u9 = Conv2DTranspose(256, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c8)
    u9 = Concatenate()([u9, c3])
    c9 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u9)
    c9 = BatchNormalization()(c9); c9 = ReLU()(c9)
    c9 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c9)
    c9 = BatchNormalization()(c9); c9 = ReLU()(c9)
    c9 = cbam_module(c9)

    u10 = Conv2DTranspose(128, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c9)
    u10 = Concatenate()([u10, c2])
    c10 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u10)
    c10 = BatchNormalization()(c10); c10 = ReLU()(c10)
    c10 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c10)
    c10 = BatchNormalization()(c10); c10 = ReLU()(c10)
    c10 = cbam_module(c10)

    u11 = Conv2DTranspose(64, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c10)
    u11 = Concatenate()([u11, c1])
    c11 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u11)
    c11 = BatchNormalization()(c11); c11 = ReLU()(c11)
    c11 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c11)
    c11 = BatchNormalization()(c11); c11 = ReLU()(c11)
    c11 = cbam_module(c11)

 
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c11)

    return Model(inputs=inputs, outputs=outputs)

if __name__ == "__main__":
    model = CustomSegUNet()
    model.summary()
# Out:
# I0000 00:00:1763906019.032042      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
#  Trainable params: 10,516,812 (40.12 MB)
#  Non-trainable params: 13,824 (54.00 KB)

# %%
class EarlyStoppingByAccuracyChange(tf.keras.callbacks.Callback):
    def __init__(self, monitor='accuracy', threshold=0.00001, patience=3, verbose=0):
        super(EarlyStoppingByAccuracyChange, self).__init__()
        self.monitor = monitor
        self.threshold = threshold
        self.patience = patience
        self.verbose = verbose
        self.wait = 0
        self.best_accuracy = -float('inf')
        self.consecutive_stops = 0

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current_accuracy = logs.get(self.monitor)
        if current_accuracy is None:
            tf.get_logger().warning(
                'Early stopping requires %s available!', self.monitor
            )
            return

        if current_accuracy > self.best_accuracy:
            self.best_accuracy = current_accuracy
            self.wait = 0
            self.consecutive_stops = 0
        else:
            self.wait += 1
            accuracy_change = current_accuracy - self.best_accuracy
            if abs(accuracy_change) < self.threshold:
                self.consecutive_stops += 1
                if self.consecutive_stops >= self.patience:
                    if self.verbose > 0:
                        print(f"Epoch {epoch+1}: Early stopping triggered due to minimal accuracy change for {self.patience} epochs.")
                    self.model.stop_training = True
            else:
                self.consecutive_stops = 0

# %%
initial_lr = 0.001
optimizer = Adam(learning_rate=initial_lr)

segunet = CustomSegUNet(input_size=(256, 256, 1))
segunet.compile(
    optimizer=optimizer,
    loss=dice_loss,
    metrics=['accuracy', jaccard_coefficient]
)
model_checkpoint_dir = 'model'

checkpoint_path = os.path.join(model_checkpoint_dir, 'cp.ckpt')

checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(model_checkpoint_dir, 'gray2750.weights.h5'),
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True,
    verbose=1
)
early_stopping = EarlyStoppingByAccuracyChange(
    monitor='accuracy',
    threshold=0.00001,
    patience=10,
    verbose=1
)
lr_reduction = ReduceLROnPlateau(monitor='loss',
                                  patience=5,
                                  verbose=1,
                                  factor=0.5,
                                  min_lr=0.00001)

start_time = time.time()
history = segunet.fit(
    train_images_gray_clahe, train_masks,
    batch_size=32,
    epochs=100,
    callbacks=[early_stopping, lr_reduction, checkpoint_callback]
)

end_time = time.time()
training_time = end_time - start_time
avg_accuracy = np.mean(history.history['accuracy'])
avg_jaccard = np.mean(history.history['jaccard_coefficient'])
print("SegUNet output shape:", segunet.output_shape)
print(f"⏱️ Thời gian huấn luyện: {training_time:.2f} giây")
print(f"✅ Accuracy trung bình: {avg_accuracy*100:.2f}%")
print(f"🔗 Jaccard trung bình: {avg_jaccard*100:.2f}%")
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1763906064.272889     193 service.cc:148] XLA service 0x7f3248002f40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1763906064.274135     193 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1763906067.663889     193 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1763906090.963415     193 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906091.189395     193 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906093.148647     193 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906093.357749     193 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906093.925802     193 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906094.135213     193 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906095.069978     193 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906095.372097     193 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906097.937106     193 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906098.355460     193 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-23 13:54:58.506034: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,128,128]{3,2,1,0}, f32[32,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-11-23 13:54:58.611284: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.105379783s
# Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,128,128]{3,2,1,0}, f32[32,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1763906118.224228     193 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 739ms/step - accuracy: 0.6464 - jaccard_coefficient: 0.4353 - loss: 0.3950
# E0000 00:00:1763906141.419595     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906141.659496     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906146.974130     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906147.213879     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906157.319467     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906157.540075     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906159.342189     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906159.550018     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906160.080205     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906160.288051     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906161.131419     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906161.422775     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906163.669190     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1763906164.061946     195 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-11-23 13:56:04.264972: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,256,128,128]{3,2,1,0}, f32[27,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-11-23 13:56:04.294084: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.029204472s
# Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,256,128,128]{3,2,1,0}, f32[27,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6492 - jaccard_coefficient: 0.4380 - loss: 0.3925
# Epoch 1: loss improved from inf to 0.34555, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 156s 3s/step - accuracy: 0.6518 - jaccard_coefficient: 0.4405 - loss: 0.3903 - learning_rate: 0.0010
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.8758 - jaccard_coefficient: 0.6666 - loss: 0.2007
# Epoch 2: loss improved from 0.34555 to 0.17721, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 774ms/step - accuracy: 0.8763 - jaccard_coefficient: 0.6682 - loss: 0.1996 - learning_rate: 0.0010
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.8939 - jaccard_coefficient: 0.7680 - loss: 0.1314
# Epoch 3: loss improved from 0.17721 to 0.12032, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 774ms/step - accuracy: 0.8943 - jaccard_coefficient: 0.7688 - loss: 0.1309 - learning_rate: 0.0010
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9091 - jaccard_coefficient: 0.8159 - loss: 0.1014
# Epoch 4: loss improved from 0.12032 to 0.10194, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9090 - jaccard_coefficient: 0.8159 - loss: 0.1015 - learning_rate: 0.0010
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9147 - jaccard_coefficient: 0.8299 - loss: 0.0930
# Epoch 5: loss improved from 0.10194 to 0.09306, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 774ms/step - accuracy: 0.9145 - jaccard_coefficient: 0.8299 - loss: 0.0930 - learning_rate: 0.0010
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9145 - jaccard_coefficient: 0.8365 - loss: 0.0891
# Epoch 6: loss improved from 0.09306 to 0.08694, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9146 - jaccard_coefficient: 0.8367 - loss: 0.0890 - learning_rate: 0.0010
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9216 - jaccard_coefficient: 0.8498 - loss: 0.0813
# Epoch 7: loss improved from 0.08694 to 0.08304, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9214 - jaccard_coefficient: 0.8497 - loss: 0.0814 - learning_rate: 0.0010
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9206 - jaccard_coefficient: 0.8509 - loss: 0.0807
# Epoch 8: loss improved from 0.08304 to 0.08052, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 774ms/step - accuracy: 0.9206 - jaccard_coefficient: 0.8509 - loss: 0.0807 - learning_rate: 0.0010
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9217 - jaccard_coefficient: 0.8560 - loss: 0.0776
# Epoch 9: loss improved from 0.08052 to 0.07732, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9217 - jaccard_coefficient: 0.8560 - loss: 0.0776 - learning_rate: 0.0010
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9253 - jaccard_coefficient: 0.8621 - loss: 0.0741
# Epoch 10: loss improved from 0.07732 to 0.07346, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9253 - jaccard_coefficient: 0.8622 - loss: 0.0741 - learning_rate: 0.0010
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9267 - jaccard_coefficient: 0.8676 - loss: 0.0709
# Epoch 11: loss did not improve from 0.07346
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 735ms/step - accuracy: 0.9265 - jaccard_coefficient: 0.8674 - loss: 0.0711 - learning_rate: 0.0010
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9278 - jaccard_coefficient: 0.8695 - loss: 0.0699
# Epoch 12: loss improved from 0.07346 to 0.06954, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9278 - jaccard_coefficient: 0.8695 - loss: 0.0698 - learning_rate: 0.0010
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9330 - jaccard_coefficient: 0.8791 - loss: 0.0644
# Epoch 13: loss improved from 0.06954 to 0.06505, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9330 - jaccard_coefficient: 0.8790 - loss: 0.0644 - learning_rate: 0.0010
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9339 - jaccard_coefficient: 0.8812 - loss: 0.0632
# Epoch 14: loss improved from 0.06505 to 0.06444, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9339 - jaccard_coefficient: 0.8811 - loss: 0.0632 - learning_rate: 0.0010
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9352 - jaccard_coefficient: 0.8850 - loss: 0.0610
# Epoch 15: loss improved from 0.06444 to 0.06125, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9352 - jaccard_coefficient: 0.8850 - loss: 0.0610 - learning_rate: 0.0010
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9351 - jaccard_coefficient: 0.8849 - loss: 0.0611
# Epoch 16: loss improved from 0.06125 to 0.06120, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9352 - jaccard_coefficient: 0.8849 - loss: 0.0611 - learning_rate: 0.0010
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9411 - jaccard_coefficient: 0.8934 - loss: 0.0563
# Epoch 17: loss improved from 0.06120 to 0.05757, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 770ms/step - accuracy: 0.9410 - jaccard_coefficient: 0.8933 - loss: 0.0564 - learning_rate: 0.0010
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9416 - jaccard_coefficient: 0.8937 - loss: 0.0561
# Epoch 18: loss improved from 0.05757 to 0.05630, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9415 - jaccard_coefficient: 0.8937 - loss: 0.0561 - learning_rate: 0.0010
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9456 - jaccard_coefficient: 0.9018 - loss: 0.0516
# Epoch 19: loss improved from 0.05630 to 0.05308, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9455 - jaccard_coefficient: 0.9017 - loss: 0.0517 - learning_rate: 0.0010
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9442 - jaccard_coefficient: 0.8988 - loss: 0.0533
# Epoch 20: loss did not improve from 0.05308
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 735ms/step - accuracy: 0.9441 - jaccard_coefficient: 0.8986 - loss: 0.0535 - learning_rate: 0.0010
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9464 - jaccard_coefficient: 0.9034 - loss: 0.0507
# Epoch 21: loss improved from 0.05308 to 0.05076, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9464 - jaccard_coefficient: 0.9034 - loss: 0.0507 - learning_rate: 0.0010
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9501 - jaccard_coefficient: 0.9102 - loss: 0.0470
# Epoch 22: loss improved from 0.05076 to 0.04998, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 774ms/step - accuracy: 0.9499 - jaccard_coefficient: 0.9100 - loss: 0.0472 - learning_rate: 0.0010
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9501 - jaccard_coefficient: 0.9089 - loss: 0.0477
# Epoch 23: loss improved from 0.04998 to 0.04758, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9501 - jaccard_coefficient: 0.9090 - loss: 0.0477 - learning_rate: 0.0010
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9502 - jaccard_coefficient: 0.9099 - loss: 0.0472
# Epoch 24: loss improved from 0.04758 to 0.04710, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9502 - jaccard_coefficient: 0.9099 - loss: 0.0472 - learning_rate: 0.0010
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9519 - jaccard_coefficient: 0.9130 - loss: 0.0455
# Epoch 25: loss improved from 0.04710 to 0.04596, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9519 - jaccard_coefficient: 0.9130 - loss: 0.0455 - learning_rate: 0.0010
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9511 - jaccard_coefficient: 0.9119 - loss: 0.0461
# Epoch 26: loss improved from 0.04596 to 0.04491, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9512 - jaccard_coefficient: 0.9120 - loss: 0.0461 - learning_rate: 0.0010
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9554 - jaccard_coefficient: 0.9198 - loss: 0.0418
# Epoch 27: loss improved from 0.04491 to 0.04216, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9554 - jaccard_coefficient: 0.9197 - loss: 0.0418 - learning_rate: 0.0010
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9572 - jaccard_coefficient: 0.9214 - loss: 0.0409
# Epoch 28: loss improved from 0.04216 to 0.04145, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9572 - jaccard_coefficient: 0.9214 - loss: 0.0409 - learning_rate: 0.0010
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9582 - jaccard_coefficient: 0.9239 - loss: 0.0396
# Epoch 29: loss improved from 0.04145 to 0.04048, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9582 - jaccard_coefficient: 0.9238 - loss: 0.0396 - learning_rate: 0.0010
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9577 - jaccard_coefficient: 0.9224 - loss: 0.0404
# Epoch 30: loss improved from 0.04048 to 0.03999, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9577 - jaccard_coefficient: 0.9224 - loss: 0.0404 - learning_rate: 0.0010
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9582 - jaccard_coefficient: 0.9237 - loss: 0.0397
# Epoch 31: loss improved from 0.03999 to 0.03954, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9582 - jaccard_coefficient: 0.9237 - loss: 0.0397 - learning_rate: 0.0010
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9589 - jaccard_coefficient: 0.9255 - loss: 0.0387
# Epoch 32: loss improved from 0.03954 to 0.03946, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9589 - jaccard_coefficient: 0.9254 - loss: 0.0387 - learning_rate: 0.0010
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9617 - jaccard_coefficient: 0.9298 - loss: 0.0364
# Epoch 33: loss improved from 0.03946 to 0.03738, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9617 - jaccard_coefficient: 0.9297 - loss: 0.0364 - learning_rate: 0.0010
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9592 - jaccard_coefficient: 0.9264 - loss: 0.0382
# Epoch 34: loss did not improve from 0.03738
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9592 - jaccard_coefficient: 0.9263 - loss: 0.0383 - learning_rate: 0.0010
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9607 - jaccard_coefficient: 0.9290 - loss: 0.0368
# Epoch 35: loss improved from 0.03738 to 0.03657, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 770ms/step - accuracy: 0.9607 - jaccard_coefficient: 0.9290 - loss: 0.0368 - learning_rate: 0.0010
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9647 - jaccard_coefficient: 0.9348 - loss: 0.0337
# Epoch 36: loss improved from 0.03657 to 0.03456, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9647 - jaccard_coefficient: 0.9347 - loss: 0.0337 - learning_rate: 0.0010
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9620 - jaccard_coefficient: 0.9310 - loss: 0.0357
# Epoch 37: loss improved from 0.03456 to 0.03447, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9621 - jaccard_coefficient: 0.9312 - loss: 0.0357 - learning_rate: 0.0010
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9650 - jaccard_coefficient: 0.9360 - loss: 0.0331
# Epoch 38: loss improved from 0.03447 to 0.03325, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9650 - jaccard_coefficient: 0.9360 - loss: 0.0331 - learning_rate: 0.0010
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9666 - jaccard_coefficient: 0.9390 - loss: 0.0315
# Epoch 39: loss improved from 0.03325 to 0.03252, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9666 - jaccard_coefficient: 0.9389 - loss: 0.0315 - learning_rate: 0.0010
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9670 - jaccard_coefficient: 0.9392 - loss: 0.0314
# Epoch 40: loss improved from 0.03252 to 0.03229, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9670 - jaccard_coefficient: 0.9391 - loss: 0.0314 - learning_rate: 0.0010
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9649 - jaccard_coefficient: 0.9360 - loss: 0.0331
# Epoch 41: loss did not improve from 0.03229
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9649 - jaccard_coefficient: 0.9360 - loss: 0.0331 - learning_rate: 0.0010
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9679 - jaccard_coefficient: 0.9413 - loss: 0.0302
# Epoch 42: loss improved from 0.03229 to 0.03056, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9678 - jaccard_coefficient: 0.9413 - loss: 0.0303 - learning_rate: 0.0010
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9672 - jaccard_coefficient: 0.9397 - loss: 0.0311
# Epoch 43: loss did not improve from 0.03056
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 735ms/step - accuracy: 0.9672 - jaccard_coefficient: 0.9397 - loss: 0.0311 - learning_rate: 0.0010
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9686 - jaccard_coefficient: 0.9423 - loss: 0.0297
# Epoch 44: loss did not improve from 0.03056
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9686 - jaccard_coefficient: 0.9422 - loss: 0.0297 - learning_rate: 0.0010
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9694 - jaccard_coefficient: 0.9434 - loss: 0.0291
# Epoch 45: loss did not improve from 0.03056
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9693 - jaccard_coefficient: 0.9433 - loss: 0.0292 - learning_rate: 0.0010
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9686 - jaccard_coefficient: 0.9417 - loss: 0.0300
# Epoch 46: loss did not improve from 0.03056
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9685 - jaccard_coefficient: 0.9416 - loss: 0.0301 - learning_rate: 0.0010
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9679 - jaccard_coefficient: 0.9410 - loss: 0.0304
# Epoch 47: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 47: loss did not improve from 0.03056
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9679 - jaccard_coefficient: 0.9409 - loss: 0.0304 - learning_rate: 0.0010
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9706 - jaccard_coefficient: 0.9457 - loss: 0.0279
# Epoch 48: loss improved from 0.03056 to 0.02787, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9706 - jaccard_coefficient: 0.9457 - loss: 0.0279 - learning_rate: 5.0000e-04
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9724 - jaccard_coefficient: 0.9488 - loss: 0.0263
# Epoch 49: loss improved from 0.02787 to 0.02652, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9724 - jaccard_coefficient: 0.9488 - loss: 0.0263 - learning_rate: 5.0000e-04
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9729 - jaccard_coefficient: 0.9498 - loss: 0.0257
# Epoch 50: loss improved from 0.02652 to 0.02609, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9729 - jaccard_coefficient: 0.9498 - loss: 0.0258 - learning_rate: 5.0000e-04
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9745 - jaccard_coefficient: 0.9529 - loss: 0.0241
# Epoch 51: loss improved from 0.02609 to 0.02436, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9745 - jaccard_coefficient: 0.9529 - loss: 0.0241 - learning_rate: 5.0000e-04
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9744 - jaccard_coefficient: 0.9528 - loss: 0.0242
# Epoch 52: loss did not improve from 0.02436
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9744 - jaccard_coefficient: 0.9528 - loss: 0.0242 - learning_rate: 5.0000e-04
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9753 - jaccard_coefficient: 0.9543 - loss: 0.0234
# Epoch 53: loss improved from 0.02436 to 0.02339, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9753 - jaccard_coefficient: 0.9543 - loss: 0.0234 - learning_rate: 5.0000e-04
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9762 - jaccard_coefficient: 0.9560 - loss: 0.0225
# Epoch 54: loss improved from 0.02339 to 0.02285, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9762 - jaccard_coefficient: 0.9560 - loss: 0.0225 - learning_rate: 5.0000e-04
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9759 - jaccard_coefficient: 0.9553 - loss: 0.0229
# Epoch 55: loss did not improve from 0.02285
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9759 - jaccard_coefficient: 0.9552 - loss: 0.0229 - learning_rate: 5.0000e-04
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9758 - jaccard_coefficient: 0.9553 - loss: 0.0228
# Epoch 56: loss did not improve from 0.02285
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9758 - jaccard_coefficient: 0.9553 - loss: 0.0229 - learning_rate: 5.0000e-04
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9762 - jaccard_coefficient: 0.9560 - loss: 0.0225
# Epoch 57: loss improved from 0.02285 to 0.02232, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9763 - jaccard_coefficient: 0.9560 - loss: 0.0225 - learning_rate: 5.0000e-04
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9768 - jaccard_coefficient: 0.9572 - loss: 0.0219
# Epoch 58: loss improved from 0.02232 to 0.02219, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9768 - jaccard_coefficient: 0.9571 - loss: 0.0219 - learning_rate: 5.0000e-04
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9761 - jaccard_coefficient: 0.9557 - loss: 0.0227
# Epoch 59: loss improved from 0.02219 to 0.02212, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9761 - jaccard_coefficient: 0.9557 - loss: 0.0226 - learning_rate: 5.0000e-04
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9770 - jaccard_coefficient: 0.9576 - loss: 0.0217
# Epoch 60: loss did not improve from 0.02212
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9770 - jaccard_coefficient: 0.9575 - loss: 0.0217 - learning_rate: 5.0000e-04
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9770 - jaccard_coefficient: 0.9572 - loss: 0.0219
# Epoch 61: loss did not improve from 0.02212
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 735ms/step - accuracy: 0.9770 - jaccard_coefficient: 0.9572 - loss: 0.0219 - learning_rate: 5.0000e-04
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9770 - jaccard_coefficient: 0.9575 - loss: 0.0217
# Epoch 62: loss improved from 0.02212 to 0.02200, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9770 - jaccard_coefficient: 0.9575 - loss: 0.0217 - learning_rate: 5.0000e-04
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9780 - jaccard_coefficient: 0.9589 - loss: 0.0210
# Epoch 63: loss improved from 0.02200 to 0.02133, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9780 - jaccard_coefficient: 0.9589 - loss: 0.0210 - learning_rate: 5.0000e-04
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9777 - jaccard_coefficient: 0.9586 - loss: 0.0211
# Epoch 64: loss improved from 0.02133 to 0.02124, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9777 - jaccard_coefficient: 0.9586 - loss: 0.0212 - learning_rate: 5.0000e-04
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9775 - jaccard_coefficient: 0.9580 - loss: 0.0214
# Epoch 65: loss improved from 0.02124 to 0.02100, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9775 - jaccard_coefficient: 0.9581 - loss: 0.0214 - learning_rate: 5.0000e-04
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9775 - jaccard_coefficient: 0.9580 - loss: 0.0214
# Epoch 66: loss improved from 0.02100 to 0.02085, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 770ms/step - accuracy: 0.9775 - jaccard_coefficient: 0.9581 - loss: 0.0214 - learning_rate: 5.0000e-04
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9792 - jaccard_coefficient: 0.9613 - loss: 0.0198
# Epoch 67: loss improved from 0.02085 to 0.02006, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9791 - jaccard_coefficient: 0.9612 - loss: 0.0198 - learning_rate: 5.0000e-04
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9785 - jaccard_coefficient: 0.9603 - loss: 0.0203
# Epoch 68: loss did not improve from 0.02006
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9785 - jaccard_coefficient: 0.9603 - loss: 0.0203 - learning_rate: 5.0000e-04
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9783 - jaccard_coefficient: 0.9597 - loss: 0.0206
# Epoch 69: loss did not improve from 0.02006
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9783 - jaccard_coefficient: 0.9597 - loss: 0.0206 - learning_rate: 5.0000e-04
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9788 - jaccard_coefficient: 0.9607 - loss: 0.0200
# Epoch 70: loss did not improve from 0.02006
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 735ms/step - accuracy: 0.9788 - jaccard_coefficient: 0.9607 - loss: 0.0200 - learning_rate: 5.0000e-04
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9793 - jaccard_coefficient: 0.9611 - loss: 0.0199
# Epoch 71: loss did not improve from 0.02006
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9792 - jaccard_coefficient: 0.9610 - loss: 0.0199 - learning_rate: 5.0000e-04
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9781 - jaccard_coefficient: 0.9594 - loss: 0.0207
# Epoch 72: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 72: loss did not improve from 0.02006
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9781 - jaccard_coefficient: 0.9594 - loss: 0.0207 - learning_rate: 5.0000e-04
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9782 - jaccard_coefficient: 0.9595 - loss: 0.0207
# Epoch 73: loss improved from 0.02006 to 0.01963, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9783 - jaccard_coefficient: 0.9596 - loss: 0.0206 - learning_rate: 2.5000e-04
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9793 - jaccard_coefficient: 0.9616 - loss: 0.0196
# Epoch 74: loss did not improve from 0.01963
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9793 - jaccard_coefficient: 0.9615 - loss: 0.0196 - learning_rate: 2.5000e-04
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9808 - jaccard_coefficient: 0.9644 - loss: 0.0181
# Epoch 75: loss improved from 0.01963 to 0.01839, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9808 - jaccard_coefficient: 0.9643 - loss: 0.0182 - learning_rate: 2.5000e-04
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9807 - jaccard_coefficient: 0.9636 - loss: 0.0185
# Epoch 76: loss improved from 0.01839 to 0.01816, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9807 - jaccard_coefficient: 0.9636 - loss: 0.0185 - learning_rate: 2.5000e-04
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9801 - jaccard_coefficient: 0.9631 - loss: 0.0188
# Epoch 77: loss did not improve from 0.01816
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9801 - jaccard_coefficient: 0.9631 - loss: 0.0188 - learning_rate: 2.5000e-04
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9801 - jaccard_coefficient: 0.9629 - loss: 0.0189
# Epoch 78: loss did not improve from 0.01816
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 733ms/step - accuracy: 0.9801 - jaccard_coefficient: 0.9630 - loss: 0.0189 - learning_rate: 2.5000e-04
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9820 - jaccard_coefficient: 0.9663 - loss: 0.0171
# Epoch 79: loss improved from 0.01816 to 0.01717, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 770ms/step - accuracy: 0.9820 - jaccard_coefficient: 0.9663 - loss: 0.0171 - learning_rate: 2.5000e-04
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9817 - jaccard_coefficient: 0.9654 - loss: 0.0176
# Epoch 80: loss did not improve from 0.01717
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9818 - jaccard_coefficient: 0.9654 - loss: 0.0176 - learning_rate: 2.5000e-04
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 732ms/step - accuracy: 0.9819 - jaccard_coefficient: 0.9666 - loss: 0.0170
# Epoch 81: loss did not improve from 0.01717
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 733ms/step - accuracy: 0.9819 - jaccard_coefficient: 0.9666 - loss: 0.0170 - learning_rate: 2.5000e-04
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9814 - jaccard_coefficient: 0.9651 - loss: 0.0177
# Epoch 82: loss did not improve from 0.01717
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9814 - jaccard_coefficient: 0.9652 - loss: 0.0177 - learning_rate: 2.5000e-04
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9808 - jaccard_coefficient: 0.9638 - loss: 0.0185
# Epoch 83: loss did not improve from 0.01717
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 735ms/step - accuracy: 0.9809 - jaccard_coefficient: 0.9639 - loss: 0.0184 - learning_rate: 2.5000e-04
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9824 - jaccard_coefficient: 0.9671 - loss: 0.0167
# Epoch 84: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 84: loss did not improve from 0.01717
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9824 - jaccard_coefficient: 0.9670 - loss: 0.0168 - learning_rate: 2.5000e-04
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9822 - jaccard_coefficient: 0.9669 - loss: 0.0169
# Epoch 85: loss improved from 0.01717 to 0.01683, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9822 - jaccard_coefficient: 0.9669 - loss: 0.0169 - learning_rate: 1.2500e-04
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9821 - jaccard_coefficient: 0.9666 - loss: 0.0170
# Epoch 86: loss improved from 0.01683 to 0.01681, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9821 - jaccard_coefficient: 0.9666 - loss: 0.0170 - learning_rate: 1.2500e-04
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9820 - jaccard_coefficient: 0.9662 - loss: 0.0172
# Epoch 87: loss improved from 0.01681 to 0.01619, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 773ms/step - accuracy: 0.9821 - jaccard_coefficient: 0.9663 - loss: 0.0172 - learning_rate: 1.2500e-04
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - accuracy: 0.9835 - jaccard_coefficient: 0.9692 - loss: 0.0157
# Epoch 88: loss improved from 0.01619 to 0.01606, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9835 - jaccard_coefficient: 0.9691 - loss: 0.0157 - learning_rate: 1.2500e-04
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9829 - jaccard_coefficient: 0.9679 - loss: 0.0163
# Epoch 89: loss did not improve from 0.01606
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 735ms/step - accuracy: 0.9829 - jaccard_coefficient: 0.9679 - loss: 0.0163 - learning_rate: 1.2500e-04
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9829 - jaccard_coefficient: 0.9678 - loss: 0.0163
# Epoch 90: loss did not improve from 0.01606
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9829 - jaccard_coefficient: 0.9679 - loss: 0.0163 - learning_rate: 1.2500e-04
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9843 - jaccard_coefficient: 0.9708 - loss: 0.0148
# Epoch 91: loss improved from 0.01606 to 0.01588, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9843 - jaccard_coefficient: 0.9707 - loss: 0.0149 - learning_rate: 1.2500e-04
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9836 - jaccard_coefficient: 0.9694 - loss: 0.0155
# Epoch 92: loss improved from 0.01588 to 0.01559, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9836 - jaccard_coefficient: 0.9694 - loss: 0.0155 - learning_rate: 1.2500e-04
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9840 - jaccard_coefficient: 0.9698 - loss: 0.0153
# Epoch 93: loss did not improve from 0.01559
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 735ms/step - accuracy: 0.9839 - jaccard_coefficient: 0.9698 - loss: 0.0153 - learning_rate: 1.2500e-04
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9836 - jaccard_coefficient: 0.9697 - loss: 0.0154
# Epoch 94: loss did not improve from 0.01559
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9835 - jaccard_coefficient: 0.9696 - loss: 0.0154 - learning_rate: 1.2500e-04
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9833 - jaccard_coefficient: 0.9686 - loss: 0.0160
# Epoch 95: loss did not improve from 0.01559
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9833 - jaccard_coefficient: 0.9686 - loss: 0.0160 - learning_rate: 1.2500e-04
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9834 - jaccard_coefficient: 0.9691 - loss: 0.0157
# Epoch 96: loss did not improve from 0.01559
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9834 - jaccard_coefficient: 0.9691 - loss: 0.0157 - learning_rate: 1.2500e-04
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9827 - jaccard_coefficient: 0.9678 - loss: 0.0164
# Epoch 97: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 97: loss did not improve from 0.01559
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 735ms/step - accuracy: 0.9827 - jaccard_coefficient: 0.9679 - loss: 0.0163 - learning_rate: 1.2500e-04
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9834 - jaccard_coefficient: 0.9687 - loss: 0.0159
# Epoch 98: loss improved from 0.01559 to 0.01540, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 772ms/step - accuracy: 0.9834 - jaccard_coefficient: 0.9688 - loss: 0.0159 - learning_rate: 6.2500e-05
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9846 - jaccard_coefficient: 0.9711 - loss: 0.0147
# Epoch 99: loss improved from 0.01540 to 0.01510, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 771ms/step - accuracy: 0.9846 - jaccard_coefficient: 0.9711 - loss: 0.0147 - learning_rate: 6.2500e-05
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - accuracy: 0.9838 - jaccard_coefficient: 0.9696 - loss: 0.0154
# Epoch 100: loss did not improve from 0.01510
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 734ms/step - accuracy: 0.9838 - jaccard_coefficient: 0.9696 - loss: 0.0154 - learning_rate: 6.2500e-05
# SegUNet output shape: (None, 256, 256, 1)
# ⏱️ Thời gian huấn luyện: 1660.04 giây
# ✅ Accuracy trung bình: 96.09%
# 🔗 Jaccard trung bình: 92.71%

# %%
acc = history.history['accuracy']
loss = history.history['loss']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Accuracy', color='green')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Loss', color='red')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('Gray_2750_acc_loss.png', dpi=300)
plt.show()

# %%
results = segunet.evaluate(test_images_gray_clahe, test_masks, verbose=1)
loss, accuracy, jaccard = results
print(f"Dice Loss: {loss:.4f}, Accuracy: {accuracy*100:.2f}%, Jaccard: {jaccard*100:.2f}%")

predictions_before = segunet.predict(test_images_gray_clahe)
predictions_before_bin = (predictions_before > 0.5).astype(np.uint8)

y_true_flat = test_masks.flatten()
y_pred_flat_before = predictions_before_bin.flatten()

print("\nClassification Report:")
print(classification_report(y_true_flat, y_pred_flat_before, target_names=["Background", "Lesion"]))

precision_before = precision_score(y_true_flat, y_pred_flat_before)
recall_before = recall_score(y_true_flat, y_pred_flat_before)
f1_before = f1_score(y_true_flat, y_pred_flat_before)

print(f"Precision: {precision_before:.4f}")
print(f"Recall:    {recall_before:.4f}")
print(f"F1-score:  {f1_before:.4f}")
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 13s 922ms/step - accuracy: 0.9243 - jaccard_coefficient: 0.8675 - loss: 0.0710
# Dice Loss: 0.0753, Accuracy: 91.96%, Jaccard: 86.01%
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 10s 700ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#   Background       0.91      0.92      0.91   8277068
#       Lesion       0.93      0.92      0.92   9548724
#
#     accuracy                           0.92  17825792
#    macro avg       0.92      0.92      0.92  17825792
# weighted avg       0.92      0.92      0.92  17825792
#
# Precision: 0.9291
# Recall:    0.9201
# F1-score:  0.9246

# %%
segunet.save('/kaggle/working/model/2.0-gray_2750_model.h5')
segunet.save('/kaggle/working/model/2.0-gray_2750_model.keras')
