# %%
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
# !pip install opencv-contrib-python
# !pip install tensorflow-addons
import os
import cv2
import time
import json
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm
import warnings
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers, models
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
warnings.filterwarnings('ignore')

import tensorflow.keras.backend as K
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.layers import Layer, Input, Conv2D, BatchNormalization, Lambda, Concatenate
import pydensecrf.densecrf as dcrf
from pydensecrf.utils import unary_from_softmax, create_pairwise_bilateral
from tensorflow.keras.layers import (
    Input, SeparableConv2D, BatchNormalization, MaxPooling2D, UpSampling2D, Conv2DTranspose,
    Concatenate, SpatialDropout2D, ReLU, GlobalAveragePooling2D, Add,
    GlobalMaxPooling2D, Dense, Reshape, Multiply, Add, Conv2D, Lambda, Activation
)
from tensorflow.keras.activations import swish
from tensorflow.keras.layers import Conv2D, Activation, Add, Multiply, UpSampling2D, Concatenate
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Input, SeparableConv2D, BatchNormalization, MaxPooling2D, Conv2DTranspose, Concatenate, SpatialDropout2D, ReLU, GlobalAveragePooling2D, GlobalMaxPooling2D, Dense, Reshape, Multiply, Add, Conv2D, Lambda
from tensorflow.keras.initializers import HeNormal
# Out:
# Collecting git+https://github.com/lucasb-eyer/pydensecrf.git
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-adjyo3my
#   Running command git clone --filter=blob:none --quiet https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-adjyo3my
#   Resolved https://github.com/lucasb-eyer/pydensecrf.git to commit 2723c7fa4f2ead16ae1ce3d8afe977724bb8f87f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-contrib-python) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: tensorflow-addons in /usr/local/lib/python3.11/dist-packages (0.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (25.0)
# Requirement already satisfied: typeguard<3.0.0,>=2.7 in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (2.13.3)

# %%
working_dir = '/kaggle/working'
for item in os.listdir(working_dir):
    item_path = os.path.join(working_dir, item)
    try:
        if os.path.isfile(item_path) or os.path.islink(item_path):
            os.unlink(item_path) 
        elif os.path.isdir(item_path):
            shutil.rmtree(item_path)  
            print(f"❌ xóa thành công {item_path}")
    except Exception as e:
        print(f"Lỗi khi xóa {item_path}: {e}")
# Out:
# ❌ xóa thành công /kaggle/working/model

# %%
def load_isic_dataset(image_path, mask_path, binary_path, csv_file, img_size=(256, 256)):
    image_files = sorted(glob(os.path.join(image_path, "ISIC_*.jpg")))
    images = []
    masks = []
    binary_masks = {}
    image_ids = []
    labels = []
    csv_data = pd.read_csv(csv_file)
    mel_label = csv_data['melanoma'].astype("int64")

    print("Đang đọc và xử lý dữ liệu...")
    for index, img_path in enumerate(tqdm(image_files)):
        img_id = os.path.basename(img_path).split('.')[0]
        mask_file = os.path.join(mask_path, f"{img_id}_segmentation.png")
        binary_file = os.path.join(binary_path, f"{img_id}_features.json")

        if not os.path.exists(mask_file):
            print(f"Không tìm thấy mask cho ảnh mặt nạ {img_id}_segmentation.png")
            continue
        if not os.path.exists(binary_file):
            print(f"Không tìm thấy mask nhị phân cho ảnh {img_id}_features.json")
            continue

        try:
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  

            mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)

            img = cv2.resize(img, img_size)
            mask = cv2.resize(mask, img_size)

            img = img / 255.0
            mask = mask / 255.0
    
            with open(binary_file, 'r') as f:
                binary_masks[img_id] = json.load(f)

            label = mel_label[index]

            images.append(img)
            masks.append(mask)
            image_ids.append(img_id)
            labels.append(label.astype("long"))

        except Exception as e:
            print(f"Lỗi khi xử lý ảnh {img_id}: {str(e)}")
            continue

    images = np.array(images)
    masks = np.array(masks)[..., np.newaxis]  
    labels = np.array(labels)

    print(f"\nĐã đọc thành công {len(images)} ảnh")
    print(f"Shape của images: {images.shape}")
    print(f"Shape của masks: {masks.shape}")
    print(f"Shape của labels: {labels.shape}")
    return images, masks, binary_masks, image_ids, labels

# %%
train_images, train_masks, train_binarys, train_image_ids, train_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2017-melanoma/Train_Data',
    mask_path='/kaggle/input/isic-2017-melanoma/Train_GroundTruth_1',
    binary_path='/kaggle/input/isic-2017-melanoma/Train_GroundTruth_2',
    csv_file="/kaggle/input/isic-2017-melanoma/Train_GroundTruth_3.csv",
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 635/635 [01:47<00:00,  5.88it/s]
# Đã đọc thành công 635 ảnh
# Shape của images: (635, 256, 256, 3)
# Shape của masks: (635, 256, 256, 1)
# Shape của labels: (635,)

# %%
test_images, test_masks, test_binarys, test_image_ids, test_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2017-melanoma/Test_Data',
    mask_path='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_1',
    binary_path='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_2',
    csv_file='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_3.csv',
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 272/272 [00:46<00:00,  5.85it/s]
# Đã đọc thành công 272 ảnh
# Shape của images: (272, 256, 256, 3)
# Shape của masks: (272, 256, 256, 1)
# Shape của labels: (272,)

# %%
def iou_metric(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred > 0.5, tf.float32)

    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    iou = (intersection + 1e-7) / (union + 1e-7)
    return iou

# %%
def compute_metric(y_true, y_pred, metric='dice_coefficient', smooth=1e-6, is_numpy=False):
    y_true_f = y_true.flatten() if is_numpy else K.flatten(y_true)
    y_pred_f = y_pred.flatten() if is_numpy else K.flatten(y_pred)
    intersection = np.sum(y_true_f * y_pred_f) if is_numpy else K.sum(y_true_f * y_pred_f)

    if 'dice' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        score = (2. * intersection + smooth) / (sum_fn(y_true_f) + sum_fn(y_pred_f) + smooth)
    elif 'jaccard' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        union = sum_fn(y_true_f) + sum_fn(y_pred_f) - intersection
        score = (intersection + smooth) / (union + smooth)
    else:
        raise ValueError(f"Unsupported metric: {metric}")

    return score if 'coefficient' in metric else 1 - score

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth)

def dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth)

def jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth)

def jaccard_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_loss', smooth)

def np_accuracy(y_true, y_pred):
    return np.mean(y_true.flatten() == y_pred.flatten())

def np_dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth, is_numpy=True)

def np_jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth, is_numpy=True)

def np_dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth, is_numpy=True)

# %%
def ConvBlock(inputs, filters=64):
    conv1 = layers.Conv2D(filters, kernel_size = (3,3), padding = "same")(inputs)
    batch_norm1 = layers.BatchNormalization()(conv1)
    act1 = layers.ReLU()(batch_norm1)    
   
    conv2 = layers.Conv2D(filters, kernel_size = (3,3), padding = "same")(act1)
    batch_norm2 = layers.BatchNormalization()(conv2)
    act2 = layers.ReLU()(batch_norm2)
    
    return act2


def encoder(inputs, filters=64):
    enc1 = ConvBlock(inputs, filters)
    MaxPool1 = layers.MaxPooling2D(strides = (2,2))(enc1)
    return enc1, MaxPool1

def decoder(inputs, skip, filters=64):
    Upsample = layers.Conv2DTranspose(filters, (2, 2), strides=2, padding="same")(inputs)
    Connect_Skip = layers.Concatenate()([Upsample, skip])
    out = ConvBlock(Connect_Skip, filters)
    return out

def get_U_Net(image_size):
    inputs = layers.Input(image_size)

    skip1, encoder_1 = encoder(inputs, 64)
    skip2, encoder_2 = encoder(encoder_1, 64*2)
    skip3, encoder_3 = encoder(encoder_2, 64*4)
    skip4, encoder_4 = encoder(encoder_3, 64*8)
    

    conv_block = ConvBlock(encoder_4, 64*16)
    

    decoder_1 = decoder(conv_block, skip4, 64*8)
    decoder_2 = decoder(decoder_1, skip3, 64*4)
    decoder_3 = decoder(decoder_2, skip2, 64*2)
    decoder_4 = decoder(decoder_3, skip1, 64)
    
    outputs = layers.Conv2D(1, 1, padding="same", activation="sigmoid")(decoder_4)
    
    model = models.Model(inputs, outputs)
    return model

input_shape = (256, 256, 1)
model = get_U_Net(input_shape)
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2             │ (None, 256, 256, 1)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_38 (Conv2D)        │ (None, 256, 256, 64)   │            640 │ input_layer_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_36    │ (None, 256, 256, 64)   │            256 │ conv2d_38[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_36 (ReLU)           │ (None, 256, 256, 64)   │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_39 (Conv2D)        │ (None, 256, 256, 64)   │         36,928 │ re_lu_36[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_37    │ (None, 256, 256, 64)   │            256 │ conv2d_39[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_37 (ReLU)           │ (None, 256, 256, 64)   │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_8           │ (None, 128, 128, 64)   │              0 │ re_lu_37[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_40 (Conv2D)        │ (None, 128, 128, 128)  │         73,856 │ max_pooling2d_8[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_38    │ (None, 128, 128, 128)  │            512 │ conv2d_40[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_38 (ReLU)           │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_41 (Conv2D)        │ (None, 128, 128, 128)  │        147,584 │ re_lu_38[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_39    │ (None, 128, 128, 128)  │            512 │ conv2d_41[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_39 (ReLU)           │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_9           │ (None, 64, 64, 128)    │              0 │ re_lu_39[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_42 (Conv2D)        │ (None, 64, 64, 256)    │        295,168 │ max_pooling2d_9[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_40    │ (None, 64, 64, 256)    │          1,024 │ conv2d_42[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_40 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_43 (Conv2D)        │ (None, 64, 64, 256)    │        590,080 │ re_lu_40[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_41    │ (None, 64, 64, 256)    │          1,024 │ conv2d_43[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_41 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_10          │ (None, 32, 32, 256)    │              0 │ re_lu_41[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_44 (Conv2D)        │ (None, 32, 32, 512)    │      1,180,160 │ max_pooling2d_10[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_42    │ (None, 32, 32, 512)    │          2,048 │ conv2d_44[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_42 (ReLU)           │ (None, 32, 32, 512)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_45 (Conv2D)        │ (None, 32, 32, 512)    │      2,359,808 │ re_lu_42[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_43    │ (None, 32, 32, 512)    │          2,048 │ conv2d_45[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_43 (ReLU)           │ (None, 32, 32, 512)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_11          │ (None, 16, 16, 512)    │              0 │ re_lu_43[0][0]         │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_46 (Conv2D)        │ (None, 16, 16, 1024)   │      4,719,616 │ max_pooling2d_11[0][0] │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_44    │ (None, 16, 16, 1024)   │          4,096 │ conv2d_46[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_44 (ReLU)           │ (None, 16, 16, 1024)   │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_47 (Conv2D)        │ (None, 16, 16, 1024)   │      9,438,208 │ re_lu_44[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_45    │ (None, 16, 16, 1024)   │          4,096 │ conv2d_47[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_45 (ReLU)           │ (None, 16, 16, 1024)   │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_8        │ (None, 32, 32, 512)    │      2,097,664 │ re_lu_45[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_8             │ (None, 32, 32, 1024)   │              0 │ conv2d_transpose_8[0]… │
# │ (Concatenate)             │                        │                │ re_lu_43[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_48 (Conv2D)        │ (None, 32, 32, 512)    │      4,719,104 │ concatenate_8[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_46    │ (None, 32, 32, 512)    │          2,048 │ conv2d_48[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_46 (ReLU)           │ (None, 32, 32, 512)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_49 (Conv2D)        │ (None, 32, 32, 512)    │      2,359,808 │ re_lu_46[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_47    │ (None, 32, 32, 512)    │          2,048 │ conv2d_49[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_47 (ReLU)           │ (None, 32, 32, 512)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_9        │ (None, 64, 64, 256)    │        524,544 │ re_lu_47[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_9             │ (None, 64, 64, 512)    │              0 │ conv2d_transpose_9[0]… │
# │ (Concatenate)             │                        │                │ re_lu_41[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_50 (Conv2D)        │ (None, 64, 64, 256)    │      1,179,904 │ concatenate_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_48    │ (None, 64, 64, 256)    │          1,024 │ conv2d_50[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_48 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_51 (Conv2D)        │ (None, 64, 64, 256)    │        590,080 │ re_lu_48[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_49    │ (None, 64, 64, 256)    │          1,024 │ conv2d_51[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_49 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_10       │ (None, 128, 128, 128)  │        131,200 │ re_lu_49[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_10            │ (None, 128, 128, 256)  │              0 │ conv2d_transpose_10[0… │
# │ (Concatenate)             │                        │                │ re_lu_39[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_52 (Conv2D)        │ (None, 128, 128, 128)  │        295,040 │ concatenate_10[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_50    │ (None, 128, 128, 128)  │            512 │ conv2d_52[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_50 (ReLU)           │ (None, 128, 128, 128)  │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_53 (Conv2D)        │ (None, 128, 128, 128)  │        147,584 │ re_lu_50[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_51    │ (None, 128, 128, 128)  │            512 │ conv2d_53[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_51 (ReLU)           │ (None, 128, 128, 128)  │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_11       │ (None, 256, 256, 64)   │         32,832 │ re_lu_51[0][0]         │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_11            │ (None, 256, 256, 128)  │              0 │ conv2d_transpose_11[0… │
# │ (Concatenate)             │                        │                │ re_lu_37[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_54 (Conv2D)        │ (None, 256, 256, 64)   │         73,792 │ concatenate_11[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_52    │ (None, 256, 256, 64)   │            256 │ conv2d_54[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_52 (ReLU)           │ (None, 256, 256, 64)   │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_55 (Conv2D)        │ (None, 256, 256, 64)   │         36,928 │ re_lu_52[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_53    │ (None, 256, 256, 64)   │            256 │ conv2d_55[0][0]        │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_53 (ReLU)           │ (None, 256, 256, 64)   │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_56 (Conv2D)        │ (None, 256, 256, 1)    │             65 │ re_lu_53[0][0]         │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 31,054,145 (118.46 MB)
#  Trainable params: 31,042,369 (118.42 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %%
class EarlyStoppingByAccuracyChange(tf.keras.callbacks.Callback):
    def __init__(self, monitor='accuracy', threshold=0.00001, patience=3, verbose=0):
        super(EarlyStoppingByAccuracyChange, self).__init__()
        self.monitor = monitor
        self.threshold = threshold
        self.patience = patience
        self.verbose = verbose
        self.wait = 0
        self.best_accuracy = -float('inf')
        self.consecutive_stops = 0

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current_accuracy = logs.get(self.monitor)
        if current_accuracy is None:
            tf.get_logger().warning(
                'Early stopping requires %s available!', self.monitor
            )
            return

        if current_accuracy > self.best_accuracy:
            self.best_accuracy = current_accuracy
            self.wait = 0
            self.consecutive_stops = 0
        else:
            self.wait += 1
            accuracy_change = current_accuracy - self.best_accuracy
            if abs(accuracy_change) < self.threshold:
                self.consecutive_stops += 1
                if self.consecutive_stops >= self.patience:
                    if self.verbose > 0:
                        print(f"Epoch {epoch+1}: Early stopping triggered due to minimal accuracy change for {self.patience} epochs.")
                    self.model.stop_training = True
            else:
                self.consecutive_stops = 0

# %%
pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-contrib-python) (1.3.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
def convert_to_gray_clahe(images):
    grays = []
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))  

    for img in images:
        if img.dtype != np.uint8:
            img = (img * 255).astype(np.uint8)
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY) 

        img_clahe = clahe.apply(gray)  
        grays.append(img_clahe)

    return np.array(grays)

train_images_gray_clahe = convert_to_gray_clahe(train_images)
test_images_gray_clahe = convert_to_gray_clahe(test_images)

# %%
initial_lr = 0.001
optimizer = Adam(learning_rate=initial_lr)

input_shape = (256, 256, 1)
unet = get_U_Net(input_shape)

unet.compile(
    optimizer=optimizer,
    loss=dice_loss,
    metrics=['accuracy', jaccard_coefficient]
)
model_checkpoint_dir = 'model'

checkpoint_path = os.path.join(model_checkpoint_dir, 'cp.ckpt')

checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(model_checkpoint_dir, 'gray2750.weights.h5'),
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True,
    verbose=1
)

early_stopping = EarlyStoppingByAccuracyChange(
    monitor='accuracy',
    threshold=0.00001,
    patience=10,
    verbose=1
)
lr_reduction = ReduceLROnPlateau(monitor='loss',
                                  patience=5,
                                  verbose=1,
                                  factor=0.5,
                                  min_lr=0.00001)

start_time = time.time()
history = unet.fit(
    train_images_gray_clahe, train_masks,
    batch_size=32,
    epochs=100,
    callbacks=[early_stopping, lr_reduction, checkpoint_callback]
)

end_time = time.time()
training_time = end_time - start_time
avg_accuracy = np.mean(history.history['accuracy'])
avg_jaccard = np.mean(history.history['jaccard_coefficient'])

print("unet output shape:", unet.output_shape)
print(f"⏱️ Thời gian huấn luyện: {training_time:.2f} giây")
print(f"✅ Accuracy trung bình: {avg_accuracy*100:.2f}%")
print(f"🔗 Jaccard trung bình: {avg_jaccard*100:.2f}%")
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7039 - jaccard_coefficient: 0.3226 - loss: 0.5252
# Epoch 1: loss improved from inf to 0.43419, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.7067 - jaccard_coefficient: 0.3265 - loss: 0.5209 - learning_rate: 0.0010
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8446 - jaccard_coefficient: 0.4915 - loss: 0.3424
# Epoch 2: loss improved from 0.43419 to 0.33508, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.8443 - jaccard_coefficient: 0.4920 - loss: 0.3421 - learning_rate: 0.0010
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8606 - jaccard_coefficient: 0.5475 - loss: 0.2933
# Epoch 3: loss improved from 0.33508 to 0.28270, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.8610 - jaccard_coefficient: 0.5482 - loss: 0.2928 - learning_rate: 0.0010
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8620 - jaccard_coefficient: 0.5668 - loss: 0.2777
# Epoch 4: loss improved from 0.28270 to 0.27980, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8621 - jaccard_coefficient: 0.5666 - loss: 0.2778 - learning_rate: 0.0010
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8814 - jaccard_coefficient: 0.6081 - loss: 0.2449
# Epoch 5: loss improved from 0.27980 to 0.24970, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8814 - jaccard_coefficient: 0.6078 - loss: 0.2452 - learning_rate: 0.0010
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8879 - jaccard_coefficient: 0.6337 - loss: 0.2255
# Epoch 6: loss improved from 0.24970 to 0.24214, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.8878 - jaccard_coefficient: 0.6326 - loss: 0.2263 - learning_rate: 0.0010
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8852 - jaccard_coefficient: 0.5990 - loss: 0.2526
# Epoch 7: loss improved from 0.24214 to 0.23196, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.8855 - jaccard_coefficient: 0.6002 - loss: 0.2516 - learning_rate: 0.0010
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8996 - jaccard_coefficient: 0.6309 - loss: 0.2268
# Epoch 8: loss improved from 0.23196 to 0.22593, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.8994 - jaccard_coefficient: 0.6310 - loss: 0.2268 - learning_rate: 0.0010
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9025 - jaccard_coefficient: 0.6556 - loss: 0.2086
# Epoch 9: loss improved from 0.22593 to 0.21469, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9023 - jaccard_coefficient: 0.6553 - loss: 0.2089 - learning_rate: 0.0010
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9015 - jaccard_coefficient: 0.6718 - loss: 0.1972
# Epoch 10: loss improved from 0.21469 to 0.21263, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9015 - jaccard_coefficient: 0.6708 - loss: 0.1979 - learning_rate: 0.0010
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8983 - jaccard_coefficient: 0.6520 - loss: 0.2119
# Epoch 11: loss did not improve from 0.21263
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.8982 - jaccard_coefficient: 0.6515 - loss: 0.2122 - learning_rate: 0.0010
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9063 - jaccard_coefficient: 0.6579 - loss: 0.2074
# Epoch 12: loss improved from 0.21263 to 0.20310, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9063 - jaccard_coefficient: 0.6582 - loss: 0.2072 - learning_rate: 0.0010
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9115 - jaccard_coefficient: 0.6868 - loss: 0.1861
# Epoch 13: loss improved from 0.20310 to 0.18859, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9115 - jaccard_coefficient: 0.6866 - loss: 0.1862 - learning_rate: 0.0010
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9064 - jaccard_coefficient: 0.6757 - loss: 0.1947
# Epoch 14: loss improved from 0.18859 to 0.18774, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9066 - jaccard_coefficient: 0.6762 - loss: 0.1944 - learning_rate: 0.0010
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9138 - jaccard_coefficient: 0.6847 - loss: 0.1876
# Epoch 15: loss improved from 0.18774 to 0.18715, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9137 - jaccard_coefficient: 0.6847 - loss: 0.1876 - learning_rate: 0.0010
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9219 - jaccard_coefficient: 0.7102 - loss: 0.1703
# Epoch 16: loss improved from 0.18715 to 0.17495, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9217 - jaccard_coefficient: 0.7099 - loss: 0.1705 - learning_rate: 0.0010
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9159 - jaccard_coefficient: 0.6886 - loss: 0.1850
# Epoch 17: loss did not improve from 0.17495
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9156 - jaccard_coefficient: 0.6885 - loss: 0.1852 - learning_rate: 0.0010
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9146 - jaccard_coefficient: 0.6926 - loss: 0.1822
# Epoch 18: loss improved from 0.17495 to 0.17489, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9147 - jaccard_coefficient: 0.6931 - loss: 0.1818 - learning_rate: 0.0010
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9148 - jaccard_coefficient: 0.6971 - loss: 0.1787
# Epoch 19: loss improved from 0.17489 to 0.17395, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9149 - jaccard_coefficient: 0.6974 - loss: 0.1784 - learning_rate: 0.0010
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9206 - jaccard_coefficient: 0.7082 - loss: 0.1712
# Epoch 20: loss did not improve from 0.17395
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9204 - jaccard_coefficient: 0.7078 - loss: 0.1715 - learning_rate: 0.0010
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9160 - jaccard_coefficient: 0.6866 - loss: 0.1866
# Epoch 21: loss did not improve from 0.17395
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9160 - jaccard_coefficient: 0.6870 - loss: 0.1863 - learning_rate: 0.0010
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9215 - jaccard_coefficient: 0.7186 - loss: 0.1640
# Epoch 22: loss improved from 0.17395 to 0.17111, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9215 - jaccard_coefficient: 0.7181 - loss: 0.1643 - learning_rate: 0.0010
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9146 - jaccard_coefficient: 0.6985 - loss: 0.1780
# Epoch 23: loss did not improve from 0.17111
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9148 - jaccard_coefficient: 0.6987 - loss: 0.1778 - learning_rate: 0.0010
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9210 - jaccard_coefficient: 0.7229 - loss: 0.1612
# Epoch 24: loss improved from 0.17111 to 0.15995, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9212 - jaccard_coefficient: 0.7230 - loss: 0.1611 - learning_rate: 0.0010
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9179 - jaccard_coefficient: 0.7041 - loss: 0.1740
# Epoch 25: loss did not improve from 0.15995
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9181 - jaccard_coefficient: 0.7045 - loss: 0.1738 - learning_rate: 0.0010
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9260 - jaccard_coefficient: 0.7316 - loss: 0.1556
# Epoch 26: loss improved from 0.15995 to 0.15658, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9259 - jaccard_coefficient: 0.7316 - loss: 0.1557 - learning_rate: 0.0010
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9248 - jaccard_coefficient: 0.7303 - loss: 0.1562
# Epoch 27: loss did not improve from 0.15658
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9248 - jaccard_coefficient: 0.7302 - loss: 0.1563 - learning_rate: 0.0010
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9208 - jaccard_coefficient: 0.7131 - loss: 0.1678
# Epoch 28: loss did not improve from 0.15658
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9207 - jaccard_coefficient: 0.7129 - loss: 0.1679 - learning_rate: 0.0010
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9217 - jaccard_coefficient: 0.7178 - loss: 0.1648
# Epoch 29: loss did not improve from 0.15658
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9219 - jaccard_coefficient: 0.7183 - loss: 0.1644 - learning_rate: 0.0010
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9290 - jaccard_coefficient: 0.7404 - loss: 0.1498
# Epoch 30: loss improved from 0.15658 to 0.15313, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9290 - jaccard_coefficient: 0.7402 - loss: 0.1500 - learning_rate: 0.0010
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9322 - jaccard_coefficient: 0.7517 - loss: 0.1420
# Epoch 31: loss improved from 0.15313 to 0.14389, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9322 - jaccard_coefficient: 0.7517 - loss: 0.1421 - learning_rate: 0.0010
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9370 - jaccard_coefficient: 0.7581 - loss: 0.1378
# Epoch 32: loss improved from 0.14389 to 0.13723, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9369 - jaccard_coefficient: 0.7582 - loss: 0.1378 - learning_rate: 0.0010
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9355 - jaccard_coefficient: 0.7594 - loss: 0.1369
# Epoch 33: loss did not improve from 0.13723
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9354 - jaccard_coefficient: 0.7591 - loss: 0.1371 - learning_rate: 0.0010
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9304 - jaccard_coefficient: 0.7461 - loss: 0.1463
# Epoch 34: loss did not improve from 0.13723
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9304 - jaccard_coefficient: 0.7461 - loss: 0.1463 - learning_rate: 0.0010
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9345 - jaccard_coefficient: 0.7573 - loss: 0.1383
# Epoch 35: loss did not improve from 0.13723
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9343 - jaccard_coefficient: 0.7567 - loss: 0.1387 - learning_rate: 0.0010
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9352 - jaccard_coefficient: 0.7429 - loss: 0.1477
# Epoch 36: loss did not improve from 0.13723
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9351 - jaccard_coefficient: 0.7431 - loss: 0.1476 - learning_rate: 0.0010
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9384 - jaccard_coefficient: 0.7653 - loss: 0.1335
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 37: loss did not improve from 0.13723
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9382 - jaccard_coefficient: 0.7650 - loss: 0.1337 - learning_rate: 0.0010
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9385 - jaccard_coefficient: 0.7716 - loss: 0.1295
# Epoch 38: loss improved from 0.13723 to 0.12767, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9386 - jaccard_coefficient: 0.7718 - loss: 0.1294 - learning_rate: 5.0000e-04
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9449 - jaccard_coefficient: 0.7926 - loss: 0.1163
# Epoch 39: loss improved from 0.12767 to 0.12041, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.9448 - jaccard_coefficient: 0.7922 - loss: 0.1165 - learning_rate: 5.0000e-04
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9429 - jaccard_coefficient: 0.7807 - loss: 0.1235
# Epoch 40: loss improved from 0.12041 to 0.11738, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9430 - jaccard_coefficient: 0.7811 - loss: 0.1232 - learning_rate: 5.0000e-04
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9471 - jaccard_coefficient: 0.8015 - loss: 0.1103
# Epoch 41: loss improved from 0.11738 to 0.11161, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9470 - jaccard_coefficient: 0.8014 - loss: 0.1104 - learning_rate: 5.0000e-04
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9505 - jaccard_coefficient: 0.8106 - loss: 0.1051
# Epoch 42: loss did not improve from 0.11161
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9504 - jaccard_coefficient: 0.8101 - loss: 0.1054 - learning_rate: 5.0000e-04
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9491 - jaccard_coefficient: 0.8071 - loss: 0.1069
# Epoch 43: loss improved from 0.11161 to 0.10594, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9491 - jaccard_coefficient: 0.8072 - loss: 0.1068 - learning_rate: 5.0000e-04
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9525 - jaccard_coefficient: 0.8129 - loss: 0.1033
# Epoch 44: loss did not improve from 0.10594
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9523 - jaccard_coefficient: 0.8126 - loss: 0.1035 - learning_rate: 5.0000e-04
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9456 - jaccard_coefficient: 0.8009 - loss: 0.1107
# Epoch 45: loss did not improve from 0.10594
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9457 - jaccard_coefficient: 0.8011 - loss: 0.1106 - learning_rate: 5.0000e-04
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9477 - jaccard_coefficient: 0.7894 - loss: 0.1185
# Epoch 46: loss did not improve from 0.10594
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9478 - jaccard_coefficient: 0.7902 - loss: 0.1180 - learning_rate: 5.0000e-04
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9470 - jaccard_coefficient: 0.7954 - loss: 0.1146
# Epoch 47: loss did not improve from 0.10594
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9471 - jaccard_coefficient: 0.7957 - loss: 0.1144 - learning_rate: 5.0000e-04
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9460 - jaccard_coefficient: 0.7930 - loss: 0.1160
# Epoch 48: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 48: loss did not improve from 0.10594
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9459 - jaccard_coefficient: 0.7928 - loss: 0.1161 - learning_rate: 5.0000e-04
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9522 - jaccard_coefficient: 0.8217 - loss: 0.0982
# Epoch 49: loss improved from 0.10594 to 0.09813, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9522 - jaccard_coefficient: 0.8217 - loss: 0.0982 - learning_rate: 2.5000e-04
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9525 - jaccard_coefficient: 0.8300 - loss: 0.0931
# Epoch 50: loss improved from 0.09813 to 0.09490, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9526 - jaccard_coefficient: 0.8298 - loss: 0.0932 - learning_rate: 2.5000e-04
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9556 - jaccard_coefficient: 0.8311 - loss: 0.0924
# Epoch 51: loss improved from 0.09490 to 0.09255, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9556 - jaccard_coefficient: 0.8311 - loss: 0.0924 - learning_rate: 2.5000e-04
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9552 - jaccard_coefficient: 0.8395 - loss: 0.0874
# Epoch 52: loss improved from 0.09255 to 0.08980, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9553 - jaccard_coefficient: 0.8393 - loss: 0.0875 - learning_rate: 2.5000e-04
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9571 - jaccard_coefficient: 0.8303 - loss: 0.0930
# Epoch 53: loss did not improve from 0.08980
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9570 - jaccard_coefficient: 0.8303 - loss: 0.0930 - learning_rate: 2.5000e-04
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9568 - jaccard_coefficient: 0.8278 - loss: 0.0945
# Epoch 54: loss improved from 0.08980 to 0.08954, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9568 - jaccard_coefficient: 0.8282 - loss: 0.0942 - learning_rate: 2.5000e-04
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9614 - jaccard_coefficient: 0.8505 - loss: 0.0809
# Epoch 55: loss improved from 0.08954 to 0.08382, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9613 - jaccard_coefficient: 0.8503 - loss: 0.0811 - learning_rate: 2.5000e-04
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9606 - jaccard_coefficient: 0.8458 - loss: 0.0837
# Epoch 56: loss improved from 0.08382 to 0.07945, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9607 - jaccard_coefficient: 0.8462 - loss: 0.0835 - learning_rate: 2.5000e-04
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9644 - jaccard_coefficient: 0.8627 - loss: 0.0739
# Epoch 57: loss improved from 0.07945 to 0.07766, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9643 - jaccard_coefficient: 0.8624 - loss: 0.0741 - learning_rate: 2.5000e-04
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9628 - jaccard_coefficient: 0.8555 - loss: 0.0781
# Epoch 58: loss did not improve from 0.07766
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9628 - jaccard_coefficient: 0.8554 - loss: 0.0781 - learning_rate: 2.5000e-04
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9650 - jaccard_coefficient: 0.8577 - loss: 0.0767
# Epoch 59: loss improved from 0.07766 to 0.07589, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9649 - jaccard_coefficient: 0.8577 - loss: 0.0767 - learning_rate: 2.5000e-04
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9641 - jaccard_coefficient: 0.8593 - loss: 0.0757
# Epoch 60: loss improved from 0.07589 to 0.07512, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9641 - jaccard_coefficient: 0.8594 - loss: 0.0757 - learning_rate: 2.5000e-04
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9638 - jaccard_coefficient: 0.8605 - loss: 0.0751
# Epoch 61: loss improved from 0.07512 to 0.07443, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9638 - jaccard_coefficient: 0.8606 - loss: 0.0751 - learning_rate: 2.5000e-04
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9640 - jaccard_coefficient: 0.8653 - loss: 0.0723
# Epoch 62: loss did not improve from 0.07443
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9639 - jaccard_coefficient: 0.8650 - loss: 0.0725 - learning_rate: 2.5000e-04
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9645 - jaccard_coefficient: 0.8629 - loss: 0.0737
# Epoch 63: loss did not improve from 0.07443
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9645 - jaccard_coefficient: 0.8628 - loss: 0.0737 - learning_rate: 2.5000e-04
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9694 - jaccard_coefficient: 0.8811 - loss: 0.0633
# Epoch 64: loss improved from 0.07443 to 0.06937, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9693 - jaccard_coefficient: 0.8806 - loss: 0.0636 - learning_rate: 2.5000e-04
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9669 - jaccard_coefficient: 0.8737 - loss: 0.0675
# Epoch 65: loss did not improve from 0.06937
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9669 - jaccard_coefficient: 0.8735 - loss: 0.0676 - learning_rate: 2.5000e-04
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9671 - jaccard_coefficient: 0.8690 - loss: 0.0702
# Epoch 66: loss did not improve from 0.06937
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9671 - jaccard_coefficient: 0.8690 - loss: 0.0702 - learning_rate: 2.5000e-04
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9656 - jaccard_coefficient: 0.8689 - loss: 0.0702
# Epoch 67: loss improved from 0.06937 to 0.06912, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9657 - jaccard_coefficient: 0.8690 - loss: 0.0702 - learning_rate: 2.5000e-04
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9695 - jaccard_coefficient: 0.8766 - loss: 0.0658
# Epoch 68: loss improved from 0.06912 to 0.06430, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9694 - jaccard_coefficient: 0.8767 - loss: 0.0658 - learning_rate: 2.5000e-04
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9662 - jaccard_coefficient: 0.8619 - loss: 0.0745
# Epoch 69: loss did not improve from 0.06430
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9662 - jaccard_coefficient: 0.8623 - loss: 0.0743 - learning_rate: 2.5000e-04
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9682 - jaccard_coefficient: 0.8777 - loss: 0.0652
# Epoch 70: loss did not improve from 0.06430
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9681 - jaccard_coefficient: 0.8772 - loss: 0.0655 - learning_rate: 2.5000e-04
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9667 - jaccard_coefficient: 0.8737 - loss: 0.0675
# Epoch 71: loss did not improve from 0.06430
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9668 - jaccard_coefficient: 0.8736 - loss: 0.0675 - learning_rate: 2.5000e-04
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9691 - jaccard_coefficient: 0.8772 - loss: 0.0655
# Epoch 72: loss did not improve from 0.06430
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9691 - jaccard_coefficient: 0.8773 - loss: 0.0655 - learning_rate: 2.5000e-04
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9698 - jaccard_coefficient: 0.8843 - loss: 0.0615
# Epoch 73: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 73: loss did not improve from 0.06430
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9696 - jaccard_coefficient: 0.8838 - loss: 0.0618 - learning_rate: 2.5000e-04
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9691 - jaccard_coefficient: 0.8762 - loss: 0.0660
# Epoch 74: loss improved from 0.06430 to 0.06344, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9691 - jaccard_coefficient: 0.8764 - loss: 0.0659 - learning_rate: 1.2500e-04
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9729 - jaccard_coefficient: 0.8925 - loss: 0.0569
# Epoch 75: loss improved from 0.06344 to 0.05666, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9729 - jaccard_coefficient: 0.8925 - loss: 0.0569 - learning_rate: 1.2500e-04
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9742 - jaccard_coefficient: 0.9000 - loss: 0.0527
# Epoch 76: loss improved from 0.05666 to 0.05383, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9742 - jaccard_coefficient: 0.8999 - loss: 0.0527 - learning_rate: 1.2500e-04
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9731 - jaccard_coefficient: 0.8884 - loss: 0.0592
# Epoch 77: loss did not improve from 0.05383
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9731 - jaccard_coefficient: 0.8887 - loss: 0.0590 - learning_rate: 1.2500e-04
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9754 - jaccard_coefficient: 0.9067 - loss: 0.0490
# Epoch 78: loss improved from 0.05383 to 0.05125, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9754 - jaccard_coefficient: 0.9065 - loss: 0.0491 - learning_rate: 1.2500e-04
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9763 - jaccard_coefficient: 0.9042 - loss: 0.0504
# Epoch 79: loss did not improve from 0.05125
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9762 - jaccard_coefficient: 0.9041 - loss: 0.0504 - learning_rate: 1.2500e-04
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9756 - jaccard_coefficient: 0.9085 - loss: 0.0480
# Epoch 80: loss improved from 0.05125 to 0.04995, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9756 - jaccard_coefficient: 0.9083 - loss: 0.0481 - learning_rate: 1.2500e-04
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9762 - jaccard_coefficient: 0.9069 - loss: 0.0489
# Epoch 81: loss did not improve from 0.04995
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9761 - jaccard_coefficient: 0.9068 - loss: 0.0489 - learning_rate: 1.2500e-04
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9752 - jaccard_coefficient: 0.8982 - loss: 0.0537
# Epoch 82: loss did not improve from 0.04995
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9752 - jaccard_coefficient: 0.8984 - loss: 0.0536 - learning_rate: 1.2500e-04
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9757 - jaccard_coefficient: 0.9038 - loss: 0.0506
# Epoch 83: loss improved from 0.04995 to 0.04951, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9757 - jaccard_coefficient: 0.9038 - loss: 0.0505 - learning_rate: 1.2500e-04
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9767 - jaccard_coefficient: 0.9104 - loss: 0.0469
# Epoch 84: loss did not improve from 0.04951
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9767 - jaccard_coefficient: 0.9101 - loss: 0.0471 - learning_rate: 1.2500e-04
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9757 - jaccard_coefficient: 0.9055 - loss: 0.0497
# Epoch 85: loss did not improve from 0.04951
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9757 - jaccard_coefficient: 0.9055 - loss: 0.0497 - learning_rate: 1.2500e-04
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9759 - jaccard_coefficient: 0.9083 - loss: 0.0482
# Epoch 86: loss improved from 0.04951 to 0.04878, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9759 - jaccard_coefficient: 0.9083 - loss: 0.0482 - learning_rate: 1.2500e-04
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9782 - jaccard_coefficient: 0.9136 - loss: 0.0452
# Epoch 87: loss improved from 0.04878 to 0.04566, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9782 - jaccard_coefficient: 0.9136 - loss: 0.0452 - learning_rate: 1.2500e-04
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9758 - jaccard_coefficient: 0.9099 - loss: 0.0473
# Epoch 88: loss did not improve from 0.04566
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9759 - jaccard_coefficient: 0.9098 - loss: 0.0473 - learning_rate: 1.2500e-04
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9772 - jaccard_coefficient: 0.9091 - loss: 0.0477
# Epoch 89: loss did not improve from 0.04566
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9772 - jaccard_coefficient: 0.9091 - loss: 0.0477 - learning_rate: 1.2500e-04
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9770 - jaccard_coefficient: 0.9059 - loss: 0.0494
# Epoch 90: loss did not improve from 0.04566
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9770 - jaccard_coefficient: 0.9059 - loss: 0.0494 - learning_rate: 1.2500e-04
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9773 - jaccard_coefficient: 0.9115 - loss: 0.0464
# Epoch 91: loss did not improve from 0.04566
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9773 - jaccard_coefficient: 0.9114 - loss: 0.0464 - learning_rate: 1.2500e-04
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9776 - jaccard_coefficient: 0.9150 - loss: 0.0444
# Epoch 92: loss improved from 0.04566 to 0.04389, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9776 - jaccard_coefficient: 0.9151 - loss: 0.0444 - learning_rate: 1.2500e-04
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9794 - jaccard_coefficient: 0.9171 - loss: 0.0433
# Epoch 93: loss did not improve from 0.04389
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9793 - jaccard_coefficient: 0.9169 - loss: 0.0434 - learning_rate: 1.2500e-04
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9792 - jaccard_coefficient: 0.9161 - loss: 0.0439
# Epoch 94: loss did not improve from 0.04389
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9792 - jaccard_coefficient: 0.9161 - loss: 0.0439 - learning_rate: 1.2500e-04
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9792 - jaccard_coefficient: 0.9147 - loss: 0.0447
# Epoch 95: loss did not improve from 0.04389
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9792 - jaccard_coefficient: 0.9146 - loss: 0.0447 - learning_rate: 1.2500e-04
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9784 - jaccard_coefficient: 0.9166 - loss: 0.0436
# Epoch 96: loss did not improve from 0.04389
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9783 - jaccard_coefficient: 0.9164 - loss: 0.0437 - learning_rate: 1.2500e-04
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9789 - jaccard_coefficient: 0.9188 - loss: 0.0424
# Epoch 97: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 97: loss improved from 0.04389 to 0.04388, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step - accuracy: 0.9789 - jaccard_coefficient: 0.9187 - loss: 0.0424 - learning_rate: 1.2500e-04
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9811 - jaccard_coefficient: 0.9250 - loss: 0.0390
# Epoch 98: loss improved from 0.04388 to 0.03988, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9811 - jaccard_coefficient: 0.9249 - loss: 0.0390 - learning_rate: 6.2500e-05
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9797 - jaccard_coefficient: 0.9205 - loss: 0.0414
# Epoch 99: loss did not improve from 0.03988
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.9798 - jaccard_coefficient: 0.9206 - loss: 0.0414 - learning_rate: 6.2500e-05
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9822 - jaccard_coefficient: 0.9307 - loss: 0.0359
# Epoch 100: loss improved from 0.03988 to 0.03780, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 36s 2s/step - accuracy: 0.9821 - jaccard_coefficient: 0.9306 - loss: 0.0360 - learning_rate: 6.2500e-05
# unet output shape: (None, 256, 256, 1)
# ⏱️ Thời gian huấn luyện: 3608.13 giây
# ✅ Accuracy trung bình: 94.41%
# 🔗 Jaccard trung bình: 79.78%

# %%
acc = history.history['accuracy']
loss = history.history['loss']
epochs_range = range(1, len(acc) + 1)


plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Accuracy', color='green')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Loss', color='red')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('Gray_2750_acc_loss.png', dpi=300)
plt.show()

# %%
def apply_morphology(mask, kernel_size=3, iterations=1):

    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))
    mask = (mask > 0.5).astype(np.uint8)  
    closed = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=iterations)

    opened = cv2.morphologyEx(closed, cv2.MORPH_OPEN, kernel, iterations=iterations)

    return opened.astype(np.float32)  

print("🔍 Đánh giá không hậu xử lý...")
results = unet.evaluate(test_images_gray_clahe, test_masks, verbose=1)
loss, accuracy, jaccard = results
print(f"Không hậu xử lý - Dice Loss: {loss:.4f}, Accuracy: {accuracy*100:.2f}%, Jaccard: {jaccard*100:.2f}%")

print("\n🔧 Đánh giá sau Morphology...")
predictions1 = unet.predict(test_images_gray_clahe)
refined_predictions1 = []

for i in tqdm(range(len(test_images_gray_clahe))):
    pred = predictions1[i].squeeze()

    morph_pred = apply_morphology(pred, kernel_size=7, iterations=2)

    refined_predictions1.append(morph_pred)


refined_predictions1 = np.expand_dims(np.array(refined_predictions1), axis=-1)
accuracy_after = np_accuracy(test_masks, refined_predictions1)
jaccard_after = np_jaccard_coefficient(test_masks, refined_predictions1)
loss_after = np_dice_loss(test_masks, refined_predictions1)

print(f"Sau Morphology - Dice Loss: {loss_after:.4f}, Accuracy: {accuracy_after*100:.2f}%, Jaccard: {jaccard_after*100:.2f}%")
# Out:
# 🔍 Đánh giá không hậu xử lý...
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 689ms/step - accuracy: 0.9203 - jaccard_coefficient: 0.7087 - loss: 0.1741
# Không hậu xử lý - Dice Loss: 0.1994, Accuracy: 91.58%, Jaccard: 67.61%
#
# 🔧 Đánh giá sau Morphology...
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 787ms/step
# 100%|██████████| 272/272 [00:00<00:00, 1593.82it/s]
# Sau Morphology - Dice Loss: 0.1844, Accuracy: 91.62%, Jaccard: 68.86%

# %%
unet.save('/kaggle/working/model/2.0-gray_2750_model.h5')
unet.save('/kaggle/working/model/2.0-gray_2750_model.keras')
