# %%
# !pip install git+https://github.com/lucasb-eyer/pydensecrf.git
# !pip install opencv-contrib-python
# !pip install tensorflow-addons

import os
import cv2
import time
import json
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from tqdm import tqdm

from sklearn.metrics import classification_report, precision_score, recall_score, f1_score

import pydensecrf.densecrf as dcrf
from pydensecrf.utils import unary_from_softmax, create_pairwise_bilateral

import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.activations import swish
from tensorflow.keras.regularizers import l2
from tensorflow.keras.initializers import HeNormal


from tensorflow.keras.layers import (
    Layer, 
    Input, 
    Conv2D, 
    BatchNormalization, 
    Lambda, 
    Concatenate,
    SeparableConv2D, 
    MaxPooling2D, 
    UpSampling2D, 
    Conv2DTranspose,
    SpatialDropout2D, 
    ReLU, 
    GlobalAveragePooling2D, 
    Add,
    GlobalMaxPooling2D, 
    Dense, 
    Reshape, 
    Multiply, 
    Activation
)
from tensorflow.keras import backend as K
# Out:
# Collecting git+https://github.com/lucasb-eyer/pydensecrf.git
#   Cloning https://github.com/lucasb-eyer/pydensecrf.git to /tmp/pip-req-build-59x99x7b
#   Running command git clone --filter=blob:none --quiet https://github.com/lucasb-eyer/pydensecrf.git /tmp/pip-req-build-59x99x7b
#   Resolved https://github.com/lucasb-eyer/pydensecrf.git to commit 2723c7fa4f2ead16ae1ce3d8afe977724bb8f87f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pydensecrf
#   Building wheel for pydensecrf (pyproject.toml) ... done
#   Created wheel for pydensecrf: filename=pydensecrf-1.0-cp311-cp311-linux_x86_64.whl size=3440337 sha256=c5fd53755acd122cf17d23976aab74717c9f7c0f870c71c0c68eb15c5c87f25b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g1joj2nu/wheels/ce/8e/34/6dcfa200a9e2ae3627d8009b8bd1ca9b24512bec50a93304de
# Successfully built pydensecrf
# Installing collected packages: pydensecrf
# Successfully installed pydensecrf-1.0
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-contrib-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.21.2->opencv-contrib-python) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.21.2->opencv-contrib-python) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-contrib-python) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.21.2->opencv-contrib-python) (2024.2.0)
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow-addons) (24.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Downloading tensorflow_addons-0.23.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 16.6 MB/s eta 0:00:0000:01
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Installing collected packages: typeguard, tensorflow-addons
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.1
#     Uninstalling typeguard-4.4.1:
#       Successfully uninstalled typeguard-4.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.16.1 requires typeguard<5,>=3, but you have typeguard 2.13.3 which is incompatible.
# inflect 7.5.0 requires typeguard>=4.0.1, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed tensorflow-addons-0.23.0 typeguard-2.13.3
# 2025-12-14 20:02:58.643875: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765742578.977353      33 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765742579.074154      33 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
working_dir = '/kaggle/working'
for item in os.listdir(working_dir):
    item_path = os.path.join(working_dir, item)
    try:
        if os.path.isfile(item_path) or os.path.islink(item_path):
            os.unlink(item_path) 
        elif os.path.isdir(item_path):
            shutil.rmtree(item_path)  
            print(f"❌ xóa thành công {item_path}")
    except Exception as e:
        print(f"Lỗi khi xóa {item_path}: {e}")
# Out:
# ❌ xóa thành công /kaggle/working/.virtual_documents

# %%
def load_isic_dataset(image_path, mask_path, binary_path, csv_file, img_size=(256, 256)):
    image_files = sorted(glob(os.path.join(image_path, "ISIC_*.jpg")))

    images = []
    masks = []
    binary_masks = {}
    image_ids = []
    labels = []

    csv_data = pd.read_csv(csv_file)
    mel_label = csv_data['melanoma'].astype("int64")

    print("Đang đọc và xử lý dữ liệu...")
    for index, img_path in enumerate(tqdm(image_files)):
        img_id = os.path.basename(img_path).split('.')[0]
        mask_file = os.path.join(mask_path, f"{img_id}_segmentation.png")
        binary_file = os.path.join(binary_path, f"{img_id}_features.json")

        if not os.path.exists(mask_file):
            print(f"Không tìm thấy mask cho ảnh mặt nạ {img_id}_segmentation.png")
            continue
        if not os.path.exists(binary_file):
            print(f"Không tìm thấy mask nhị phân cho ảnh {img_id}_features.json")
            continue

        try:
            img = cv2.imread(img_path)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 

            mask = cv2.imread(mask_file, cv2.IMREAD_GRAYSCALE)

            img = cv2.resize(img, img_size)
            mask = cv2.resize(mask, img_size)

            img = img / 255.0
            mask = mask / 255.0

            with open(binary_file, 'r') as f:
                binary_masks[img_id] = json.load(f)

            label = mel_label[index]

            images.append(img)
            masks.append(mask)
            image_ids.append(img_id)
            labels.append(label.astype("long"))

        except Exception as e:
            print(f"Lỗi khi xử lý ảnh {img_id}: {str(e)}")
            continue

    images = np.array(images)
    masks = np.array(masks)[..., np.newaxis]  
    labels = np.array(labels)

    print(f"\nĐã đọc thành công {len(images)} ảnh")
    print(f"Shape của images: {images.shape}")
    print(f"Shape của masks: {masks.shape}")
    print(f"Shape của labels: {labels.shape}")

    return images, masks, binary_masks, image_ids, labels

# %%
train_images, train_masks, train_binarys, train_image_ids, train_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2017-melanoma/Train_Data',
    mask_path='/kaggle/input/isic-2017-melanoma/Train_GroundTruth_1',
    binary_path='/kaggle/input/isic-2017-melanoma/Train_GroundTruth_2',
    csv_file="/kaggle/input/isic-2017-melanoma/Train_GroundTruth_3.csv",
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 635/635 [01:51<00:00,  5.72it/s]
# Đã đọc thành công 635 ảnh
# Shape của images: (635, 256, 256, 3)
# Shape của masks: (635, 256, 256, 1)
# Shape của labels: (635,)

# %%
test_images, test_masks, test_binarys, test_image_ids, test_labels = load_isic_dataset(
    image_path='/kaggle/input/isic-2017-melanoma/Test_Data',
    mask_path='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_1',
    binary_path='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_2',
    csv_file='/kaggle/input/isic-2017-melanoma/Test_GroundTruth_3.csv',
    img_size=(256, 256)
)
# Out:
# Đang đọc và xử lý dữ liệu...
# 100%|██████████| 272/272 [00:38<00:00,  7.02it/s]
# Đã đọc thành công 272 ảnh
# Shape của images: (272, 256, 256, 3)
# Shape của masks: (272, 256, 256, 1)
# Shape của labels: (272,)

# %%
def convert_to_gray_clahe(images_normalized):
    images_clahe = []
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))

    for img in images_normalized:       
        img_uint8 = np.uint8(img * 255)

        if len(img_uint8.shape) == 3:
            img_gray = cv2.cvtColor(img_uint8, cv2.COLOR_RGB2GRAY)
        else:
            img_gray = img_uint8  

        img_clahe_uint8 = clahe.apply(img_gray)

        img_clahe = img_clahe_uint8.astype(np.float32) / 255.0

        images_clahe.append(img_clahe)

    return np.array(images_clahe)

train_images_gray_clahe = convert_to_gray_clahe(train_images)
test_images_gray_clahe = convert_to_gray_clahe(test_images)

print(f"Shape ảnh huấn luyện sau CLAHE: {train_images_gray_clahe.shape}")
# Out:
# Shape ảnh huấn luyện sau CLAHE: (635, 256, 256)

# %%
def compute_metric(y_true, y_pred, metric='dice_coefficient', smooth=1e-6, is_numpy=False):
    y_true_f = y_true.flatten() if is_numpy else K.flatten(y_true)
    y_pred_f = y_pred.flatten() if is_numpy else K.flatten(y_pred)
    intersection = np.sum(y_true_f * y_pred_f) if is_numpy else K.sum(y_true_f * y_pred_f)

    if 'dice' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        score = (2. * intersection + smooth) / (sum_fn(y_true_f) + sum_fn(y_pred_f) + smooth)
    elif 'jaccard' in metric:
        sum_fn = np.sum if is_numpy else K.sum
        union = sum_fn(y_true_f) + sum_fn(y_pred_f) - intersection
        score = (intersection + smooth) / (union + smooth)
    else:
        raise ValueError(f"Unsupported metric: {metric}")

    return score if 'coefficient' in metric else 1 - score

def dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth)

def dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth)

def jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth)

def jaccard_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_loss', smooth)

def np_accuracy(y_true, y_pred):
    return np.mean(y_true.flatten() == y_pred.flatten())

def np_dice_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_coefficient', smooth, is_numpy=True)

def np_jaccard_coefficient(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'jaccard_coefficient', smooth, is_numpy=True)

def np_dice_loss(y_true, y_pred, smooth=1e-6):
    return compute_metric(y_true, y_pred, 'dice_loss', smooth, is_numpy=True)

# %%
def cbam_module(input_features, reduction_ratio=8):

    filters = input_features.shape[-1]
    
    avg_pool = GlobalAveragePooling2D()(input_features)
    max_pool = GlobalMaxPooling2D()(input_features)
    
    shared_dense_1 = Dense(filters // reduction_ratio, 
                           activation='relu', 
                           kernel_initializer='he_normal', 
                           use_bias=True)
    
    shared_dense_2 = Dense(filters, 
                           use_bias=True)
    
    avg_out = shared_dense_2(shared_dense_1(avg_pool))
    max_out = shared_dense_2(shared_dense_1(max_pool))
    
    channel_sum = Add()([avg_out, max_out])
    channel_attention = Activation('sigmoid')(channel_sum)
    channel_attention = Reshape((1, 1, filters))(channel_attention)
    channel_refined = Multiply()([input_features, channel_attention])
   
    avg_spatial = Lambda(lambda x: K.mean(x, axis=-1, keepdims=True), 
                         output_shape=lambda s: (s[0], s[1], s[2], 1))(channel_refined)
    max_spatial = Lambda(lambda x: K.max(x, axis=-1, keepdims=True), 
                         output_shape=lambda s: (s[0], s[1], s[2], 1))(channel_refined)
    

    spatial_concat = Concatenate(axis=-1)([avg_spatial, max_spatial])
    
    spatial_attention = Conv2D(1, 
                               (7, 7), 
                               padding='same', 
                               activation='sigmoid', 
                               use_bias=False)(spatial_concat)
    
    refined_features = Multiply()([channel_refined, spatial_attention])    
    
    return refined_features

# %%
def CustomSegUNet(input_size=(256, 256, 1)):
    inputs = Input(input_size)

    c1 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(inputs)
    c1 = BatchNormalization()(c1); c1 = ReLU()(c1)
    c1 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c1)
    c1 = BatchNormalization()(c1); c1 = ReLU()(c1)
    c1 = SpatialDropout2D(0.1)(c1)
    p1 = MaxPooling2D((2, 2))(c1)

    c2 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p1)
    c2 = BatchNormalization()(c2); c2 = ReLU()(c2)
    c2 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c2)
    c2 = BatchNormalization()(c2); c2 = ReLU()(c2)
    c2 = SpatialDropout2D(0.1)(c2)
    p2 = MaxPooling2D((2, 2))(c2)

    c3 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p2)
    c3 = BatchNormalization()(c3); c3 = ReLU()(c3)
    c3 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c3)
    c3 = BatchNormalization()(c3); c3 = ReLU()(c3)
    c3 = SpatialDropout2D(0.1)(c3)
    p3 = MaxPooling2D((2, 2))(c3)

    c4 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p3)
    c4 = BatchNormalization()(c4); c4 = ReLU()(c4)
    c4 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c4)
    c4 = BatchNormalization()(c4); c4 = ReLU()(c4)
    c4 = SpatialDropout2D(0.1)(c4)
    p4 = MaxPooling2D((2, 2))(c4)

    c5 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(p4)
    c5 = BatchNormalization()(c5); c5 = ReLU()(c5)
    c5 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c5)
    c5 = BatchNormalization()(c5); c5 = ReLU()(c5)
    c5 = SpatialDropout2D(0.1)(c5)
    p5 = MaxPooling2D((2, 2))(c5)

    c6 = SeparableConv2D(1024, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal(), dilation_rate=(2, 2))(p5)
    c6 = BatchNormalization()(c6)
    c6 = ReLU()(c6)
    c6 = SpatialDropout2D(0.2)(c6)

    u7 = Conv2DTranspose(512, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c6)
    u7 = Concatenate()([u7, c5])
    c7 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u7)
    c7 = BatchNormalization()(c7); c7 = ReLU()(c7)
    c7 = SeparableConv2D(512, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c7)
    c7 = BatchNormalization()(c7); c7 = ReLU()(c7)
    c7 = cbam_module(c7)

    u8 = Conv2DTranspose(256, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c7)
    u8 = Concatenate()([u8, c4])
    c8 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u8)
    c8 = BatchNormalization()(c8); c8 = ReLU()(c8)
    c8 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c8)
    c8 = BatchNormalization()(c8); c8 = ReLU()(c8)
    c8 = cbam_module(c8)

    u9 = Conv2DTranspose(256, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c8)
    u9 = Concatenate()([u9, c3])
    c9 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u9)
    c9 = BatchNormalization()(c9); c9 = ReLU()(c9)
    c9 = SeparableConv2D(256, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c9)
    c9 = BatchNormalization()(c9); c9 = ReLU()(c9)
    c9 = cbam_module(c9)

    u10 = Conv2DTranspose(128, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c9)
    u10 = Concatenate()([u10, c2])
    c10 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u10)
    c10 = BatchNormalization()(c10); c10 = ReLU()(c10)
    c10 = SeparableConv2D(128, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c10)
    c10 = BatchNormalization()(c10); c10 = ReLU()(c10)
    c10 = cbam_module(c10)

    u11 = Conv2DTranspose(64, (3, 3), strides=2, padding='same', kernel_initializer=HeNormal())(c10)
    u11 = Concatenate()([u11, c1])
    c11 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(u11)
    c11 = BatchNormalization()(c11); c11 = ReLU()(c11)
    c11 = SeparableConv2D(64, (3, 3), padding='same', depthwise_initializer=HeNormal(), pointwise_initializer=HeNormal())(c11)
    c11 = BatchNormalization()(c11); c11 = ReLU()(c11)
    c11 = cbam_module(c11)
 
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c11)

    return Model(inputs=inputs, outputs=outputs)

if __name__ == "__main__":
    model = CustomSegUNet()
    model.summary()
# Out:
# I0000 00:00:1765742746.701201      33 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 256, 256, 1)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d          │ (None, 256, 256, 64)   │            137 │ input_layer[0][0]      │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 64)   │            256 │ separable_conv2d[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu (ReLU)              │ (None, 256, 256, 64)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_1        │ (None, 256, 256, 64)   │          4,736 │ re_lu[0][0]            │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256, 256, 64)   │            256 │ separable_conv2d_1[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_1 (ReLU)            │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d         │ (None, 256, 256, 64)   │              0 │ re_lu_1[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ spatial_dropout2d[0][… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_2        │ (None, 128, 128, 128)  │          8,896 │ max_pooling2d[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 128, 128, 128)  │            512 │ separable_conv2d_2[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_2 (ReLU)            │ (None, 128, 128, 128)  │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_3        │ (None, 128, 128, 128)  │         17,664 │ re_lu_2[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 128, 128, 128)  │            512 │ separable_conv2d_3[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_3 (ReLU)            │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_1       │ (None, 128, 128, 128)  │              0 │ re_lu_3[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 128)    │              0 │ spatial_dropout2d_1[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_4        │ (None, 64, 64, 256)    │         34,176 │ max_pooling2d_1[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_4[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_4 (ReLU)            │ (None, 64, 64, 256)    │              0 │ batch_normalization_4… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_5        │ (None, 64, 64, 256)    │         68,096 │ re_lu_4[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_5[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_5 (ReLU)            │ (None, 64, 64, 256)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_2       │ (None, 64, 64, 256)    │              0 │ re_lu_5[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ spatial_dropout2d_2[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_6        │ (None, 32, 32, 256)    │         68,096 │ max_pooling2d_2[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_6[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_6 (ReLU)            │ (None, 32, 32, 256)    │              0 │ batch_normalization_6… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_7        │ (None, 32, 32, 256)    │         68,096 │ re_lu_6[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_7[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_7 (ReLU)            │ (None, 32, 32, 256)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_3       │ (None, 32, 32, 256)    │              0 │ re_lu_7[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 16, 16, 256)    │              0 │ spatial_dropout2d_3[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_8        │ (None, 16, 16, 512)    │        133,888 │ max_pooling2d_3[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_8[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_8 (ReLU)            │ (None, 16, 16, 512)    │              0 │ batch_normalization_8… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_9        │ (None, 16, 16, 512)    │        267,264 │ re_lu_8[0][0]          │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_9[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_9 (ReLU)            │ (None, 16, 16, 512)    │              0 │ batch_normalization_9… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_4       │ (None, 16, 16, 512)    │              0 │ re_lu_9[0][0]          │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 8, 8, 512)      │              0 │ spatial_dropout2d_4[0… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_10       │ (None, 8, 8, 1024)     │        529,920 │ max_pooling2d_4[0][0]  │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 8, 8, 1024)     │          4,096 │ separable_conv2d_10[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_10 (ReLU)           │ (None, 8, 8, 1024)     │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ spatial_dropout2d_5       │ (None, 8, 8, 1024)     │              0 │ re_lu_10[0][0]         │
# │ (SpatialDropout2D)        │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 16, 16, 512)    │      4,719,104 │ spatial_dropout2d_5[0… │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate (Concatenate) │ (None, 16, 16, 1024)   │              0 │ conv2d_transpose[0][0… │
# │                           │                        │                │ spatial_dropout2d_4[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_11       │ (None, 16, 16, 512)    │        534,016 │ concatenate[0][0]      │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_11[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_11 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_12       │ (None, 16, 16, 512)    │        267,264 │ re_lu_11[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 16, 16, 512)    │          2,048 │ separable_conv2d_12[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_12 (ReLU)           │ (None, 16, 16, 512)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d  │ (None, 512)            │              0 │ re_lu_12[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d      │ (None, 512)            │              0 │ re_lu_12[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 64)             │         32,832 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d[… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 512)            │         33,280 │ dense[0][0],           │
# │                           │                        │                │ dense[1][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 512)            │              0 │ dense_1[0][0],         │
# │                           │                        │                │ dense_1[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 512)            │              0 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape (Reshape)         │ (None, 1, 1, 512)      │              0 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply (Multiply)       │ (None, 16, 16, 512)    │              0 │ re_lu_12[0][0],        │
# │                           │                        │                │ reshape[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda (Lambda)           │ (None, 16, 16, 1)      │              0 │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_1 (Lambda)         │ (None, 16, 16, 1)      │              0 │ multiply[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_1             │ (None, 16, 16, 2)      │              0 │ lambda[0][0],          │
# │ (Concatenate)             │                        │                │ lambda_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 16, 16, 1)      │             98 │ concatenate_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_1 (Multiply)     │ (None, 16, 16, 512)    │              0 │ multiply[0][0],        │
# │                           │                        │                │ conv2d[0][0]           │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 32, 32, 256)    │      1,179,904 │ multiply_1[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_2             │ (None, 32, 32, 512)    │              0 │ conv2d_transpose_1[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_3[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_13       │ (None, 32, 32, 256)    │        135,936 │ concatenate_2[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_13[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_13 (ReLU)           │ (None, 32, 32, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_14       │ (None, 32, 32, 256)    │         68,096 │ re_lu_13[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 32, 32, 256)    │          1,024 │ separable_conv2d_14[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_14 (ReLU)           │ (None, 32, 32, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 256)            │              0 │ re_lu_14[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_1    │ (None, 256)            │              0 │ re_lu_14[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_2 (Dense)           │ (None, 32)             │          8,224 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_3 (Dense)           │ (None, 256)            │          8,448 │ dense_2[0][0],         │
# │                           │                        │                │ dense_2[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 256)            │              0 │ dense_3[0][0],         │
# │                           │                        │                │ dense_3[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 256)            │              0 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_1 (Reshape)       │ (None, 1, 1, 256)      │              0 │ activation_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_2 (Multiply)     │ (None, 32, 32, 256)    │              0 │ re_lu_14[0][0],        │
# │                           │                        │                │ reshape_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_2 (Lambda)         │ (None, 32, 32, 1)      │              0 │ multiply_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_3 (Lambda)         │ (None, 32, 32, 1)      │              0 │ multiply_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 32, 32, 2)      │              0 │ lambda_2[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 32, 32, 1)      │             98 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_3 (Multiply)     │ (None, 32, 32, 256)    │              0 │ multiply_2[0][0],      │
# │                           │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 64, 64, 256)    │        590,080 │ multiply_3[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 64, 64, 512)    │              0 │ conv2d_transpose_2[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_2[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_15       │ (None, 64, 64, 256)    │        135,936 │ concatenate_4[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_15    │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_15[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_15 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_16       │ (None, 64, 64, 256)    │         68,096 │ re_lu_15[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_16    │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_16[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_16 (ReLU)           │ (None, 64, 64, 256)    │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 256)            │              0 │ re_lu_16[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_2    │ (None, 256)            │              0 │ re_lu_16[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 32)             │          8,224 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 256)            │          8,448 │ dense_4[0][0],         │
# │                           │                        │                │ dense_4[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 256)            │              0 │ dense_5[0][0],         │
# │                           │                        │                │ dense_5[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 256)            │              0 │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_2 (Reshape)       │ (None, 1, 1, 256)      │              0 │ activation_2[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_4 (Multiply)     │ (None, 64, 64, 256)    │              0 │ re_lu_16[0][0],        │
# │                           │                        │                │ reshape_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_4 (Lambda)         │ (None, 64, 64, 1)      │              0 │ multiply_4[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_5 (Lambda)         │ (None, 64, 64, 1)      │              0 │ multiply_4[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_5             │ (None, 64, 64, 2)      │              0 │ lambda_4[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 64, 64, 1)      │             98 │ concatenate_5[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_5 (Multiply)     │ (None, 64, 64, 256)    │              0 │ multiply_4[0][0],      │
# │                           │                        │                │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 128, 128, 128)  │        295,040 │ multiply_5[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_6             │ (None, 128, 128, 256)  │              0 │ conv2d_transpose_3[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d_1[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_17       │ (None, 128, 128, 128)  │         35,200 │ concatenate_6[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_17    │ (None, 128, 128, 128)  │            512 │ separable_conv2d_17[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_17 (ReLU)           │ (None, 128, 128, 128)  │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_18       │ (None, 128, 128, 128)  │         17,664 │ re_lu_17[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_18    │ (None, 128, 128, 128)  │            512 │ separable_conv2d_18[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_18 (ReLU)           │ (None, 128, 128, 128)  │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 128)            │              0 │ re_lu_18[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_3    │ (None, 128)            │              0 │ re_lu_18[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 16)             │          2,064 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 128)            │          2,176 │ dense_6[0][0],         │
# │                           │                        │                │ dense_6[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 128)            │              0 │ dense_7[0][0],         │
# │                           │                        │                │ dense_7[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 128)            │              0 │ add_3[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_3 (Reshape)       │ (None, 1, 1, 128)      │              0 │ activation_3[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_6 (Multiply)     │ (None, 128, 128, 128)  │              0 │ re_lu_18[0][0],        │
# │                           │                        │                │ reshape_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_6 (Lambda)         │ (None, 128, 128, 1)    │              0 │ multiply_6[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_7 (Lambda)         │ (None, 128, 128, 1)    │              0 │ multiply_6[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_7             │ (None, 128, 128, 2)    │              0 │ lambda_6[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 128, 128, 1)    │             98 │ concatenate_7[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_7 (Multiply)     │ (None, 128, 128, 128)  │              0 │ multiply_6[0][0],      │
# │                           │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_4        │ (None, 256, 256, 64)   │         73,792 │ multiply_7[0][0]       │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_8             │ (None, 256, 256, 128)  │              0 │ conv2d_transpose_4[0]… │
# │ (Concatenate)             │                        │                │ spatial_dropout2d[0][… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_19       │ (None, 256, 256, 64)   │          9,408 │ concatenate_8[0][0]    │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_19    │ (None, 256, 256, 64)   │            256 │ separable_conv2d_19[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_19 (ReLU)           │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_20       │ (None, 256, 256, 64)   │          4,736 │ re_lu_19[0][0]         │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_20    │ (None, 256, 256, 64)   │            256 │ separable_conv2d_20[0… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ re_lu_20 (ReLU)           │ (None, 256, 256, 64)   │              0 │ batch_normalization_2… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 64)             │              0 │ re_lu_20[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_max_pooling2d_4    │ (None, 64)             │              0 │ re_lu_20[0][0]         │
# │ (GlobalMaxPooling2D)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_8 (Dense)           │ (None, 8)              │            520 │ global_average_poolin… │
# │                           │                        │                │ global_max_pooling2d_… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_9 (Dense)           │ (None, 64)             │            576 │ dense_8[0][0],         │
# │                           │                        │                │ dense_8[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 64)             │              0 │ dense_9[0][0],         │
# │                           │                        │                │ dense_9[1][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 64)             │              0 │ add_4[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ reshape_4 (Reshape)       │ (None, 1, 1, 64)       │              0 │ activation_4[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_8 (Multiply)     │ (None, 256, 256, 64)   │              0 │ re_lu_20[0][0],        │
# │                           │                        │                │ reshape_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_8 (Lambda)         │ (None, 256, 256, 1)    │              0 │ multiply_8[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ lambda_9 (Lambda)         │ (None, 256, 256, 1)    │              0 │ multiply_8[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_9             │ (None, 256, 256, 2)    │              0 │ lambda_8[0][0],        │
# │ (Concatenate)             │                        │                │ lambda_9[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 256, 256, 1)    │             98 │ concatenate_9[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ multiply_9 (Multiply)     │ (None, 256, 256, 64)   │              0 │ multiply_8[0][0],      │
# │                           │                        │                │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 256, 256, 1)    │             65 │ multiply_9[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 9,464,140 (36.10 MB)
#  Trainable params: 9,452,364 (36.06 MB)
#  Non-trainable params: 11,776 (46.00 KB)

# %%
class EarlyStoppingByAccuracyChange(tf.keras.callbacks.Callback):
    def __init__(self, monitor='accuracy', threshold=0.00001, patience=3, verbose=0):
        super(EarlyStoppingByAccuracyChange, self).__init__()
        self.monitor = monitor
        self.threshold = threshold
        self.patience = patience
        self.verbose = verbose
        self.wait = 0
        self.best_accuracy = -float('inf')
        self.consecutive_stops = 0

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        current_accuracy = logs.get(self.monitor)
        if current_accuracy is None:
            tf.get_logger().warning(
                'Early stopping requires %s available!', self.monitor
            )
            return

        if current_accuracy > self.best_accuracy:
            self.best_accuracy = current_accuracy
            self.wait = 0
            self.consecutive_stops = 0
        else:
            self.wait += 1
            accuracy_change = current_accuracy - self.best_accuracy
            if abs(accuracy_change) < self.threshold:
                self.consecutive_stops += 1
                if self.consecutive_stops >= self.patience:
                    if self.verbose > 0:
                        print(f"Epoch {epoch+1}: Early stopping triggered due to minimal accuracy change for {self.patience} epochs.")
                    self.model.stop_training = True
            else:
                self.consecutive_stops = 0

# %%
initial_lr = 0.001
optimizer = Adam(learning_rate=initial_lr)

segunet = CustomSegUNet(input_size=(256, 256, 1))
segunet.compile(
    optimizer=optimizer,
    loss=dice_loss,
    metrics=['accuracy', jaccard_coefficient]
)
model_checkpoint_dir = 'model'
checkpoint_path = os.path.join(model_checkpoint_dir, 'cp.ckpt')

checkpoint_callback = ModelCheckpoint(
    filepath=os.path.join(model_checkpoint_dir, 'gray2750.weights.h5'),
    save_weights_only=True,
    monitor='loss',
    mode='min',
    save_best_only=True,
    verbose=1
)
early_stopping = EarlyStoppingByAccuracyChange(
    monitor='accuracy',
    threshold=0.00001,
    patience=10,
    verbose=1
)
lr_reduction = ReduceLROnPlateau(monitor='loss',
                                  patience=5,
                                  verbose=1,
                                  factor=0.5,
                                  min_lr=0.00001)

start_time = time.time()
history = segunet.fit(
    train_images_gray_clahe, train_masks,
    batch_size=32,
    epochs=100,
    callbacks=[early_stopping, lr_reduction, checkpoint_callback]
)

end_time = time.time()
training_time = end_time - start_time

avg_accuracy = np.mean(history.history['accuracy'])
avg_jaccard = np.mean(history.history['jaccard_coefficient'])

print("SegUNet output shape:", segunet.output_shape)
print(f"⏱️ Thời gian huấn luyện: {training_time:.2f} giây")
print(f"✅ Accuracy trung bình: {avg_accuracy*100:.2f}%")
print(f"🔗 Jaccard trung bình: {avg_jaccard*100:.2f}%")
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765742779.373917     190 service.cc:148] XLA service 0x78d8700164f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1765742779.375217     190 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1765742782.193336     190 cuda_dnn.cc:529] Loaded cuDNN version 90300
# E0000 00:00:1765742802.821512     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742803.047761     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742804.404343     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742804.615015     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742805.184097     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742805.394797     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742806.334427     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742806.637933     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742809.209161     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742809.627174     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-14 20:06:49.778083: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,128,128]{3,2,1,0}, f32[32,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-14 20:06:49.883378: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.105418756s
# Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,256,128,128]{3,2,1,0}, f32[32,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# I0000 00:00:1765742826.786960     190 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 19/20 ━━━━━━━━━━━━━━━━━━━━ 0s 709ms/step - accuracy: 0.6128 - jaccard_coefficient: 0.2425 - loss: 0.6113
# E0000 00:00:1765742848.342656     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742848.583002     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742853.887144     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742854.127660     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742861.209793     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742861.430179     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742862.706922     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742862.915444     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742863.445882     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742863.656110     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742864.498496     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742864.789877     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742867.038358     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1765742867.431131     190 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-14 20:07:47.634603: E external/local_xla/xla/service/slow_operation_alarm.cc:65] Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,256,128,128]{3,2,1,0}, f32[27,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 2025-12-14 20:07:47.663521: E external/local_xla/xla/service/slow_operation_alarm.cc:133] The operation took 1.029006694s
# Trying algorithm eng18{k11=0} for conv (f32[256,1,3,3]{3,2,1,0}, u8[0]{0}) custom-call(f32[27,256,128,128]{3,2,1,0}, f32[27,256,128,128]{3,2,1,0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, feature_group_count=256, custom_call_target="__cudnn$convBackwardFilter", backend_config={"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"leakyrelu_alpha":0,"side_input_scale":0},"force_earliest_schedule":false,"operation_queue_id":"0","wait_on_operation_queues":[]} is taking a while...
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6148 - jaccard_coefficient: 0.2439 - loss: 0.6096
# Epoch 1: loss improved from inf to 0.57806, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 135s 3s/step - accuracy: 0.6167 - jaccard_coefficient: 0.2451 - loss: 0.6081 - learning_rate: 0.0010
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.7570 - jaccard_coefficient: 0.3833 - loss: 0.4467
# Epoch 2: loss improved from 0.57806 to 0.42990, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.7580 - jaccard_coefficient: 0.3841 - loss: 0.4459 - learning_rate: 0.0010
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.8470 - jaccard_coefficient: 0.4574 - loss: 0.3743
# Epoch 3: loss improved from 0.42990 to 0.34379, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.8471 - jaccard_coefficient: 0.4590 - loss: 0.3729 - learning_rate: 0.0010
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.8814 - jaccard_coefficient: 0.5365 - loss: 0.3036
# Epoch 4: loss improved from 0.34379 to 0.28240, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.8815 - jaccard_coefficient: 0.5378 - loss: 0.3026 - learning_rate: 0.0010
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.8988 - jaccard_coefficient: 0.6235 - loss: 0.2332
# Epoch 5: loss improved from 0.28240 to 0.23442, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.8988 - jaccard_coefficient: 0.6235 - loss: 0.2333 - learning_rate: 0.0010
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9058 - jaccard_coefficient: 0.6488 - loss: 0.2138
# Epoch 6: loss improved from 0.23442 to 0.20928, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 729ms/step - accuracy: 0.9059 - jaccard_coefficient: 0.6491 - loss: 0.2136 - learning_rate: 0.0010
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9126 - jaccard_coefficient: 0.6691 - loss: 0.1996
# Epoch 7: loss improved from 0.20928 to 0.19590, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9127 - jaccard_coefficient: 0.6693 - loss: 0.1994 - learning_rate: 0.0010
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9186 - jaccard_coefficient: 0.6987 - loss: 0.1780
# Epoch 8: loss improved from 0.19590 to 0.17764, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9186 - jaccard_coefficient: 0.6988 - loss: 0.1780 - learning_rate: 0.0010
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9054 - jaccard_coefficient: 0.6743 - loss: 0.1952
# Epoch 9: loss did not improve from 0.17764
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9059 - jaccard_coefficient: 0.6753 - loss: 0.1945 - learning_rate: 0.0010
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9275 - jaccard_coefficient: 0.7168 - loss: 0.1652
# Epoch 10: loss improved from 0.17764 to 0.15986, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9274 - jaccard_coefficient: 0.7172 - loss: 0.1649 - learning_rate: 0.0010
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9285 - jaccard_coefficient: 0.7355 - loss: 0.1529
# Epoch 11: loss improved from 0.15986 to 0.15300, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9286 - jaccard_coefficient: 0.7355 - loss: 0.1529 - learning_rate: 0.0010
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9380 - jaccard_coefficient: 0.7666 - loss: 0.1324
# Epoch 12: loss improved from 0.15300 to 0.13845, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9379 - jaccard_coefficient: 0.7661 - loss: 0.1327 - learning_rate: 0.0010
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9336 - jaccard_coefficient: 0.7622 - loss: 0.1354
# Epoch 13: loss improved from 0.13845 to 0.13486, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9337 - jaccard_coefficient: 0.7622 - loss: 0.1354 - learning_rate: 0.0010
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9381 - jaccard_coefficient: 0.7565 - loss: 0.1389
# Epoch 14: loss did not improve from 0.13486
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9380 - jaccard_coefficient: 0.7564 - loss: 0.1389 - learning_rate: 0.0010
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9335 - jaccard_coefficient: 0.7635 - loss: 0.1353
# Epoch 15: loss did not improve from 0.13486
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9335 - jaccard_coefficient: 0.7632 - loss: 0.1355 - learning_rate: 0.0010
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9323 - jaccard_coefficient: 0.7627 - loss: 0.1351
# Epoch 16: loss improved from 0.13486 to 0.13401, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9325 - jaccard_coefficient: 0.7628 - loss: 0.1351 - learning_rate: 0.0010
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9405 - jaccard_coefficient: 0.7660 - loss: 0.1330
# Epoch 17: loss improved from 0.13401 to 0.13352, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9404 - jaccard_coefficient: 0.7660 - loss: 0.1330 - learning_rate: 0.0010
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9470 - jaccard_coefficient: 0.7996 - loss: 0.1116
# Epoch 18: loss improved from 0.13352 to 0.11568, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9469 - jaccard_coefficient: 0.7993 - loss: 0.1118 - learning_rate: 0.0010
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9469 - jaccard_coefficient: 0.8021 - loss: 0.1101
# Epoch 19: loss improved from 0.11568 to 0.11115, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9469 - jaccard_coefficient: 0.8021 - loss: 0.1101 - learning_rate: 0.0010
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9529 - jaccard_coefficient: 0.8231 - loss: 0.0973
# Epoch 20: loss improved from 0.11115 to 0.09955, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9529 - jaccard_coefficient: 0.8229 - loss: 0.0974 - learning_rate: 0.0010
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9548 - jaccard_coefficient: 0.8220 - loss: 0.0981
# Epoch 21: loss did not improve from 0.09955
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9546 - jaccard_coefficient: 0.8214 - loss: 0.0985 - learning_rate: 0.0010
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9534 - jaccard_coefficient: 0.8196 - loss: 0.0994
# Epoch 22: loss did not improve from 0.09955
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9533 - jaccard_coefficient: 0.8194 - loss: 0.0995 - learning_rate: 0.0010
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9535 - jaccard_coefficient: 0.8115 - loss: 0.1042
# Epoch 23: loss did not improve from 0.09955
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9534 - jaccard_coefficient: 0.8116 - loss: 0.1041 - learning_rate: 0.0010
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9545 - jaccard_coefficient: 0.8206 - loss: 0.0990
# Epoch 24: loss improved from 0.09955 to 0.09778, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9545 - jaccard_coefficient: 0.8207 - loss: 0.0989 - learning_rate: 0.0010
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9577 - jaccard_coefficient: 0.8398 - loss: 0.0872
# Epoch 25: loss improved from 0.09778 to 0.09055, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9576 - jaccard_coefficient: 0.8396 - loss: 0.0874 - learning_rate: 0.0010
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9565 - jaccard_coefficient: 0.8328 - loss: 0.0914
# Epoch 26: loss improved from 0.09055 to 0.08813, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9565 - jaccard_coefficient: 0.8330 - loss: 0.0912 - learning_rate: 0.0010
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9643 - jaccard_coefficient: 0.8554 - loss: 0.0780
# Epoch 27: loss improved from 0.08813 to 0.07944, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9642 - jaccard_coefficient: 0.8553 - loss: 0.0781 - learning_rate: 0.0010
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9589 - jaccard_coefficient: 0.8401 - loss: 0.0871
# Epoch 28: loss did not improve from 0.07944
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9589 - jaccard_coefficient: 0.8401 - loss: 0.0871 - learning_rate: 0.0010
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9579 - jaccard_coefficient: 0.8422 - loss: 0.0858
# Epoch 29: loss did not improve from 0.07944
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 704ms/step - accuracy: 0.9580 - jaccard_coefficient: 0.8423 - loss: 0.0857 - learning_rate: 0.0010
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9602 - jaccard_coefficient: 0.8518 - loss: 0.0802
# Epoch 30: loss did not improve from 0.07944
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9602 - jaccard_coefficient: 0.8514 - loss: 0.0804 - learning_rate: 0.0010
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9626 - jaccard_coefficient: 0.8580 - loss: 0.0766
# Epoch 31: loss did not improve from 0.07944
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9625 - jaccard_coefficient: 0.8575 - loss: 0.0769 - learning_rate: 0.0010
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9652 - jaccard_coefficient: 0.8557 - loss: 0.0779
# Epoch 32: loss improved from 0.07944 to 0.07590, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9651 - jaccard_coefficient: 0.8558 - loss: 0.0778 - learning_rate: 0.0010
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9633 - jaccard_coefficient: 0.8588 - loss: 0.0763
# Epoch 33: loss did not improve from 0.07590
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 702ms/step - accuracy: 0.9632 - jaccard_coefficient: 0.8585 - loss: 0.0764 - learning_rate: 0.0010
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9621 - jaccard_coefficient: 0.8547 - loss: 0.0786
# Epoch 34: loss did not improve from 0.07590
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9620 - jaccard_coefficient: 0.8545 - loss: 0.0787 - learning_rate: 0.0010
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9632 - jaccard_coefficient: 0.8598 - loss: 0.0755
# Epoch 35: loss did not improve from 0.07590
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9632 - jaccard_coefficient: 0.8597 - loss: 0.0755 - learning_rate: 0.0010
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9657 - jaccard_coefficient: 0.8660 - loss: 0.0719
# Epoch 36: loss improved from 0.07590 to 0.07481, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9656 - jaccard_coefficient: 0.8657 - loss: 0.0720 - learning_rate: 0.0010
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9660 - jaccard_coefficient: 0.8657 - loss: 0.0721
# Epoch 37: loss improved from 0.07481 to 0.07147, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9660 - jaccard_coefficient: 0.8657 - loss: 0.0721 - learning_rate: 0.0010
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9644 - jaccard_coefficient: 0.8562 - loss: 0.0777
# Epoch 38: loss did not improve from 0.07147
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9644 - jaccard_coefficient: 0.8564 - loss: 0.0776 - learning_rate: 0.0010
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9658 - jaccard_coefficient: 0.8594 - loss: 0.0762
# Epoch 39: loss did not improve from 0.07147
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 702ms/step - accuracy: 0.9658 - jaccard_coefficient: 0.8596 - loss: 0.0761 - learning_rate: 0.0010
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9663 - jaccard_coefficient: 0.8712 - loss: 0.0691
# Epoch 40: loss improved from 0.07147 to 0.07059, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9663 - jaccard_coefficient: 0.8711 - loss: 0.0691 - learning_rate: 0.0010
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9687 - jaccard_coefficient: 0.8843 - loss: 0.0615
# Epoch 41: loss improved from 0.07059 to 0.06262, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9688 - jaccard_coefficient: 0.8842 - loss: 0.0615 - learning_rate: 0.0010
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9710 - jaccard_coefficient: 0.8891 - loss: 0.0588
# Epoch 42: loss improved from 0.06262 to 0.05911, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9710 - jaccard_coefficient: 0.8890 - loss: 0.0588 - learning_rate: 0.0010
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9729 - jaccard_coefficient: 0.8947 - loss: 0.0557
# Epoch 43: loss improved from 0.05911 to 0.05727, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9729 - jaccard_coefficient: 0.8946 - loss: 0.0558 - learning_rate: 0.0010
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9756 - jaccard_coefficient: 0.9043 - loss: 0.0502
# Epoch 44: loss improved from 0.05727 to 0.05100, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9755 - jaccard_coefficient: 0.9043 - loss: 0.0503 - learning_rate: 0.0010
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9747 - jaccard_coefficient: 0.8992 - loss: 0.0531
# Epoch 45: loss did not improve from 0.05100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9747 - jaccard_coefficient: 0.8992 - loss: 0.0531 - learning_rate: 0.0010
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9735 - jaccard_coefficient: 0.8950 - loss: 0.0555
# Epoch 46: loss did not improve from 0.05100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9735 - jaccard_coefficient: 0.8950 - loss: 0.0555 - learning_rate: 0.0010
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9743 - jaccard_coefficient: 0.8995 - loss: 0.0529
# Epoch 47: loss did not improve from 0.05100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9743 - jaccard_coefficient: 0.8996 - loss: 0.0529 - learning_rate: 0.0010
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9729 - jaccard_coefficient: 0.8958 - loss: 0.0551
# Epoch 48: loss did not improve from 0.05100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9730 - jaccard_coefficient: 0.8959 - loss: 0.0551 - learning_rate: 0.0010
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9749 - jaccard_coefficient: 0.8996 - loss: 0.0529
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 49: loss did not improve from 0.05100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9749 - jaccard_coefficient: 0.8996 - loss: 0.0529 - learning_rate: 0.0010
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9766 - jaccard_coefficient: 0.9076 - loss: 0.0485
# Epoch 50: loss improved from 0.05100 to 0.04948, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9766 - jaccard_coefficient: 0.9075 - loss: 0.0485 - learning_rate: 5.0000e-04
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9773 - jaccard_coefficient: 0.9075 - loss: 0.0486
# Epoch 51: loss improved from 0.04948 to 0.04780, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9773 - jaccard_coefficient: 0.9076 - loss: 0.0486 - learning_rate: 5.0000e-04
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9781 - jaccard_coefficient: 0.9159 - loss: 0.0439
# Epoch 52: loss improved from 0.04780 to 0.04435, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9781 - jaccard_coefficient: 0.9159 - loss: 0.0439 - learning_rate: 5.0000e-04
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9802 - jaccard_coefficient: 0.9221 - loss: 0.0405
# Epoch 53: loss improved from 0.04435 to 0.04003, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9802 - jaccard_coefficient: 0.9221 - loss: 0.0405 - learning_rate: 5.0000e-04
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9795 - jaccard_coefficient: 0.9201 - loss: 0.0417
# Epoch 54: loss did not improve from 0.04003
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9795 - jaccard_coefficient: 0.9201 - loss: 0.0417 - learning_rate: 5.0000e-04
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9793 - jaccard_coefficient: 0.9198 - loss: 0.0418
# Epoch 55: loss did not improve from 0.04003
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 702ms/step - accuracy: 0.9793 - jaccard_coefficient: 0.9198 - loss: 0.0418 - learning_rate: 5.0000e-04
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9796 - jaccard_coefficient: 0.9226 - loss: 0.0403
# Epoch 56: loss did not improve from 0.04003
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 702ms/step - accuracy: 0.9796 - jaccard_coefficient: 0.9225 - loss: 0.0403 - learning_rate: 5.0000e-04
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9809 - jaccard_coefficient: 0.9247 - loss: 0.0391
# Epoch 57: loss improved from 0.04003 to 0.03848, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9809 - jaccard_coefficient: 0.9247 - loss: 0.0391 - learning_rate: 5.0000e-04
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9808 - jaccard_coefficient: 0.9262 - loss: 0.0384
# Epoch 58: loss did not improve from 0.03848
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9808 - jaccard_coefficient: 0.9261 - loss: 0.0384 - learning_rate: 5.0000e-04
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9815 - jaccard_coefficient: 0.9254 - loss: 0.0388
# Epoch 59: loss did not improve from 0.03848
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9814 - jaccard_coefficient: 0.9254 - loss: 0.0388 - learning_rate: 5.0000e-04
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9809 - jaccard_coefficient: 0.9244 - loss: 0.0393
# Epoch 60: loss did not improve from 0.03848
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9809 - jaccard_coefficient: 0.9244 - loss: 0.0393 - learning_rate: 5.0000e-04
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9808 - jaccard_coefficient: 0.9248 - loss: 0.0391
# Epoch 61: loss improved from 0.03848 to 0.03832, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9809 - jaccard_coefficient: 0.9249 - loss: 0.0391 - learning_rate: 5.0000e-04
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9815 - jaccard_coefficient: 0.9247 - loss: 0.0392
# Epoch 62: loss did not improve from 0.03832
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9815 - jaccard_coefficient: 0.9248 - loss: 0.0391 - learning_rate: 5.0000e-04
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9821 - jaccard_coefficient: 0.9281 - loss: 0.0373
# Epoch 63: loss improved from 0.03832 to 0.03692, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9821 - jaccard_coefficient: 0.9282 - loss: 0.0373 - learning_rate: 5.0000e-04
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - accuracy: 0.9832 - jaccard_coefficient: 0.9340 - loss: 0.0342
# Epoch 64: loss improved from 0.03692 to 0.03526, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9832 - jaccard_coefficient: 0.9339 - loss: 0.0342 - learning_rate: 5.0000e-04
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9832 - jaccard_coefficient: 0.9316 - loss: 0.0354
# Epoch 65: loss improved from 0.03526 to 0.03492, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9832 - jaccard_coefficient: 0.9316 - loss: 0.0354 - learning_rate: 5.0000e-04
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9834 - jaccard_coefficient: 0.9351 - loss: 0.0336
# Epoch 66: loss improved from 0.03492 to 0.03366, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9834 - jaccard_coefficient: 0.9351 - loss: 0.0336 - learning_rate: 5.0000e-04
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9838 - jaccard_coefficient: 0.9335 - loss: 0.0344
# Epoch 67: loss did not improve from 0.03366
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9838 - jaccard_coefficient: 0.9335 - loss: 0.0344 - learning_rate: 5.0000e-04
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9835 - jaccard_coefficient: 0.9361 - loss: 0.0330
# Epoch 68: loss improved from 0.03366 to 0.03356, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9835 - jaccard_coefficient: 0.9361 - loss: 0.0330 - learning_rate: 5.0000e-04
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9847 - jaccard_coefficient: 0.9394 - loss: 0.0312
# Epoch 69: loss improved from 0.03356 to 0.03200, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 740ms/step - accuracy: 0.9846 - jaccard_coefficient: 0.9394 - loss: 0.0313 - learning_rate: 5.0000e-04
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9836 - jaccard_coefficient: 0.9368 - loss: 0.0326
# Epoch 70: loss did not improve from 0.03200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9836 - jaccard_coefficient: 0.9368 - loss: 0.0327 - learning_rate: 5.0000e-04
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9844 - jaccard_coefficient: 0.9384 - loss: 0.0318
# Epoch 71: loss did not improve from 0.03200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9844 - jaccard_coefficient: 0.9383 - loss: 0.0319 - learning_rate: 5.0000e-04
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9846 - jaccard_coefficient: 0.9396 - loss: 0.0312
# Epoch 72: loss improved from 0.03200 to 0.03188, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9845 - jaccard_coefficient: 0.9395 - loss: 0.0312 - learning_rate: 5.0000e-04
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9847 - jaccard_coefficient: 0.9387 - loss: 0.0316
# Epoch 73: loss improved from 0.03188 to 0.03141, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 733ms/step - accuracy: 0.9847 - jaccard_coefficient: 0.9388 - loss: 0.0316 - learning_rate: 5.0000e-04
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9855 - jaccard_coefficient: 0.9437 - loss: 0.0290
# Epoch 74: loss improved from 0.03141 to 0.03066, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9855 - jaccard_coefficient: 0.9435 - loss: 0.0291 - learning_rate: 5.0000e-04
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9857 - jaccard_coefficient: 0.9411 - loss: 0.0303
# Epoch 75: loss improved from 0.03066 to 0.02997, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 735ms/step - accuracy: 0.9857 - jaccard_coefficient: 0.9412 - loss: 0.0303 - learning_rate: 5.0000e-04
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9855 - jaccard_coefficient: 0.9439 - loss: 0.0289
# Epoch 76: loss improved from 0.02997 to 0.02988, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9855 - jaccard_coefficient: 0.9438 - loss: 0.0289 - learning_rate: 5.0000e-04
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9856 - jaccard_coefficient: 0.9465 - loss: 0.0275
# Epoch 77: loss improved from 0.02988 to 0.02946, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9856 - jaccard_coefficient: 0.9463 - loss: 0.0276 - learning_rate: 5.0000e-04
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9858 - jaccard_coefficient: 0.9443 - loss: 0.0286
# Epoch 78: loss did not improve from 0.02946
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9858 - jaccard_coefficient: 0.9443 - loss: 0.0287 - learning_rate: 5.0000e-04
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9856 - jaccard_coefficient: 0.9437 - loss: 0.0290
# Epoch 79: loss improved from 0.02946 to 0.02882, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9856 - jaccard_coefficient: 0.9437 - loss: 0.0290 - learning_rate: 5.0000e-04
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9854 - jaccard_coefficient: 0.9463 - loss: 0.0276
# Epoch 80: loss did not improve from 0.02882
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9855 - jaccard_coefficient: 0.9461 - loss: 0.0277 - learning_rate: 5.0000e-04
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9862 - jaccard_coefficient: 0.9456 - loss: 0.0280
# Epoch 81: loss improved from 0.02882 to 0.02813, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9862 - jaccard_coefficient: 0.9456 - loss: 0.0280 - learning_rate: 5.0000e-04
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9862 - jaccard_coefficient: 0.9466 - loss: 0.0275
# Epoch 82: loss improved from 0.02813 to 0.02771, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9863 - jaccard_coefficient: 0.9465 - loss: 0.0275 - learning_rate: 5.0000e-04
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9859 - jaccard_coefficient: 0.9429 - loss: 0.0294
# Epoch 83: loss did not improve from 0.02771
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9859 - jaccard_coefficient: 0.9429 - loss: 0.0294 - learning_rate: 5.0000e-04
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9859 - jaccard_coefficient: 0.9456 - loss: 0.0280
# Epoch 84: loss did not improve from 0.02771
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9859 - jaccard_coefficient: 0.9456 - loss: 0.0280 - learning_rate: 5.0000e-04
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9869 - jaccard_coefficient: 0.9488 - loss: 0.0263
# Epoch 85: loss improved from 0.02771 to 0.02731, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9869 - jaccard_coefficient: 0.9487 - loss: 0.0263 - learning_rate: 5.0000e-04
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9868 - jaccard_coefficient: 0.9495 - loss: 0.0259
# Epoch 86: loss improved from 0.02731 to 0.02636, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9868 - jaccard_coefficient: 0.9494 - loss: 0.0259 - learning_rate: 5.0000e-04
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9867 - jaccard_coefficient: 0.9468 - loss: 0.0273
# Epoch 87: loss did not improve from 0.02636
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 702ms/step - accuracy: 0.9867 - jaccard_coefficient: 0.9468 - loss: 0.0273 - learning_rate: 5.0000e-04
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9866 - jaccard_coefficient: 0.9490 - loss: 0.0262
# Epoch 88: loss improved from 0.02636 to 0.02617, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 732ms/step - accuracy: 0.9866 - jaccard_coefficient: 0.9490 - loss: 0.0262 - learning_rate: 5.0000e-04
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9871 - jaccard_coefficient: 0.9488 - loss: 0.0263
# Epoch 89: loss did not improve from 0.02617
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 702ms/step - accuracy: 0.9871 - jaccard_coefficient: 0.9488 - loss: 0.0263 - learning_rate: 5.0000e-04
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9872 - jaccard_coefficient: 0.9508 - loss: 0.0252
# Epoch 90: loss improved from 0.02617 to 0.02564, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9872 - jaccard_coefficient: 0.9508 - loss: 0.0252 - learning_rate: 5.0000e-04
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9873 - jaccard_coefficient: 0.9517 - loss: 0.0247
# Epoch 91: loss improved from 0.02564 to 0.02516, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9873 - jaccard_coefficient: 0.9517 - loss: 0.0247 - learning_rate: 5.0000e-04
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 701ms/step - accuracy: 0.9881 - jaccard_coefficient: 0.9527 - loss: 0.0242
# Epoch 92: loss improved from 0.02516 to 0.02451, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9880 - jaccard_coefficient: 0.9527 - loss: 0.0242 - learning_rate: 5.0000e-04
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9878 - jaccard_coefficient: 0.9514 - loss: 0.0249
# Epoch 93: loss did not improve from 0.02451
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9878 - jaccard_coefficient: 0.9514 - loss: 0.0249 - learning_rate: 5.0000e-04
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9884 - jaccard_coefficient: 0.9531 - loss: 0.0240
# Epoch 94: loss did not improve from 0.02451
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 702ms/step - accuracy: 0.9883 - jaccard_coefficient: 0.9530 - loss: 0.0241 - learning_rate: 5.0000e-04
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9880 - jaccard_coefficient: 0.9524 - loss: 0.0244
# Epoch 95: loss improved from 0.02451 to 0.02438, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9880 - jaccard_coefficient: 0.9524 - loss: 0.0244 - learning_rate: 5.0000e-04
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9874 - jaccard_coefficient: 0.9493 - loss: 0.0260
# Epoch 96: loss did not improve from 0.02438
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9874 - jaccard_coefficient: 0.9493 - loss: 0.0260 - learning_rate: 5.0000e-04
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9875 - jaccard_coefficient: 0.9530 - loss: 0.0241
# Epoch 97: loss did not improve from 0.02438
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9875 - jaccard_coefficient: 0.9530 - loss: 0.0241 - learning_rate: 5.0000e-04
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9877 - jaccard_coefficient: 0.9526 - loss: 0.0243
# Epoch 98: loss improved from 0.02438 to 0.02380, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 730ms/step - accuracy: 0.9877 - jaccard_coefficient: 0.9527 - loss: 0.0243 - learning_rate: 5.0000e-04
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 703ms/step - accuracy: 0.9881 - jaccard_coefficient: 0.9543 - loss: 0.0234
# Epoch 99: loss improved from 0.02380 to 0.02359, saving model to model/gray2750.weights.h5
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 15s 731ms/step - accuracy: 0.9882 - jaccard_coefficient: 0.9543 - loss: 0.0234 - learning_rate: 5.0000e-04
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 702ms/step - accuracy: 0.9883 - jaccard_coefficient: 0.9522 - loss: 0.0245
# Epoch 100: loss did not improve from 0.02359
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 14s 703ms/step - accuracy: 0.9883 - jaccard_coefficient: 0.9523 - loss: 0.0245 - learning_rate: 5.0000e-04
# SegUNet output shape: (None, 256, 256, 1)
# ⏱️ Thời gian huấn luyện: 1561.95 giây
# ✅ Accuracy trung bình: 96.19%
# 🔗 Jaccard trung bình: 86.31%

# %%
acc = history.history['accuracy']
loss = history.history['loss']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Accuracy', color='green')
plt.title('Training Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Loss', color='red')
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.savefig('Gray_2750_acc_loss.png', dpi=300)
plt.show()

# %%
def apply_morphology(mask, kernel_size=3, iterations=1):
    kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (kernel_size, kernel_size))
    mask = (mask > 0.5).astype(np.uint8)  

    closed = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel, iterations=iterations)

    opened = cv2.morphologyEx(closed, cv2.MORPH_OPEN, kernel, iterations=iterations)

    return opened.astype(np.float32)  

print("🔍 Đánh giá không hậu xử lý...")
results = segunet.evaluate(test_images_gray_clahe, test_masks, verbose=1)
loss, accuracy, jaccard = results
print(f"Không hậu xử lý - Dice Loss: {loss:.4f}, Accuracy: {accuracy*100:.2f}%, Jaccard: {jaccard*100:.2f}%")

print("\n🔧 Đánh giá sau Morphology...")
predictions1 = segunet.predict(test_images_gray_clahe)
refined_predictions1 = []

for i in tqdm(range(len(test_images_gray_clahe))):
    pred = predictions1[i].squeeze()
    morph_pred = apply_morphology(pred, kernel_size=7, iterations=2)

    refined_predictions1.append(morph_pred)

refined_predictions1 = np.expand_dims(np.array(refined_predictions1), axis=-1)

accuracy_after = np_accuracy(test_masks, refined_predictions1)
jaccard_after = np_jaccard_coefficient(test_masks, refined_predictions1)
loss_after = np_dice_loss(test_masks, refined_predictions1)

print(f"Sau Morphology - Dice Loss: {loss_after:.4f}, Accuracy: {accuracy_after*100:.2f}%, Jaccard: {jaccard_after*100:.2f}%")
# Out:
# 🔍 Đánh giá không hậu xử lý...
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 11s 804ms/step - accuracy: 0.9297 - jaccard_coefficient: 0.7327 - loss: 0.1584
# Không hậu xử lý - Dice Loss: 0.1872, Accuracy: 92.35%, Jaccard: 69.76%
#
# 🔧 Đánh giá sau Morphology...
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 599ms/step
# 100%|██████████| 272/272 [00:00<00:00, 1375.50it/s]
# Sau Morphology - Dice Loss: 0.1715, Accuracy: 92.37%, Jaccard: 70.72%

# %%
segunet.save('/kaggle/working/model/2.0-gray_2750_model.h5')
segunet.save('/kaggle/working/model/2.0-gray_2750_model.keras')
